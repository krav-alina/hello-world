# %%
with open ('Тургенев Иван. Том 6. Дворянское гнездо. Накануне. Первая любовь - royallib.ru.txt') as file1:
    tom6 = file1.read()

# %%
from sklearn.feature_extraction.text import CountVectorizer
import nltk
from collections import Counter
import re
import os

# %%
from nltk.corpus import stopwords
from nltk.tokenize import word_tokenize
import nltk
nltk.download('punkt')
# Out:
# [nltk_data] Downloading package punkt to
# [nltk_data]     C:\Users\sidor\AppData\Roaming\nltk_data...
# [nltk_data]   Package punkt is already up-to-date!
# True

# %%
import nltk
nltk.download('stopwords')
# Out:
# [nltk_data] Downloading package stopwords to
# [nltk_data]     C:\Users\sidor\AppData\Roaming\nltk_data...
# [nltk_data]   Package stopwords is already up-to-date!
# True

# %%
from pymystem3 import Mystem

# %%
mystem = Mystem()

# %%
def normalized_text (word):
    word = word.lower()
    word = re.sub("[!\"#$%&\'—()*+,-»«./:;<=>?@[\\]^_`{|}~]?",'',word)
    print(word)

# %%
normalized_text(tom6)
# Out:
# спасибо что скачали книгу в бесплатной электронной библиотеке
#
# все книги автора
#
# эта же книга в других форматах
#
# приятного чтения
#
#
#
#
# иван сергеевич тургенев
#
# собрание сочинений в двенадцати томах
#
# том  дворянское гнездо накануне первая любовь
#
#
#
# дворянское гнездо
#
#
#
#
#
# весенний светлый день клонился к вечеру небольшие розовые тучки стояли высоко в ясном небе и казалось не плыли мимо а уходили в самую глубь лазури
#
# перед раскрытым окном красивого дома в одной из крайних улиц губернского города о… дело происходило в  году сидели две женщины  одна лет пятидесяти другая уже старушка семидесяти лет
#
# ...

# %%
def len_text (word):
    word = word.lower()
    word = re.sub("[!\"#$%&\'—()*+,-»«./:;<=>?@[\\]^_`{|}~]?",'',word)
    word = word.split()
    output = len(word)
    return output

# %%
len_text(tom6)
# Out:
# 109051

# %%
def remove_stopwords(Word_list):
        processed_Word_list = []
        for Word in Word_list:
            if Word not in stopwords.words("russian"):
                processed_Word_list.append(Word)
        return processed_Word_list

# %%
#filtered_words = [Word for Word in tom6 if Word not in stopwords.words('russian')]
#text = 'здравствуй дорогой читатель сегодня очень ветренно поэтому я и он не пошли гулять хотя очень хотелось'
#text = ' '.join([word for word in text.split() if word not in (stopwords.words('russian'))])
tom6 = " ".join([word for word in tom6.split() if word not in(stopwords.words('russian'))])

# %%
bigram_vectorizer = CountVectorizer(ngram_range=(2,4),
                                    token_pattern=r'[А-Яа-я]+', min_df=1)

# %%
analyze = bigram_vectorizer.build_analyzer()

# %%
z = analyze(tom6)

# %%
Counter(z).most_common()
# Out:
# [('аркадий павлыч', 46),
#  ('продолжал он', 39),
#  ('из под', 39),
#  ('а что', 38),
#  ('николай еремеич', 36),
#  ('что то', 33),
#  ('г н', 32),
#  ('прибавил он', 32),
#  ('ко мне', 31),
#  ('татьяна борисовна', 28),
#  ('малек адель', 28),
#  ('спросил я', 27),
#  ('из за', 26),
#  ('какой то', 24),
#  ('пантелей еремеич', 24),
#  ('тех пор', 23),
#  ('петр петрович', 23),
#  ('малек аделя', 22),
#  ('как то', 21),
#  ('должно быть', 21),
#  ('по прежнему', 21),
#  ('ей богу', 21),
#  ('кое где', 18),
#  ('что это', 18),
#  ('как же', 17),
#  ('сих пор', 17),
#  ('что ж', 16),
#  ('крайней мере', 16),
#  ('кто то', 16),
#  ('дикий барин', 16),
#  ('я признаюсь', 15),
#  ('мардарий аполлоныч', 15),
#  ('подумал я', 14),
#  ('стало быть', 14),
#  ('николай иваныч', 14),
#  ('виктор александрыч', 14),
#  ('го го', 14),
#  ('друг друга', 13),
#  ('тому назад', 13),
#  ('спросил его', 13),
#  ('где нибудь', 13),
#  ('самом деле', 13),
#  ('вс это', 13),
# ...

# %%
def ngrams_text (word,num):
    word = word.lower()
    word = re.sub("[!\"#$%&\'—()*+,-»«./:;<=>?@[\\]^_`{|}~]?",'',word)
    #tokens = re.findall ('он\s\w+',word)
    #tokens = [token for token in word.split(" ") if token != ""]
    mystem.lemmatize(word)
    wordsFiltered = []
    for w in word:
        if w not in stopwords:
            wordsFiltered.append(w)
    
    output = list(ngrams(tokens,num))
    mostcommon = Counter(output).most_common()
    return mostcommon
#лемматизировать можно прямо из nltk，lemmatize, а стоп слова также есть в nltk.есть такая тетрадка. 
#чтобы свести все свои документы в один нужно просто конкатенировать все переменны. открывааем и читаем фал, сохраняем в переменную, складываем все переменные.
#append только для списка

# %%
def ngrams_text (word,num):
    word = word.lower()
    word = re.sub("[!\"#$%&\'—()*+,-»«./:;<=>?@[\\]^_`{|}~]?",'',word)
    #tokens = re.findall ('он\s\w+',word)
    #tokens = [token for token in word.split(" ") if token != ""]
    mystem.lemmatize(word)
    wordsFiltered = []
    for w in word:
        if w not in stopwords:
            wordsFiltered.append(w)
    
    output = list(ngrams(tokens,num))
    mostcommon = Counter(output).most_common()
    return mostcommon
#лемматизировать можно прямо из nltk，lemmatize, а стоп слова также есть в nltk.есть такая тетрадка. 
#чтобы свести все свои документы в один нужно просто конкатенировать все переменны. открывааем и читаем фал, сохраняем в переменную, складываем все переменные.
#append только для списка

# %%
def ngrams_text (word,num):
    word = word.lower()
    word = re.sub("[!\"#$%&\'—()*+,-»«./:;<=>?@[\\]^_`{|}~]?",'',word)
    #tokens = re.findall ('он\s\w+',word)
    #tokens = [token for token in word.split(" ") if token != ""]
    mystem.lemmatize(word)
    wordsFiltered = []
    for w in word:
        if w not in stopwords:
            wordsFiltered.append(w)
    
    output = list(ngrams(tokens,num))
    mostcommon = Counter(output).most_common()
    return mostcommon
#лемматизировать можно прямо из nltk，lemmatize, а стоп слова также есть в nltk.есть такая тетрадка. 
#чтобы свести все свои документы в один нужно просто конкатенировать все переменны. открывааем и читаем фал, сохраняем в переменную, складываем все переменные.
#append только для списка

# %%
ngrams_text("любовь",3)
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-22-120f9802b2fd> in <module>
# ----> 1 ngrams_text("любовь",3)
#
# <ipython-input-5-5e497a6001b9> in ngrams_text(word, num)
#       4     #tokens = re.findall ('он\s\w+',word)
#       5     #tokens = [token for token in word.split(" ") if token != ""]
# ----> 6     mystem.lemmatize(word)
#       7     wordsFiltered = []
#       8     for w in word:
#
# c:\users\sidor\appdata\local\programs\python\python37\lib\site-packages\pymystem3\mystem.py in lemmatize(self, text)
#     263         need_encode = (sys.version_info[0] < 3 and isinstance(text, str))
#     264
# --> 265         infos = self.analyze(text)
#     266         lemmas = list(filter(None, map(self._get_lemma, infos)))
#     267
#
# c:\users\sidor\appdata\local\programs\python\python37\lib\site-packages\pymystem3\mystem.py in analyze(self, text)
# ...

# %%
from nltk.util import ngrams

# %%
ngrams_text(tom6,3)
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-15-f6c145f82854> in <module>
# ----> 1 ngrams_text(tom6,3)
#
# <ipython-input-5-5e497a6001b9> in ngrams_text(word, num)
#       4     #tokens = re.findall ('он\s\w+',word)
#       5     #tokens = [token for token in word.split(" ") if token != ""]
# ----> 6     mystem.lemmatize(word)
#       7     wordsFiltered = []
#       8     for w in word:
#
# c:\users\sidor\appdata\local\programs\python\python37\lib\site-packages\pymystem3\mystem.py in lemmatize(self, text)
#     263         need_encode = (sys.version_info[0] < 3 and isinstance(text, str))
#     264
# --> 265         infos = self.analyze(text)
#     266         lemmas = list(filter(None, map(self._get_lemma, infos)))
#     267
#
# c:\users\sidor\appdata\local\programs\python\python37\lib\site-packages\pymystem3\mystem.py in analyze(self, text)
# ...
