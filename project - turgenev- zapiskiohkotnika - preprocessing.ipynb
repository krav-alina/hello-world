# %%
with open ('Тургенев Иван. Том 3. Записки охотника - royallib.ru.txt') as file1:
    tom3 = file1.read()

# %%
from sklearn.feature_extraction.text import CountVectorizer
import nltk
from collections import Counter
import re
import os

# %%
from nltk.corpus import stopwords
from nltk.tokenize import word_tokenize
import nltk
nltk.download('punkt')
# Out:
# [nltk_data] Downloading package punkt to
# [nltk_data]     C:\Users\sidor\AppData\Roaming\nltk_data...
# [nltk_data]   Package punkt is already up-to-date!
# True

# %%
import nltk
nltk.download('stopwords')
# Out:
# [nltk_data] Downloading package stopwords to
# [nltk_data]     C:\Users\sidor\AppData\Roaming\nltk_data...
# [nltk_data]   Package stopwords is already up-to-date!
# True

# %%
from pymystem3 import Mystem

# %%
mystem = Mystem()

# %%
def normalized_text (word):
    word = word.lower()
    word = re.sub("[!\"#$%&\'—()*+,-»«./:;<=>?@[\\]^_`{|}~]?",'',word)
    print(word)

# %%
normalized_text(tom3)
# Out:
# спасибо скачали книгу бесплатной электронной библиотеке   все книги автора  эта книга других форматах  приятного чтения иван сергеевич тургенев собрание сочинений двенадцати томах том  записки охотника записки охотника хорь калиныч кому случалось волховского уезда перебираться жиздринский того вероятно поражала резкая разница породой людей орловской губернии калужской породой орловский мужик невелик ростом сутуловат угрюм глядит исподлобья живет дрянных осиновых избенках ходит барщину торговлей занимается ест плохо носит лапти калужский оброчный мужик обитает просторных сосновых избах высок ростом глядит смело весело лицом чист бел торгует маслом дегтем праздникам ходит сапогах орловская деревня мы говорим восточной части орловской губернии обыкновенно расположена среди распаханных полей близ оврага коекак превращенного грязный пруд кроме немногих ракит готовых услугам двухтрех тощих берез деревца версту кругом увидишь изба лепится избе крыши закиданы гнилой соломой… калужская деревня напротив большею частью окружена лесом избы стоят вольней прямей крыты тесом ворота плотно запираются плетень задворке разметан вывалился наружу зовет гости всякую прохожую свинью… и охотника калужской губернии лучше в орловской губернии последние леса площадя  площадями называются орловской губернии большие сплошные массы кустов орловское наречие отличается вообще множеством своебытных весьма метких довольно безобразных слов оборотов исчезнут лет пять болот помине нет калужской напротив засеки тянутся сотни болота десятки верст перевелась благородная птица тетерев водится добродушный дупель хлопотунья куропатка своим порывистым взлетом веселит пугает стрелка собаку в качестве охотника посещая жиздринский уезд  сошелся поле познакомился одним калужским мелким помещиком полутыкиным страстным охотником и следовательно отличным человеком водились ним правда некоторые слабости он например сватался богатых невест губернии и получив отказ руки дому сокрушенным сердцем доверял свое горе всем друзьям знакомым родителям невест продолжал посылать подарок кислые персики другие сырые произведения своего сада любил повторять анекдот который несмотря уважение гна полутыкина достоинствам решительно никого смешил хвалил сочинения акима нахимова повесть пинну  заикался называл собаку астрономом вместо однако говорил одначе завел доме французскую кухню тайна которой понятиям повара состояла полном изменении естественного вкуса каждого кушанья мясо искусника отзывалось рыбой рыба  грибами макароны  порохом зато одна морковка попадала суп приняв вида ромба трапеции но исключением этих немногих незначительных недостатков гн полутыкин был сказано отличный человек в первый день моего знакомства г полутыкиным пригласил ночь себе  до верст пять будет  прибавил он  пешком идти далеко зайдемте сперва хорю читатель позволит передавать заиканья  а хорь  а мужик… он отсюда близехонько мы отправились нему посреди леса расчищенной разработанной поляне возвышалась одинокая усадьба хоря она состояла нескольких сосновых срубов соединенных заборами главной избой тянулся навес подпертый тоненькими столбиками мы вошли нас встретил молодой парень лет двадцати высокий красивый  а федя дома хорь  спросил гн полутыкин  нет хорь город уехал  отвечал парень улыбаясь показывая ряд белых снег зубов  тележку заложить прикажете  да брат тележку да принеси нам квасу мы вошли избу ни одна суздальская картина залепляла чистых бревенчатых стен углу тяжелым образом серебряном окладе теплилась лампадка липовый стол недавно выскоблен вымыт бревнами косякам окон скиталось резвых прусаков скрывалось задумчивых тараканов молодой парень скоро появился большой белой кружкой наполненной хорошим квасом огромным ломтем пшеничного хлеба дюжиной соленых огурцов деревянной миске он поставил припасы стол прислонился двери начал улыбкой поглядывать не успели доесть нашей закуски телега застучала крыльцом мы вышли мальчик лет пятнадцати кудрявый краснощекий сидел кучером трудом удерживал сытого пегого жеребца круг ...

# %%
def len_text (word):
    word = word.lower()
    word = re.sub("[!\"#$%&\'—()*+,-»«./:;<=>?@[\\]^_`{|}~]?",'',word)
    word = word.split()
    output = len(word)
    return output

# %%
len_text(tom3)
# Out:
# 102437

# %%
def remove_stopwords(Word_list):
        processed_Word_list = []
        for Word in Word_list:
            if Word not in stopwords.words("russian"):
                processed_Word_list.append(Word)
        return processed_Word_list

# %%
#filtered_words = [Word for Word in tom6 if Word not in stopwords.words('russian')]
#text = 'здравствуй дорогой читатель сегодня очень ветренно поэтому я и он не пошли гулять хотя очень хотелось'
#text = ' '.join([word for word in text.split() if word not in (stopwords.words('russian'))])
tom3 = " ".join([word for word in tom3.split() if word not in(stopwords.words('russian'))])

# %%
bigram_vectorizer = CountVectorizer(ngram_range=(2,4),
                                    token_pattern=r'[А-Яа-я]+', min_df=1)

# %%
analyze = bigram_vectorizer.build_analyzer()

# %%
z = analyze(tom3)

# %%
Counter(z).most_common()
# Out:
# [('аркадий павлыч', 46),
#  ('продолжал он', 39),
#  ('из под', 39),
#  ('а что', 38),
#  ('николай еремеич', 36),
#  ('что то', 33),
#  ('г н', 32),
#  ('прибавил он', 32),
#  ('ко мне', 31),
#  ('татьяна борисовна', 28),
#  ('малек адель', 28),
#  ('спросил я', 27),
#  ('из за', 26),
#  ('какой то', 24),
#  ('пантелей еремеич', 24),
#  ('тех пор', 23),
#  ('петр петрович', 23),
#  ('малек аделя', 22),
#  ('как то', 21),
#  ('должно быть', 21),
#  ('по прежнему', 21),
#  ('ей богу', 21),
#  ('кое где', 18),
#  ('что это', 18),
#  ('как же', 17),
#  ('сих пор', 17),
#  ('что ж', 16),
#  ('крайней мере', 16),
#  ('кто то', 16),
#  ('дикий барин', 16),
#  ('я признаюсь', 15),
#  ('мардарий аполлоныч', 15),
#  ('подумал я', 14),
#  ('стало быть', 14),
#  ('николай иваныч', 14),
#  ('виктор александрыч', 14),
#  ('го го', 14),
#  ('друг друга', 13),
#  ('тому назад', 13),
#  ('спросил его', 13),
#  ('где нибудь', 13),
#  ('самом деле', 13),
#  ('вс это', 13),
#  ('александра андреевна', 13),
#  ('боже мой', 13),
#  ('братцы мои', 13),
#  ('лет двадцати', 12),
#  ('на день', 12),
#  ('в течение', 12),
#  ('ч рт', 12),
#  ('ну ну', 12),
#  ('ну что', 12),
#  ('чуть чуть', 12),
#  ('молодой человек', 12),
#  ('кое как', 11),
#  ('заметил я', 11),
#  ('не знаю', 11),
#  ('что такое', 11),
#  ('бог знает', 11),
#  ('все таки', 11),
#  ('сквозь зубы', 11),
#  ('пантелея еремеича', 11),
#  ('васе благородие', 11),
#  ('го го го', 11),
#  ('меня я', 10),
#  ('ну ж', 10),
#  ('где то', 10),
#  ('мог заметить', 10),
#  ('вс равно', 10),
#  ('по видимому', 10),
#  ('вот с', 10),
#  ('и вс', 10),
#  ('во первых', 10),
#  ('во вторых', 10),
#  ('милостивый государь', 10),
#  ('как это', 10),
#  ('да это', 10),
#  ('татьяны борисовны', 10),
#  ('н полутыкин', 9),
#  ('а это', 9),
#  ('высокого роста', 9),
#  ('что дескать', 9),
#  ('поднял голову', 9),
#  ('небольшого молчания', 9),
#  ('я говорю', 9),
#  ('правда ли', 9),
#  ('делать нечего', 9),
#  ('начал я', 9),
#  ('да да', 9),
#  ('а впрочем', 9),
#  ('нашему брату', 9),
#  ('скажу вам', 9),
#  ('ах ты', 9),
#  ('как так', 9),
#  ('отцы наши', 9),
#  ('г беневоленский', 9),
#  ('тихон иваныч', 9),
#  ('г н полутыкин', 9),
#  ('двух трех', 8),
#  ('он обращаясь', 8),
#  ('человек лет', 8),
#  ('сколько мог', 8),
#  ('что ты', 8),
#  ('несколько мгновений', 8),
#  ('вс таки', 8),
#  ('одно прекрасное', 8),
#  ('я знал', 8),
#  ('хороший человек', 8),
#  ('каким образом', 8),
#  ('я подошел', 8),
#  ('слава богу', 8),
#  ('ну хорошо', 8),
#  ('опять таки', 8),
#  ('таком случае', 8),
#  ('по французски', 8),
#  ('вошел комнату', 8),
#  ('нет с', 8),
#  ('что мол', 8),
#  ('сохрани бог', 8),
#  ('ну да', 8),
#  ('это такое', 8),
#  ('взад вперед', 8),
#  ('самой середине', 8),
#  ('ах вы', 8),
#  ('ш потом', 8),
#  ('но но', 8),
#  ('го го го го', 8),
#  ('орловской губернии', 7),
#  ('лет сорока', 7),
#  ('проговорил он', 7),
#  ('милости просим', 7),
#  ('четверть часа', 7),
#  ('промолвил он', 7),
#  ('я человек', 7),
#  ('целый день', 7),
#  ('прекрасное утро', 7),
#  ('знаете ли', 7),
#  ('а знаю', 7),
#  ('правду сказать', 7),
#  ('куда то', 7),
#  ('какие то', 7),
#  ('обращаясь ко', 7),
#  ('царство небесное', 7),
#  ('э э', 7),
#  ('ну вот', 7),
#  ('мой сосед', 7),
#  ('федор михеич', 7),
#  ('я посмотрел', 7),
#  ('татьяна ильинична', 7),
#  ('александр владимирыч', 7),
#  ('вс едино', 7),
#  ('на нем', 7),
#  ('я я', 7),
#  ('какая то', 7),
#  ('обеими руками', 7),
#  ('заговорил он', 7),
#  ('да что', 7),
#  ('вы отцы', 7),
#  ('не правда', 7),
#  ('как зовут', 7),
#  ('обе руки', 7),
#  ('павел андреич', 7),
#  ('направо налево', 7),
#  ('чьи это', 7),
#  ('это куры', 7),
#  ('ардалион михайлыч', 7),
#  ('василий дмитрич', 7),
#  ('николая иваныча', 7),
#  ('одно прекрасное утро', 7),
#  ('ах вы отцы', 7),
#  ('не правда ли', 7),
#  ('чьи это куры', 7),
#  ('г на', 6),
#  ('мы вышли', 6),
#  ('большими шагами', 6),
#  ('открыл глаза', 6),
#  ('покачал головой', 6),
#  ('какой нибудь', 6),
#  ('лишь изредка', 6),
#  ('наш брат', 6),
#  ('есть есть', 6),
#  ('что вы', 6),
#  ('всяком случае', 6),
#  ('и вероятно', 6),
#  ('и и', 6),
#  ('с а', 6),
#  ('прости господи', 6),
#  ('а вс', 6),
#  ('изволите знать', 6),
#  ('изволите видеть', 6),
#  ('ну это', 6),
#  ('это вс', 6),
#  ('по русски', 6),
#  ('то вс', 6),
#  ('долго долго', 6),
#  ('ради бога', 6),
#  ('что да', 6),
#  ('всем телом', 6),
#  ('каким то', 6),
#  ('я а', 6),
#  ('я думал', 6),
#  ('другое утро', 6),
#  ('а то', 6),
#  ('нет это', 6),
#  ('малый лет', 6),
#  ('дать взять', 6),
#  ('я сел', 6),
#  ('вс время', 6),
#  ('с самого', 6),
#  ('я остановился', 6),
#  ('передо мною', 6),
#  ('я стал', 6),
#  ('вс кругом', 6),
#  ('спросил федя', 6),
#  ('давным давно', 6),
#  ('проговорил наконец', 6),
#  ('глаза я', 6),
#  ('господь знает', 6),
#  ('начал он', 6),
#  ('далеко далеко', 6),
#  ('кивнул головой', 6),
#  ('что делать', 6),
#  ('я мог', 6),
#  ('будешь делать', 6),
#  ('батюшка аркадий', 6),
#  ('н пеночкин', 6),
#  ('гаврила антоныч', 6),
#  ('лови лови', 6),
#  ('очень рад', 6),
#  ('капитон тимофеич', 6),
#  ('видите ли', 6),
#  ('ростислав адамыч', 6),
#  ('сколько мог заметить', 6),
#  ('обращаясь ко мне', 6),
#  ('батюшка аркадий павлыч', 6),
#  ('г н пеночкин', 6),
#  ('мы отправились', 5),
#  ('мы вошли', 5),
#  ('да так', 5),
#  ('раздался голос', 5),
#  ('мы поехали', 5),
#  ('каждый день', 5),
#  ('своего барина', 5),
#  ('ну полно', 5),
#  ('раза два', 5),
#  ('друг другом', 5),
#  ('отвечал он', 5),
#  ('продолжал старик', 5),
#  ('полно полно', 5),
#  ('принадлежал числу', 5),
#  ('когда то', 5),
#  ('таким образом', 5),
#  ('и самом', 5),
#  ('это это', 5),
#  ('однако же', 5),
#  ('прошлом году', 5),
#  ('чем нибудь', 5),
#  ('сказал я', 5),
#  ('большей частью', 5),
#  ('я поднял', 5),
#  ('подошел ко', 5),
#  ('чего тебе', 5),
#  ('спросил наконец', 5),
#  ('а вы', 5),
#  ('батюшка продолжал', 5),
#  ('своем веку', 5),
#  ('лет пятидесяти', 5),
#  ('а почем', 5),
#  ('возвратном пути', 5),
#  ('к счастью', 5),
#  ('кто это', 5),
#  ('а человек', 5),
#  ('таких случаях', 5),
#  ('своей стороны', 5),
#  ('ничего с', 5),
#  ('и словно', 5),
#  ('я начал', 5),
#  ('я да', 5),
#  ('не успел', 5),
#  ('я отвечал', 5),
#  ('закрыл глаза', 5),
#  ('думал я', 5),
#  ('мы пошли', 5),
#  ('что нибудь', 5),
#  ('ног головы', 5),
#  ('возразил я', 5),
#  ('лука петрович', 5),
#  ('ли спросил', 5),
#  ('господь ведает', 5),
#  ('да он', 5),
#  ('да вы', 5),
#  ('а а', 5),
#  ('хорошо хорошо', 5),
#  ('промолвил наконец', 5),
#  ('вс лицо', 5),
#  ('собственного достоинства', 5),
#  ('друг мой', 5),
#  ('ты ты', 5),
#  ('и казалось', 5),
#  ('пор вс', 5),
#  ('какую то', 5),
#  ('а вон', 5),
#  ('спросил костя', 5),
#  ('ты господи', 5),
#  ('может быть', 5),
#  ('он помолчав', 5),
#  ('махнул рукой', 5),
#  ('спросил он', 5),
#  ('воскликнул я', 5),
#  ('я хотел', 5),
#  ('барин барин', 5),
#  ('это так', 5),
#  ('в день', 5),
#  ('соседней комнате', 5),
#  ('никак нет', 5),
#  ('главный конторщик', 5),
#  ('вашей милости', 5),
#  ('лет тридцати', 5),
#  ('николай еремеев', 5),
#  ('но прежде', 5),
#  ('те те', 5),
#  ('анастасей иваныч', 5),
#  ('вот это', 5),
#  ('н беневоленский', 5),
#  ('дикого барина', 5),
#  ('о о', 5),
#  ('ай ай', 5),
#  ('вышел отставку', 5),
#  ('самого дня', 5),
#  ('еремей лукич', 5),
#  ('малек аделе', 5),
#  ('евгений александрыч', 5),
#  ('и самом деле', 5),
#  ('я поднял голову', 5),
#  ('спросил я а', 5),
#  ('ах ты господи', 5),
#  ('вы отцы наши', 5),
#  ('лови лови лови', 5),
#  ('г н беневоленский', 5),
#  ('ах вы отцы наши', 5),
#  ('он например', 4),
#  ('на полутыкина', 4),
#  ('мальчик лет', 4),
#  ('лет двадцать', 4),
#  ('двадцать пять', 4),
#  ('да тебе', 4),
#  ('вы батюшка', 4),
#  ('сами знаете', 4),
#  ('с тех', 4),
#  ('посудите сами', 4),
#  ('я согласился', 4),
#  ('свое достоинство', 4),
#  ('послушай ка', 4),
#  ('я нет', 4),
#  ('часа спустя', 4),
#  ('я бросился', 4),
#  ('он указывая', 4),
#  ('своего друга', 4),
#  ('ну говори', 4),
#  ('по своему', 4),
#  ('веселый час', 4),
#  ('а тебе', 4),
#  ('голову набок', 4),
#  ('я глядя', 4),
#  ('нанковом кафтане', 4),
#  ('и действительно', 4),
#  ('раз как', 4),
#  ('дворовый человек', 4),
#  ('выражение лица', 4),
#  ('верст десять', 4),
#  ('да знать', 4),
#  ('человек высокого', 4),
#  ('вид лет', 4),
#  ('барин то', 4),
#  ('я вышел', 4),
#  ('год пошел', 4),
#  ('я знаете', 4),
#  ('понюхал табаку', 4),
#  ('оно точно', 4),
#  ('моей жены', 4),
#  ('лет десять', 4),
#  ('я разумеется', 4),
#  ('ну знаете', 4),
#  ('а да', 4),
#  ('во всяком', 4),
#  ('небольшого молчанья', 4),
#  ('мы помолчали', 4),
#  ('утра вечера', 4),
#  ('две недели', 4),
#  ('то он', 4),
#  ('к нему', 4),
#  ('качнув головой', 4),
#  ('я оглянулся', 4),
#  ('он подошел', 4),
#  ('говорю я', 4),
#  ('вот видите', 4),
#  ('через полчаса', 4),
#  ('уездном городе', 4),
#  ('подали чай', 4),
#  ('дело то', 4),
#  ('поверите ли', 4),
#  ('я опять', 4),
#  ('всякий случай', 4),
#  ('это я', 4),
#  ('впрочем прибавил', 4),
#  ('так то', 4),
#  ('вс хуже', 4),
#  ('нашего брата', 4),
#  ('первых порах', 4),
#  ('человек то', 4),
#  ('лицо такое', 4),
#  ('могу сказать', 4),
#  ('прямо глаза', 4),
#  ('к чему', 4),
#  ('друг другу', 4),
#  ('взял руку', 4),
#  ('довольно много', 4),
#  ('нескольких шагах', 4),
#  ('я пошел', 4),
#  ('провел рукой', 4),
#  ('какое то', 4),
#  ('он говорил', 4),
#  ('вы думаете', 4),
#  ('отвечал я', 4),
#  ('я нашел', 4),
#  ('а скажите', 4),
#  ('да продолжал', 4),
#  ('так таки', 4),
#  ('я говорит', 4),
#  ('пять верст', 4),
#  ('василий николаич', 4),
#  ('пробормотал он', 4),
#  ('ну ступай', 4),
#  ('закричал вслед', 4),
#  ('леж нь', 4),
#  ('говорил он', 4),
#  ('потрепал плечу', 4),
#  ('одной рукой', 4),
#  ('возразил он', 4),
#  ('он это', 4),
#  ('правой руки', 4),
#  ('продолжал стоять', 4),
#  ('скажи пожалуйста', 4),
#  ('настоящее имя', 4),
#  ('то барин', 4),
#  ('а я', 4),
#  ('нельзя с', 4),
#  ('такие дни', 4),
#  ('я узнал', 4),
#  ('словно вс', 4),
#  ('подхватил ильюша', 4),
#  ('нет отвечал', 4),
#  ('посмотрите ка', 4),
#  ('кругом вс', 4),
#  ('еще бы', 4),
#  ('положил голову', 4),
#  ('целым часам', 4),
#  ('это спросил', 4),
#  ('мимо меня', 4),
#  ('каких нибудь', 4),
#  ('достал из', 4),
#  ('я тотчас', 4),
#  ('вс тело', 4),
#  ('прибавил небольшого', 4),
#  ('отвечал касьян', 4),
#  ('что тебе', 4),
#  ('так да', 4),
#  ('заговорил наконец', 4),
#  ('дворовые люди', 4),
#  ('нанковый кафтан', 4),
#  ('поднял брови', 4),
#  ('слушаю с', 4),
#  ('да помилуйте', 4),
#  ('выражением лица', 4),
#  ('что надобно', 4),
#  ('ну же', 4),
#  ('это однако', 4),
#  ('целый год', 4),
#  ('нет брат', 4),
#  ('руки карманы', 4),
#  ('свой вопрос', 4),
#  ('спросил меня', 4),
#  ('хорошо а', 4),
#  ('ко комнату', 4),
#  ('вот как', 4),
#  ('главный кассир', 4),
#  ('плисовым воротником', 4),
#  ('то что', 4),
#  ('посмотрел меня', 4),
#  ('сел лавку', 4),
#  ('протянул руку', 4),
#  ('фома кузьмич', 4),
#  ('или быть', 4),
#  ('мардария аполлоныча', 4),
#  ('как как', 4),
#  ('н чернобай', 4),
#  ('молодых людей', 4),
#  ('чем то', 4),
#  ('старая девица', 4),
#  ('сверх того', 4),
#  ('в таком', 4),
#  ('вдоль опушки', 4),
#  ('то далеко', 4),
#  ('то образом', 4),
#  ('кирила селифаныч', 4),
#  ('кружок это', 4),
#  ('шесть месяцев', 4),
#  ('чертопханов он', 4),
#  ('ва ва', 4),
#  ('пантелею еремеичу', 4),
#  ('несколько дней', 4),
#  ('дней спустя', 4),
#  ('пантелей чертопханов', 4),
#  ('ка сюда', 4),
#  ('повторил чертопханов', 4),
#  ('да зе', 4),
#  ('казачок перфишка', 4),
#  ('г на полутыкина', 4),
#  ('продолжал он обращаясь', 4),
#  ('с тех пор', 4),
#  ('раз как то', 4),
#  ('подошел ко мне', 4),
#  ('во всяком случае', 4),
#  ('он обращаясь ко', 4),
#  ('э э э', 4),
#  ('я опять таки', 4),
#  ('малый лет двадцати', 4),
#  ('тех пор вс', 4),
#  ('никак нет с', 4),
#  ('те те те', 4),
#  ('г н чернобай', 4),
#  ('в таком случае', 4),
#  ('ай ай ай', 4),
#  ('несколько дней спустя', 4),
#  ('но но но', 4),
#  ('он обращаясь ко мне', 4),
#  ('лови лови лови лови', 4),
#  ('лет пять', 3),
#  ('верст пять', 3),
#  ('спросил г', 3),
#  ('заметил он', 3),
#  ('кланялся пояс', 3),
#  ('ну теперь', 3),
#  ('господского дома', 3),
#  ('скажите пожалуйста', 3),
#  ('а отчего', 3),
#  ('пять тому', 3),
#  ('отправились охоту', 3),
#  ('разбудил меня', 3),
#  ('любопытством посмотрел', 3),
#  ('хорь говорил', 3),
#  ('посмотрел сбоку', 3),
#  ('продолжал вполголоса', 3),
#  ('сенном сарае', 3),
#  ('поднимаясь места', 3),
#  ('а ты', 3),
#  ('ног моих', 3),
#  ('доброй ночи', 3),
#  ('довольно долго', 3),
#  ('мог заснуть', 3),
#  ('я наконец', 3),
#  ('они оба', 3),
#  ('ну ты', 3),
#  ('тебе вс', 3),
#  ('этакой а', 3),
#  ('то то', 3),
#  ('вошел избу', 3),
#  ('знаю заслужил', 3),
#  ('мной я', 3),
#  ('говорил мало', 3),
#  ('нему навстречу', 3),
#  ('последнее время', 3),
#  ('время моего', 3),
#  ('моего рассказа', 3),
#  ('русского мужика', 3),
#  ('обращали внимания', 3),
#  ('другое время', 3),
#  ('посмотри ка', 3),
#  ('отсюда верст', 3),
#  ('да и', 3),
#  ('мы въехали', 3),
#  ('но быть', 3),
#  ('вс выше', 3),
#  ('выше выше', 3),
#  ('синем небе', 3),
#  ('легавая собака', 3),
#  ('ко всему', 3),
#  ('если б', 3),
#  ('ружья собаки', 3),
#  ('несколько времени', 3),
#  ('расположении духа', 3),
#  ('ночь дворе', 3),
#  ('нет уж', 3),
#  ('мне самому', 3),
#  ('верст кругом', 3),
#  ('березовую рощу', 3),
#  ('как нибудь', 3),
#  ('глаза большие', 3),
#  ('прямо лицо', 3),
#  ('твой муж', 3),
#  ('то кажется', 3),
#  ('промолвил ермолай', 3),
#  ('встал подошел', 3),
#  ('под навеса', 3),
#  ('голос из', 3),
#  ('а почему', 3),
#  ('посмотрел арину', 3),
#  ('н зверков', 3),
#  ('вы вс', 3),
#  ('того ну', 3),
#  ('ну есть', 3),
#  ('что думаете', 3),
#  ('своей особе', 3),
#  ('вообразите себе', 3),
#  ('ноги я', 3),
#  ('тебе батюшка', 3),
#  ('воля ваша', 3),
#  ('доложу вам', 3),
#  ('знал отвечать', 3),
#  ('спросил ермолая', 3),
#  ('дети есть', 3),
#  ('теперь а', 3),
#  ('это время', 3),
#  ('всем околотке', 3),
#  ('я добрался', 3),
#  ('в нескольких', 3),
#  ('что впрочем', 3),
#  ('бог ведает', 3),
#  ('него то', 3),
#  ('кого то', 3),
#  ('и точно', 3),
#  ('петра ильича', 3),
#  ('это человек', 3),
#  ('екатерининского времени', 3),
#  ('несколько нос', 3),
#  ('ваше сиятельство', 3),
#  ('свое дело', 3),
#  ('и сказать', 3),
#  ('спуская глаз', 3),
#  ('мы сидели', 3),
#  ('то было', 3),
#  ('увидал мужика', 3),
#  ('твой барин', 3),
#  ('ты говорит', 3),
#  ('назад и', 3),
#  ('я мол', 3),
#  ('барин спросил', 3),
#  ('пять рублев', 3),
#  ('причем однако', 3),
#  ('вы изволите', 3),
#  ('знаете ну', 3),
#  ('глаза вот', 3),
#  ('так есть', 3),
#  ('господа бога', 3),
#  ('вс ничего', 3),
#  ('извольте беспокоиться', 3),
#  ('рукой лицу', 3),
#  ('матушка ваша', 3),
#  ('я скажу', 3),
#  ('ах это', 3),
#  ('подумал подумал', 3),
#  ('а знаете', 3),
#  ('вс семейство', 3),
#  ('отец то', 3),
#  ('то человек', 3),
#  ('день день', 3),
#  ('право знаю', 3),
#  ('это того', 3),
#  ('прибавил лекарь', 3),
#  ('я кажется', 3),
#  ('вот оно', 3),
#  ('право слово', 3),
#  ('целым дням', 3),
#  ('что делаешь', 3),
#  ('а тем', 3),
#  ('должен сказать', 3),
#  ('что как', 3),
#  ('однажды ночью', 3),
#  ('господи боже', 3),
#  ('что вами', 3),
#  ('б знали', 3),
#  ('не могу', 3),
#  ('вас александра', 3),
#  ('теперь ну', 3),
#  ('нет нет', 3),
#  ('бог ними', 3),
#  ('вы быть', 3),
#  ('ума сошел', 3),
#  ('мое имя', 3),
#  ('да с', 3),
#  ('с да', 3),
#  ('говорит я', 3),
#  ('рубля полтиной', 3),
#  ('высокого росту', 3),
#  ('отправился вслед', 3),
#  ('вслед ним', 3),
#  ('я дал', 3),
#  ('очень приятно', 3),
#  ('вышел вон', 3),
#  ('меня а', 3),
#  ('она очень', 3),
#  ('карие глаза', 3),
#  ('всякого другого', 3),
#  ('течение разговора', 3),
#  ('после обеда', 3),
#  ('русской литературе', 3),
#  ('самое время', 3),
#  ('никак мог', 3),
#  ('очень мало', 3),
#  ('верите ли', 3),
#  ('посмотрел него', 3),
#  ('ну подумал', 3),
#  ('нем довольно', 3),
#  ('беговых дрожках', 3),
#  ('по немецки', 3),
#  ('черты лица', 3),
#  ('будет да', 3),
#  ('а бы', 3),
#  ('бы например', 3),
#  ('таки скажу', 3),
#  ('ведь вы', 3),
#  ('вы может', 3),
#  ('может знаете', 3),
#  ('так нам', 3),
#  ('двумя трубами', 3),
#  ('и говорит', 3),
#  ('вы кажется', 3),
#  ('продолжал овсяников', 3),
#  ('что а', 3),
#  ('ей ей', 3),
#  ('я это', 3),
#  ('это место', 3),
#  ('вот мол', 3),
#  ('что притча', 3),
#  ('наследство получил', 3),
#  ('а ну', 3),
#  ('этот то', 3),
#  ('поперек толще', 3),
#  ('вздохнул ну', 3),
#  ('поспешно проговорил', 3),
#  ('в комнате', 3),
#  ('я знаю', 3),
#  ('ну вели', 3),
#  ('заговорил старик', 3),
#  ('что самом', 3),
#  ('имеется ну', 3),
#  ('сами посудите', 3),
#  ('должен человек', 3),
#  ('под полы', 3),
#  ('эх ты', 3),
#  ('понизив голос', 3),
#  ('смотри меня', 3),
#  ('бог тобой', 3),
#  ('ступай богом', 3),
#  ('франц иваныч', 3),
#  ('любезный читатель', 3),
#  ('почетного звания', 3),
#  ('эй ты', 3),
#  ('спасите меня', 3),
#  ('сударь франц', 3),
#  ('крайнему изумлению', 3),
#  ('недели две', 3),
#  ('нам навстречу', 3),
#  ('среднего роста', 3),
#  ('охотник владимир', 3),
#  ('чувства собственного', 3),
#  ('дать знать', 3),
#  ('человек с', 3),
#  ('я сказал', 3),
#  ('пожалуйста начал', 3),
#  ('у кого', 3),
#  ('а вот', 3),
#  ('ну промолвил', 3),
#  ('нет батюшка', 3),
#  ('слава тебе', 3),
#  ('тебе господи', 3),
#  ('пошла потеха', 3),
#  ('вс ты', 3),
#  ('я как', 3),
#  ('и по', 3),
#  ('в такие', 3),
#  ('да я', 3),
#  ('воскликнул наконец', 3),
#  ('сторону я', 3),
#  ('это просто', 3),
#  ('и снова', 3),
#  ('всем своим', 3),
#  ('он принадлежал', 3),
#  ('мое любопытство', 3),
#  ('нет видал', 3),
#  ('федя а', 3),
#  ('ту пору', 3),
#  ('конца дней', 3),
#  ('да поди', 3),
#  ('поди ты', 3),
#  ('то а', 3),
#  ('отчего то', 3),
#  ('это последнее', 3),
#  ('отвечал павел', 3),
#  ('разрыв травы', 3),
#  ('кого нибудь', 3),
#  ('одном месте', 3),
#  ('стало видно', 3),
#  ('продолжал павел', 3),
#  ('поглядел кругом', 3),
#  ('помолчав немного', 3),
#  ('кверху свои', 3),
#  ('ты скажи', 3),
#  ('от самого', 3),
#  ('ее то', 3),
#  ('ведь это', 3),
#  ('сидел возле', 3),
#  ('моего слуха', 3),
#  ('обратился ко', 3),
#  ('третьего дня', 3),
#  ('полы кафтана', 3),
#  ('да ось', 3),
#  ('как угодно', 3),
#  ('мне я', 3),
#  ('я отправился', 3),
#  ('немного сторону', 3),
#  ('он поднял', 3),
#  ('вскочил ноги', 3),
#  ('ноги что', 3),
#  ('спросил опять', 3),
#  ('он указал', 3),
#  ('сделай одолжение', 3),
#  ('да нет', 3),
#  ('ли прибавил', 3),
#  ('то ему', 3),
#  ('мне а', 3),
#  ('можно можно', 3),
#  ('я глядел', 3),
#  ('он глядя', 3),
#  ('он вздохнул', 3),
#  ('он тотчас', 3),
#  ('добрые люди', 3),
#  ('ну конечно', 3),
#  ('дома то', 3),
#  ('возвысив голос', 3),
#  ('то сказал', 3),
#  ('его мы', 3),
#  ('его я', 3),
#  ('одного слова', 3),
#  ('есть ну', 3),
#  ('человек есть', 3),
#  ('весь рот', 3),
#  ('неча сказать', 3),
#  ('души чает', 3),
#  ('человек молодой', 3),
#  ('роста небольшого', 3),
#  ('аркадия павлыча', 3),
#  ('со всем', 3),
#  ('велел заложить', 3),
#  ('резким голосом', 3),
#  ('продолжал аркадий', 3),
#  ('с отвечал', 3),
#  ('деревенской жизни', 3),
#  ('это дело', 3),
#  ('своей участи', 3),
#  ('в сенях', 3),
#  ('наши милостивцы', 3),
#  ('что брат', 3),
#  ('пуще прежнего', 3),
#  ('ну и', 3),
#  ('следующий день', 3),
#  ('всем признакам', 3),
#  ('мало нет', 3),
#  ('он качнув', 3),
#  ('посиневшие губы', 3),
#  ('молодой мужик', 3),
#  ('софрон яковлич', 3),
#  ('знаю вас', 3),
#  ('а тебя', 3),
#  ('хорошо ступайте', 3),
#  ('проговорил сквозь', 3),
#  ('глаза словно', 3),
#  ('господи мое', 3),
#  ('самого утра', 3),
#  ('повторил свой', 3),
#  ('забирай вс', 3),
#  ('вс забирай', 3),
#  ('впалые щеки', 3),
#  ('перебил меня', 3),
#  ('есть как', 3),
#  ('соседней комнаты', 3),
#  ('глазами навыкате', 3),
#  ('здесь место', 3),
#  ('он вышел', 3),
#  ('вышел я', 3),
#  ('сама барыня', 3),
#  ('же с', 3),
#  ('хорошо вот', 3),
#  ('тэк с', 3),
#  ('наше дело', 3),
#  ('заговорил опять', 3),
#  ('а хорошо', 3),
#  ('снова принялся', 3),
#  ('в истопники', 3),
#  ('а будешь', 3),
#  ('константин наркизыч', 3),
#  ('а дело', 3),
#  ('нечего сказать', 3),
#  ('только я', 3),
#  ('да коли', 3),
#  ('фу ты', 3),
#  ('тебе говорю', 3),
#  ('закричал он', 3),
#  ('тебе говорят', 3),
#  ('верст восемь', 3),
#  ('шевелились лепетали', 3),
#  ('я назвал', 3),
#  ('назвал себя', 3),
#  ('девочка лет', 3),
#  ('лет двенадцати', 3),
#  ('посмотрел кругом', 3),
#  ('поднял глаза', 3),
#  ('проговорила она', 3),
#  ('снял шапку', 3),
#  ('каждом шагу', 3),
#  ('посреди двора', 3),
#  ('не хотите', 3),
#  ('ты ли', 3),
#  ('вячеслав илларионович', 3),
#  ('своего начальника', 3),
#  ('генерал хвалынский', 3),
#  ('а позвольте', 3),
#  ('я велел', 3),
#  ('то как', 3),
#  ('это вы', 3),
#  ('дай бог', 3),
#  ('чюки чюк', 3),
#  ('он шел', 3),
#  ('его что', 3),
#  ('барин такой', 3),
#  ('постоялых двориков', 3),
#  ('большой дороге', 3),
#  ('князь н', 3),
#  ('отставной поручик', 3),
#  ('карими глазами', 3),
#  ('лет восемь', 3),
#  ('восемь тому', 3),
#  ('т д', 3),
#  ('спросил князь', 3),
#  ('понимяем с', 3),
#  ('отчего же', 3),
#  ('я постучался', 3),
#  ('назар назар', 3),
#  ('у меня', 3),
#  ('татьяну борисовну', 3),
#  ('в одно', 3),
#  ('татьяне борисовне', 3),
#  ('умоляющим голосом', 3),
#  ('г те', 3),
#  ('большие светлые', 3),
#  ('такого то', 3),
#  ('а именно', 3),
#  ('ты боже', 3),
#  ('души то', 3),
#  ('возле окна', 3),
#  ('несколько слов', 3),
#  ('двадцатый год', 3),
#  ('ко луг', 3),
#  ('ко лбу', 3),
#  ('телега запряженная', 3),
#  ('жаль тебя', 3),
#  ('ну хочешь', 3),
#  ('и любила', 3),
#  ('вас милостивый', 3),
#  ('он знает', 3),
#  ('штатский генерал', 3),
#  ('на вид', 3),
#  ('проговорил дикий', 3),
#  ('вс продолжал', 3),
#  ('какую хочешь', 3),
#  ('перебирая пальцами', 3),
#  ('странное дело', 3),
#  ('он пел', 3),
#  ('ударив кулаком', 3),
#  ('богу хорошо', 3),
#  ('положил руку', 3),
#  ('однако ж', 3),
#  ('самым носом', 3),
#  ('ни одной', 3),
#  ('угодно я', 3),
#  ('петром петровичем', 3),
#  ('рт возьми', 3),
#  ('дело прошлое', 3),
#  ('хотите расскажу', 3),
#  ('любезный петр', 3),
#  ('он я', 3),
#  ('что угодно', 3),
#  ('матрена матрена', 3),
#  ('голову назад', 3),
#  ('ну однако', 3),
#  ('таким то', 3),
#  ('оно конечно', 3),
#  ('ну говорит', 3),
#  ('я сидел', 3),
#  ('подняла голову', 3),
#  ...]

# %%
def ngrams_text (word,num):
    word = word.lower()
    word = re.sub("[!\"#$%&\'—()*+,-»«./:;<=>?@[\\]^_`{|}~]?",'',word)
    #tokens = re.findall ('он\s\w+',word)
    #tokens = [token for token in word.split(" ") if token != ""]
    mystem.lemmatize(word)
    wordsFiltered = []
    for w in word:
        if w not in stopwords:
            wordsFiltered.append(w)
    
    output = list(ngrams(tokens,num))
    mostcommon = Counter(output).most_common()
    return mostcommon
#лемматизировать можно прямо из nltk，lemmatize, а стоп слова также есть в nltk.есть такая тетрадка. 
#чтобы свести все свои документы в один нужно просто конкатенировать все переменны. открывааем и читаем фал, сохраняем в переменную, складываем все переменные.
#append только для списка

# %%
def ngrams_text (word,num):
    word = word.lower()
    word = re.sub("[!\"#$%&\'—()*+,-»«./:;<=>?@[\\]^_`{|}~]?",'',word)
    #tokens = re.findall ('он\s\w+',word)
    #tokens = [token for token in word.split(" ") if token != ""]
    mystem.lemmatize(word)
    wordsFiltered = []
    for w in word:
        if w not in stopwords:
            wordsFiltered.append(w)
    
    output = list(ngrams(tokens,num))
    mostcommon = Counter(output).most_common()
    return mostcommon
#лемматизировать можно прямо из nltk，lemmatize, а стоп слова также есть в nltk.есть такая тетрадка. 
#чтобы свести все свои документы в один нужно просто конкатенировать все переменны. открывааем и читаем фал, сохраняем в переменную, складываем все переменные.
#append только для списка

# %%
def ngrams_text (word,num):
    word = word.lower()
    word = re.sub("[!\"#$%&\'—()*+,-»«./:;<=>?@[\\]^_`{|}~]?",'',word)
    #tokens = re.findall ('он\s\w+',word)
    #tokens = [token for token in word.split(" ") if token != ""]
    mystem.lemmatize(word)
    wordsFiltered = []
    for w in word:
        if w not in stopwords:
            wordsFiltered.append(w)
    
    output = list(ngrams(tokens,num))
    mostcommon = Counter(output).most_common()
    return mostcommon
#лемматизировать можно прямо из nltk，lemmatize, а стоп слова также есть в nltk.есть такая тетрадка. 
#чтобы свести все свои документы в один нужно просто конкатенировать все переменны. открывааем и читаем фал, сохраняем в переменную, складываем все переменные.
#append только для списка

# %%
ngrams_text("любовь",3)
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-22-120f9802b2fd> in <module>
# ----> 1 ngrams_text("любовь",3)
#
# <ipython-input-5-5e497a6001b9> in ngrams_text(word, num)
#       4     #tokens = re.findall ('он\s\w+',word)
#       5     #tokens = [token for token in word.split(" ") if token != ""]
# ----> 6     mystem.lemmatize(word)
#       7     wordsFiltered = []
#       8     for w in word:
#
# c:\users\sidor\appdata\local\programs\python\python37\lib\site-packages\pymystem3\mystem.py in lemmatize(self, text)
#     263         need_encode = (sys.version_info[0] < 3 and isinstance(text, str))
#     264
# --> 265         infos = self.analyze(text)
#     266         lemmas = list(filter(None, map(self._get_lemma, infos)))
#     267
#
# c:\users\sidor\appdata\local\programs\python\python37\lib\site-packages\pymystem3\mystem.py in analyze(self, text)
#     248         result = []
#     249         for line in text.splitlines():
# --> 250             result.extend(self._analyze_impl(line))
#     251         return result
#     252
#
# c:\users\sidor\appdata\local\programs\python\python37\lib\site-packages\pymystem3\mystem.py in _analyze_impl(self, text)
#     308                 self._start_mystem()
#     309
# --> 310             self._procin.write(text)
#     311             self._procin.write(_NL)
#     312
#
# ValueError: I/O operation on closed file

# %%
from nltk.util import ngrams

# %%
ngrams_text(tom6,3)
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-15-f6c145f82854> in <module>
# ----> 1 ngrams_text(tom6,3)
#
# <ipython-input-5-5e497a6001b9> in ngrams_text(word, num)
#       4     #tokens = re.findall ('он\s\w+',word)
#       5     #tokens = [token for token in word.split(" ") if token != ""]
# ----> 6     mystem.lemmatize(word)
#       7     wordsFiltered = []
#       8     for w in word:
#
# c:\users\sidor\appdata\local\programs\python\python37\lib\site-packages\pymystem3\mystem.py in lemmatize(self, text)
#     263         need_encode = (sys.version_info[0] < 3 and isinstance(text, str))
#     264
# --> 265         infos = self.analyze(text)
#     266         lemmas = list(filter(None, map(self._get_lemma, infos)))
#     267
#
# c:\users\sidor\appdata\local\programs\python\python37\lib\site-packages\pymystem3\mystem.py in analyze(self, text)
#     248         result = []
#     249         for line in text.splitlines():
# --> 250             result.extend(self._analyze_impl(line))
#     251         return result
#     252
#
# c:\users\sidor\appdata\local\programs\python\python37\lib\site-packages\pymystem3\mystem.py in _analyze_impl(self, text)
#     308                 self._start_mystem()
#     309
# --> 310             self._procin.write(text)
#     311             self._procin.write(_NL)
#     312
#
# ValueError: I/O operation on closed file
