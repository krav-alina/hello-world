# %%
with open ('Тургенев Иван. Том 5. Рудин. Повести и рассказы 1853-1857 - royallib.ru.txt') as file1:
    tom5 = file1.read()

# %%
from sklearn.feature_extraction.text import CountVectorizer
import nltk
from collections import Counter
import re
import os

# %%
from nltk.corpus import stopwords
from nltk.tokenize import word_tokenize
import nltk
nltk.download('punkt')
# Out:
# [nltk_data] Downloading package punkt to
# [nltk_data]     C:\Users\sidor\AppData\Roaming\nltk_data...
# [nltk_data]   Package punkt is already up-to-date!
# True

# %%
import nltk
nltk.download('stopwords')
# Out:
# [nltk_data] Downloading package stopwords to
# [nltk_data]     C:\Users\sidor\AppData\Roaming\nltk_data...
# [nltk_data]   Package stopwords is already up-to-date!
# True

# %%
from pymystem3 import Mystem

# %%
mystem = Mystem()

# %%
tom5 = tom5.lower()
tom5 = re.sub("[!\"#$%&\'—()*+,-»«./:;<=>?@[\\]^_`{|}~]?",'',tom5)
tom5 = " ".join([word for word in tom5.split() if word not in(stopwords.words('russian'))])

# %% [markdown]
# def len_text (word):
#     word = word.lower()
#     word = re.sub("[!\"#$%&\'—()*+,-»«./:;<=>?@[\\]^_`{|}~]?",'',word)
#     word = word.split()
#     output = len(word)
#     return output

# %% [markdown]
# def remove_stopwords(Word_list):
#         processed_Word_list = []
#         for Word in Word_list:
#             if Word not in stopwords.words("russian"):
#                 processed_Word_list.append(Word)
#         return processed_Word_list

# %% [markdown]
# #filtered_words = [Word for Word in tom6 if Word not in stopwords.words('russian')]
# #text = 'здравствуй дорогой читатель сегодня очень ветренно поэтому я и он не пошли гулять хотя очень хотелось'
# #text = ' '.join([word for word in text.split() if word not in (stopwords.words('russian'))])
# #tom5 = " ".join([word for word in tom5.split() if word not in(stopwords.words('russian'))])

# %%
bigram_vectorizer = CountVectorizer(ngram_range=(2,2),
                                    token_pattern=r'[А-Яа-я]+', min_df=1)

# %%
analyze = bigram_vectorizer.build_analyzer()

# %%
z = analyze(tom5)

# %%
Counter(z).most_common()
# Out:
# [('дарья михайловна', 115),
#  ('александра павловна', 97),
#  ('вс это', 45),
#  ('дарьи михайловны', 37),
#  ('сих пор', 32),
#  ('наталья алексеевна', 32),
#  ('софья николаевна', 28),
#  ('вера николаевна', 25),
#  ('тех пор', 24),
#  ('михайло михайлыч', 24),
#  ('глафира ивановна', 23),
#  ('это вс', 21),
#  ('марья александровна', 20),
#  ('крайней мере', 20),
#  ('тому назад', 19),
#  ('дмитрий николаич', 19),
#  ('передо мною', 16),
#  ('фрау луизе', 16),
#  ('дарье михайловне', 15),
#  ('африкан семеныч', 15),
#  ('друг друга', 14),
#  ('бог знает', 13),
#  ('ради бога', 13),
#  ('самом деле', 13),
#  ('ш потом', 13),
#  ('спросила александра', 13),
#  ('константин диомидыч', 12),
#  ('возразил рудин', 12),
#  ('это письмо', 11),
#  ('вс равно', 11),
#  ('помолчав немного', 11),
#  ('слава богу', 11),
#  ('молодой человек', 11),
#  ('сергей павлыч', 11),
#  ('василий васильевич', 10),
#  ('дай бог', 10),
#  ('поднял голову', 10),
#  ('возразил лежнев', 10),
#  ('алексей петрович', 9),
#  ('алексея петровича', 9),
#  ('марье александровне', 9),
#  ('это слово', 9),
#  ('яков иваныч', 9),
#  ('третьего дня', 9),
#  ('п б', 9),
#  ('ваша матушка', 9),
#  ('александре павловне', 9),
#  ('спросил рудин', 9),
#  ('марьи александровны', 8),
#  ('петровича марье', 8),
#  ('должен сознаться', 8),
#  ('друг другу', 8),
#  ('несколько мгновений', 8),
#  ('взад вперед', 8),
#  ('это значит', 8),
#  ('позвольте узнать', 8),
#  ('сельцо м', 8),
#  ('м ое', 8),
#  ('твой п', 8),
#  ('тому сельцо', 8),
#  ('начал рудин', 8),
#  ('никак нетс', 7),
#  ('александровны алексею', 7),
#  ('алексею петровичу', 7),
#  ('петровичу село', 7),
#  ('село но', 7),
#  ('ваше письмо', 7),
#  ('передо мной', 7),
#  ('это очень', 7),
#  ('всяком случае', 7),
#  ('это мгновение', 7),
#  ('взял руку', 7),
#  ('это мгновенье', 7),
#  ('б письмо', 7),
#  ('одно слово', 7),
#  ('поз мный', 7),
#  ('александру павловну', 7),
#  ('продолжал рудин', 7),
#  ('продолжал лежнев', 7),
#  ('желаю знать', 6),
#  ('точно такс', 6),
#  ('несколько лет', 6),
#  ('это время', 6),
#  ('весь свой', 6),
#  ('умный человек', 6),
#  ('эта девушка', 6),
#  ('последнее письмо', 6),
#  ('точки зрения', 6),
#  ('позвольте спросить', 6),
#  ('странное дело', 6),
#  ('чтото сказать', 6),
#  ('начал читать', 6),
#  ('высокого роста', 6),
#  ('закрыл глаза', 6),
#  ('обе руки', 6),
#  ('последнее время', 6),
#  ('г те', 6),
#  ('александры павловны', 6),
#  ('дарью михайловну', 6),
#  ('промолвил рудин', 6),
#  ('спросил лежнев', 6),
#  ('самой середине', 5),
#  ('свое время', 5),
#  ('руки груди', 5),
#  ('понизив голос', 5),
#  ('александровне санктпетербург', 5),
#  ('вс кончено', 5),
#  ('делать нечего', 5),
#  ('милостивый государь', 5),
#  ('человека который', 5),
#  ('одним словом', 5),
#  ('каждое слово', 5),
#  ('скажите пожалуйста', 5),
#  ('нашего брата', 5),
#  ('другое дело', 5),
#  ('тебе сказать', 5),
#  ('отчего это', 5),
#  ('эта мысль', 5),
#  ('вышла замуж', 5),
#  ('рукою лбу', 5),
#  ('сколько мог', 5),
#  ('мог заметить', 5),
#  ('небольшого роста', 5),
#  ('своего рода', 5),
#  ('каким это', 5),
#  ('это образом', 5),
#  ('никак мог', 5),
#  ('голова болит', 5),
#  ('вышел вон', 5),
#  ('вернулся комнату', 5),
#  ('софье николаевне', 5),
#  ('это знаю', 5),
#  ('моего отца', 5),
#  ('семен николаич', 5),
#  ('верой николаевной', 5),
#  ('веру николаевну', 5),
#  ('веры николаевны', 5),
#  ('вере николаевне', 5),
#  ('лет двадцать', 5),
#  ('другое утро', 5),
#  ('неужели это', 5),
#  ('ч рт', 5),
#  ('опустил глаза', 5),
#  ('следующий день', 5),
#  ('мог понять', 5),
#  ('должен сказать', 5),
#  ('хотел сказать', 5),
#  ('проговорила дарья', 5),
#  ('промолвила дарья', 5),
#  ('заметила дарья', 5),
#  ('наталье алексеевне', 5),
#  ('спросил волынцев', 5),
#  ('рудин посмотрел', 5),
#  ('проговорил лежнев', 5),
#  ('лежнев встал', 5),
#  ('глафиры ивановны', 4),
#  ('человек лет', 4),
#  ('лет тому', 4),
#  ('вс время', 4),
#  ('тебе скажу', 4),
#  ('пункту первому', 4),
#  ('это тебе', 4),
#  ('четвертого дня', 4),
#  ('это слишком', 4),
#  ('стакан воды', 4),
#  ('покачал головой', 4),
#  ('схватил руку', 4),
#  ('уехал границу', 4),
#  ('это сказать', 4),
#  ('большею частью', 4),
#  ('прошел мимо', 4),
#  ('свой век', 4),
#  ('нашей разлуки', 4),
#  ('буду говорить', 4),
#  ('нечего делать', 4),
#  ('наш брат', 4),
#  ('несколько шагов', 4),
#  ('наше время', 4),
#  ('мое последнее', 4),
#  ('сердце мое', 4),
#  ('мое сердце', 4),
#  ('это прекрасно', 4),
#  ('письмо это', 4),
#  ('своей комнате', 4),
#  ('это кажется', 4),
#  ('дня нашего', 4),
#  ('нашего знакомства', 4),
#  ('четыре часа', 4),
#  ('мог ожидать', 4),
#  ('никак ожидал', 4),
#  ('последние слова', 4),
#  ('будьте осторожны', 4),
#  ('сказала однажды', 4),
#  ('сквозь зубы', 4),
#  ('вперед комнате', 4),
#  ('вошел комнату', 4),
#  ('моей любви', 4),
#  ('лицо руками', 4),
#  ('своей матери', 4),
#  ('это правда', 4),
#  ('ой губернии', 4),
#  ('самого утра', 4),
#  ('скоро вернулся', 4),
#  ('девять лет', 4),
#  ('своем веку', 4),
#  ('марья петровна', 4),
#  ('любезный друг', 4),
#  ('прощай твой', 4),
#  ('очень мила', 4),
#  ('это это', 4),
#  ('очень рад', 4),
#  ('раздался голос', 4),
#  ('могу сказать', 4),
#  ('это ужасно', 4),
#  ('хотите сказать', 4),
#  ('подняла голову', 4),
#  ('взял шляпу', 4),
#  ('скажу тебе', 4),
#  ('воскликнул это', 4),
#  ('это вздор', 4),
#  ('версты две', 4),
#  ('темные глаза', 4),
#  ('это человек', 4),
#  ('правду сказать', 4),
#  ('своего брата', 4),
#  ('сказал гагин', 4),
#  ('мгновений спустя', 4),
#  ('стиснул руку', 4),
#  ('беговых дрожках', 4),
#  ('это такое', 4),
#  ('продолжала дарья', 4),
#  ('воскликнула дарья', 4),
#  ('которые сами', 4),
#  ('подхватил пигасов', 4),
#  ('дмитрий николаевич', 4),
#  ('общие рассуждения', 4),
#  ('свои силы', 4),
#  ('рудин взял', 4),
#  ('провел рукой', 4),
#  ('мось лежнев', 4),
#  ('начал лежнев', 4),
#  ('проговорил рудин', 4),
#  ('повторил рудин', 4),
#  ('рудин это', 4),
#  ('повторил лежнев', 4),
#  ('перебила александра', 4),
#  ('это рудин', 4),
#  ('воскликнула александра', 4),
#  ('алексеевна начал', 4),
#  ('воскликнул рудин', 4),
#  ('рудин встал', 4),
#  ('главный приказчик', 3),
#  ('несколько поодаль', 3),
#  ('прямо против', 3),
#  ('двух лет', 3),
#  ('кивнул головой', 3),
#  ('руки спину', 3),
#  ('быстро пробежал', 3),
#  ('воскликнула глафира', 3),
#  ('наступило молчание', 3),
#  ('принялся читать', 3),
#  ('го июня', 3),
#  ('разным местам', 3),
#  ('ах это', 3),
#  ('знаю почему', 3),
#  ('знать хочу', 3),
#  ('господском доме', 3),
#  ('овес сено', 3),
#  ('кончить это', 3),
#  ('махнул рукой', 3),
#  ('вошел гостиную', 3),
#  ('благодарна ваше', 3),
#  ('б алексея', 3),
#  ('можете представить', 3),
#  ('самим собою', 3),
#  ('хочу говорить', 3),
#  ('никакого права', 3),
#  ('слишком поздно', 3),
#  ('мои мысли', 3),
#  ('своем прошедшем', 3),
#  ('странный человек', 3),
#  ('очень жаль', 3),
#  ('пора кончить', 3),
#  ('но го', 3),
#  ('письмо алексей', 3),
#  ('те которые', 3),
#  ('тех которые', 3),
#  ('могу судить', 3),
#  ('опятьтаки скажу', 3),
#  ('большей частью', 3),
#  ('санктпетербург го', 3),
#  ('ко мне', 3),
#  ('б знали', 3),
#  ('хочется говорить', 3),
#  ('слов своих', 3),
#  ('это легко', 3),
#  ('четыре года', 3),
#  ('июня года', 3),
#  ('милая марья', 3),
#  ('пускай наш', 3),
#  ('лишь изредка', 3),
#  ('брат вс', 3),
#  ('ч рту', 3),
#  ('это доказывает', 3),
#  ('рано поздно', 3),
#  ('какое это', 3),
#  ('м б', 3),
#  ('го июля', 3),
#  ('мое мнение', 3),
#  ('ваш друг', 3),
#  ('это чтото', 3),
#  ('это кончится', 3),
#  ('двадцать года', 3),
#  ('свет божий', 3),
#  ('той самой', 3),
#  ('нем вс', 3),
#  ('дать взять', 3),
#  ('такое истина', 3),
#  ('белокурый господин', 3),
#  ('свой рассказ', 3),
#  ('осторожны попрежнему', 3),
#  ('вон комнаты', 3),
#  ('четверть часа', 3),
#  ('глазами навыкате', 3),
#  ('пришли память', 3),
#  ('мог заснуть', 3),
#  ('прибавила вполголоса', 3),
#  ('посмотрела лицо', 3),
#  ('существо эта', 3),
#  ('это говорите', 3),
#  ('никак ожидала', 3),
#  ('софьи николаевны', 3),
#  ('немного прибавила', 3),
#  ('очень тяжело', 3),
#  ('человек весьма', 3),
#  ('очень любили', 3),
#  ('пасынков очень', 3),
#  ('живо помню', 3),
#  ('это происходило', 3),
#  ('это место', 3),
#  ('поднял глаза', 3),
#  ('осталась та', 3),
#  ('каким знал', 3),
#  ('татьяны васильевны', 3),
#  ('таким выражением', 3),
#  ('погода чудесная', 3),
#  ('хочу сказать', 3),
#  ('хотела сказать', 3),
#  ('погодя немного', 3),
#  ('пасынков это', 3),
#  ('подошел окну', 3),
#  ('медленно проговорил', 3),
#  ('выражение лица', 3),
#  ('вс сказал', 3),
#  ('протянул руку', 3),
#  ('всем существе', 3),
#  ('это свидание', 3),
#  ('ах батюшка', 3),
#  ('якова иваныча', 3),
#  ('елисей вышел', 3),
#  ('вслед мной', 3),
#  ('господин доктор', 3),
#  ('губернский город', 3),
#  ('оно нужно', 3),
#  ('оба помолчали', 3),
#  ('это спросил', 3),
#  ('славная вещь', 3),
#  ('прибавил помолчав', 3),
#  ('осталась моей', 3),
#  ('наше дело', 3),
#  ('подошел нему', 3),
#  ('практическим человеком', 3),
#  ('будешь делать', 3),
#  ('черты лица', 3),
#  ('николаевна очень', 3),
#  ('лицо вс', 3),
#  ('опустила глаза', 3),
#  ('вс знаете', 3),
#  ('начал рассказывать', 3),
#  ('это беда', 3),
#  ('нынешнего дня', 3),
#  ('любил страстно', 3),
#  ('както странно', 3),
#  ('елисея тимофеича', 3),
#  ('жила матушкой', 3),
#  ('свои глаза', 3),
#  ('рукой волосам', 3),
#  ('своею матерью', 3),
#  ('наклонил голову', 3),
#  ('ое июня', 3),
#  ('лицо изменилось', 3),
#  ('очень люблю', 3),
#  ('манон леско', 3),
#  ('слова слова', 3),
#  ('чтото такое', 3),
#  ('быстрыми шагами', 3),
#  ('узнал тотчас', 3),
#  ('жена ваша', 3),
#  ('это последнее', 3),
#  ('самый день', 3),
#  ('самой смерти', 3),
#  ('глаза глядели', 3),
#  ('это невозможно', 3),
#  ('горе тому', 3),
#  ('тридцать пять', 3),
#  ('пять лет', 3),
#  ('вся бледная', 3),
#  ('мои годы', 3),
#  ('сказала это', 3),
#  ('сердце билось', 3),
#  ('продолжал приимков', 3),
#  ('разделся лег', 3),
#  ('понимаю почему', 3),
#  ('думал глядя', 3),
#  ('быть это', 3),
#  ('одно чувство', 3),
#  ('пришло голову', 3),
#  ('моей памяти', 3),
#  ('хотя сущности', 3),
#  ('можешь представить', 3),
#  ('свое дело', 3),
#  ('мной сделали', 3),
#  ('могу понять', 3),
#  ('протянул руки', 3),
#  ('клянусь тебе', 3),
#  ('вс мое', 3),
#  ('провел ночь', 3),
#  ('направился дому', 3),
#  ('пришел домой', 3),
#  ('га га', 3),
#  ('прошло часа', 3),
#  ('следующее утро', 3),
#  ('спросил кондрат', 3),
#  ('кондрат засмеялся', 3),
#  ('заметил вполголоса', 3),
#  ('изза угла', 3),
#  ('мный пожар', 3),
#  ('целый день', 3),
#  ('голову увидал', 3),
#  ('противоположном берегу', 3),
#  ('соломенной шляпе', 3),
#  ('первого взгляда', 3),
#  ('продолжал гагин', 3),
#  ('солнце село', 3),
#  ('это ася', 3),
#  ('прибавил обратясь', 3),
#  ('одно мгновенье', 3),
#  ('чему это', 3),
#  ('изредка останавливаясь', 3),
#  ('домой тотчас', 3),
#  ('прикажете делать', 3),
#  ('идти домой', 3),
#  ('каждый день', 3),
#  ('день прошел', 3),
#  ('подумав немного', 3),
#  ('приподняла голову', 3),
#  ('знаешь тебе', 3),
#  ('полчаса спустя', 3),
#  ('кроме никого', 3),
#  ('выйти отставку', 3),
#  ('руку крепко', 3),
#  ('ваш брат', 3),
#  ('ш пот', 3),
#  ('вчерашнего дня', 3),
#  ('это точно', 3),
#  ('перебил гагин', 3),
#  ('гн н', 3),
#  ('принужденной улыбкой', 3),
#  ('благородный человек', 3),
#  ('посудите сами', 3),
#  ('час тому', 3),
#  ('анна николаевна', 3),
#  ('вс знает', 3),
#  ('вашему брату', 3),
#  ('честным человеком', 3),
#  ('вс свете', 3),
#  ('другое время', 3),
#  ('шесть часов', 3),
#  ('моей жизни', 3),
#  ('павловна вс', 3),
#  ('проговорила александра', 3),
#  ('константину диомидычу', 3),
#  ('михайловны ласунской', 3),
#  ('михайлыч лежнев', 3),
#  ('возразил волынцев', 3),
#  ('господин пигасов', 3),
#  ('звук голоса', 3),
#  ('браво браво', 3),
#  ('михайловна знаете', 3),
#  ('голосом пигасов', 3),
#  ('это знать', 3),
#  ('елена антоновна', 3),
#  ('эгоисты которые', 3),
#  ('сами живут', 3),
#  ('возразила дарья', 3),
#  ('михайловна слегка', 3),
#  ('знаете это', 3),
#  ('лакей вошел', 3),
#  ('спросил пигасов', 3),
#  ('продолжал пигасов', 3),
#  ('отвечала наталья', 3),
#  ('проговорила наталья', 3),
#  ('михайловна пигасов', 3),
#  ('заметил рудин', 3),
#  ('вс слова', 3),
#  ('франц дарья', 3),
#  ('рудин говорил', 3),
#  ('дарьей михайловной', 3),
#  ('покорно благодарю', 3),
#  ('возразил пигасов', 3),
#  ('рудин подошел', 3),
#  ('рудин наклонил', 3),
#  ('спросила дарья', 3),
#  ('рудин начал', 3),
#  ('рудин остановился', 3),
#  ('посмотрела рудина', 3),
#  ('лежнев михайло', 3),
#  ('рудин помолчал', 3),
#  ('человек высокого', 3),
#  ('хотел чтото', 3),
#  ('это другое', 3),
#  ('любви это', 3),
#  ('наталья взглянула', 3),
#  ('целое утро', 3),
#  ('посмотрел лицо', 3),
#  ('лежнев это', 3),
#  ('прошелся комнате', 3),
#  ('начала александра', 3),
#  ('возразила наталья', 3),
#  ('наталья опустила', 3),
#  ('г басистов', 3),
#  ('долго сидела', 3),
#  ('очень сведущ', 3),
#  ('чужой счет', 3),
#  ('ком говорите', 3),
#  ('наталья ребенок', 3),
#  ('говорить нем', 3),
#  ('перебил лежнев', 3),
#  ('перебила наталья', 3),
#  ('повторила наталья', 3),
#  ('пришла сюда', 3),
#  ('рудин наталья', 3),
#  ('волынцев встал', 3),
#  ('начал ходить', 3),
#  ('лежнев рудин', 3),
#  ('михайловна очень', 3),
#  ('письмо рудина', 3),
#  ('михаила михайлыча', 3),
#  ('пигасов засмеялся', 3),
#  ('пью здоровье', 3),
#  ('наши дороги', 3),
#  ('дороги разошлись', 3),
#  ('повести рассказы', 2),
#  ('собственной господской', 2),
#  ('вотчинной конторы', 2),
#  ('конного двора', 2),
#  ('каждое утро', 2),
#  ('собственную контору', 2),
#  ('управляющий василий', 2),
#  ('утра вечера', 2),
#  ('стол покрытый', 2),
#  ('василия васильевича', 2),
#  ('свое имение', 2),
#  ('неподвижно глядел', 2),
#  ('скрестив руки', 2),
#  ('бурмистр павел', 2),
#  ('большим белым', 2),
#  ('белым лбом', 2),
#  ('блестящими глазами', 2),
#  ('левон взял', 2),
#  ('начал тонким', 2),
#  ('июля года', 2),
#  ('полевые прочие', 2),
#  ('прочие работы', 2),
#  ('сегодня левон', 2),
#  ('который вс', 2),
#  ('лист бумаги', 2),
#  ('тонким голоском', 2),
#  ('пункт й', 2),
#  ('прекрасно воскликнула', 2),
#  ('нечего сказать', 2),
#  ('сказать это', 2),
#  ('это должно', 2),
#  ('обратившись кинтилиану', 2),
#  ('комнате вс', 2),
#  ('заметки барыни', 2),
#  ('спросила барыня', 2),
#  ('фи фи', 2),
#  ('приведу порядок', 2),
#  ('снова принялся', 2),
#  ('спросить каждого', 2),
#  ('каждого дворового', 2),
#  ('трепетным голосом', 2),
#  ('прибавила глафира', 2),
#  ('сколько выходит', 2),
#  ('мое приказание', 2),
#  ('человек которого', 2),
#  ('изволили приказать', 2),
#  ('сама сама', 2),
#  ('сама вс', 2),
#  ('чему говорить', 2),
#  ('ивановна снова', 2),
#  ('изредка подергивая', 2),
#  ('опекунский совет', 2),
#  ('возразил старик', 2),
#  ('должно знать', 2),
#  ('василью васильевичу', 2),
#  ('василья васильевича', 2),
#  ('собственной моей', 2),
#  ('бумаге вс', 2),
#  ('определить содержание', 2),
#  ('повторил секретарь', 2),
#  ('нужно кинтилиан', 2),
#  ('достала кармана', 2),
#  ('записную книжечку', 2),
#  ('никита голанец', 2),
#  ('это ужас', 2),
#  ('должен знать', 2),
#  ('спросить почему', 2),
#  ('знать почему', 2),
#  ('васильевич это', 2),
#  ('сию минуту', 2),
#  ('ступайте вон', 2),
#  ('снова принялась', 2),
#  ('принялась ходить', 2),
#  ('ходить комнате', 2),
#  ('пожалуйте барыне', 2),
#  ('чашку чаю', 2),
#  ('кажется значительно', 2),
#  ('почел нужное', 2),
#  ('моего нового', 2),
#  ('счет которые', 2),
#  ('странно улыбнулся', 2),
#  ('голову подушку', 2),
#  ('этим последним', 2),
#  ('послушайте сказал', 2),
#  ('одной девушки', 2),
#  ('марью александровну', 2),
#  ('давно кажется', 2),
#  ('двоюродный брат', 2),
#  ('марьей александровной', 2),
#  ('мог рассказать', 2),
#  ('марта го', 2),
#  ('любезная марья', 2),
#  ('остался дома', 2),
#  ('вс лето', 2),
#  ('моего письма', 2),
#  ('которая ожидала', 2),
#  ('пять минут', 2),
#  ('продолжать писать', 2),
#  ('остаюсь искренно', 2),
#  ('получила ваше', 2),
#  ('право знаю', 2),
#  ('позвольте предложить', 2),
#  ('марья б', 2),
#  ('думал моем', 2),
#  ('моем письме', 2),
#  ('говорить вами', 2),
#  ('непременно нужно', 2),
#  ('имею никакого', 2),
#  ('одинок земле', 2),
#  ('свое одиночество', 2),
#  ('моей прошедшей', 2),
#  ('прошедшей жизни', 2),
#  ('оттого именно', 2),
#  ('александровне петербург', 2),
#  ('тайны своей', 2),
#  ('право кажется', 2),
#  ('преданный марьи', 2),
#  ('спасибо марья', 2),
#  ('очень доброе', 2),
#  ('обо всем', 2),
#  ('свое прошедшее', 2),
#  ('сердце человека', 2),
#  ('вс ясно', 2),
#  ('боже боже', 2),
#  ('слишком винить', 2),
#  ('скажите милость', 2),
#  ('каждого человека', 2),
#  ('приходит голову', 2),
#  ('каждый делает', 2),
#  ('делает судьбу', 2),
#  ('слишком рано', 2),
#  ('тотчас понял', 2),
#  ('одним тех', 2),
#  ('стремление истине', 2),
#  ('наша психология', 2),
#  ('точно наша', 2),
#  ('мгновения природа', 2),
#  ('наши сердца', 2),
#  ('нам суждено', 2),
#  ('облаком волнистым', 2),
#  ('полно полно', 2),
#  ('это прошло', 2),
#  ('го мая', 2),
#  ('чувство оно', 2),
#  ('оно возбудило', 2),
#  ('почему именно', 2),
#  ('это чувство', 2),
#  ('немногих словах', 2),
#  ('свои мысли', 2),
#  ('такое жизнь', 2),
#  ('могу представить', 2),
#  ('женщины крайней', 2),
#  ('свое окончательное', 2),
#  ('особенно тех', 2),
#  ('знаю могу', 2),
#  ('скажете вы', 2),
#  ('положим это', 2),
#  ('нахлынуло разом', 2),
#  ('вместе нами', 2),
#  ('трудно легко', 2),
#  ('представить можете', 2),
#  ('вс дело', 2),
#  ('это делает', 2),
#  ('каждое движение', 2),
#  ('внутренний голос', 2),
#  ('самое мгновение', 2),
#  ('руки мои', 2),
#  ('стало стыдно', 2),
#  ('м алексея', 2),
#  ('недаром гласит', 2),
#  ('знали вс', 2),
#  ('конце письма', 2),
#  ('этим именем', 2),
#  ('слова вс', 2),
#  ('это удивляет', 2),
#  ('вашего брата', 2),
#  ('вся жизнь', 2),
#  ('люди простые', 2),
#  ('зовут философкой', 2),
#  ('останусь конца', 2),
#  ('конца верна', 2),
#  ('силы изменили', 2),
#  ('попасть общую', 2),
#  ('общую колею', 2),
#  ('ждать надеяться', 2),
#  ('говорили крыльях', 2),
#  ('часто долго', 2),
#  ('повторяю женщины', 2),
#  ('свои убеждения', 2),
#  ('жизнь вс', 2),
#  ('достигнуть цели', 2),
#  ('старых девушек', 2),
#  ('поглядеть попристальнее', 2),
#  ('ваше положение', 2),
#  ('прекрасно положим', 2),
#  ('почему это', 2),
#  ('вижу точно', 2),
#  ('конце моего', 2),
#  ('наверное знаю', 2),
#  ('хотя сердце', 2),
#  ('такие горькие', 2),
#  ('другого раза', 2),
#  ('сперва думала', 2),
#  ('слишком стар', 2),
#  ('начале письма', 2),
#  ('это ясно', 2),
#  ('дважды четыре', 2),
#  ('добрый человек', 2),
#  ('чему спешить', 2),
#  ('такая женщина', 2),
#  ('сумел оценить', 2),
#  ('целую ночь', 2),
#  ('года тому', 2),
#  ('пришла голову', 2),
#  ('блестящая мысль', 2),
#  ('тебе письмо', 2),
#  ('одну женщину', 2),
#  ('вместе нею', 2),
#  ('наслаждаться жизнью', 2),
#  ('милый друг', 2),
#  ('эта женщина', 2),
#  ('первого дня', 2),
#  ('чтото необыкновенное', 2),
#  ('говорю вс', 2),
#  ('знаю знать', 2),
#  ('вс письмо', 2),
#  ('тебе кланяться', 2),
#  ('погода стояла', 2),
#  ('весь весь', 2),
#  ('каким горьким', 2),
#  ('это нами', 2),
#  ('убедился окончательно', 2),
#  ('дней десять', 2),
#  ('это известие', 2),
#  ('сколько кажется', 2),
#  ('матушка очень', 2),
#  ('кажется это', 2),
#  ('выходит замуж', 2),
#  ('молодого человека', 2),
#  ('желаю счастья', 2),
#  ('хотя минуту', 2),
#  ('ключ это', 2),
#  ('последнего письма', 2),
#  ('самого никто', 2),
#  ('влюбился одну', 2),
#  ('это странно', 2),
#  ('светлые глаза', 2),
#  ('увидел первый', 2),
#  ('закрыть глаза', 2),
#  ('той роковой', 2),
#  ('говоря правду', 2),
#  ('обо едва', 2),
#  ('я мог', 2),
#  ('пустился вслед', 2),
#  ('которого вышла', 2),
#  ('ожидал буду', 2),
#  ('одном немецком', 2),
#  ('тото есть', 2),
#  ('любовь вовсе', 2),
#  ('дошел путем', 2),
#  ('купил это', 2),
#  ('тихим светом', 2),
#  ('первый день', 2),
#  ('литературная знаменитость', 2),
#  ('выражение глаза', 2),
#  ('проводить рукою', 2),
#  ('хвастаться своими', 2),
#  ('люди говорил', 2),
#  ('думаете возразил', 2),
#  ('около десяти', 2),
#  ('этих писем', 2),
#  ('сердце сжалось', 2),
#  ('девушку которая', 2),
#  ('вскочил бросился', 2),
#  ('оно состояло', 2),
#  ('занимал довольно', 2),
#  ('довольно важное', 2),
#  ('важное место', 2),
#  ('сидела окна', 2),
#  ('которую влюбился', 2),
#  ('почел долгом', 2),
#  ('волосами большими', 2),
#  ('силу воли', 2),
#  ('двадцати трех', 2),
#  ('трех лет', 2),
#  ('шестнадцать лет', 2),
#  ('ко благоволила', 2),
#  ('гораздо реже', 2),
#  ('хотя несколько', 2),
#  ('чертами лица', 2),
#  ('лежа диване', 2),
#  ('сколько помнится', 2),
#  ('заснуть день', 2),
#  ('скрестив груди', 2),
#  ('груди руки', 2),
#  ('проговорила варвара', 2),
#  ('татьяна васильевна', 2),
#  ('расхаживать комнате', 2),
#  ('писарь идет', 2),
#  ('варвара встала', 2),
#  ('спросила софья', 2),
#  ('очень приятно', 2),
#  ('константин александрыч', 2),
#  ('посмотрел софью', 2),
#  ('покачала головой', 2),
#  ('знаете софья', 2),
#  ('попка попка', 2),
#  ('софья остановилась', 2),
#  ('довольно плохо', 2),
#  ('странное существо', 2),
#  ('сел подле', 2),
#  ('николаевна начал', 2),
#  ('должен сообщить', 2),
#  ('устремив глаза', 2),
#  ('мог вообразить', 2),
#  ('ваши годы', 2),
#  ('вс глядя', 2),
#  ('прибавил ш', 2),
#  ('обернулась ко', 2),
#  ('кровь бросилась', 2),
#  ('бросилась голову', 2),
#  ('знаете говорю', 2),
#  ('проговорила никак', 2),
#  ('какого мнения', 2),
#  ('мнения нем', 2),
#  ('какое имеете', 2),
#  ('имеете право', 2),
#  ('это говорить', 2),
#  ('закрыл лицо', 2),
#  ('послышался голос', 2),
#  ('голос горничной', 2),
#  ('начал раскланиваться', 2),
#  ('право помню', 2),
#  ('лицом стене', 2),
#  ('ко комнату', 2),
#  ('обрадовался приходу', 2),
#  ('раза комнате', 2),
#  ('свои длинные', 2),
#  ('очень давно', 2),
#  ('лет восемь', 2),
#  ('чемто вроде', 2),
#  ('около двух', 2),
#  ('день проходя', 2),
#  ('кустом сирени', 2),
#  ('звуке моего', 2),
#  ('моего голоса', 2),
#  ('знаю возразил', 2),
#  ('всей душой', 2),
#  ('помню также', 2),
#  ('вс лицо', 2),
#  ('молодых людей', 2),
#  ('весьма приятно', 2),
#  ('стихи своим', 2),
#  ('сказала милый', 2),
#  ('ночь мог', 2),
#  ('голову пришло', 2),
#  ('черные волосы', 2),
#  ('поступил университет', 2),
#  ('помню одну', 2),
#  ('друг дружке', 2),
#  ('нами небо', 2),
#  ('бросился шею', 2),
#  ('семь лет', 2),
#  ('улыбка осталась', 2),
#  ('моего друга', 2),
#  ('довольно часто', 2),
#  ('громче громче', 2),
#  ('глаза вс', 2),
#  ('чей фант', 2),
#  ('фант вынется', 2),
#  ('досада разбирала', 2),
#  ('совершенно неожиданно', 2),
#  ('очень любил', 2),
#  ('тонким голосом', 2),
#  ('ночного неба', 2),
#  ('сняла шляпу', 2),
#  ('холодной улыбкой', 2),
#  ('взял книгу', 2),
#  ('честный человек', 2),
#  ('значит спросил', 2),
#  ('спросил это', 2),
#  ('диван закрыл', 2),
#  ('мной стоял', 2),
#  ('некоторой степени', 2),
#  ('пасынков помолчал', 2),
#  ('упрекать ее', 2),
#  ('сел диван', 2),
#  ('вернулся поздно', 2),
#  ('кроме кого', 2),
#  ('кого спросил', 2),
#  ('сердце забилось', 2),
#  ('наш разговор', 2),
#  ('обо мне', 2),
#  ('должен непременно', 2),
#  ('руку бросился', 2),
#  ('бросился нему', 2),
#  ('шею зарыдал', 2),
#  ('несколько дней', 2),
#  ('решился пойти', 2),
#  ('голос прерывался', 2),
#  ('ощущений это', 2),
#  ('прошло лет', 2),
#  ('течение времени', 2),
#  ('глушь даль', 2),
#  ('одной отдаленных', 2),
#  ('отдаленных губерний', 2),
#  ('тотчас велел', 2),
#  ('это узнал', 2),
#  ('извольте извольте', 2),
#  ('лет десять', 2),
#  ('плохо плохо', 2),
#  ('исхудалую руку', 2),
#  ('яша воскликнул', 2),
#  ('начал глядеть', 2),
#  ('начал это', 2),
#  ('это сказал', 2),
#  ('сказал елисей', 2),
#  ('стрелой стрелой', 2),
#  ('порядочный человек', 2),
#  ('видно нам', 2),
#  ('бог всем', 2),
#  ('опустил голову', 2),
#  ('очень этому', 2),
#  ('руку рука', 2),
#  ('очень скверно', 2),
#  ('роста очень', 2),
#  ('узнать спросил', 2),
#  ('сделайте одолжение', 2),
#  ('поговорить вами', 2),
#  ('желая сказать', 2),
#  ('сказать охота', 2),
#  ('моего приятеля', 2),
#  ('помилуйте начал', 2),
#  ('послать губернский', 2),
#  ('запасной экономии', 2),
#  ('искоса взглянув', 2),
#  ('сил моих', 2),
#  ('быстро отворил', 2),
#  ('это похвально', 2),
#  ('заговорил пасынков', 2),
#  ('удивительное спокойствие', 2),
#  ('руку это', 2),
#  ('проговорил пасынков', 2),
#  ('глядел кудато', 2),
#  ('тебе писал', 2),
#  ('знаю право', 2),
#  ('сказал правду', 2),
#  ('скоро разлюбил', 2),
#  ...]
