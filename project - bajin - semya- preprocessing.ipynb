# %%
with open ('Бацзинь - Семья.txt') as file1:
    bajin2 = file1.read()

# %%
from sklearn.feature_extraction.text import CountVectorizer
import nltk
from collections import Counter
import re
import os

# %%
from nltk.corpus import stopwords
from nltk.tokenize import word_tokenize
import nltk
nltk.download('punkt')
# Out:
# [nltk_data] Downloading package punkt to
# [nltk_data]     C:\Users\sidor\AppData\Roaming\nltk_data...
# [nltk_data]   Package punkt is already up-to-date!
# True

# %%
import nltk
nltk.download('stopwords')
# Out:
# [nltk_data] Downloading package stopwords to
# [nltk_data]     C:\Users\sidor\AppData\Roaming\nltk_data...
# [nltk_data]   Package stopwords is already up-to-date!
# True

# %%
from pymystem3 import Mystem

# %%
mystem = Mystem()

# %%
def normalized_text (word):
    word = word.lower()
    word = re.sub("[!\"#$%&\'—()*+,-»«./:;<=>?@[\\]^_`{|}~]?",'',word)
    word = " ".join([word for word in word.split() if word not in(stopwords.words('russian'))])
    word = word.split()
    output = len(word)
    return output

# %%
normalized_text(bajin2)
# Out:
# 69346

# %%
#filtered_words = [Word for Word in tom6 if Word not in stopwords.words('russian')]
#text = 'здравствуй дорогой читатель сегодня очень ветренно поэтому я и он не пошли гулять хотя очень хотелось'
#text = ' '.join([word for word in text.split() if word not in (stopwords.words('russian'))])
#tom = " ".join([word for word in tom.split() if word not in(stopwords.words('russian'))])

# %%
bigram_vectorizer = CountVectorizer(ngram_range=(4,6),
                                    token_pattern=r'[А-Яа-я]+', min_df=2)

# %%
analyze = bigram_vectorizer.build_analyzer()

# %%
z = analyze(bajin2)

# %%
Counter(z).most_common()
# Out:
# [('цзюе минь и цзюе', 23),
#  ('минь и цзюе хой', 23),
#  ('цзюе минь и цзюе хой', 23),
#  ('к себе в комнату', 19),
#  ('ни за что не', 17),
#  ('ни о чем не', 15),
#  ('до тех пор пока', 14),
#  ('шу хуа и шу', 13),
#  ('цзюе хой цзюе синь', 12),
#  ('что то сказать но', 11),
#  ('цзюе хой не мог', 11),
#  ('с этими словами она', 10),
#  ('во что бы то', 9),
#  ('что бы то ни', 9),
#  ('бы то ни стало', 9),
#  ('но вместе с тем', 9),
#  ('цзюе синь цзюе хой', 9),
#  ('во что бы то ни', 9),
#  ('что бы то ни стало', 9),
#  ('во что бы то ни стало', 9),
#  ('в этот момент он', 8),
#  ('посмотрел на цзюе хоя', 8),
#  ('с этими словами он', 8),
#  ('до сих пор не', 8),
#  ('в то же время', 7),
#  ('цзюе минь цзюе хой', 7),
#  ('вместе с цзюе минем', 7),
#  ('цзюе цюнь и цзюе', 7),
#  ('цюнь и цзюе ши', 7),
#  ('хуа и шу чжэнь', 7),
#  ('цзюе хой и цзюе', 7),
#  ('цзюе цюнь и цзюе ши', 7),
#  ('шу хуа и шу чжэнь', 7),
#  ('и в то же', 6),
#  ('с этими словами цзюе', 6),
#  ('цзюе хой цзюе минь', 6),
#  ('меня за то что', 6),
#  ('цзюе синь цзюе минь', 6),
#  ('кто умеет пить вино', 6),
#  ('не умеет пить вина', 6),
#  ('цзюе хоя цзюе хой', 6),
#  ('хой и цзюе минь', 6),
#  ('хуа и шу ин', 6),
#  ('кэ ань и кэ', 6),
#  ('ань и кэ дин', 6),
#  ('чжан хой жу и', 6),
#  ('и в то же время', 6),
#  ('цзюе хой и цзюе минь', 6),
#  ('шу хуа и шу ин', 6),
#  ('кэ ань и кэ дин', 6),
#  ('не знаю почему но', 5),
#  ('и вместе с тем', 5),
#  ('мин фэн мин фэн', 5),
#  ('ни в чем не', 5),
#  ('никак не предполагал что', 5),
#  ('я не могу больше', 5),
#  ('не проронил ни слова', 5),
#  ('у себя в комнате', 5),
#  ('что у меня нет', 5),
#  ('цзюе хой поднял голову', 5),
#  ('цзюе миня и цзюе', 5),
#  ('миня и цзюе хоя', 5),
#  ('тех пор пока не', 5),
#  ('в том что ты', 5),
#  ('цзюе синь и его', 5),
#  ('за то что я', 5),
#  ('на цзюе хоя и', 5),
#  ('все больше и больше', 5),
#  ('на цзюе хоя цзюе', 5),
#  ('я не в силах', 5),
#  ('цзюе ин цзюе цюнь', 5),
#  ('шу ин шу хуа', 5),
#  ('ин шу хуа и', 5),
#  ('хотела что то сказать', 5),
#  ('грохот барабанов и гонгов', 5),
#  ('она хотела что то', 5),
#  ('цзюе миня и цзюе хоя', 5),
#  ('до тех пор пока не', 5),
#  ('меня за то что я', 5),
#  ('шу ин шу хуа и', 5),
#  ('хотела что то сказать но', 5),
#  ('вмешался в разговор цзюе', 4),
#  ('к цзюе миню и', 4),
#  ('цзюе миню и цзюе', 4),
#  ('миню и цзюе хою', 4),
#  ('на душе у него', 4),
#  ('душе у него было', 4),
#  ('ему казалось что он', 4),
#  ('цзюе хою казалось что', 4),
#  ('этими словами цзюе хой', 4),
#  ('посмотрела на цзюе хоя', 4),
#  ('в тот момент когда', 4),
#  ('с тех пор как', 4),
#  ('он не проронил ни', 4),
#  ('цзюе синя и мэй', 4),
#  ('вспомнив о чем то', 4),
#  ('конечно ответил цзюе хой', 4),
#  ('и чжан хой жу', 4),
#  ('цзюе хой все еще', 4),
#  ('цзюе хой знал что', 4),
#  ('в один прекрасный день', 4),
#  ('на середине озера и', 4),
#  ('смотрели друг на друга', 4),
#  ('что бы ни случилось', 4),
#  ('молодой барин мин фэн', 4),
#  ('цзюе хой понял что', 4),
#  ('в комнате цзюе синя', 4),
#  ('же в конце концов', 4),
#  ('себя в руки и', 4),
#  ('синь цзюе минь и', 4),
#  ('поднял голову и посмотрел', 4),
#  ('голову и посмотрел на', 4),
#  ('беседка на середине озера', 4),
#  ('несколько дней тому назад', 4),
#  ('цинь и цзюе минь', 4),
#  ('почему ты не хочешь', 4),
#  ('шу ин и ее', 4),
#  ('но так и не', 4),
#  ('из за того что', 4),
#  ('кто бы мог подумать', 4),
#  ('бы мог подумать что', 4),
#  ('старый господин гао и', 4),
#  ('он не мог больше', 4),
#  ('не мог совладать с', 4),
#  ('как и все остальные', 4),
#  ('всего через два дня', 4),
#  ('у него из глаз', 4),
#  ('жуй цзюе я здесь', 4),
#  ('цзюе миню и цзюе хою', 4),
#  ('на душе у него было', 4),
#  ('с этими словами цзюе хой', 4),
#  ('цзюе синь цзюе минь и', 4),
#  ('на цзюе хоя цзюе хой', 4),
#  ('ин шу хуа и шу', 4),
#  ('кто бы мог подумать что', 4),
#  ('она хотела что то сказать', 4),
#  ('шу ин шу хуа и шу', 4),
#  ('ин шу хуа и шу чжэнь', 4),
#  ('она хотела что то сказать но', 4),
#  ('очки в золотой оправе', 3),
#  ('понял в чем дело', 3),
#  ('на цзюе миня он', 3),
#  ('по обе стороны от', 3),
#  ('все так же улыбаясь', 3),
#  ('разве я когда нибудь', 3),
#  ('но цзюе хой не', 3),
#  ('через некоторое время он', 3),
#  ('стоял у письменного стола', 3),
#  ('у письменного стола и', 3),
#  ('услышав голос цзюе хоя', 3),
#  ('неужели ты не знаешь', 3),
#  ('он чувствовал что должен', 3),
#  ('вид будто ничего не', 3),
#  ('у нее в ушах', 3),
#  ('но в конце концов', 3),
#  ('она и сама не', 3),
#  ('о чем ты говоришь', 3),
#  ('я что нибудь придумаю', 3),
#  ('то ни стало должны', 3),
#  ('а через некоторое время', 3),
#  ('его к себе и', 3),
#  ('брачный договор с семьей', 3),
#  ('на другой день после', 3),
#  ('лишь для того чтобы', 3),
#  ('цзюе синь как обычно', 3),
#  ('в контору к старшему', 3),
#  ('контору к старшему брату', 3),
#  ('все ближе и ближе', 3),
#  ('цзюе хой что ты', 3),
#  ('хой поднял голову и', 3),
#  ('я и сама не', 3),
#  ('ничего не случится если', 3),
#  ('хотел что то сказать', 3),
#  ('не было в комнате', 3),
#  ('смотрел на цзюе миня', 3),
#  ('цзюе хой ты не', 3),
#  ('дело в том что', 3),
#  ('удивленно спросил цзюе минь', 3),
#  ('разговор на другую тему', 3),
#  ('не обращал внимания на', 3),
#  ('обратилась к цзюе миню', 3),
#  ('не произнося ни слова', 3),
#  ('перебил его цзюе хой', 3),
#  ('слухи о том что', 3),
#  ('вместе с цзюе хоем', 3),
#  ('по обе стороны улицы', 3),
#  ('все равно ничего не', 3),
#  ('с цзюе минем он', 3),
#  ('и посмотрел на цзюе', 3),
#  ('по лицу цзюе хоя', 3),
#  ('увидев что цзюе хой', 3),
#  ('разочарованно сказал цзюе хой', 3),
#  ('сказал цзюе хой он', 3),
#  ('цзюе хою цзюе хой', 3),
#  ('цзюе хой ничего не', 3),
#  ('цзюе хой смотрел на', 3),
#  ('на самом же деле', 3),
#  ('думал о том как', 3),
#  ('все сильнее и сильнее', 3),
#  ('он поднял голову и', 3),
#  ('цзюе хой вышел из', 3),
#  ('что ты тут делаешь', 3),
#  ('цзюе хой но он', 3),
#  ('с утра до вечера', 3),
#  ('когда они вышли из', 3),
#  ('поднялись по каменным ступеням', 3),
#  ('они смотрели друг на', 3),
#  ('цзюе хой почувствовал что', 3),
#  ('он никак не предполагал', 3),
#  ('неужели ты думаешь что', 3),
#  ('в этот момент не', 3),
#  ('я ни за что', 3),
#  ('неужели вы думаете что', 3),
#  ('цзюе хою не хотелось', 3),
#  ('цзюе хой почему ты', 3),
#  ('ответил цзюе хой цзюе', 3),
#  ('ничего не сказал и', 3),
#  ('любит цветы зимней сливы', 3),
#  ('за руку хай чэня', 3),
#  ('вернулся к себе в', 3),
#  ('себе в комнату и', 3),
#  ('но у меня не', 3),
#  ('у меня не хватает', 3),
#  ('и в конце концов', 3),
#  ('у кого нибудь из', 3),
#  ('но на этот раз', 3),
#  ('в это время в', 3),
#  ('цзюе хой чувствовал как', 3),
#  ('а на самом деле', 3),
#  ('у меня на душе', 3),
#  ('если что нибудь случится', 3),
#  ('взял себя в руки', 3),
#  ('цзюе ши и цзюе', 3),
#  ('умеет пить вино спрашивает', 3),
#  ('шу ин и шу', 3),
#  ('ин и шу хуа', 3),
#  ('цзюе хой он не', 3),
#  ('цзюе хой кивнул и', 3),
#  ('середине озера и горбатый', 3),
#  ('по каменным ступеням и', 3),
#  ('в этот момент она', 3),
#  ('не думать о ней', 3),
#  ('что я не в', 3),
#  ('больше ни о чем', 3),
#  ('тем временем цзюе синь', 3),
#  ('цзюе синя но он', 3),
#  ('кэ мин и его', 3),
#  ('мин и его братья', 3),
#  ('во главе с цзюе', 3),
#  ('цзюе хой в этот', 3),
#  ('хой в этот момент', 3),
#  ('ин цзюе цюнь и', 3),
#  ('цзюе синь и трое', 3),
#  ('синь и трое его', 3),
#  ('жуй цзюе шу ин', 3),
#  ('кэ мин и цзюе', 3),
#  ('мин и цзюе синь', 3),
#  ('на лбу у нее', 3),
#  ('все только что случившееся', 3),
#  ('спросил цзюе хой он', 3),
#  ('в том что у', 3),
#  ('он чуть было не', 3),
#  ('как будто кто то', 3),
#  ('посмотрел на цзюе миня', 3),
#  ('послышались чьи то шаги', 3),
#  ('у него за спиной', 3),
#  ('он то и дело', 3),
#  ('цзюе хой подошел к', 3),
#  ('спросил цзюе хой цзюе', 3),
#  ('цзюе хой не ответил', 3),
#  ('цинь и шу ин', 3),
#  ('на носу мин фэн', 3),
#  ('рукой за грудь и', 3),
#  ('об этом цзюе хой', 3),
#  ('и цзюе хой не', 3),
#  ('к себе хай чэня', 3),
#  ('к павильону на озере', 3),
#  ('что толку в том', 3),
#  ('толку в том что', 3),
#  ('в том что я', 3),
#  ('в павильоне на озере', 3),
#  ('несколько лет тому назад', 3),
#  ('потянул цзюе хоя за', 3),
#  ('цзюе хоя за рукав', 3),
#  ('началось с того что', 3),
#  ('у них не было', 3),
#  ('кэ мин не мог', 3),
#  ('мог совладать с собой', 3),
#  ('я до сих пор', 3),
#  ('ты же знаешь что', 3),
#  ('юнь хуа неужели ты', 3),
#  ('вэнь и старая мисс', 3),
#  ('мин фэн поняла что', 3),
#  ('о мин фэн он', 3),
#  ('никогда больше не увидит', 3),
#  ('смотрела на цзюе хоя', 3),
#  ('она еще так молода', 3),
#  ('за то что они', 3),
#  ('на глазах навернулись слезы', 3),
#  ('кто мог подумать что', 3),
#  ('в мире так много', 3),
#  ('что бы ты ни', 3),
#  ('цзюе миня цзюе хой', 3),
#  ('цзюе миня за рукав', 3),
#  ('цзюе минь не мог', 3),
#  ('из стороны в сторону', 3),
#  ('но ни за что', 3),
#  ('ни в коем случае', 3),
#  ('в коем случае не', 3),
#  ('третий молодой барин цзюе', 3),
#  ('молодой барин цзюе хой', 3),
#  ('а про себя подумал', 3),
#  ('про себя цзюе хой', 3),
#  ('еще что то сказать', 3),
#  ('не верил своим ушам', 3),
#  ('здесь ты слышишь меня', 3),
#  ('на глазах у него', 3),
#  ('подошел к двери и', 3),
#  ('цзюе синь все еще', 3),
#  ('хой цзюе синь долго', 3),
#  ('стоял у письменного стола и', 3),
#  ('бы то ни стало должны', 3),
#  ('в контору к старшему брату', 3),
#  ('цзюе хой поднял голову и', 3),
#  ('и посмотрел на цзюе хоя', 3),
#  ('они смотрели друг на друга', 3),
#  ('он никак не предполагал что', 3),
#  ('я ни за что не', 3),
#  ('к себе в комнату и', 3),
#  ('взял себя в руки и', 3),
#  ('синь цзюе минь и цзюе', 3),
#  ('кто умеет пить вино спрашивает', 3),
#  ('шу ин и шу хуа', 3),
#  ('поднял голову и посмотрел на', 3),
#  ('беседка на середине озера и', 3),
#  ('на середине озера и горбатый', 3),
#  ('что я не в силах', 3),
#  ('кэ мин и его братья', 3),
#  ('цзюе хой в этот момент', 3),
#  ('цзюе ин цзюе цюнь и', 3),
#  ('ин цзюе цюнь и цзюе', 3),
#  ('цзюе синь и трое его', 3),
#  ('кэ мин и цзюе синь', 3),
#  ('что толку в том что', 3),
#  ('потянул цзюе хоя за рукав', 3),
#  ('не мог совладать с собой', 3),
#  ('я до сих пор не', 3),
#  ('но ни за что не', 3),
#  ('ни в коем случае не', 3),
#  ('третий молодой барин цзюе хой', 3),
#  ('еще что то сказать но', 3),
#  ('цзюе хой цзюе синь долго', 3),
#  ('что бы то ни стало должны', 3),
#  ('цзюе синь цзюе минь и цзюе', 3),
#  ('синь цзюе минь и цзюе хой', 3),
#  ('беседка на середине озера и горбатый', 3),
#  ('цзюе ин цзюе цюнь и цзюе', 3),
#  ('ин цзюе цюнь и цзюе ши', 3),
#  ('то в одну то', 2),
#  ('в одну то в', 2),
#  ('одну то в другую', 2),
#  ('то в другую сторону', 2),
#  ('и никогда больше не', 2),
#  ('цзюе хой чувствовал себя', 2),
#  ('друг на друга как', 2),
#  ('этими словами цзюе минь', 2),
#  ('цзюе хой взглянул на', 2),
#  ('у меня замечательный брат', 2),
#  ('подняться по каменным ступеням', 2),
#  ('мин фэн повернулась и', 2),
#  ('и пошла в сторону', 2),
#  ('прошел к себе в', 2),
#  ('о чем это ты', 2),
#  ('цзюе хой стоял рядом', 2),
#  ('делая вид что сердится', 2),
#  ('последовал за цзюе минем', 2),
#  ('заметил цзюе синь все', 2),
#  ('обратилась цинь к цзюе', 2),
#  ('в свою очередь спросил', 2),
#  ('но у нас в', 2),
#  ('пояснил цзюе минь он', 2),
#  ('во время летних каникул', 2),
#  ('себя цзюе хой в', 2),
#  ('милая почему ты не', 2),
#  ('шепнула ей на ухо', 2),
#  ('вышли из главного дома', 2),
#  ('по каменным ступеням во', 2),
#  ('каменным ступеням во двор', 2),
#  ('я никак не могу', 2),
#  ('то здесь то там', 2),
#  ('сам того не замечая', 2),
#  ('через несколько минут из', 2),
#  ('левой комнаты главного дома', 2),
#  ('это был голос старой', 2),
#  ('не нужно так много', 2),
#  ('в это время из', 2),
#  ('но ему казалось что', 2),
#  ('он не знал что', 2),
#  ('сказал он самому себе', 2),
#  ('к тому же кругу', 2),
#  ('тому же кругу что', 2),
#  ('же кругу что и', 2),
#  ('кругу что и цинь', 2),
#  ('что и цинь тогда', 2),
#  ('цзюе хой вошел в', 2),
#  ('письменного стола и разговаривал', 2),
#  ('стола и разговаривал с', 2),
#  ('голову взглянул на него', 2),
#  ('на него а потом', 2),
#  ('подняла голову и посмотрела', 2),
#  ('голову и посмотрела на', 2),
#  ('ты не знаешь что', 2),
#  ('сердито продолжал цзюе хой', 2),
#  ('видя что цзюе хой', 2),
#  ('цзюе хой не на', 2),
#  ('хой не на шутку', 2),
#  ('глядя на цзюе хоя', 2),
#  ('ничего не говорила и', 2),
#  ('не потому ли что', 2),
#  ('и все из за', 2),
#  ('чувствовал что должен сказать', 2),
#  ('встала и подошла к', 2),
#  ('цзюе хой я тоже', 2),
#  ('они не знали что', 2),
#  ('с грустью в голосе', 2),
#  ('у вас в семье', 2),
#  ('она смотрела на цзюе', 2),
#  ('смотрела на цзюе миня', 2),
#  ('а какой прок от', 2),
#  ('ты ни в чем', 2),
#  ('в чем не виноват', 2),
#  ('или нет это неважно', 2),
#  ('этими словами она направилась', 2),
#  ('словами она направилась к', 2),
#  ('она направилась к двери', 2),
#  ('у цзюе миня он', 2),
#  ('я никак не предполагал', 2),
#  ('цзюе минь ничего не', 2),
#  ('минь ничего не сказал', 2),
#  ('это был звонкий голос', 2),
#  ('был звонкий голос мин', 2),
#  ('звонкий голос мин фэн', 2),
#  ('голос мин фэн на', 2),
#  ('еще плыл в воздухе', 2),
#  ('перед собой свои тайны', 2),
#  ('и сама не знала', 2),
#  ('сама не знала что', 2),
#  ('старшая барышня была жива', 2),
#  ('барышня была жива она', 2),
#  ('это она научила меня', 2),
#  ('так же как и', 2),
#  ('была такой же как', 2),
#  ('си эр которая служит', 2),
#  ('эр которая служит у', 2),
#  ('которая служит у пятой', 2),
#  ('сказала мин фэн и', 2),
#  ('все выше и выше', 2),
#  ('опустилась в плетеное кресло', 2),
#  ('все еще стоит перед', 2),
#  ('обратилась к дочери цинь', 2),
#  ('ей казалось что она', 2),
#  ('мне тебя не переспорить', 2),
#  ('немного отлегло от сердца', 2),
#  ('неужели ты хочешь чтобы', 2),
#  ('ты хочешь чтобы я', 2),
#  ('на это никакого внимания', 2),
#  ('по твоему выходит что', 2),
#  ('себе в комнату она', 2),
#  ('она подошла к письменному', 2),
#  ('подошла к письменному столу', 2),
#  ('но я не могу', 2),
#  ('мы во что бы', 2),
#  ('новую дорогу для наших', 2),
#  ('дорогу для наших сестер', 2),
#  ('наших сестер в будущем', 2),
#  ('несмотря на то что', 2),
#  ('выросли в одной семье', 2),
#  ('у цзюе синя был', 2),
#  ('отец позвал его к', 2),
#  ('позвал его к себе', 2),
#  ('к себе и сказал', 2),
#  ('вернувшись к себе в', 2),
#  ('себе в комнату он', 2),
#  ('на кровать и закрывшись', 2),
#  ('кровать и закрывшись с', 2),
#  ('и закрывшись с головой', 2),
#  ('не знал и не', 2),
#  ('той о которой он', 2),
#  ('о которой он мечтал', 2),
#  ('себя в комнате он', 2),
#  ('обо всем на свете', 2),
#  ('ни радости ни печали', 2),
#  ('в контору й компании', 2),
#  ('другой день после обеда', 2),
#  ('ушел оставив его одного', 2),
#  ('в тот же день', 2),
#  ('тридцать с лишним юаней', 2),
#  ('с лишним юаней наличными', 2),
#  ('одни и те же', 2),
#  ('никто не мешал им', 2),
#  ('никогда не думал что', 2),
#  ('цзюе синь казалось совсем', 2),
#  ('обо всем что было', 2),
#  ('ему все равно не', 2),
#  ('вместе с тем он', 2),
#  ('теперь у него есть', 2),
#  ('больше всего на свете', 2),
#  ('вспыхнуло движение го мая', 2),
#  ('лавке торговавшей новыми книгами', 2),
#  ('философия поклонов и непротивленчество', 2),
#  ('они то и дело', 2),
#  ('о своем горе и', 2),
#  ('благодарности надежды и любви', 2),
#  ('синь как обычно отправился', 2),
#  ('во второй половине дня', 2),
#  ('он во что бы', 2),
#  ('дверная занавеска шевельнулась и', 2),
#  ('и в ком нату', 2),
#  ('обе пьесы безусловно хороши', 2),
#  ('даже не поднял головы', 2),
#  ('жаль что у меня', 2),
#  ('улыбнулся цзюе хой он', 2),
#  ('мне ка жется что', 2),
#  ('я и сам знаю', 2),
#  ('братья и цзянь юнь', 2),
#  ('подошла к столу цзюе', 2),
#  ('синь цзюе хой что', 2),
#  ('цинь у меня есть', 2),
#  ('приподнялся в кресле и', 2),
#  ('и опять принялся за', 2),
#  ('цинь отрицательно покачала головой', 2),
#  ('отрицательно покачала головой я', 2),
#  ('и сама не знаю', 2),
#  ('такой же как и', 2),
#  ('же как и вы', 2),
#  ('и года как она', 2),
#  ('из под очков в', 2),
#  ('под очков в золотой', 2),
#  ('очков в золотой оправе', 2),
#  ('о цзюе сине и', 2),
#  ('она до сих пор', 2),
#  ('в разговор цзюе хой', 2),
#  ('свое мнение цзюе минь', 2),
#  ('он хотел что то', 2),
#  ('на него как будто', 2),
#  ('посмотрела на него но', 2),
#  ('сердито сказал цзюе хой', 2),
#  ('цинь дело в том', 2),
#  ('у вас в доме', 2),
#  ('вот в чем дело', 2),
#  ('на цзянь юня он', 2),
#  ('цзюе синь никак не', 2),
#  ('синь никак не мог', 2),
#  ('я считаю что так', 2),
#  ('лицо у него было', 2),
#  ('все так же печально', 2),
#  ('следили за тем как', 2),
#  ('смотрел на цинь и', 2),
#  ('я ничего не могу', 2),
#  ('внимательно прислушивался к их', 2),
#  ('прислушивался к их разговору', 2),
#  ('о чем он думает', 2),
#  ('цинь удивленно посмотрела на', 2),
#  ('не знаю что с', 2),
#  ('чтобы кто нибудь не', 2),
#  ('словно вспомнив о чем', 2),
#  ('тут же обратилась к', 2),
#  ('и цинь цзюе синь', 2),
#  ('цзюе синь проводил их', 2),
#  ('синь проводил их до', 2),
#  ('а цзюе минь и', 2),
#  ('на лбу у него', 2),
#  ('от волнения не мог', 2),
#  ('руку чжан хой жу', 2),
#  ('чжан хой жу у', 2),
#  ('кто мог знать что', 2),
#  ('его цзюе хой он', 2),
#  ('прижимал руку к груди', 2),
#  ('о том что власти', 2),
#  ('виться с петицией в', 2),
#  ('с петицией в канцелярию', 2),
#  ('петицией в канцелярию дуцзюня', 2),
#  ('в канцелярию дуцзюня требования', 2),
#  ('канцелярию дуцзюня требования которые', 2),
#  ('дуцзюня требования которые мы', 2),
#  ('требования которые мы собираемся', 2),
#  ('которые мы собираемся выставить', 2),
#  ('мы собираемся выставить уже', 2),
#  ('собираемся выставить уже выработаны', 2),
#  ('выставить уже выработаны ты', 2),
#  ('уже выработаны ты пойдешь', 2),
#  ('выработаны ты пойдешь чжан', 2),
#  ('ты пойдешь чжан хой', 2),
#  ('пойдешь чжан хой жу', 2),
#  ('чжан хой жу торопился', 2),
#  ('хой жу торопился конечно', 2),
#  ('жу торопился конечно ответил', 2),
#  ('торопился конечно ответил цзюе', 2),
#  ('ответил цзюе хой они', 2),
#  ('цзюе хой они уже', 2),
#  ('хой они уже были', 2),
#  ('они уже были недалеко', 2),
#  ('уже были недалеко от', 2),
#  ('были недалеко от школы', 2),
#  ('недалеко от школы шли', 2),
#  ('от школы шли широко', 2),
#  ('школы шли широко шагая', 2),
#  ('шли широко шагая и', 2),
#  ('широко шагая и вот', 2),
#  ('шагая и вот с', 2),
#  ('и вот с каким', 2),
#  ('вот с каким то', 2),
#  ('с каким то странным', 2),
#  ('каким то странным чувством', 2),
#  ('то странным чувством вошли', 2),
#  ('странным чувством вошли в', 2),
#  ('чувством вошли в нее', 2),
#  ('вошли в нее на', 2),
#  ('в нее на спортивной', 2),
#  ('нее на спортивной площадке', 2),
#  ('на спортивной площадке собрались', 2),
#  ('спортивной площадке собрались студенты', 2),
#  ('площадке собрались студенты жившие', 2),
#  ('собрались студенты жившие при', 2),
#  ('студенты жившие при школе', 2),
#  ('жившие при школе они', 2),
#  ('при школе они собирались', 2),
#  ('школе они собирались группами', 2),
#  ('они собирались группами о', 2),
#  ('собирались группами о чем', 2),
#  ('группами о чем то', 2),
#  ('о чем то совещались', 2),
#  ('чем то совещались и', 2),
#  ('то совещались и шумели', 2),
#  ('совещались и шумели так', 2),
#  ('и шумели так что', 2),
#  ('шумели так что казалось', 2),
#  ('так что казалось вся', 2),
#  ('что казалось вся школа', 2),
#  ('казалось вся школа пришла', 2),
#  ('вся школа пришла в', 2),
#  ('школа пришла в движение', 2),
#  ('пришла в движение чжан', 2),
#  ('в движение чжан хой', 2),
#  ('движение чжан хой жу', 2),
#  ('чжан хой жу понял', 2),
#  ('хой жу понял что', 2),
#  ('жу понял что новости', 2),
#  ('понял что новости опередили', 2),
#  ('что новости опередили его', 2),
#  ('новости опередили его действительно', 2),
#  ('опередили его действительно он', 2),
#  ('его действительно он увидел', 2),
#  ('действительно он увидел хуан', 2),
#  ('он увидел хуан цунь', 2),
#  ('увидел хуан цунь жэня', 2),
#  ('хуан цунь жэня того', 2),
#  ('цунь жэня того кто', 2),
#  ('жэня того кто играл', 2),
#  ('того кто играл отца', 2),
#  ('кто играл отца в', 2),
#  ('играл отца в деле', 2),
#  ('отца в деле всей', 2),
#  ('в деле всей жизни', 2),
#  ('деле всей жизни но', 2),
#  ('всей жизни но когда', 2),
#  ('жизни но когда началась', 2),
#  ('но когда началась драка', 2),
#  ('когда началась драка дело', 2),
#  ('началась драка дело всей', 2),
#  ('драка дело всей жизни', 2),
#  ('дело всей жизни уже', 2),
#  ('всей жизни уже окончилось', 2),
#  ('жизни уже окончилось поскольку', 2),
#  ('уже окончилось поскольку новости', 2),
#  ('окончилось поскольку новости всем', 2),
#  ('поскольку новости всем были', 2),
#  ('новости всем были известны', 2),
#  ('всем были известны чжан', 2),
#  ('были известны чжан хой', 2),
#  ('известны чжан хой жу', 2),
#  ('чжан хой жу не', 2),
#  ('хой жу не пришлось', 2),
#  ('жу не пришлось ни', 2),
#  ('не пришлось ни о', 2),
#  ('пришлось ни о чем', 2),
#  ('ни о чем докладывать', 2),
#  ('о чем докладывать он', 2),
#  ('чем докладывать он вместе', 2),
#  ('докладывать он вместе с', 2),
#  ('он вместе с цзюе', 2),
#  ('с цзюе хоем протиснулся', 2),
#  ('цзюе хоем протиснулся в', 2),
#  ('хоем протиснулся в толпу', 2),
#  ('протиснулся в толпу слушая', 2),
#  ('в толпу слушая о', 2),
#  ('толпу слушая о чем', 2),
#  ('слушая о чем говорят', 2),
#  ('о чем говорят товарищи', 2),
#  ('чем говорят товарищи потом', 2),
#  ('говорят товарищи потом все', 2),
#  ('товарищи потом все же', 2),
#  ('потом все же взял', 2),
#  ('все же взял слово', 2),
#  ('же взял слово и', 2),
#  ('взял слово и рассказал', 2),
#  ('слово и рассказал обо', 2),
#  ('и рассказал обо всем', 2),
#  ('рассказал обо всем с', 2),
#  ('обо всем с самого', 2),
#  ('всем с самого начала', 2),
#  ('с самого начала студенты', 2),
#  ('самого начала студенты оживленно', 2),
#  ('начала студенты оживленно обсуждали', 2),
#  ('студенты оживленно обсуждали случившееся', 2),
#  ('оживленно обсуждали случившееся до', 2),
#  ('обсуждали случившееся до тех', 2),
#  ('случившееся до тех пор', 2),
#  ('пор пока не пришло', 2),
#  ('пока не пришло время', 2),
#  ('не пришло время выступать', 2),
#  ('пришло время выступать в', 2),
#  ('время выступать в экстренных', 2),
#  ('выступать в экстренных случаях', 2),
#  ('в экстренных случаях местом', 2),
#  ('экстренных случаях местом сбора', 2),
#  ('случаях местом сбора служил', 2),
#  ('местом сбора служил парк', 2),
#  ('сбора служил парк шао', 2),
#  ('служил парк шао чэн', 2),
#  ('парк шао чэн когда', 2),
#  ('шао чэн когда в', 2),
#  ('чэн когда в парк', 2),
#  ('когда в парк пришла', 2),
#  ('в парк пришла колонна', 2),
#  ('парк пришла колонна в', 2),
#  ('пришла колонна в которой', 2),
#  ('колонна в которой находились', 2),
#  ('в которой находились цзюе', 2),
#  ('которой находились цзюе хой', 2),
#  ('находились цзюе хой и', 2),
#  ('цзюе хой и чжан', 2),
#  ('хой и чжан хой', 2),
#  ('чжан хой жу там', 2),
#  ('хой жу там уже', 2),
#  ('жу там уже собрались', 2),
#  ('там уже собрались студенты', 2),
#  ('уже собрались студенты нескольких', 2),
#  ('собрались студенты нескольких училищ', 2),
#  ('студенты нескольких училищ и', 2),
#  ('нескольких училищ и школ', 2),
#  ('училищ и школ созвать', 2),
#  ('и школ созвать их', 2),
#  ('школ созвать их в', 2),
#  ('созвать их в воскресенье', 2),
#  ('их в воскресенье было', 2),
#  ('в воскресенье было нелегко', 2),
#  ('воскресенье было нелегко тем', 2),
#  ('было нелегко тем более', 2),
#  ('нелегко тем более что', 2),
#  ('тем более что в', 2),
#  ('более что в некоторых', 2),
#  ('что в некоторых школах', 2),
#  ('в некоторых школах уже', 2),
#  ('некоторых школах уже объявили', 2),
#  ('школах уже объявили зимние', 2),
#  ('уже объявили зимние каникулы', 2),
#  ('объявили зимние каникулы поэтому', 2),
#  ('зимние каникулы поэтому пришли', 2),
#  ('каникулы поэтому пришли не', 2),
#  ('поэтому пришли не все', 2),
#  ('пришли не все только', 2),
#  ('не все только из', 2),
#  ('все только из нескольких', 2),
#  ('только из нескольких главных', 2),
#  ('из нескольких главных училищ', 2),
#  ('нескольких главных училищ и', 2),
#  ('главных училищ и школ', 2),
#  ('училищ и школ собравшихся', 2),
#  ('и школ собравшихся было', 2),
#  ('школ собравшихся было значительно', 2),
#  ('собравшихся было значительно меньше', 2),
#  ('было значительно меньше реально', 2),
#  ('значительно меньше реально существующей', 2),
#  ('меньше реально существующей цифры', 2),
#  ('реально существующей цифры их', 2),
#  ('существующей цифры их пришло', 2),
#  ('цифры их пришло далеко', 2),
#  ('их пришло далеко не', 2),
#  ('пришло далеко не так', 2),
#  ('далеко не так много', 2),
#  ('не так много как', 2),
#  ('так много как на', 2),
#  ('много как на проверку', 2),
#  ('как на проверку контрабандных', 2),
#  ('на проверку контрабандных товаров', 2),
#  ('проверку контрабандных товаров или', 2),
#  ('контрабандных товаров или на', 2),
#  ('товаров или на демонстрацию', 2),
#  ('или на демонстрацию и', 2),
#  ('на демонстрацию и все', 2),
#  ('демонстрацию и все таки', 2),
#  ('и все таки собралось', 2),
#  ('все таки собралось более', 2),
#  ('таки собралось более двухсот', 2),
#  ('собралось более двухсот человек', 2),
#  ('более двухсот человек небо', 2),
#  ('двухсот человек небо стало', 2),
#  ('человек небо стало серым', 2),
#  ('небо стало серым и', 2),
#  ('стало серым и все', 2),
#  ('серым и все вокруг', 2),
#  ('и все вокруг окрасилось', 2),
#  ('все вокруг окрасилось в', 2),
#  ('вокруг окрасилось в тусклый', 2),
#  ('окрасилось в тусклый серый', 2),
#  ('в тусклый серый цвет', 2),
#  ('тусклый серый цвет зажгли', 2),
#  ('серый цвет зажгли фонари', 2),
#  ('цвет зажгли фонари вряд', 2),
#  ('зажгли фонари вряд ли', 2),
#  ('фонари вряд ли имело', 2),
#  ('вряд ли имело смысл', 2),
#  ('ли имело смысл ждать', 2),
#  ('имело смысл ждать кого', 2),
#  ('смысл ждать кого нибудь', 2),
#  ('ждать кого нибудь еще', 2),
#  ('кого нибудь еще время', 2),
#  ('нибудь еще время было', 2),
#  ('еще время было позднее', 2),
#  ('время было позднее огромная', 2),
#  ('было позднее огромная толпа', 2),
#  ('позднее огромная толпа двинулась', 2),
#  ('огромная толпа двинулась к', 2),
#  ('толпа двинулась к канцелярии', 2),
#  ('двинулась к канцелярии дуцзюня', 2),
#  ('к канцелярии дуцзюня цзюе', 2),
#  ('канцелярии дуцзюня цзюе хоем', 2),
#  ('дуцзюня цзюе хоем владели', 2),
#  ('цзюе хоем владели горячие', 2),
#  ('хоем владели горячие чувства', 2),
#  ('владели горячие чувства он', 2),
#  ('горячие чувства он не', 2),
#  ('чувства он не мог', 2),
#  ('он не мог ни', 2),
#  ('не мог ни минуты', 2),
#  ('мог ни минуты оставаться', 2),
#  ('ни минуты оставаться спокойным', 2),
#  ('минуты оставаться спокойным и', 2),
#  ('оставаться спокойным и взволнованно', 2),
#  ('спокойным и взволнованно оглядывался', 2),
#  ('и взволнованно оглядывался по', 2),
#  ('взволнованно оглядывался по сторонам', 2),
#  ('оглядывался по сторонам по', 2),
#  ('по сторонам по обе', 2),
#  ('сторонам по обе стороны', 2),
#  ('обе стороны улицы стояли', 2),
#  ('стороны улицы стояли толпы', 2),
#  ('улицы стояли толпы зевак', 2),
#  ('стояли толпы зевак одни', 2),
#  ('толпы зевак одни глазели', 2),
#  ('зевак одни глазели с', 2),
#  ('одни глазели с любопытством', 2),
#  ('глазели с любопытством другие', 2),
#  ('с любопытством другие шепотом', 2),
#  ('любопытством другие шепотом переговаривались', 2),
#  ('другие шепотом переговаривались третьи', 2),
#  ('шепотом переговаривались третьи посмеивались', 2),
#  ('переговаривались третьи посмеивались а', 2),
#  ('третьи посмеивались а некоторые', 2),
#  ('посмеивались а некоторые в', 2),
#  ('а некоторые в панике', 2),
#  ('некоторые в панике проталкивались', 2),
#  ('в панике проталкивались стремясь', 2),
#  ('панике проталкивались стремясь уйти', 2),
#  ('проталкивались стремясь уйти прочь', 2),
#  ('стремясь уйти прочь опять', 2),
#  ('уйти прочь опять идут', 2),
#  ('прочь опять идут будь', 2),
#  ('опять идут будь они', 2),
#  ('идут будь они прокляты', 2),
#  ('будь они прокляты проверять', 2),
#  ('они прокляты проверять иностранную', 2),
#  ('прокляты проверять иностранную контрабанду', 2),
#  ('проверять иностранную контрабанду кому', 2),
#  ('иностранную контрабанду кому же', 2),
#  ('контрабанду кому же сегодня', 2),
#  ('кому же сегодня не', 2),
#  ('же сегодня не повезет', 2),
#  ('сегодня не повезет услышал', 2),
#  ('не повезет услышал цзюе', 2),
#  ('повезет услышал цзюе хой', 2),
#  ('услышал цзюе хой нездешнюю', 2),
#  ('цзюе хой нездешнюю речь', 2),
#  ('хой нездешнюю речь он', 2),
#  ('нездешнюю речь он повернул', 2),
#  ('речь он повернул голову', 2),
#  ('к порядку к порядку', 2),
#  ('пока не добьемся своего', 2),
#  ('о том что произошло', 2),
#  ('с цзюе минем и', 2),
#  ('о том что происходит', 2),
#  ('как быстро летит время', 2),
#  ('и он не мог', 2),
#  ('рассмотреть его как следует', 2),
#  ('он забыл обо всем', 2),
#  ('цзюе хой чувствовал что', 2),
#  ('столкновения между студентами и', 2),
#  ('между студентами и солдатами', 2),
#  ('не чем иным как', 2),
#  ('с собрания объединенного союза', 2),
#  ('собрания объединенного союза учащихся', 2),
#  ('в плетеном кресле у', 2),
#  ('цзюе хой уставился на', 2),
#  ('в нем не было', 2),
#  ('он никак не мог', 2),
#  ('никак не мог придумать', 2),
#  ('вот уже не сколько', 2),
#  ('уже не сколько дней', 2),
#  ('но как только он', 2),
#  ('и увидев что цзюе', 2),
#  ('что цзюе хой все', 2),
#  ('я всегда говорил что', 2),
#  ('будешь настаивать на своем', 2),
#  ('чэнь итай пойди позови', 2),
#  ('итай пойди позови его', 2),
#  ('пойди позови его старшего', 2),
#  ('позови его старшего брата', 2),
#  ('мысль пришла ему в', 2),
#  ('пришла ему в голову', 2),
#  ('если я узнаю что', 2),
#  ('больше не вступал в', 2),
#  ('обратился к цзюе синю', 2),
#  ('какой прок в том', 2),
#  ('прок в том что', 2),
#  ('голос у цзюе синя', 2),
#  ('цзюе синя стал печальным', 2),
#  ('обращался к цзюе хою', 2),
#  ('к цзюе хою цзюе', 2),
#  ('хой поднял голову посмотрел', 2),
#  ('поднял голову посмотрел на', 2),
#  ('посмотрел на цзюе синя', 2),
#  ('но ничего не сказал', 2),
#  ('о чем шла речь', 2),
#  ('хой ничего не ответил', 2),
#  ('ничего не ответил и', 2),
#  ('бы точно так же', 2),
#  ('оставшись один в комнате', 2),
#  ('один в комнате он', 2),
#  ('какое это имеет к', 2),
#  ('это имеет к тебе', 2),
#  ('цзюе хой оставшись один', 2),
#  ('из угла в угол', 2),
#  ('что они сделают со', 2),
#  ('они сделают со мной', 2),
#  ('этими словами он вышел', 2),
#  ('а мин фэн все', 2),
#  ('когда они подошли к', 2),
#  ('второй молодой барин он', 2),
#  ('но все таки я', 2),
#  ('он вовсе не хотел', 2),
#  ('мин фэн ничего не', 2),
#  ('ничего не ответила и', 2),
#  ('с цветами зимней сливы', 2),
#  ('подняла голову и улыбнулась', 2),
#  ('там он показал рукой', 2),
#  ('он показал рукой на', 2),
#  ('у него в руках', 2),
#  ('террасе для рыбной ловли', 2),
#  ('я слышала его голос', 2),
#  ('даже не хочешь поговорить', 2),
#  ('не хочешь поговорить со', 2),
#  ('хочешь поговорить со мной', 2),
#  ('что у тебя нет', 2),
#  ('с си эр я', 2),
#  ('удивленно спросил цзюе хой', 2),
#  ('он пошел по тропинке', 2),
#  ('пошел по тропинке вдоль', 2),
#  ('достал из кармана носовой', 2),
#  ('из кармана носовой платок', 2),
#  ('если госпожа узнает она', 2),
#  ('цзюе хой взял ее', 2),
#  ('взял ее за руку', 2),
#  ('мин фэн не проронила', 2),
#  ('фэн не проронила ни', 2),
#  ('не проронила ни слова', 2),
#  ('она опять ничего не', 2),
#  ('ты думаешь что я', 2),
#  ('сделать все что угодно', 2),
#  ('должно случиться так рано', 2),
#  ('бы ни случилось я', 2),
#  ('но в этот момент', 2),
#  ('я не хочу чтобы', 2),
#  ('за что не стану', 2),
#  ('за всю свою жизнь', 2),
#  ('я часто про себя', 2),
#  ('как было бы хорошо', 2),
#  ('было бы хорошо если', 2),
#  ('бы хорошо если бы', 2),
#  ('не для меня я', 2),
#  ...]

# %%
def ngrams_text (word,num):
    word = word.lower()
    word = re.sub("[!\"#$%&\'—()*+,-»«./:;<=>?@[\\]^_`{|}~]?",'',word)
    #tokens = re.findall ('он\s\w+',word)
    #tokens = [token for token in word.split(" ") if token != ""]
    mystem.lemmatize(word)
    wordsFiltered = []
    for w in word:
        if w not in stopwords:
            wordsFiltered.append(w)
    
    output = list(ngrams(tokens,num))
    mostcommon = Counter(output).most_common()
    return mostcommon
#лемматизировать можно прямо из nltk，lemmatize, а стоп слова также есть в nltk.есть такая тетрадка. 
#чтобы свести все свои документы в один нужно просто конкатенировать все переменны. открывааем и читаем фал, сохраняем в переменную, складываем все переменные.
#append только для списка

# %%
def ngrams_text (word,num):
    word = word.lower()
    word = re.sub("[!\"#$%&\'—()*+,-»«./:;<=>?@[\\]^_`{|}~]?",'',word)
    #tokens = re.findall ('он\s\w+',word)
    #tokens = [token for token in word.split(" ") if token != ""]
    mystem.lemmatize(word)
    wordsFiltered = []
    for w in word:
        if w not in stopwords:
            wordsFiltered.append(w)
    
    output = list(ngrams(tokens,num))
    mostcommon = Counter(output).most_common()
    return mostcommon
#лемматизировать можно прямо из nltk，lemmatize, а стоп слова также есть в nltk.есть такая тетрадка. 
#чтобы свести все свои документы в один нужно просто конкатенировать все переменны. открывааем и читаем фал, сохраняем в переменную, складываем все переменные.
#append только для списка

# %%
def ngrams_text (word,num):
    word = word.lower()
    word = re.sub("[!\"#$%&\'—()*+,-»«./:;<=>?@[\\]^_`{|}~]?",'',word)
    #tokens = re.findall ('он\s\w+',word)
    #tokens = [token for token in word.split(" ") if token != ""]
    mystem.lemmatize(word)
    wordsFiltered = []
    for w in word:
        if w not in stopwords:
            wordsFiltered.append(w)
    
    output = list(ngrams(tokens,num))
    mostcommon = Counter(output).most_common()
    return mostcommon
#лемматизировать можно прямо из nltk，lemmatize, а стоп слова также есть в nltk.есть такая тетрадка. 
#чтобы свести все свои документы в один нужно просто конкатенировать все переменны. открывааем и читаем фал, сохраняем в переменную, складываем все переменные.
#append только для списка

# %%
ngrams_text("любовь",3)
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-22-120f9802b2fd> in <module>
# ----> 1 ngrams_text("любовь",3)
#
# <ipython-input-5-5e497a6001b9> in ngrams_text(word, num)
#       4     #tokens = re.findall ('он\s\w+',word)
#       5     #tokens = [token for token in word.split(" ") if token != ""]
# ----> 6     mystem.lemmatize(word)
#       7     wordsFiltered = []
#       8     for w in word:
#
# c:\users\sidor\appdata\local\programs\python\python37\lib\site-packages\pymystem3\mystem.py in lemmatize(self, text)
#     263         need_encode = (sys.version_info[0] < 3 and isinstance(text, str))
#     264
# --> 265         infos = self.analyze(text)
#     266         lemmas = list(filter(None, map(self._get_lemma, infos)))
#     267
#
# c:\users\sidor\appdata\local\programs\python\python37\lib\site-packages\pymystem3\mystem.py in analyze(self, text)
#     248         result = []
#     249         for line in text.splitlines():
# --> 250             result.extend(self._analyze_impl(line))
#     251         return result
#     252
#
# c:\users\sidor\appdata\local\programs\python\python37\lib\site-packages\pymystem3\mystem.py in _analyze_impl(self, text)
#     308                 self._start_mystem()
#     309
# --> 310             self._procin.write(text)
#     311             self._procin.write(_NL)
#     312
#
# ValueError: I/O operation on closed file

# %%
from nltk.util import ngrams

# %%
ngrams_text(tom6,3)
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-15-f6c145f82854> in <module>
# ----> 1 ngrams_text(tom6,3)
#
# <ipython-input-5-5e497a6001b9> in ngrams_text(word, num)
#       4     #tokens = re.findall ('он\s\w+',word)
#       5     #tokens = [token for token in word.split(" ") if token != ""]
# ----> 6     mystem.lemmatize(word)
#       7     wordsFiltered = []
#       8     for w in word:
#
# c:\users\sidor\appdata\local\programs\python\python37\lib\site-packages\pymystem3\mystem.py in lemmatize(self, text)
#     263         need_encode = (sys.version_info[0] < 3 and isinstance(text, str))
#     264
# --> 265         infos = self.analyze(text)
#     266         lemmas = list(filter(None, map(self._get_lemma, infos)))
#     267
#
# c:\users\sidor\appdata\local\programs\python\python37\lib\site-packages\pymystem3\mystem.py in analyze(self, text)
#     248         result = []
#     249         for line in text.splitlines():
# --> 250             result.extend(self._analyze_impl(line))
#     251         return result
#     252
#
# c:\users\sidor\appdata\local\programs\python\python37\lib\site-packages\pymystem3\mystem.py in _analyze_impl(self, text)
#     308                 self._start_mystem()
#     309
# --> 310             self._procin.write(text)
#     311             self._procin.write(_NL)
#     312
#
# ValueError: I/O operation on closed file
