# %%
with open ('Бацзинь - Семья.txt') as file1:
    bajin2 = file1.read()

# %%
from sklearn.feature_extraction.text import CountVectorizer
import nltk
from collections import Counter
import re
import os

# %%
from nltk.corpus import stopwords
from nltk.tokenize import word_tokenize
import nltk
nltk.download('punkt')
# Out:
# [nltk_data] Downloading package punkt to
# [nltk_data]     C:\Users\sidor\AppData\Roaming\nltk_data...
# [nltk_data]   Package punkt is already up-to-date!
# True

# %%
import nltk
nltk.download('stopwords')
# Out:
# [nltk_data] Downloading package stopwords to
# [nltk_data]     C:\Users\sidor\AppData\Roaming\nltk_data...
# [nltk_data]   Package stopwords is already up-to-date!
# True

# %%
from pymystem3 import Mystem

# %%
mystem = Mystem()

# %%
bajin2 = bajin2.lower()
bajin2 = re.sub("[!\"#$%&\'—()*+,-»«./:;<=>?@[\\]^_`{|}~]?",'',bajin2)
bajin2 = " ".join([word for word in bajin2.split() if word not in(stopwords.words('russian'))])

# %% [markdown]
# def normalized_text (word):
#     word = word.lower()
#     word = re.sub("[!\"#$%&\'—()*+,-»«./:;<=>?@[\\]^_`{|}~]?",'',word)
#     word = " ".join([word for word in word.split() if word not in(stopwords.words('russian'))])
#     word = word.split()
#     output = len(word)
#     return output

# %% [markdown]
# #filtered_words = [Word for Word in tom6 if Word not in stopwords.words('russian')]
# #text = 'здравствуй дорогой читатель сегодня очень ветренно поэтому я и он не пошли гулять хотя очень хотелось'
# #text = ' '.join([word for word in text.split() if word not in (stopwords.words('russian'))])
# #tom = " ".join([word for word in tom.split() if word not in(stopwords.words('russian'))])

# %%
bigram_vectorizer = CountVectorizer(ngram_range=(2,2),
                                    token_pattern=r'[А-Яа-я]+', min_df=2)

# %%
analyze = bigram_vectorizer.build_analyzer()

# %%
z = analyze(bajin2)

# %%
Counter(z).most_common()
# Out:
# [('чжан хойжу', 45),
#  ('госпожа чжоу', 43),
#  ('чэнь итай', 42),
#  ('госпожа чжан', 41),
#  ('господин гао', 32),
#  ('несколько дней', 31),
#  ('этими словами', 30),
#  ('цзюеминь цзюехой', 30),
#  ('друг друга', 28),
#  ('обо всем', 28),
#  ('молодой барин', 28),
#  ('цзюе хой', 28),
#  ('это время', 26),
#  ('старшего брата', 26),
#  ('старый господин', 26),
#  ('последнее время', 25),
#  ('старший брат', 22),
#  ('поднял голову', 22),
#  ('друг другу', 22),
#  ('зимней сливы', 22),
#  ('хуан цуньжэнь', 22),
#  ('некоторое время', 21),
#  ('тех пор', 21),
#  ('целыми днями', 20),
#  ('третий молодой', 20),
#  ('каждый день', 19),
#  ('спросил цзюехой', 19),
#  ('умеет пить', 19),
#  ('ответил цзюехой', 18),
#  ('цзюе минь', 18),
#  ('господина гао', 18),
#  ('госпожи чжоу', 18),
#  ('конце концов', 17),
#  ('старого господина', 17),
#  ('несколько лет', 16),
#  ('цзюехой мог', 16),
#  ('пить вино', 16),
#  ('сюй цяньжу', 16),
#  ('цзюе синь', 15),
#  ('пор пока', 14),
# ...

# %%
def ngrams_text (word,num):
    tokens = [token for token in word.split(" ") if token != ""]
    mystem.lemmatize(word)
    output = list(ngrams(tokens,num))
    mostcommon = Counter(output).most_common()
    return mostcommon

# %%
ngrams_text(bajin2,2)
# Out:
# [(('чжан', 'хойжу'), 45),
#  (('госпожа', 'чжоу'), 43),
#  (('чэнь', 'итай'), 42),
#  (('госпожа', 'чжан'), 41),
#  (('господин', 'гао'), 32),
#  (('несколько', 'дней'), 31),
#  (('этими', 'словами'), 30),
#  (('цзюеминь', 'цзюехой'), 30),
#  (('друг', 'друга'), 28),
#  (('обо', 'всем'), 28),
#  (('молодой', 'барин'), 28),
#  (('цзюе', 'хой'), 28),
#  (('это', 'время'), 26),
#  (('старшего', 'брата'), 26),
#  (('старый', 'господин'), 26),
#  (('последнее', 'время'), 25),
#  (('старший', 'брат'), 22),
#  (('поднял', 'голову'), 22),
#  (('друг', 'другу'), 22),
#  (('зимней', 'сливы'), 22),
#  (('хуан', 'цуньжэнь'), 22),
#  (('некоторое', 'время'), 21),
#  (('тех', 'пор'), 21),
#  (('целыми', 'днями'), 20),
#  (('третий', 'молодой'), 20),
#  (('каждый', 'день'), 19),
#  (('спросил', 'цзюехой'), 19),
#  (('умеет', 'пить'), 19),
#  (('ответил', 'цзюехой'), 18),
#  (('цзюе', 'минь'), 18),
#  (('господина', 'гао'), 18),
#  (('госпожи', 'чжоу'), 18),
#  (('конце', 'концов'), 17),
# ...

# %%
from nltk.util import ngrams
