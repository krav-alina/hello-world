# %%
with open ('Цзинь Ба. Избранное  - royallib.com.txt') as file1:
    bajin3 = file1.read()

# %%
from sklearn.feature_extraction.text import CountVectorizer
import nltk
from collections import Counter
import re
import os

# %%
from nltk.corpus import stopwords
from nltk.tokenize import word_tokenize
import nltk
nltk.download('punkt')
# Out:
# [nltk_data] Downloading package punkt to
# [nltk_data]     C:\Users\sidor\AppData\Roaming\nltk_data...
# [nltk_data]   Package punkt is already up-to-date!
# True

# %%
import nltk
nltk.download('stopwords')
# Out:
# [nltk_data] Downloading package stopwords to
# [nltk_data]     C:\Users\sidor\AppData\Roaming\nltk_data...
# [nltk_data]   Package stopwords is already up-to-date!
# True

# %%
from pymystem3 import Mystem

# %%
mystem = Mystem()

# %%
def normalized_text (word):
    word = word.lower()
    word = re.sub("[!\"#$%&\'—()*+,-»«./:;<=>?@[\\]^_`{|}~]?",'',word)
    word = " ".join([word for word in word.split() if word not in(stopwords.words('russian'))])
    word = word.split()
    output = len(word)
    return output

# %%
normalized_text(bajin3)
# Out:
# 103107

# %%
#filtered_words = [Word for Word in tom6 if Word not in stopwords.words('russian')]
#text = 'здравствуй дорогой читатель сегодня очень ветренно поэтому я и он не пошли гулять хотя очень хотелось'
#text = ' '.join([word for word in text.split() if word not in (stopwords.words('russian'))])
#tom = " ".join([word for word in tom.split() if word not in(stopwords.words('russian'))])

# %%
bigram_vectorizer = CountVectorizer(ngram_range=(4,6),
                                    token_pattern=r'[А-Яа-я]+', min_df=2)

# %%
analyze = bigram_vectorizer.build_analyzer()

# %%
z = analyze(bajin3)

# %%
Counter(z).most_common()
# Out:
# [('и в самом деле', 12),
#  ('у меня не было', 12),
#  ('и сам не знал', 11),
#  ('ни о чем не', 10),
#  ('ни за что не', 10),
#  ('к тому же я', 9),
#  ('он и сам не', 9),
#  ('и в конце концов', 9),
#  ('в то же время', 8),
#  ('ему казалось что он', 7),
#  ('у него не было', 7),
#  ('одно и то же', 7),
#  ('с тех пор как', 7),
#  ('не все ли равно', 7),
#  ('до сих пор не', 7),
#  ('во что бы то', 7),
#  ('что бы то ни', 7),
#  ('бы то ни стало', 7),
#  ('во время культурной революции', 7),
#  ('во что бы то ни', 7),
#  ('что бы то ни стало', 7),
#  ('во что бы то ни стало', 7),
#  ('а может быть и', 6),
#  ('ни в чем не', 6),
#  ('и в голову не', 6),
#  ('он не знал что', 6),
#  ('я и сам не', 6),
#  ('в тот момент когда', 6),
#  ('в том что я', 6),
#  ('ни в коем случае', 6),
#  ('бы то ни было', 6),
#  ('я до сих пор', 6),
#  ('маленький ван и красноносый', 6),
#  ('ван и красноносый чэньсань', 6),
#  ('он и сам не знал', 6),
#  ('маленький ван и красноносый чэньсань', 6),
#  ('что то сказать но', 5),
#  ('ни на что не', 5),
#  ('из глаз полились слезы', 5),
#  ('он ничего не ответил', 5),
#  ('в том числе и', 5),
#  ('ничего не оставалось как', 5),
#  ('к тому же он', 5),
#  ('не осталось и следа', 5),
#  ('у него на душе', 5),
#  ('я ни за что', 5),
#  ('дело в том что', 5),
#  ('был не в состоянии', 5),
#  ('но на этот раз', 5),
#  ('и в то же', 5),
#  ('из за того что', 5),
#  ('у меня перед глазами', 5),
#  ('но вместе с тем', 5),
#  ('и в то же время', 5),
#  ('он поднял голову и', 4),
#  ('стало не по себе', 4),
#  ('хотел что то сказать', 4),
#  ('с утра до вечера', 4),
#  ('так ничего и не', 4),
#  ('он то и дело', 4),
#  ('сердце сжалось от боли', 4),
#  ('о чем не думай', 4),
#  ('думала о том как', 4),
#  ('и представить себе не', 4),
#  ('не надо об этом', 4),
#  ('не знал что ответить', 4),
#  ('не думай об этом', 4),
#  ('ты в самом деле', 4),
#  ('ты не должен так', 4),
#  ('но он не мог', 4),
#  ('вмешалась в разговор мать', 4),
#  ('он так и не', 4),
#  ('но я не могу', 4),
#  ('закрыл лицо руками и', 4),
#  ('время от времени он', 4),
#  ('вид у него был', 4),
#  ('себя за то что', 4),
#  ('за то что не', 4),
#  ('не думать об этом', 4),
#  ('и он понял что', 4),
#  ('но на самом деле', 4),
#  ('я не могу не', 4),
#  ('о том как она', 4),
#  ('как бы то ни', 4),
#  ('о том что было', 4),
#  ('на самом же деле', 4),
#  ('на какое то время', 4),
#  ('на этот раз я', 4),
#  ('и все это время', 4),
#  ('в тот же день', 4),
#  ('за всю свою жизнь', 4),
#  ('я не верю что', 4),
#  ('да к тому же', 4),
#  ('в том что он', 4),
#  ('но так и не', 4),
#  ('спас мне жизнь и', 4),
#  ('год перевод б мудрова', 4),
#  ('сто пятьдесят долларов пособия', 4),
#  ('ремнями с медными пряжками', 4),
#  ('и по сей день', 4),
#  ('я люблю нашу родину', 4),
#  ('люблю нашу родину а', 4),
#  ('нашу родину а кто', 4),
#  ('родину а кто любит', 4),
#  ('а кто любит меня', 4),
#  ('в то время я', 4),
#  ('об учителе лу сине', 4),
#  ('хотел что то сказать но', 4),
#  ('ни о чем не думай', 4),
#  ('я ни за что не', 4),
#  ('как бы то ни было', 4),
#  ('я люблю нашу родину а', 4),
#  ('люблю нашу родину а кто', 4),
#  ('нашу родину а кто любит', 4),
#  ('родину а кто любит меня', 4),
#  ('я люблю нашу родину а кто', 4),
#  ('люблю нашу родину а кто любит', 4),
#  ('нашу родину а кто любит меня', 4),
#  ('словом не обмолвился о', 3),
#  ('не обмолвился о том', 3),
#  ('не мог найти ответа', 3),
#  ('на этот раз он', 3),
#  ('голову и взглянул на', 3),
#  ('поднялся на третий этаж', 3),
#  ('из стороны в сторону', 3),
#  ('ему стало не по', 3),
#  ('три с половиной года', 3),
#  ('ничего не было видно', 3),
#  ('что то в ответ', 3),
#  ('то в ответ и', 3),
#  ('он имел в виду', 3),
#  ('относились к нему с', 3),
#  ('похлопал его по плечу', 3),
#  ('собрав все свое мужество', 3),
#  ('не стоит об этом', 3),
#  ('что же мне делать', 3),
#  ('я имею в виду', 3),
#  ('с тревогой смотрела на', 3),
#  ('едва держался на ногах', 3),
#  ('подошел к столу и', 3),
#  ('он закрыл лицо руками', 3),
#  ('что то пробормотал в', 3),
#  ('к своему рабочему месту', 3),
#  ('звонок на обед он', 3),
#  ('то и дело останавливался', 3),
#  ('он снова перевел взгляд', 3),
#  ('снова перевел взгляд на', 3),
#  ('с болью в сердце', 3),
#  ('тех пор как они', 3),
#  ('не думала о том', 3),
#  ('не зная что делать', 3),
#  ('я и представить себе', 3),
#  ('я тоже так думаю', 3),
#  ('уже совсем другим тоном', 3),
#  ('он долго молчал потом', 3),
#  ('до сих пор нет', 3),
#  ('он не знал сколько', 3),
#  ('сладкий напиток из пшеничной', 3),
#  ('напиток из пшеничной муки', 3),
#  ('знал что ответить и', 3),
#  ('сам не знал почему', 3),
#  ('он понял что это', 3),
#  ('зачем ты так говоришь', 3),
#  ('по правде говоря я', 3),
#  ('сумочку и направилась к', 3),
#  ('и направилась к двери', 3),
#  ('и не дожидаясь ответа', 3),
#  ('управляющий и начальник отдела', 3),
#  ('ничего об этом не', 3),
#  ('что я не могу', 3),
#  ('в это время вошла', 3),
#  ('я во всем виноват', 3),
#  ('как бы она не', 3),
#  ('лучше бы мне умереть', 3),
#  ('так же как и', 3),
#  ('и все же он', 3),
#  ('всю дорогу его преследовал', 3),
#  ('ему так хотелось чтобы', 3),
#  ('не должен так говорить', 3),
#  ('и стала смотреть на', 3),
#  ('не могу же я', 3),
#  ('в этой мрачной холодной', 3),
#  ('этой мрачной холодной комнате', 3),
#  ('но через некоторое время', 3),
#  ('мать ушла к себе', 3),
#  ('подошла к окну и', 3),
#  ('сколько в них было', 3),
#  ('ответа на этот вопрос', 3),
#  ('не знала на что', 3),
#  ('знала на что решиться', 3),
#  ('не знал что у', 3),
#  ('она не знала что', 3),
#  ('до тех пор пока', 3),
#  ('никому не было до', 3),
#  ('не было до него', 3),
#  ('сюань что с тобой', 3),
#  ('взглянул на мать и', 3),
#  ('все будет в порядке', 3),
#  ('и время от времени', 3),
#  ('у него не хватает', 3),
#  ('на душе стало легче', 3),
#  ('я не в силах', 3),
#  ('я ни о чем', 3),
#  ('на глаза навернулись слезы', 3),
#  ('он перевел взгляд на', 3),
#  ('у нас еще есть', 3),
#  ('она подошла к окну', 3),
#  ('смотрели друг на друга', 3),
#  ('какое то странное чувство', 3),
#  ('и уж тем более', 3),
#  ('об этом но не', 3),
#  ('не сводил глаз с', 3),
#  ('он был не в', 3),
#  ('но он ничего не', 3),
#  ('не было ни одного', 3),
#  ('и дело с концом', 3),
#  ('и сам не мог', 3),
#  ('в этот момент он', 3),
#  ('какое то время он', 3),
#  ('я не хочу чтобы', 3),
#  ('но в конце концов', 3),
#  ('в тот день он', 3),
#  ('ей стало казаться что', 3),
#  ('от голода и холода', 3),
#  ('у меня нет сил', 3),
#  ('у меня больше не', 3),
#  ('именно потому что я', 3),
#  ('я не могу забыть', 3),
#  ('на нее как на', 3),
#  ('и с тех пор', 3),
#  ('я долго не мог', 3),
#  ('я изо всех сил', 3),
#  ('с ума от любви', 3),
#  ('что все в порядке', 3),
#  ('в то самое время', 3),
#  ('и стал смотреть на', 3),
#  ('он не мог не', 3),
#  ('что он не может', 3),
#  ('у них не было', 3),
#  ('в этот миг он', 3),
#  ('очень может быть что', 3),
#  ('не мог вымолвить ни', 3),
#  ('мог вымолвить ни слова', 3),
#  ('о чем только что', 3),
#  ('на душе у него', 3),
#  ('на его лице не', 3),
#  ('в какой то момент', 3),
#  ('это не имеет значения', 3),
#  ('ему казалось что в', 3),
#  ('о том что она', 3),
#  ('и подумать не мог', 3),
#  ('на сердце у него', 3),
#  ('за возвращение к земле', 3),
#  ('о том что у', 3),
#  ('мысль о том что', 3),
#  ('о возвращении к земле', 3),
#  ('но всякий раз когда', 3),
#  ('он всеми силами старался', 3),
#  ('о том что его', 3),
#  ('думал о том что', 3),
#  ('чэнь чжэнь понял что', 3),
#  ('смотрел на чэнь чжэня', 3),
#  ('я не хочу быть', 3),
#  ('в таком случае тебе', 3),
#  ('если бы кто нибудь', 3),
#  ('о том что все', 3),
#  ('сих пор не могу', 3),
#  ('я был уверен что', 3),
#  ('мне показалось что он', 3),
#  ('не прошло и года', 3),
#  ('в коем случае не', 3),
#  ('но я уже не', 3),
#  ('не приходило в голову', 3),
#  ('смилуйтесь сжальтесь ради жизни', 3),
#  ('сжальтесь ради жизни человека', 3),
#  ('кто бы мог подумать', 3),
#  ('бы мог подумать что', 3),
#  ('я никак не мог', 3),
#  ('в течение многих лет', 3),
#  ('только для того чтобы', 3),
#  ('шанхайского отделения союза писателей', 3),
#  ('я в то время', 3),
#  ('передай друзьям у меня', 3),
#  ('друзьям у меня все', 3),
#  ('у меня все в', 3),
#  ('меня все в порядке', 3),
#  ('по сей день я', 3),
#  ('говорит о том что', 3),
#  ('вспоминая об учителе лу', 3),
#  ('сорок пять лет назад', 3),
#  ('один из моих друзей', 3),
#  ('я так и не', 3),
#  ('года перевод т никитиной', 3),
#  ('ночной дождь в горах', 3),
#  ('дождь в горах башань', 3),
#  ('я во второй раз', 3),
#  ('запись такое то число', 3),
#  ('культурная революция все еще', 3),
#  ('революция все еще терзает', 3),
#  ('все еще терзает людей', 3),
#  ('всекитайского собрания народных представителей', 3),
#  ('словом не обмолвился о том', 3),
#  ('ему стало не по себе', 3),
#  ('что то в ответ и', 3),
#  ('он снова перевел взгляд на', 3),
#  ('с тех пор как они', 3),
#  ('не думала о том как', 3),
#  ('я и представить себе не', 3),
#  ('сладкий напиток из пшеничной муки', 3),
#  ('не знал что ответить и', 3),
#  ('и сам не знал почему', 3),
#  ('сумочку и направилась к двери', 3),
#  ('ты не должен так говорить', 3),
#  ('в этой мрачной холодной комнате', 3),
#  ('не знала на что решиться', 3),
#  ('никому не было до него', 3),
#  ('я ни о чем не', 3),
#  ('себя за то что не', 3),
#  ('он был не в состоянии', 3),
#  ('он и сам не мог', 3),
#  ('не мог вымолвить ни слова', 3),
#  ('я до сих пор не', 3),
#  ('до сих пор не могу', 3),
#  ('я и сам не знал', 3),
#  ('ни в коем случае не', 3),
#  ('смилуйтесь сжальтесь ради жизни человека', 3),
#  ('кто бы мог подумать что', 3),
#  ('передай друзьям у меня все', 3),
#  ('друзьям у меня все в', 3),
#  ('у меня все в порядке', 3),
#  ('вспоминая об учителе лу сине', 3),
#  ('ночной дождь в горах башань', 3),
#  ('культурная революция все еще терзает', 3),
#  ('революция все еще терзает людей', 3),
#  ('я до сих пор не могу', 3),
#  ('передай друзьям у меня все в', 3),
#  ('друзьям у меня все в порядке', 3),
#  ('культурная революция все еще терзает людей', 3),
#  ('в таком случае я', 2),
#  ('он был уже на', 2),
#  ('словно сам с собой', 2),
#  ('так по крайней мере', 2),
#  ('по крайней мере ему', 2),
#  ('ни словом не обмолвился', 2),
#  ('но ничего не сказала', 2),
#  ('но он знал что', 2),
#  ('и не мог найти', 2),
#  ('от этой мысли стало', 2),
#  ('но ему казалось что', 2),
#  ('тому же я не', 2),
#  ('лицо его озарилось улыбкой', 2),
#  ('поднял голову и взглянул', 2),
#  ('сосед со второго этажа', 2),
#  ('на третий этаж и', 2),
#  ('добежал до парадной двери', 2),
#  ('двери выглянул на улицу', 2),
#  ('это мужчина и женщина', 2),
#  ('в чем не виноват', 2),
#  ('кто то окликнул его', 2),
#  ('поднял голову и увидел', 2),
#  ('с жалостью глядя на', 2),
#  ('жалостью глядя на сына', 2),
#  ('между мужем и женой', 2),
#  ('мать прошла к себе', 2),
#  ('словно эхо повторил он', 2),
#  ('повалился на кровать и', 2),
#  ('всю ночь его мучили', 2),
#  ('ночь его мучили кошмары', 2),
#  ('он ничего не может', 2),
#  ('я не могу бросить', 2),
#  ('не могу бросить мать', 2),
#  ('с собой я не', 2),
#  ('на него презрительный взгляд', 2),
#  ('бросил на него удивленный', 2),
#  ('на него удивленный взгляд', 2),
#  ('него удивленный взгляд но', 2),
#  ('да он и не', 2),
#  ('в голову не могло', 2),
#  ('голову не могло прийти', 2),
#  ('не могло прийти что', 2),
#  ('наконец он пришел в', 2),
#  ('он пришел в себя', 2),
#  ('есть ему не хотелось', 2),
#  ('ему смелости и он', 2),
#  ('он не заметил как', 2),
#  ('о чем то с', 2),
#  ('глядя ей в спину', 2),
#  ('и он с сильно', 2),
#  ('он с сильно бьющимся', 2),
#  ('с сильно бьющимся сердцем', 2),
#  ('как раз в это', 2),
#  ('раз в это время', 2),
#  ('в это время она', 2),
#  ('ведь у него нет', 2),
#  ('не подозревал что именно', 2),
#  ('когда он вошел а', 2),
#  ('но выражение его лица', 2),
#  ('стоит ли из за', 2),
#  ('ли из за этого', 2),
#  ('перерыв еще не кончился', 2),
#  ('мне пора на службу', 2),
#  ('как ни в чем', 2),
#  ('в чем не бывало', 2),
#  ('пока она не скрылась', 2),
#  ('хоть бы кто нибудь', 2),
#  ('на службу подумал он', 2),
#  ('он думал об одном', 2),
#  ('попросить у нее прощения', 2),
#  ('сел за стол и', 2),
#  ('сослуживец подошел к нему', 2),
#  ('ему и в голову', 2),
#  ('в голову не пришло', 2),
#  ('на душе стало легко', 2),
#  ('с жалостью на него', 2),
#  ('она хотела что то', 2),
#  ('принес две чашки кофе', 2),
#  ('и внимательно на него', 2),
#  ('внимательно на него посмотрела', 2),
#  ('глаза но тут же', 2),
#  ('сам во всем виноват', 2),
#  ('стоит об этом говорить', 2),
#  ('и я никогда больше', 2),
#  ('с тобой я не', 2),
#  ('подумав о том что', 2),
#  ('имею в виду не', 2),
#  ('он и сел к', 2),
#  ('и сел к столу', 2),
#  ('ждала его а он', 2),
#  ('его а он и', 2),
#  ('у него не хватило', 2),
#  ('он до сих пор', 2),
#  ('в глазах его стояли', 2),
#  ('глазах его стояли слезы', 2),
#  ('я не знаю ее', 2),
#  ('что я не знаю', 2),
#  ('мать вздохнула ладно иди', 2),
#  ('он едва держался на', 2),
#  ('и то не хватает', 2),
#  ('взглянула на него и', 2),
#  ('не в силах был', 2),
#  ('но не почувствовал боли', 2),
#  ('пить я больше не', 2),
#  ('я больше не могу', 2),
#  ('шушэн он вспомнил о', 2),
#  ('все было в порядке', 2),
#  ('ее в больницу но', 2),
#  ('не раньше чем через', 2),
#  ('бы я ни был', 2),
#  ('он не мог с', 2),
#  ('этот мир не для', 2),
#  ('на что не способен', 2),
#  ('встать но тут же', 2),
#  ('луч света во мраке', 2),
#  ('что с тобой спросила', 2),
#  ('с тобой спросила она', 2),
#  ('не отрываясь смотрел на', 2),
#  ('взяла его под руку', 2),
#  ('то пробормотал в ответ', 2),
#  ('поднялись на третий этаж', 2),
#  ('при встрече с ней', 2),
#  ('его не было дома', 2),
#  ('ничего не сказал мне', 2),
#  ('выбрось ее из головы', 2),
#  ('в голосе его звучали', 2),
#  ('на него посмотрела ты', 2),
#  ('я с детства не', 2),
#  ('и из глаз полились', 2),
#  ('крепко сжал ее руку', 2),
#  ('все из за тебя', 2),
#  ('он еще не знал', 2),
#  ('у письменного стола и', 2),
#  ('и приводила себя в', 2),
#  ('приводила себя в порядок', 2),
#  ('он кивнул в ответ', 2),
#  ('о том что ему', 2),
#  ('все хуже и хуже', 2),
#  ('прозвенел звонок на обед', 2),
#  ('едва держась на ногах', 2),
#  ('по противоположной стороне он', 2),
#  ('он не в состоянии', 2),
#  ('и ни о чем', 2),
#  ('и все из за', 2),
#  ('мама окликнул он ее', 2),
#  ('из глаз покатились слезы', 2),
#  ('боль во всем теле', 2),
#  ('было по прежнему пусто', 2),
#  ('чтобы не огорчать мать', 2),
#  ('ничего не ответил и', 2),
#  ('размышляя о чем то', 2),
#  ('она не знает что', 2),
#  ('она склонилась над ним', 2),
#  ('представить себе не мог', 2),
#  ('себе не мог что', 2),
#  ('кто знает может быть', 2),
#  ('не так уж серьезно', 2),
#  ('на этот счет у', 2),
#  ('этот счет у него', 2),
#  ('счет у него не', 2),
#  ('это все равно что', 2),
#  ('за эти два года', 2),
#  ('присела на край кровати', 2),
#  ('но спать не хотелось', 2),
#  ('долго молчал потом вздохнул', 2),
#  ('о чем то своем', 2),
#  ('что ответить и молча', 2),
#  ('он заставил себя улыбнуться', 2),
#  ('болью в сердце смотрел', 2),
#  ('он отвернулся к стене', 2),
#  ('каждый из нас должен', 2),
#  ('еще три тысячи двести', 2),
#  ('три тысячи двести юаней', 2),
#  ('я знаю что ты', 2),
#  ('просто не в силах', 2),
#  ('дойти до такого состояния', 2),
#  ('главный управляющий и управляющий', 2),
#  ('но он счел своим', 2),
#  ('он счел своим долгом', 2),
#  ('я хорошо себя чувствую', 2),
#  ('не думаешь о себе', 2),
#  ('что с тобой испугалась', 2),
#  ('мама иди в убежище', 2),
#  ('он лег на кровать', 2),
#  ('не прошло и нескольких', 2),
#  ('по прежнему спокойно и', 2),
#  ('никому зла почему же', 2),
#  ('вэньсюань в таком случае', 2),
#  ('а то не успеешь', 2),
#  ('на следующий день он', 2),
#  ('витали где то далеко', 2),
#  ('не может быть думал', 2),
#  ('и никак не мог', 2),
#  ('он приговорен к смерти', 2),
#  ('приговорен к смерти и', 2),
#  ('это время вошла шушэн', 2),
#  ('и ушла к себе', 2),
#  ('почему ты все время', 2),
#  ('ко мне хорошо относится', 2),
#  ('во всяком случае лучше', 2),
#  ('он удивленно посмотрел на', 2),
#  ('это я во всем', 2),
#  ('с жалостью смотрела на', 2),
#  ('до самой смерти не', 2),
#  ('мать тут ни при', 2),
#  ('тут ни при чем', 2),
#  ('ты ничего не понимаешь', 2),
#  ('раздался женский голос господин', 2),
#  ('он испуганно взглянул на', 2),
#  ('не знаю что делать', 2),
#  ('до этого не дойдет', 2),
#  ('чему быть того не', 2),
#  ('быть того не миновать', 2),
#  ('вас это не касается', 2),
#  ('как ты да я', 2),
#  ('я не такая как', 2),
#  ('он не знал куда', 2),
#  ('не знал куда идти', 2),
#  ('человек одной ногой уже', 2),
#  ('ничего у меня нет', 2),
#  ('мне теперь все равно', 2),
#  ('не думай обо мне', 2),
#  ('ни одного человека который', 2),
#  ('и сам не знаю', 2),
#  ('дорогу его преследовал голос', 2),
#  ('я умер я мертв', 2),
#  ('что это не туберкулез', 2),
#  ('как бы там ни', 2),
#  ('бы там ни было', 2),
#  ('он лежал на кровати', 2),
#  ('не веришь китайским врачам', 2),
#  ('не сердись на нее', 2),
#  ('взяла его руку в', 2),
#  ('его руку в свою', 2),
#  ('слышно было как крысы', 2),
#  ('почему же я не', 2),
#  ('принести себя в жертву', 2),
#  ('о делах в банке', 2),
#  ('когда я не смогу', 2),
#  ('что у тебя за', 2),
#  ('все наладится ты займешься', 2),
#  ('наладится ты займешься просвещением', 2),
#  ('ты займешься просвещением я', 2),
#  ('займешься просвещением я буду', 2),
#  ('просвещением я буду тебе', 2),
#  ('я буду тебе помогать', 2),
#  ('в комнату вошла мать', 2),
#  ('я все сама сделаю', 2),
#  ('как ты себя чувствуешь', 2),
#  ('надо мне уже лучше', 2),
#  ('как раз в этот', 2),
#  ('на душе у меня', 2),
#  ('с благодарностью взглянул на', 2),
#  ('ничего не ответила и', 2),
#  ('стала смотреть на улицу', 2),
#  ('до чего же она', 2),
#  ('что вы решили делать', 2),
#  ('она не знала на', 2),
#  ('знал что у нее', 2),
#  ('и не подозревал что', 2),
#  ('но как быть с', 2),
#  ('я знаю что не', 2),
#  ('разговор на другую тему', 2),
#  ('а через два дня', 2),
#  ('куда то в пространство', 2),
#  ('шутит она или говорит', 2),
#  ('она или говорит серьезно', 2),
#  ('представить себе не могла', 2),
#  ('себе не могла что', 2),
#  ('ее бросило в жар', 2),
#  ('не знала что сказать', 2),
#  ('что у меня на', 2),
#  ('завтра в восемь утра', 2),
#  ('в том что она', 2),
#  ('сердце не в силах', 2),
#  ('не в силах сопротивляться', 2),
#  ('должна за него бороться', 2),
#  ('жду вас в гуашэнъюане', 2),
#  ('голос его слегка дрожал', 2),
#  ('а обо мне не', 2),
#  ('ты говорила что тебе', 2),
#  ('смотреть ему в глаза', 2),
#  ('в самом деле так', 2),
#  ('ни на что решиться', 2),
#  ('обсуждали положение на фронте', 2),
#  ('поднялась на третий этаж', 2),
#  ('едва войдя в комнату', 2),
#  ('не надо было его', 2),
#  ('никогда о нем не', 2),
#  ('о нем не заботилась', 2),
#  ('только и знаешь что', 2),
#  ('с любовью и жалостью', 2),
#  ('не смел поднять глаза', 2),
#  ('поднял голову лицо его', 2),
#  ('голову лицо его было', 2),
#  ('вэньсюань ничего не ответил', 2),
#  ('он испуганно поднял голову', 2),
#  ('было но тут же', 2),
#  ('но тут же снова', 2),
#  ('он не верил своим', 2),
#  ('не верил своим ушам', 2),
#  ('не предвещало ничего хорошего', 2),
#  ('из за тебя я', 2),
#  ('она заявила что я', 2),
#  ('я тебе не жена', 2),
#  ('кончится война придет победа', 2),
#  ('пока не улучшится обстановка', 2),
#  ('не один год а', 2),
#  ('все из за меня', 2),
#  ('ты ведь не поправился', 2),
#  ('и низко опустив голову', 2),
#  ('следовали один за другим', 2),
#  ('было до него дела', 2),
#  ('и то и дело', 2),
#  ('перед глазами все поплыло', 2),
#  ('уже не слышал его', 2),
#  ('я же просил тебя', 2),
#  ('нельзя же из за', 2),
#  ('же из за денег', 2),
#  ('он уронил голову на', 2),
#  ('уронил голову на стол', 2),
#  ('голову на стол и', 2),
#  ('мать подошла к нему', 2),
#  ('она поднялась и ушла', 2),
#  ('он тупо смотрел на', 2),
#  ('но я не хочу', 2),
#  ('для нас нет места', 2),
#  ('но она даже не', 2),
#  ('меня но я не', 2),
#  ('я не могу расстаться', 2),
#  ('расстаться ни с ней', 2),
#  ('ни с ней ни', 2),
#  ('я не вправе тебя', 2),
#  ('не дает ему отдохнуть', 2),
#  ('знаю что ты не', 2),
#  ('потеряв контроль над собой', 2),
#  ('о нем о его', 2),
#  ('ну и что ж', 2),
#  ('мы больше не будем', 2),
#  ('больше не будем ссориться', 2),
#  ('отнял руки от лица', 2),
#  ('по лицу пробежала судорога', 2),
#  ('он отпил несколько глотков', 2),
#  ('отошла к столу и', 2),
#  ('и все будет в', 2),
#  ('не произнесла ни слова', 2),
#  ('то же время он', 2),
#  ('не пропустить ни единого', 2),
#  ('пропустить ни единого слова', 2),
#  ('него не хватает мужества', 2),
#  ('в комнате не было', 2),
#  ('подошла к кровати и', 2),
#  ('не так уж я', 2),
#  ('у нас с ним', 2),
#  ('о чем то говорили', 2),
#  ('он доживает последние дни', 2),
#  ('коротко ответила мать а', 2),
#  ('с каким то мужчиной', 2),
#  ('с боку на бок', 2),
#  ('комок подступил к горлу', 2),
#  ('посмотрела на него и', 2),
#  ('он смотрел на нее', 2),
#  ('он боролся с собой', 2),
#  ('так и не решился', 2),
#  ('с каждым днем все', 2),
#  ('и если бы не', 2),
#  ('не мог сомкнуть глаз', 2),
#  ('но мог ли он', 2),
#  ('как ушат холодной воды', 2),
#  ('здоровье у меня неважное', 2),
#  ('почему он не может', 2),
#  ('что будет со мной', 2),
#  ('сказать несколько слов на', 2),
#  ('я постараюсь прийти пораньше', 2),
#  ('ему показалось что он', 2),
#  ('но в это время', 2),
#  ('рано или поздно все', 2),
#  ('к смерти и не', 2),
#  ('глаза его были сухими', 2),
#  ('ни о чем думать', 2),
#  ('он не мог оставаться', 2),
#  ('что творится у него', 2),
#  ('творится у него на', 2),
#  ('он был очень взволнован', 2),
#  ('не хотелось ни лежать', 2),
#  ('хотелось ни лежать ни', 2),
#  ('ни лежать ни сидеть', 2),
#  ('он прошелся по комнате', 2),
#  ('мне все это снится', 2),
#  ('в коридоре раздались шаги', 2),
#  ('за то что я', 2),
#  ('он знал что она', 2),
#  ('она о чем то', 2),
#  ('в окно на улицу', 2),
#  ('не знаю но я', 2),
#  ('напишу как только приеду', 2),
#  ('никак не мог уснуть', 2),
#  ('меня ненавидеть береги себя', 2),
#  ('коротко ответил вэньсюань и', 2),
#  ('в прошлом году он', 2),
#  ('потому что знал что', 2),
#  ('к себе а он', 2),
#  ('он никогда не говорил', 2),
#  ('никогда не говорил о', 2),
#  ('справлялась о его здоровье', 2),
#  ('что все это очень', 2),
#  ('и решил больше не', 2),
#  ('пишет о своей жизни', 2),
#  ('но почему ты так', 2),
#  ('он не мог ни', 2),
#  ('с выходом на работу', 2),
#  ('но у меня не', 2),
#  ('кто знает быть может', 2),
#  ('я не могу жить', 2),
#  ('не смог бы ответить', 2),
#  ('я не стою тебя', 2),
#  ('он все равно не', 2),
#  ('так ни о чем', 2),
#  ('спрятал письмо в карман', 2),
#  ('все с тем же', 2),
#  ('но было уже поздно', 2),
#  ('вдруг ему показалось что', 2),
#  ('по прежнему присылала деньги', 2),
#  ('все в порядке с', 2),
#  ('с благодарностью глядя на', 2),
#  ('мать он покачал головой', 2),
#  ('думать об этом но', 2),
#  ('этом но не мог', 2),
#  ('трудится в поте лица', 2),
#  ('и никому не было', 2),
#  ('спешили по своим делам', 2),
#  ('на несколько дней отпуск', 2),
#  ('а про себя подумал', 2),
#  ('он никогда больше не', 2),
#  ('никогда больше не увидит', 2),
#  ('через силу улыбнулся и', 2),
#  ('она подошла к нему', 2),
#  ('что близок конец и', 2),
#  ('сжалось от боли она', 2),
#  ('а я и не', 2),
#  ('я и не боюсь', 2),
#  ('у нас в семье', 2),
#  ('сделал вид что не', 2),
#  ('тот момент когда он', 2),
#  ('не может быть он', 2),
#  ('от этой мысли на', 2),
#  ('этой мысли на душе', 2),
#  ('мысли на душе стало', 2),
#  ('в том что этот', 2),
#  ('он видел перед собой', 2),
#  ('ни днем ни ночью', 2),
#  ('но не успел он', 2),
#  ('и он не мог', 2),
#  ('но так ничего и', 2),
#  ('и на третий день', 2),
#  ('из бумажных цветов с', 2),
#  ('ни во что не', 2),
#  ('все страдания он не', 2),
#  ('не бойся ты не', 2),
#  ('бойся ты не умрешь', 2),
#  ('с каждым днем ухудшалось', 2),
#  ('каждым днем ухудшалось и', 2),
#  ('не вставал с постели', 2),
#  ('что он не в', 2),
#  ('он не в силах', 2),
#  ('кричать он не мог', 2),
#  ('этому никакого значения но', 2),
#  ('как она будет жить', 2),
#  ('все равно никто не', 2),
#  ('можно было подумать что', 2),
#  ('снова напомнила о себе', 2),
#  ('он никак не мог', 2),
#  ('куда они уехали не', 2),
#  ('они уехали не знаю', 2),
#  ('уехали не знаю бабушка', 2),
#  ('в тот день когда', 2),
#  ('тот день когда я', 2),
#  ('за эти несколько месяцев', 2),
#  ('не сводя глаз с', 2),
#  ('казалось что все это', 2),
#  ('у меня есть еще', 2),
#  ('меня есть еще время', 2),
#  ('перевод е рождественской молчановой', 2),
#  ('стоны души в бескрайней', 2),
#  ('души в бескрайней тьме', 2),
#  ('не придал этому значения', 2),
#  ('придал этому значения и', 2),
#  ('этому значения и продолжал', 2),
#  ('было достаточно чтобы понять', 2),
#  ('нибудь и дело с', 2),
#  ('в сердце ли лэна', 2),
#  ('словно пробудившись ото сна', 2),
#  ('стало немного страшно он', 2),
#  ('ли лэн не мог', 2),
#  ('какое то время они', 2),
#  ('то ли из любопытства', 2),
#  ('ли из любопытства то', 2),
#  ('из любопытства то ли', 2),
#  ('его бьют его тащат', 2),
#  ('бьют его тащат бросают', 2),
#  ('его тащат бросают на', 2),
#  ('ему ничего не известно', 2),
#  ('из плоти и крови', 2),
#  ('стал шарить вокруг себя', 2),
#  ('шарить вокруг себя и', 2),
#  ('о чем то болтали', 2),
#  ('спрыгнул с кровати и', 2),
#  ('в ее голосе слышалось', 2),
#  ('судя по всему он', 2),
#  ('прочь я не хочу', 2),
#  ('то же что и', 2),
#  ('он не мог понять', 2),
#  ('идти в семью лай', 2),
#  ('об этом я уже', 2),
#  ('не мог удержаться чтобы', 2),
#  ('мог удержаться чтобы не', 2),
#  ('больше всего на свете', 2),
#  ('его но он не', 2),
#  ('но он не замечал', 2),
#  ('он изо всех сил', 2),
#  ('изо всех сил сопротивляется', 2),
#  ('этого он не мог', 2),
#  ('и он почувствовал что', 2),
#  ('ему показалось что все', 2),
#  ('и он даже не', 2),
#  ('он перестал бывать у', 2),
#  ('а для него она', 2),
#  ('и бросил на него', 2),
#  ('после того как была', 2),
#  ('того как была опубликована', 2),
#  ('не могу не могу', 2),
#  ('он остался таким как', 2),
#  ('я не могу любить', 2),
#  ('не могу любить и', 2),
#  ('то что он говорил', 2),
#  ('но в этот момент', 2),
#  ('приносит себя в жертву', 2),
#  ('с такой силой что', 2),
#  ('оглядываясь по сторонам словно', 2),
#  ('на одной из них', 2),
#  ('ду дасинь и не', 2),
#  ('снова стал смотреть на', 2),
#  ('с ней о том', 2),
#  ('о том о сем', 2),
#  ('ли лэну и его', 2),
#  ('лэну и его сестре', 2),
#  ('готова пожертвовать всем ради', 2),
#  ('она то и дело', 2),
#  ('и было видно что', 2),
#  ('в конце концов она', 2),
#  ('что это ты так', 2),
#  ('о чем ты думаешь', 2),
#  ('не что иное как', 2),
#  ('по телу пробежала дрожь', 2),
#  ('приходил в их дом', 2),
#  ('однажды вечером ду дасинь', 2),
#  ('кивнул в ответ и', 2),
#  ('мне было знать что', 2),
#  ('закончила она с улыбкой', 2),
#  ('я на самом деле', 2),
#  ('я отвечаю что она', 2),
#  ('по крайней мере он', 2),
#  ('больше не могу терпеть', 2),
#  ('не проронил ни слова', 2),
#  ('на нее и в', 2),
#  ('стало казаться что она', 2),
#  ('ду дасинь по прежнему', 2),
#  ('он ничего не сказал', 2),
#  ('в доме своего дяди', 2),
#  ('мне в душу я', 2),
#  ('в конце концов как', 2),
#  ('и я увидел как', 2),
#  ('я буду очень рад', 2),
#  ('изо всех сил старался', 2),
#  ('но не мог удержаться', 2),
#  ('с дядей и тетей', 2),
#  ('с тех пор я', 2),
#  ('что в мире нет', 2),
#  ('я люблю тебя я', 2),
#  ('люблю тебя я скоро', 2),
#  ('тебя я скоро сойду', 2),
#  ('я скоро сойду с', 2),
#  ('скоро сойду с ума', 2),
#  ('сойду с ума от', 2),
#  ('ума от любви я', 2),
#  ('не сводил с нее', 2),
#  ('не чувствовал себя одиноким', 2),
#  ('что у нее есть', 2),
#  ('она так и не', 2),
#  ('то самое время когда', 2),
#  ('мне стало ясно что', 2),
#  ('в то время когда', 2),
#  ('о том что уже', 2),
#  ('по лицу ду дасиня', 2),
#  ('лицу ду дасиня пробежала', 2),
#  ('на лице ду дасиня', 2),
#  ('никто не обратил на', 2),
#  ('но какое отношение это', 2),
#  ('ему казалось что его', 2),
#  ('казалось что его сердце', 2),
#  ('любви к нему она', 2),
#  ('он не должен любить', 2),
#  ('то была ли цзиншу', 2),
#  ('она не находила в', 2),
#  ('глубоко запавших глазах она', 2),
#  ('во всем его облике', 2),
#  ('однажды под вечер ду', 2),
#  ('под вечер ду дасинь', 2),
#  ('господин ду вы еще', 2),
#  ('в том что ты', 2),
#  ('никогда никого не любил', 2),
#  ('лишь для того чтобы', 2),
#  ('тем не менее я', 2),
#  ('не менее я еще', 2),
#  ('я своими глазами видел', 2),
#  ('я не в состоянии', 2),
#  ('не произнося ни слова', 2),
#  ('это действительно может произойти', 2),
#  ('когда подумаю об этом', 2),
#  ('что с этого момента', 2),
#  ('казалось что он не', 2),
#  ('он не может больше', 2),
#  ('они не смогли бы', 2),
#  ('но как бы то', 2),
#  ('он прекрасно понимал что', 2),
#  ('у него на сердце', 2),
#  ('сердце у него было', 2),
#  ('лишь вместе с моей', 2),
#  ('вместе с моей смертью', 2),
#  ('из за меня я', 2),
#  ('я не имею права', 2),
#  ('я должен идти к', 2),
#  ('он не смог бы', 2),
#  ('ду дасинь естественно не', 2),
#  ('и сам ду дасинь', 2),
#  ('на пустынной улице лишь', 2),
#  ('пустынной улице лишь изредка', 2),
#  ('ду дасинь в этот', 2),
#  ('не в этом дело', 2),
#  ('обернулся и увидел что', 2),
#  ('ничего не сказал и', 2),
#  ('еще какое то время', 2),
#  ('и сказал что у', 2),
#  ('и к тому же', 2),
#  ('за того что я', 2),
#  ('был вполне здоров но', 2),
#  ('вернуться к себе в', 2),
#  ('к себе в яншупу', 2),
#  ('день ото дня все', 2),
#  ('о планах на будущее', 2),
#  ('контроль над собой он', 2),
#  ('он несколько раз порывался', 2),
#  ('и о чем то', 2),
#  ('о своей любви и', 2),
#  ('собрал все свое мужество', 2),
#  ('все свое мужество и', 2),
#  ('что в городе шанхае', 2),
#  ('красная опасность распространяется повсюду', 2),
#  ('тем не менее они', 2),
#  ('ты из партии революции', 2),
#  ('чжан сказал ему что', 2),
#  ('а я как раз', 2),
#  ...]

# %%
def ngrams_text (word,num):
    word = word.lower()
    word = re.sub("[!\"#$%&\'—()*+,-»«./:;<=>?@[\\]^_`{|}~]?",'',word)
    #tokens = re.findall ('он\s\w+',word)
    #tokens = [token for token in word.split(" ") if token != ""]
    mystem.lemmatize(word)
    wordsFiltered = []
    for w in word:
        if w not in stopwords:
            wordsFiltered.append(w)
    
    output = list(ngrams(tokens,num))
    mostcommon = Counter(output).most_common()
    return mostcommon
#лемматизировать можно прямо из nltk，lemmatize, а стоп слова также есть в nltk.есть такая тетрадка. 
#чтобы свести все свои документы в один нужно просто конкатенировать все переменны. открывааем и читаем фал, сохраняем в переменную, складываем все переменные.
#append только для списка

# %%
def ngrams_text (word,num):
    word = word.lower()
    word = re.sub("[!\"#$%&\'—()*+,-»«./:;<=>?@[\\]^_`{|}~]?",'',word)
    #tokens = re.findall ('он\s\w+',word)
    #tokens = [token for token in word.split(" ") if token != ""]
    mystem.lemmatize(word)
    wordsFiltered = []
    for w in word:
        if w not in stopwords:
            wordsFiltered.append(w)
    
    output = list(ngrams(tokens,num))
    mostcommon = Counter(output).most_common()
    return mostcommon
#лемматизировать можно прямо из nltk，lemmatize, а стоп слова также есть в nltk.есть такая тетрадка. 
#чтобы свести все свои документы в один нужно просто конкатенировать все переменны. открывааем и читаем фал, сохраняем в переменную, складываем все переменные.
#append только для списка

# %%
def ngrams_text (word,num):
    word = word.lower()
    word = re.sub("[!\"#$%&\'—()*+,-»«./:;<=>?@[\\]^_`{|}~]?",'',word)
    #tokens = re.findall ('он\s\w+',word)
    #tokens = [token for token in word.split(" ") if token != ""]
    mystem.lemmatize(word)
    wordsFiltered = []
    for w in word:
        if w not in stopwords:
            wordsFiltered.append(w)
    
    output = list(ngrams(tokens,num))
    mostcommon = Counter(output).most_common()
    return mostcommon
#лемматизировать можно прямо из nltk，lemmatize, а стоп слова также есть в nltk.есть такая тетрадка. 
#чтобы свести все свои документы в один нужно просто конкатенировать все переменны. открывааем и читаем фал, сохраняем в переменную, складываем все переменные.
#append только для списка

# %%
ngrams_text("любовь",3)
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-22-120f9802b2fd> in <module>
# ----> 1 ngrams_text("любовь",3)
#
# <ipython-input-5-5e497a6001b9> in ngrams_text(word, num)
#       4     #tokens = re.findall ('он\s\w+',word)
#       5     #tokens = [token for token in word.split(" ") if token != ""]
# ----> 6     mystem.lemmatize(word)
#       7     wordsFiltered = []
#       8     for w in word:
#
# c:\users\sidor\appdata\local\programs\python\python37\lib\site-packages\pymystem3\mystem.py in lemmatize(self, text)
#     263         need_encode = (sys.version_info[0] < 3 and isinstance(text, str))
#     264
# --> 265         infos = self.analyze(text)
#     266         lemmas = list(filter(None, map(self._get_lemma, infos)))
#     267
#
# c:\users\sidor\appdata\local\programs\python\python37\lib\site-packages\pymystem3\mystem.py in analyze(self, text)
#     248         result = []
#     249         for line in text.splitlines():
# --> 250             result.extend(self._analyze_impl(line))
#     251         return result
#     252
#
# c:\users\sidor\appdata\local\programs\python\python37\lib\site-packages\pymystem3\mystem.py in _analyze_impl(self, text)
#     308                 self._start_mystem()
#     309
# --> 310             self._procin.write(text)
#     311             self._procin.write(_NL)
#     312
#
# ValueError: I/O operation on closed file

# %%
from nltk.util import ngrams

# %%
ngrams_text(tom6,3)
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-15-f6c145f82854> in <module>
# ----> 1 ngrams_text(tom6,3)
#
# <ipython-input-5-5e497a6001b9> in ngrams_text(word, num)
#       4     #tokens = re.findall ('он\s\w+',word)
#       5     #tokens = [token for token in word.split(" ") if token != ""]
# ----> 6     mystem.lemmatize(word)
#       7     wordsFiltered = []
#       8     for w in word:
#
# c:\users\sidor\appdata\local\programs\python\python37\lib\site-packages\pymystem3\mystem.py in lemmatize(self, text)
#     263         need_encode = (sys.version_info[0] < 3 and isinstance(text, str))
#     264
# --> 265         infos = self.analyze(text)
#     266         lemmas = list(filter(None, map(self._get_lemma, infos)))
#     267
#
# c:\users\sidor\appdata\local\programs\python\python37\lib\site-packages\pymystem3\mystem.py in analyze(self, text)
#     248         result = []
#     249         for line in text.splitlines():
# --> 250             result.extend(self._analyze_impl(line))
#     251         return result
#     252
#
# c:\users\sidor\appdata\local\programs\python\python37\lib\site-packages\pymystem3\mystem.py in _analyze_impl(self, text)
#     308                 self._start_mystem()
#     309
# --> 310             self._procin.write(text)
#     311             self._procin.write(_NL)
#     312
#
# ValueError: I/O operation on closed file
