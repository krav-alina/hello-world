# %%
with open ('Цзинь Ба. Избранное  - royallib.com.txt') as file1:
    bajin3 = file1.read()

# %%
from sklearn.feature_extraction.text import CountVectorizer
import nltk
from collections import Counter
import re
import os

# %%
from nltk.corpus import stopwords
from nltk.tokenize import word_tokenize
import nltk
nltk.download('punkt')
# Out:
# [nltk_data] Downloading package punkt to
# [nltk_data]     C:\Users\sidor\AppData\Roaming\nltk_data...
# [nltk_data]   Package punkt is already up-to-date!
# True

# %%
import nltk
nltk.download('stopwords')
# Out:
# [nltk_data] Downloading package stopwords to
# [nltk_data]     C:\Users\sidor\AppData\Roaming\nltk_data...
# [nltk_data]   Package stopwords is already up-to-date!
# True

# %%
from pymystem3 import Mystem

# %%
mystem = Mystem()

# %% [markdown]
# def normalized_text (word):
#     word = word.lower()
#     word = re.sub("[!\"#$%&\'—()*+,-»«./:;<=>?@[\\]^_`{|}~]?",'',word)
#     word = " ".join([word for word in word.split() if word not in(stopwords.words('russian'))])
#     word = word.split()
#     output = len(word)
#     return output

# %% [markdown]
# #filtered_words = [Word for Word in tom6 if Word not in stopwords.words('russian')]
# #text = 'здравствуй дорогой читатель сегодня очень ветренно поэтому я и он не пошли гулять хотя очень хотелось'
# #text = ' '.join([word for word in text.split() if word not in (stopwords.words('russian'))])
# #tom = " ".join([word for word in tom.split() if word not in(stopwords.words('russian'))])

# %%
bajin3 = bajin3.lower()
bajin3 = re.sub("[!\"#$%&\'—()*+,-»«./:;<=>?@[\\]^_`{|}~]?",'',bajin3)
bajin3 = " ".join([word for word in bajin3.split() if word not in(stopwords.words('russian'))])

# %%
bigram_vectorizer = CountVectorizer(ngram_range=(2,2),
                                    token_pattern=r'[А-Яа-я]+', min_df=2)

# %%
analyze = bigram_vectorizer.build_analyzer()

# %%
z = analyze(bajin3)

# %%
Counter(z).most_common()
# Out:
# [('чэнь чжэнь', 115),
#  ('ду дасинь', 105),
#  ('сяо шань', 72),
#  ('ду дасиня', 55),
#  ('самом деле', 49),
#  ('друг друга', 48),
#  ('лао шэ', 44),
#  ('это время', 39),
#  ('чжан вэйцюня', 36),
#  ('чэнь чжэня', 36),
#  ('некоторое время', 35),
#  ('несколько дней', 34),
#  ('господин ду', 29),
#  ('конце концов', 28),
#  ('сих пор', 27),
#  ('культурной революции', 26),
#  ('покачал головой', 24),
#  ('обо всем', 24),
#  ('юань жуньшэнь', 24),
#  ('господин чэнь', 22),
#  ('молодой человек', 21),
#  ('несколько лет', 21),
#  ('десять лет', 21),
#  ('тех пор', 19),
#  ('чжан вэйцюнь', 19),
#  ('закрыл глаза', 18),
#  ('каждый день', 18),
#  ('лет назад', 18),
#  ('таком случае', 17),
#  ('крайней мере', 17),
#  ('поднял голову', 17),
#  ('целыми днями', 17),
#  ('чэнь чжэню', 17),
#  ('несколько слов', 16),
#  ('сяо чэнь', 16),
#  ('последнее время', 15),
#  ('ду дасиню', 15),
#  ('опустив голову', 14),
#  ('друг другу', 14),
#  ('опустил голову', 14),
#  ('ответил вэньсюань', 14),
#  ('несколько месяцев', 14),
#  ('следующий день', 14),
#  ('время времени', 14),
#  ('критики борьбы', 14),
#  ('союза писателей', 14),
#  ('госпожа чжан', 13),
#  ('изо сил', 13),
#  ('покачала головой', 12),
#  ('сказала шушэн', 12),
#  ('госпожа ван', 12),
#  ('господин ван', 12),
#  ('каждым днем', 12),
#  ('какоето время', 12),
#  ('старший брат', 12),
#  ('мисс чжан', 12),
#  ('маленький ван', 12),
#  ('перевод тникитиной', 12),
#  ('подумал вэньсюань', 11),
#  ('выражение лица', 11),
#  ('подняла голову', 11),
#  ('начальник отдела', 11),
#  ('ответила мать', 11),
#  ('время болезни', 11),
#  ('своей любви', 11),
#  ('молодые люди', 11),
#  ('фэн лю', 11),
#  ('сей день', 11),
#  ('весь день', 10),
#  ('бросил взгляд', 10),
#  ('сказала мать', 10),
#  ('твоя мать', 10),
#  ('открыл глаза', 10),
#  ('худое лицо', 10),
#  ('день ото', 10),
#  ('ото дня', 10),
#  ('долго молчал', 10),
#  ('четыре года', 10),
#  ('никак мог', 10),
#  ('своей жизни', 10),
#  ('госпожа фан', 10),
#  ('ван бинцзюнь', 10),
#  ('старый чжан', 10),
#  ('цзян цин', 10),
#  ('перевод тсорокиной', 10),
#  ('несколько минут', 9),
#  ('эта мысль', 9),
#  ('средних лет', 9),
#  ('следующее утро', 9),
#  ('тому назад', 9),
#  ('года назад', 9),
#  ('всеми силами', 9),
#  ('свои мысли', 9),
#  ('лишь изредка', 9),
#  ('это очень', 9),
#  ('молодого человека', 9),
#  ('гао хунфа', 9),
#  ('двадцать лет', 9),
#  ('красноносый чэньсань', 9),
#  ('министры генералы', 9),
#  ('культурная революция', 9),
#  ('очень хотелось', 8),
#  ('спросила мать', 8),
#  ('всем виноват', 8),
#  ('душе стало', 8),
#  ('последние годы', 8),
#  ('голос дрожал', 8),
#  ('это сон', 8),
#  ('таких людей', 8),
#  ('последние дни', 8),
#  ('день рождения', 8),
#  ('перевел взгляд', 8),
#  ('поднялся наверх', 8),
#  ('всяком случае', 8),
#  ('стиснув зубы', 8),
#  ('принял решение', 8),
#  ('господин чжоу', 8),
#  ('моей жизни', 8),
#  ('вернулся домой', 8),
#  ('мое сердце', 8),
#  ('пожертвовать всем', 8),
#  ('ду дасинем', 8),
#  ('любовь ненависть', 8),
#  ('чжу лэу', 8),
#  ('возвращение земле', 8),
#  ('прошло года', 8),
#  ('дедушка чжан', 8),
#  ('отделения союза', 8),
#  ('шевелить мозгами', 8),
#  ('третий этаж', 7),
#  ('шесть лет', 7),
#  ('тихо сказала', 7),
#  ('чтото сказать', 7),
#  ('тебе трудно', 7),
#  ('каждое слово', 7),
#  ('едва слышно', 7),
#  ('сердце учащенно', 7),
#  ('лист бумаги', 7),
#  ('сердце сжалось', 7),
#  ('постарайся уснуть', 7),
#  ('проговорила мать', 7),
#  ('это сделать', 7),
#  ('понял это', 7),
#  ('мать ушла', 7),
#  ('ответила шушэн', 7),
#  ('одного человека', 7),
#  ('несколько глотков', 7),
#  ('две недели', 7),
#  ('подумала шушэн', 7),
#  ('это невозможно', 7),
#  ('это слово', 7),
#  ('это лишь', 7),
#  ('тебе нужно', 7),
#  ('хотел сказать', 7),
#  ('прошлом году', 7),
#  ('очень скоро', 7),
#  ('произнести слова', 7),
#  ('такие люди', 7),
#  ('однажды вечером', 7),
#  ('мог понять', 7),
#  ('люди которые', 7),
#  ('сделать это', 7),
#  ('глубокой ночью', 7),
#  ('конечном счете', 7),
#  ('подняв голову', 7),
#  ('старшего брата', 7),
#  ('шестнадцать рабов', 7),
#  ('сын господина', 7),
#  ('идти вперед', 7),
#  ('вдова чжао', 7),
#  ('ван красноносый', 7),
#  ('сунь эрсао', 7),
#  ('десяти лет', 7),
#  ('проговорил делакруа', 7),
#  ('пять лет', 7),
#  ('седьмого мая', 7),
#  ('время культурной', 7),
#  ('одним словом', 7),
#  ('несколько шагов', 6),
#  ('стало легче', 6),
#  ('никому дела', 6),
#  ('голову взглянул', 6),
#  ('господин чжан', 6),
#  ('посмотрел мать', 6),
#  ('мать молча', 6),
#  ('похлопал плечу', 6),
#  ('проговорил вэньсюань', 6),
#  ('свое мужество', 6),
#  ('несколько часов', 6),
#  ('бросила мать', 6),
#  ('сказать правду', 6),
#  ('столько времени', 6),
#  ('сказал самому', 6),
#  ('каждый вечер', 6),
#  ('лицо руками', 6),
#  ('остается лишь', 6),
#  ('глаз полились', 6),
#  ('полились слезы', 6),
#  ('бросила взгляд', 6),
#  ('шушэн мать', 6),
#  ('такое время', 6),
#  ('управляющий чжоу', 6),
#  ('сжалось боли', 6),
#  ('скоро придет', 6),
#  ('наша контора', 6),
#  ('рано поздно', 6),
#  ('думал вэньсюань', 6),
#  ('знакомый голос', 6),
#  ('человека который', 6),
#  ('лицо мужа', 6),
#  ('стала смотреть', 6),
#  ('вошла мать', 6),
#  ('это правда', 6),
#  ('спросил вэньсюань', 6),
#  ('молодая женщина', 6),
#  ('голос звучал', 6),
#  ('сквозь слезы', 6),
#  ('снова стал', 6),
#  ('вечерней газете', 6),
#  ('дать возможность', 6),
#  ('каждый месяц', 6),
#  ('это страшно', 6),
#  ('мать сын', 6),
#  ('среднюю школу', 6),
#  ('знаю это', 6),
#  ('сердце мое', 6),
#  ('мои слова', 6),
#  ('мог думать', 6),
#  ('советую тебе', 6),
#  ('человек который', 6),
#  ('хочу жить', 6),
#  ('командующего гарнизоном', 6),
#  ('моей душе', 6),
#  ('приходилось слышать', 6),
#  ('стал смотреть', 6),
#  ('средней школы', 6),
#  ('последние слова', 6),
#  ('юань жуньшэня', 6),
#  ('долго мог', 6),
#  ('это имеет', 6),
#  ('коем случае', 6),
#  ('чжоу байшунь', 6),
#  ('мог сказать', 6),
#  ('будут жить', 6),
#  ('чжоу жушуй', 6),
#  ('такие минуты', 6),
#  ('движение мая', 6),
#  ('честно говоря', 6),
#  ('моем сердце', 6),
#  ('сто пятьдесят', 6),
#  ('пятьдесят долларов', 6),
#  ('плотник асы', 6),
#  ('кузнец фэн', 6),
#  ('те годы', 6),
#  ('раб душой', 6),
#  ('мин фэн', 6),
#  ('десятков лет', 6),
#  ('сорок пять', 6),
#  ('таким образом', 5),
#  ('мать жена', 5),
#  ('мог найти', 5),
#  ('прийти пораньше', 5),
#  ('плетеное кресло', 5),
#  ('мужчина женщина', 5),
#  ('мысли путались', 5),
#  ('глядя сына', 5),
#  ('ото сна', 5),
#  ('это письмо', 5),
#  ('имел виду', 5),
#  ('старина ван', 5),
#  ('силу улыбнулся', 5),
#  ('сказал чжун', 5),
#  ('улыбнулся чжун', 5),
#  ('хотел чтото', 5),
#  ('произнес слова', 5),
#  ('ко всему', 5),
#  ('едва сдерживая', 5),
#  ('мать шушэн', 5),
#  ('это слишком', 5),
#  ('свое решение', 5),
#  ('глазах стояли', 5),
#  ('стояли слезы', 5),
#  ('учащенно забилось', 5),
#  ('одно время', 5),
#  ('закрыл лицо', 5),
#  ('вышла комнаты', 5),
#  ('выбрось головы', 5),
#  ('говорила шушэн', 5),
#  ('кивнул ответ', 5),
#  ('превозмогая боль', 5),
#  ('вэньсюань ответил', 5),
#  ('главный управляющий', 5),
#  ('ласково говорила', 5),
#  ('другим тоном', 5),
#  ('шушэн это', 5),
#  ('шли молча', 5),
#  ('тихо ответил', 5),
#  ('своем здоровье', 5),
#  ('правде говоря', 5),
#  ('слова матери', 5),
#  ('прошелся комнате', 5),
#  ('это касается', 5),
#  ('твоя жена', 5),
#  ('стоял своем', 5),
#  ('несколько человек', 5),
#  ('страшный сон', 5),
#  ('своей комнаты', 5),
#  ('хватало сил', 5),
#  ('должен говорить', 5),
#  ('сдерживая слезы', 5),
#  ('старая женщина', 5),
#  ('принести жертву', 5),
#  ('дней назад', 5),
#  ('буду тебе', 5),
#  ('управляющий чэнь', 5),
#  ('подошла окну', 5),
#  ('втором этаже', 5),
#  ('последние силы', 5),
#  ('могло случиться', 5),
#  ('твоей матери', 5),
#  ('немного денег', 5),
#  ('подошла нему', 5),
#  ('произнес вэньсюань', 5),
#  ('подошла кровати', 5),
#  ('бедный мальчик', 5),
#  ('тихо заплакал', 5),
#  ('осталось следа', 5),
#  ('господин чжун', 5),
#  ('боль груди', 5),
#  ('очень занята', 5),
#  ('коротко ответил', 5),
#  ('лишь несколько', 5),
#  ('хороший человек', 5),
#  ('разные люди', 5),
#  ('весь мир', 5),
#  ('лишь одно', 5),
#  ('стало казаться', 5),
#  ('затем снова', 5),
#  ('двоюродная сестра', 5),
#  ('могу любить', 5),
#  ('правую руку', 5),
#  ('это случилось', 5),
#  ('впереди ждет', 5),
#  ('точки зрения', 5),
#  ('могу забыть', 5),
#  ('наш дом', 5),
#  ('пять дней', 5),
#  ('обратном пути', 5),
#  ('дасинь цзиншу', 5),
#  ('люди должны', 5),
#  ('очень просто', 5),
#  ('длинными ресницами', 5),
#  ('человек это', 5),
#  ('это действительно', 5),
#  ('столько лет', 5),
#  ('голод холод', 5),
#  ('почему это', 5),
#  ('именно поэтому', 5),
#  ('этих словах', 5),
#  ('те времена', 5),
#  ('партия красных', 5),
#  ('старый чэнь', 5),
#  ('вымолвить слова', 5),
#  ('мог ответить', 5),
#  ('свой долг', 5),
#  ('друг другом', 5),
#  ('улыбаясь сказал', 5),
#  ('жизни человека', 5),
#  ('люди шли', 5),
#  ('жушуй жолань', 5),
#  ('ответил жушуй', 5),
#  ('жолань жушуй', 5),
#  ('свое время', 5),
#  ('день утром', 5),
#  ('семь лет', 5),
#  ('стать чиновником', 5),
#  ('мисс цинь', 5),
#  ('мужчины дрянь', 5),
#  ('целый день', 5),
#  ('мог подумать', 5),
#  ('мои предки', 5),
#  ('моего отца', 5),
#  ('спас жизнь', 5),
#  ('перевод бмудрова', 5),
#  ('минской эпохи', 5),
#  ('мои мысли', 5),
#  ('это конец', 5),
#  ('часто приходилось', 5),
#  ('эликсир долголетия', 5),
#  ('года перевод', 5),
#  ('медными пряжками', 5),
#  ('отделении союза', 5),
#  ('отделение союза', 5),
#  ('ба цзиня', 5),
#  ('многих лет', 5),
#  ('плохой человек', 5),
#  ('несколько десятков', 5),
#  ('критике борьбе', 5),
#  ('лу сине', 5),
#  ('выкупом невесты', 5),
#  ('глаза снова', 4),
#  ('обернулся увидел', 4),
#  ('часов вечера', 4),
#  ('какойто человек', 4),
#  ('горел свет', 4),
#  ('задавал вопрос', 4),
#  ('второй день', 4),
#  ('рано утром', 4),
#  ('должна вернуться', 4),
#  ('это равно', 4),
#  ('сердце взволнованно', 4),
#  ('тупо глядя', 4),
#  ('жена сын', 4),
#  ('своей дорогой', 4),
#  ('сказал правду', 4),
#  ('половиной года', 4),
#  ('часы пробили', 4),
#  ('рабочего дня', 4),
#  ('ждать пока', 4),
#  ('старина чжун', 4),
#  ('сел стол', 4),
#  ('это самое', 4),
#  ('стало легко', 4),
#  ('покачав головой', 4),
#  ('сказал лишь', 4),
#  ('две чашки', 4),
#  ('чашки кофе', 4),
#  ('официант принес', 4),
#  ('утра вечера', 4),
#  ('холодной воды', 4),
#  ('голосе слышалось', 4),
#  ('руками голову', 4),
#  ('тридцать четыре', 4),
#  ('сел столу', 4),
#  ('сразу понял', 4),
#  ('хватило мужества', 4),
#  ('вышла замуж', 4),
#  ('это говорит', 4),
#  ('мать вздохнула', 4),
#  ('подошел столу', 4),
#  ('средней школе', 4),
#  ('сказал вэньсюань', 4),
#  ('отпил глоток', 4),
#  ('щеки ввалились', 4),
#  ('такого состояния', 4),
#  ('молодой женщины', 4),
#  ('тихо сказал', 4),
#  ('сказал это', 4),
#  ('никто знает', 4),
#  ('врач сказал', 4),
#  ('слез глаза', 4),
#  ('голова кружилась', 4),
#  ('взяла руку', 4),
#  ('крепко сжал', 4),
#  ('сжал руку', 4),
#  ('тихим голосом', 4),
#  ('это шушэн', 4),
#  ('японцы захватили', 4),
#  ('тихо проговорил', 4),
#  ('голова горела', 4),
#  ('болью сердце', 4),
#  ('мать очень', 4),
#  ('глаз покатились', 4),
#  ('мать это', 4),
#  ('смотрел мать', 4),
#  ('всем теле', 4),
#  ('постели мать', 4),
#  ('дверь постучали', 4),
#  ('мать подошла', 4),
#  ('лицо шушэн', 4),
#  ('опустила голову', 4),
#  ('сладкий напиток', 4),
#  ('зажгла свет', 4),
#  ('подошла постели', 4),
#  ('знал ответить', 4),
#  ('ко относится', 4),
#  ('голос дрогнул', 4),
#  ('каждый должен', 4),
#  ('никто знал', 4),
#  ('мою жизнь', 4),
#  ('часто говорил', 4),
#  ('вэньсюань знал', 4),
#  ('десять часов', 4),
#  ('очень устал', 4),
#  ('дожидаясь ответа', 4),
#  ('раздались шаги', 4),
#  ('вэньсюань сидел', 4),
#  ('умру это', 4),
#  ('пошел домой', 4),
#  ('время вошла', 4),
#  ('комнату шушэн', 4),
#  ('произнесла шушэн', 4),
#  ('часто думал', 4),
#  ('лицу пробежала', 4),
#  ('самой смерти', 4),
#  ('мать старая', 4),
#  ('женский голос', 4),
#  ('проговорила шушэн', 4),
#  ('тому времени', 4),
#  ('должен жить', 4),
#  ('мать вэньсюань', 4),
#  ('отпил несколько', 4),
#  ('дватри года', 4),
#  ('шушэн взглянула', 4),
#  ('комнату вошла', 4),
#  ('могу уехать', 4),
#  ('проговорила жена', 4),
#  ('вмешалась разговор', 4),
#  ('разговор мать', 4),
#  ('спасибо тебе', 4),
#  ('этих слов', 4),
#  ('прожить жизнь', 4),
#  ('стараясь скрыть', 4),
#  ('действительно очень', 4),
#  ('тишина покой', 4),
#  ('полные слез', 4),
#  ('коротко ответила', 4),
#  ('восемь утра', 4),
#  ('слегка дрожал', 4),
#  ('угрызения совести', 4),
#  ('смотреть глаза', 4),
#  ('спросила шушэн', 4),
#  ('свои чувства', 4),
#  ('выход положения', 4),
#  ('почему должна', 4),
#  ('глаза навернулись', 4),
#  ('навернулись слезы', 4),
#  ('это значит', 4),
#  ('терпеть любые', 4),
#  ('молча смотрел', 4),
#  ('слабым голосом', 4),
#  ('пробежала судорога', 4),
#  ('послышались шаги', 4),
#  ('усмехнулся вэньсюань', 4),
#  ('хватает мужества', 4),
#  ('своего рода', 4),
#  ('закрытыми глазами', 4),
#  ('десять тысяч', 4),
#  ('разрешение выезд', 4),
#  ('очень трудно', 4),
#  ('обращал внимания', 4),
#  ('опустилась кресло', 4),
#  ('которую читал', 4),
#  ('какойто голос', 4),
#  ('свое место', 4),
#  ('спинку кресла', 4),
#  ('боролся собой', 4),
#  ('мог жить', 4),
#  ('довольная улыбка', 4),
#  ('своими мыслями', 4),
#  ('уронив голову', 4),
#  ('мог дать', 4),
#  ('дожидаясь пока', 4),
#  ('очень взволнован', 4),
#  ('мать взяла', 4),
#  ('это вовсе', 4),
#  ('тихо проговорила', 4),
#  ('мог уснуть', 4),
#  ('первое время', 4),
#  ('тему разговора', 4),
#  ('глаза стали', 4),
#  ('голос становился', 4),
#  ('какоето странное', 4),
#  ('могу жить', 4),
#  ('немного успокоился', 4),
#  ('покончил собой', 4),
#  ('сводил глаз', 4),
#  ('япония капитулировала', 4),
#  ('немного времени', 4),
#  ('оставалось лишь', 4),
#  ('слишком поздно', 4),
#  ('триумф сатаны', 4),
#  ('открытыми глазами', 4),
#  ('судя всему', 4),
#  ('стук дверь', 4),
#  ('осенние воды', 4),
#  ('это происходило', 4),
#  ('свое счастье', 4),
#  ('свое сердце', 4),
#  ('мог удержаться', 4),
#  ('донесся голос', 4),
#  ('вместе матерью', 4),
#  ('младший брат', 4),
#  ('остались лишь', 4),
#  ('цзиншу словно', 4),
#  ('доброе лицо', 4),
#  ('людей это', 4),
#  ('чэнь бинбо', 4),
#  ('чжэн яньхуа', 4),
#  ('линь цююэ', 4),
#  ('этому поводу', 4),
#  ('мои хозяйки', 4),
#  ('мог заснуть', 4),
#  ('хозяйская дочь', 4),
#  ('любовь это', 4),
#  ('лицо просветлело', 4),
#  ('самое время', 4),
#  ('стало ясно', 4),
#  ('сошел ума', 4),
#  ('казалось ктото', 4),
#  ('еле слышно', 4),
#  ('обратил внимания', 4),
#  ('какое отношение', 4),
#  ('должен любить', 4),
#  ('такого человека', 4),
#  ('нашей семьи', 4),
#  ('сердце стало', 4),
#  ('стал рабом', 4),
#  ('отец мать', 4),
#  ('это человек', 4),
#  ('обращая внимания', 4),
#  ('взад вперед', 4),
#  ('простой люд', 4),
#  ('ши байгао', 4),
#  ('мог вымолвить', 4),
#  ('имеет значения', 4),
#  ('речь идет', 4),
#  ('должен сказать', 4),
#  ('силами старался', 4),
#  ('дни ночи', 4),
#  ('жить вместе', 4),
#  ('промолвил жушуй', 4),
#  ('ясные глаза', 4),
#  ('собравшись духом', 4),
#  ('занималась заря', 4),
#  ('произнес жушуй', 4),
#  ('возвращении земле', 4),
#  ('жушуй знал', 4),
#  ('китае г', 4),
#  ('нелюбимая жена', 4),
#  ('двух лет', 4),
#  ('всем этим', 4),
#  ('жэньминь жушуй', 4),
#  ('сказал чэнь', 4),
#  ('рассмеялся чэнь', 4),
#  ('считал это', 4),
#  ('покладая рук', 4),
#  ('понял чэнь', 4),
#  ('чэнь чжэнем', 4),
#  ('спросил жушуй', 4),
#  ('наклонив голову', 4),
#  ('ответил чэнь', 4),
#  ('предки рабами', 4),
#  ('моего деда', 4),
#  ('год перевод', 4),
#  ('долларов пособия', 4),
#  ('пошли быстрее', 4),
#  ('китайский народ', 4),
#  ('моими глазами', 4),
#  ('наш государь', 4),
#  ('министров генералов', 4),
#  ('марсельские ночи', 4),
#  ('проговорил приятель', 4),
#  ('передо мной', 4),
#  ('ради жизни', 4),
#  ('свои силы', 4),
#  ('общественной безопасности', 4),
#  ('линь бяо', 4),
#  ('короче говоря', 4),
#  ('ремнями медными', 4),
#  ('тяжелые времена', 4),
#  ('школу кадров', 4),
#  ('течение многих', 4),
#  ('реакционного авторитета', 4),
#  ('старого общества', 4),
#  ('хай жуя', 4),
#  ('собрании критики', 4),
#  ('прочел эссе', 4),
#  ('собрания народных', 4),
#  ('народных представителей', 4),
#  ('люблю нашу', 4),
#  ('нашу родину', 4),
#  ('родину любит', 4),
#  ('великой культурной', 4),
#  ('чжао дань', 4),
#  ('собственных мыслей', 4),
#  ('лу синь', 4),
#  ('моих друзей', 4),
#  ('лишним лет', 4),
#  ('лао чжоу', 4),
#  ('больничной койке', 4),
#  ('великая культурная', 4),
#  ('такоето число', 4),
#  ('свободе творчества', 4),
#  ('базовых школ', 4),
#  ('базовую школу', 4),
#  ('китайскую культуру', 4),
#  ('ба цзинь', 3),
#  ('гул самолетов', 3),
#  ('ночь выдалась', 3),
#  ('весь город', 3),
#  ('словно нарочно', 3),
#  ('вчера вечером', 3),
#  ('вместе всеми', 3),
#  ('одной женщины', 3),
#  ('письмо несколько', 3),
#  ('словом обмолвился', 3),
#  ('день снова', 3),
#  ('снова снова', 3),
#  ('найти ответа', 3),
#  ('пронеслось голове', 3),
#  ('словно очнулся', 3),
#  ('иду домой', 3),
#  ('шушэн вернется', 3),
#  ('сердца отлегло', 3),
#  ('мог заметить', 3),
#  ('ту сторону', 3),
#  ('зажегся свет', 3),
#  ('парадная дверь', 3),
#  ('второго этажа', 3),
#  ('поднялся третий', 3),
#  ('дверь комнаты', 3),
#  ('здоровьем неважно', 3),
#  ('взволнованно билось', 3),
#  ('это мужчина', 3),
#  ('мог сделать', 3),
#  ('голову увидел', 3),
#  ('мать мама', 3),
#  ('тихо спросила', 3),
#  ('жалостью глядя', 3),
#  ('мужем женой', 3),
#  ('поднимая головы', 3),
#  ('полном изнеможении', 3),
#  ('могу бросить', 3),
#  ('каждом шагу', 3),
#  ('тебе жизнь', 3),
#  ('стороны сторону', 3),
#  ('попросить прощения', 3),
#  ('плохо выглядишь', 3),
#  ('года это', 3),
#  ('взгляд вэньсюань', 3),
#  ('одного слова', 3),
#  ('отчетливо слышал', 3),
#  ('листы корректуры', 3),
#  ('прозвенел звонок', 3),
#  ('чтото ответ', 3),
#  ('преследовала мысль', 3),
#  ('увидел это', 3),
#  ('лет тридцати', 3),
#  ('пошел следом', 3),
#  ('чтото сказал', 3),
#  ('бьющимся сердцем', 3),
#  ('глазами стояла', 3),
#  ('ушах звучал', 3),
#  ('звонкий смех', 3),
#  ('убитый горем', 3),
#  ('иди домой', 3),
#  ('вмешался разговор', 3),
#  ('относились нему', 3),
#  ('печально проговорил', 3),
#  ('тебе стоит', 3),
#  ('махнул рукой', 3),
#  ('ван вэньсюань', 3),
#  ('перерыв кончился', 3),
#  ('постоял несколько', 3),
#  ('собрав свое', 3),
#  ('дрожащим голосом', 3),
#  ('нужно поговорить', 3),
#  ('смотрел вслед', 3),
#  ('огромным трудом', 3),
#  ('заботливо спросил', 3),
#  ('подошел официант', 3),
#  ('трудно представить', 3),
#  ('глубины души', 3),
#  ('вместе мной', 3),
#  ('такая жизнь', 3),
#  ('смысл жить', 3),
#  ('это невыносимо', 3),
#  ('мать тобой', 3),
#  ('решительно заявила', 3),
#  ('печально произнес', 3),
#  ('направилась выходу', 3),
#  ('задал вопрос', 3),
#  ('имею виду', 3),
#  ('домой дом', 3),
#  ('полоска света', 3),
#  ('это сказала', 3),
#  ('мать поставила', 3),
#  ('низко опустив', 3),
#  ('тревогой смотрела', 3),
#  ('эта женщина', 3),
#  ('холодно бросила', 3),
#  ('тридцати лет', 3),
#  ('казалось слышал', 3),
#  ('мать снова', 3),
#  ('говорила мать', 3),
#  ('едва держался', 3),
#  ('держался ногах', 3),
#  ('села столу', 3),
#  ('пламя свечи', 3),
#  ('голову взглянула', 3),
#  ('тысяч юаней', 3),
#  ('направился двери', 3),
#  ('несколькими словами', 3),
#  ('прошел мимо', 3),
#  ('грустно улыбнулся', 3),
#  ('улыбнулся вэньсюань', 3),
#  ('лет десять', 3),
#  ('самое страшное', 3),
#  ('год назад', 3),
#  ('сказал боцин', 3),
#  ('холодно ответил', 3),
#  ('вэньсюань вздохнул', 3),
#  ('мог оставаться', 3),
#  ('третий день', 3),
#  ('дома улице', 3),
#  ('это голос', 3),
#  ('лицо боцина', 3),
#  ('лицо горело', 3),
#  ('луч света', 3),
#  ('ноги слушались', 3),
#  ('начался приступ', 3),
#  ('тебе плохо', 3),
#  ('входной двери', 3),
#  ('прижалась нему', 3),
#  ('тихо ответила', 3),
#  ('чтото пробормотал', 3),
#  ('лишь опустил', 3),
#  ('ответила жена', 3),
#  ('мать говорила', 3),
#  ('кончится война', 3),
#  ('голосе звучали', 3),
#  ('удивленно спросила', 3),
#  ('мать увидела', 3),
#  ('говорить спокойно', 3),
#  ('снова принялась', 3),
#  ('мать бросила', 3),
#  ('укрыла одеялом', 3),
#  ('письменного стола', 3),
#  ('около двух', 3),
#  ('такого случая', 3),
#  ('погода стояла', 3),
#  ('моросил дождь', 3),
#  ('потемнело глазах', 3),
#  ('окинул взглядом', 3),
#  ('своему рабочему', 3),
#  ('рабочему месту', 3),
#  ('звонок обед', 3),
#  ('испуганно поднял', 3),
#  ('изза стола', 3),
#  ('выйдя улицу', 3),
#  ('дело останавливался', 3),
#  ('кафе международное', 3),
#  ('гдето рядом', 3),
#  ('снова перевел', 3),
#  ('делая вид', 3),
#  ('украдкой наблюдал', 3),
#  ('сама сделаю', 3),
#  ('покатились слезы', 3),
#  ('нечего бояться', 3),
#  ('слова сына', 3),
#  ('улыбнулся сказал', 3),
#  ('последнюю фразу', 3),
#  ('лицо матери', 3),
#  ('подняться постели', 3),
#  ('мать принесла', 3),
#  ('посреди комнаты', 3),
#  ('зная делать', 3),
#  ('тринадцать лет', 3),
#  ('очень прошу', 3),
#  ('какое дело', 3),
#  ('глазами стояло', 3),
#  ('будем когданибудь', 3),
#  ('подступил горлу', 3),
#  ('войне конец', 3),
#  ('тебе сказал', 3),
#  ('хунань гуанси', 3),
#  ('словно желая', 3),
#  ('край кровати', 3),
#  ('весь поту', 3),
#  ('почему сих', 3),
#  ('комнате матери', 3),
#  ('погас свет', 3),
#  ('знал сколько', 3),
#  ('напиток пшеничной', 3),
#  ('пшеничной муки', 3),
#  ('молча кивнул', 3),
#  ('заставил улыбнуться', 3),
#  ('скорее это', 3),
#  ('отвернулся стене', 3),
#  ('господина чжоу', 3),
#  ('знал почему', 3),
#  ('время шли', 3),
#  ('собой ради', 3),
#  ('мать слова', 3),
#  ('ответ вэньсюань', 3),
#  ('двести юаней', 3),
#  ('закрыть глаза', 3),
#  ('стал думать', 3),
#  ('думать дальше', 3),
#  ('пять месяцев', 3),
#  ('рабочий день', 3),
#  ('рассеянно глядя', 3),
#  ('ко рту', 3),
#  ('управляющий управляющий', 3),
#  ('речь шла', 3),
#  ('это необходимо', 3),
#  ('это дело', 3),
#  ('шушэн приходила', 3),
#  ('пойди ляг', 3),
#  ('опустился кресло', 3),
#  ('мама иди', 3),
#  ('никому зла', 3),
#  ('почему нам', 3),
#  ('поднялся навстречу', 3),
#  ('принесла тебе', 3),
#  ('ответила та', 3),
#  ('сумочку направилась', 3),
#  ('направилась двери', 3),
#  ('покусывая губы', 3),
#  ('вэньсюань закашлялся', 3),
#  ('управляющий начальник', 3),
#  ('гдето далеко', 3),
#  ('уронил голову', 3),
#  ('оживленно беседовали', 3),
#  ('ходят слухи', 3),
#  ('высказать свое', 3),
#  ('билет самолет', 3),
#  ('воцарилась тишина', 3),
#  ('другие мысли', 3),
#  ('медленно пошел', 3),
#  ('могу расстаться', 3),
#  ('помолчав добавил', 3),
#  ('вошла шушэн', 3),
#  ('отключают свет', 3),
#  ('глаза сюань', 3),
#  ('почему время', 3),
#  ('удивленно посмотрел', 3),
#  ('каких пор', 3),
#  ('дав договорить', 3),
#  ('хочу лишь', 3),
#  ('произнес это', 3),
#  ('творится душе', 3),
#  ('услышав слова', 3),
#  ('мать прежде', 3),
#  ('ласковые слова', 3),
#  ('этому значения', 3),
#  ('однажды мать', 3),
#  ('нужны деньги', 3),
#  ('столько людей', 3),
#  ('сказала жена', 3),
#  ('жена мать', 3),
#  ('голос господин', 3),
#  ('испуганно взглянул', 3),
#  ('сердце бешено', 3),
#  ('говорила женщина', 3),
#  ('придется бежать', 3),
#  ('унималась старуха', 3),
#  ('знал идти', 3),
#  ('широко раскрыв', 3),
#  ('раскрыв глаза', 3),
#  ('прошло месяца', 3),
#  ('одной ногой', 3),
#  ('уговаривал вэньсюань', 3),
#  ('это просто', 3),
#  ('вэньсюань вздрогнул', 3),
#  ('ладно хватит', 3),
#  ('вэньсюань взял', 3),
#  ('взял руку', 3),
#  ('дорогу преследовал', 3),
#  ('конец конец', 3),
#  ('доктор чжан', 3),
#  ('принялся успокаивать', 3),
#  ('это туберкулез', 3),
#  ('черная тень', 3),
#  ('это трудно', 3),
#  ('спустя немного', 3),
#  ('ласково сказала', 3),
#  ('мечты надежды', 3),
#  ('улыбка шушэн', 3),
#  ('почему могу', 3),
#  ('раньше обычного', 3),
#  ('обратилась нему', 3),
#  ('хорошие вести', 3),
#  ('прогонят японцев', 3),
#  ('тебе помогать', 3),
#  ('взволнованно произнес', 3),
#  ('мрачной холодной', 3),
#  ('холодной комнате', 3),
#  ('ответил подумал', 3),
#  ('говорит серьезно', 3),
#  ('нужно уезжать', 3),
#  ('почему сегодня', 3),
#  ('сегодня рано', 3),
#  ('изза болезни', 3),
#  ('мать хотя', 3),
#  ('знал это', 3),
#  ('жизнь это', 3),
#  ('жалкое существование', 3),
#  ('отвела глаза', 3),
#  ('слишком добр', 3),
#  ('ранили сердце', 3),
#  ('тихо вздохнул', 3),
#  ('никто мог', 3),
#  ('оторвать глаз', 3),
#  ('глаз казалось', 3),
#  ('ответа вопрос', 3),
#  ('прошлась комнате', 3),
#  ('шушэн покраснела', 3),
#  ('сидя напротив', 3),
#  ...]
