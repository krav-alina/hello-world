# %%
with open ('Тургенев Иван. Том 9. Новь. Повести и рассказы 1874-1877 - royallib.ru.txt') as file1:
    tom9 = file1.read()

# %%
from sklearn.feature_extraction.text import CountVectorizer
import nltk
from collections import Counter
import re
import os

# %%
from nltk.corpus import stopwords
from nltk.tokenize import word_tokenize
import nltk
nltk.download('punkt')
# Out:
# [nltk_data] Downloading package punkt to
# [nltk_data]     C:\Users\sidor\AppData\Roaming\nltk_data...
# [nltk_data]   Package punkt is already up-to-date!
# True

# %%
import nltk
nltk.download('stopwords')
# Out:
# [nltk_data] Downloading package stopwords to
# [nltk_data]     C:\Users\sidor\AppData\Roaming\nltk_data...
# [nltk_data]   Package stopwords is already up-to-date!
# True

# %%
from pymystem3 import Mystem

# %%
mystem = Mystem()

# %%
tom9 = tom9.lower()
tom9 = re.sub("[!\"#$%&\'—()*+,-»«./:;<=>?@[\\]^_`{|}~]?",'',tom9)
tom9 = " ".join([word for word in tom9.split() if word not in(stopwords.words('russian'))])

# %% [markdown]
# def remove_stopwords(Word_list):
#         processed_Word_list = []
#         for Word in Word_list:
#             if Word not in stopwords.words("russian"):
#                 processed_Word_list.append(Word)
#         return processed_Word_list

# %%
bigram_vectorizer = CountVectorizer(ngram_range=(2,2),
                                    token_pattern=r'[А-Яа-я]+', min_df=1)

# %%
analyze = bigram_vectorizer.build_analyzer()

# %%
z = analyze(tom9)

# %%
Counter(z).most_common()
# Out:
# [('валентина михайловна', 100),
#  ('вс это', 30),
#  ('тех пор', 27),
#  ('василий федотыч', 27),
#  ('друг друга', 25),
#  ('парамон семеныч', 24),
#  ('марианна викентьевна', 21),
#  ('сих пор', 20),
#  ('крайней мере', 19),
#  ('милостивый государь', 19),
#  ('господин паклин', 19),
#  ('ваше превосходительство', 19),
#  ('вс равно', 17),
#  ('т д', 17),
#  ('алексей дмитрич', 17),
#  ('следующий день', 16),
#  ('это вс', 15),
#  ('тому назад', 15),
#  ('обе руки', 15),
#  ('самом деле', 15),
#  ('моего отца', 15),
#  ('спросил нежданов', 15),
#  ('валентины михайловны', 14),
#  ('анна захаровна', 14),
#  ('вошел комнату', 13),
#  ('это такое', 13),
#  ('таком случае', 13),
#  ('друг другу', 13),
#  ('промолвил нежданов', 13),
#  ('семен петрович', 13),
#  ('другое утро', 12),
#  ('некоторой степени', 12),
#  ('муза павловна', 11),
#  ('это мгновенье', 11),
#  ('отвечал нежданов', 11),
#  ('начал говорить', 11),
#  ('полях рядом', 11),
#  ('это слово', 10),
#  ('сквозь зубы', 10),
#  ('парамона семеныча', 10),
#  ('взад вперед', 10),
#  ('это дело', 10),
#  ('нечто вроде', 10),
#  ('ч рт', 10),
#  ('всяком случае', 10),
#  ('борис андреич', 10),
#  ('спросила марианна', 10),
#  ('э э', 9),
#  ('передо мною', 9),
#  ('несколько мгновений', 9),
#  ('каким образом', 9),
#  ('это значит', 9),
#  ('воскликнул паклин', 9),
#  ('сергей михайлович', 9),
#  ('обратился ко', 8),
#  ('четверть часа', 8),
#  ('молодые люди', 8),
#  ('господин нежданов', 8),
#  ('воскликнул калломейцев', 8),
#  ('нежданов маркелов', 8),
#  ('марианна нежданов', 8),
#  ('воскликнула марианна', 8),
#  ('отвечал соломин', 8),
#  ('одной стороны', 7),
#  ('протянул руку', 7),
#  ('сию минуту', 7),
#  ('пороге двери', 7),
#  ('руки ноги', 7),
#  ('времени времени', 7),
#  ('это это', 7),
#  ('безо всякой', 7),
#  ('вс время', 7),
#  ('несколько дней', 7),
#  ('обеими руками', 7),
#  ('вернулся домой', 7),
#  ('пожал руку', 7),
#  ('последние слова', 7),
#  ('первых порах', 7),
#  ('настасей настасеич', 7),
#  ('одной рукой', 7),
#  ('хотел сказать', 7),
#  ('отец алексей', 7),
#  ('погодя немного', 7),
#  ('это нужно', 7),
#  ('алексей дмитриевич', 7),
#  ('василия николаевича', 7),
#  ('нежданов отправился', 7),
#  ('анной захаровной', 7),
#  ('начал нежданов', 7),
#  ('заметил нежданов', 7),
#  ('марианна это', 7),
#  ('промолвил соломин', 7),
#  ('промолвила марианна', 7),
#  ('татьяна осиповна', 7),
#  ('вписано карандашом', 7),
#  ('рядом фразой', 7),
#  ('пожал плечами', 6),
#  ('покачал головою', 6),
#  ('молодой человек', 6),
#  ('никак ожидал', 6),
#  ('своей стороны', 6),
#  ('одно слово', 6),
#  ('дать взять', 6),
#  ('это очень', 6),
#  ('сверху вниз', 6),
#  ('каждое слово', 6),
#  ('друг другом', 6),
#  ('никандр вавилыч', 6),
#  ('ради бога', 6),
#  ('отчего это', 6),
#  ('странное дело', 6),
#  ('прощай прощай', 6),
#  ('самый день', 6),
#  ('своего отца', 6),
#  ('имел права', 6),
#  ('стой стой', 6),
#  ('молодых людей', 6),
#  ('промолвил громко', 6),
#  ('начал паклин', 6),
#  ('тебе это', 6),
#  ('нежданов отвечал', 6),
#  ('сипягин снова', 6),
#  ('нежданов это', 6),
#  ('нежданов начал', 6),
#  ('последнее время', 6),
#  ('воскликнул нежданов', 6),
#  ('марианна соломин', 6),
#  ('двенадцать лет', 5),
#  ('человек лет', 5),
#  ('вс нем', 5),
#  ('т п', 5),
#  ('проходя мимо', 5),
#  ('свое дело', 5),
#  ('слава богу', 5),
#  ('человека который', 5),
#  ('буду ждать', 5),
#  ('обо всем', 5),
#  ('мои слова', 5),
#  ('известное дело', 5),
#  ('поднял голову', 5),
#  ('ш потом', 5),
#  ('посреди комнаты', 5),
#  ('лишь изредка', 5),
#  ('сказать тебе', 5),
#  ('подошел нему', 5),
#  ('своим убеждениям', 5),
#  ('это письмо', 5),
#  ('образ мыслей', 5),
#  ('направо налево', 5),
#  ('высокого роста', 5),
#  ('моей тетки', 5),
#  ('рт знает', 5),
#  ('чу чу', 5),
#  ('понизив голос', 5),
#  ('несколько слов', 5),
#  ('это сделал', 5),
#  ('мя го', 5),
#  ('очень просто', 5),
#  ('моей матери', 5),
#  ('соседней комнате', 5),
#  ('сто рублей', 5),
#  ('гн паклин', 5),
#  ('нужно знать', 5),
#  ('честный человек', 5),
#  ('остродумов машурина', 5),
#  ('продолжал нежданов', 5),
#  ('продолжал паклин', 5),
#  ('подумал паклин', 5),
#  ('нежданов сел', 5),
#  ('день сипягин', 5),
#  ('взял руку', 5),
#  ('князя г', 5),
#  ('это неправда', 5),
#  ('калломейцев это', 5),
#  ('сказал это', 5),
#  ('сипягин калломейцев', 5),
#  ('нежданов мог', 5),
#  ('спросил маркелов', 5),
#  ('две недели', 5),
#  ('думалось нежданову', 5),
#  ('милый друг', 5),
#  ('почему это', 5),
#  ('отвечала марианна', 5),
#  ('везде везде', 5),
#  ('фомушка фимушка', 5),
#  ('назад назад', 5),
#  ('подумал нежданов', 5),
#  ('гна соломина', 5),
#  ('хотела сказать', 5),
#  ('т е', 5),
#  ('объяснение синецкой', 5),
#  ('соломин синецкая', 5),
#  ('лет тридцати', 4),
#  ('яков петрович', 4),
#  ('это совершенно', 4),
#  ('снизу вверх', 4),
#  ('место которое', 4),
#  ('это должно', 4),
#  ('таким образом', 4),
#  ('ой губернии', 4),
#  ('нашем доме', 4),
#  ('парамоном семенычем', 4),
#  ('чувство которое', 4),
#  ('ту минуту', 4),
#  ('пожала плечом', 4),
#  ('молодыми людьми', 4),
#  ('третьего дня', 4),
#  ('эта девушка', 4),
#  ('той самой', 4),
#  ('боку бок', 4),
#  ('тихим голосом', 4),
#  ('другое дело', 4),
#  ('хотел удалиться', 4),
#  ('д т', 4),
#  ('прощай брат', 4),
#  ('целый день', 4),
#  ('нужно нужно', 4),
#  ('нужно это', 4),
#  ('ой ой', 4),
#  ('живой человек', 4),
#  ('петр петрович', 4),
#  ('остались одни', 4),
#  ('покачала головою', 4),
#  ('можете представить', 4),
#  ('протянула руку', 4),
#  ('дело идет', 4),
#  ('сорвалось языка', 4),
#  ('моему отцу', 4),
#  ('сослали сибирь', 4),
#  ('часы руках', 4),
#  ('знаю знаю', 4),
#  ('мои часы', 4),
#  ('ящик стола', 4),
#  ('порфирий петрович', 4),
#  ('это сделать', 4),
#  ('ту пору', 4),
#  ('это мое', 4),
#  ('мое дело', 4),
#  ('своей комнате', 4),
#  ('следующее утро', 4),
#  ('делать нечего', 4),
#  ('новое лицо', 4),
#  ('начал снова', 4),
#  ('тех которые', 4),
#  ('человек который', 4),
#  ('некоторое время', 4),
#  ('тебе говорю', 4),
#  ('понятное дело', 4),
#  ('свое лицо', 4),
#  ('слабым голосом', 4),
#  ('люди которые', 4),
#  ('послышался голос', 4),
#  ('ха ха', 4),
#  ('который вс', 4),
#  ('дядя егор', 4),
#  ('чему это', 4),
#  ('стал расспрашивать', 4),
#  ('человека которого', 4),
#  ('тех двух', 4),
#  ('это человек', 4),
#  ('марфе савишне', 4),
#  ('час спустя', 4),
#  ('подошел двери', 4),
#  ('нам обоим', 4),
#  ('бокового кармана', 4),
#  ('машурина остродумов', 4),
#  ('паклин это', 4),
#  ('очень очень', 4),
#  ('сила самсоныч', 4),
#  ('горбатую сестру', 4),
#  ('некоторых пор', 4),
#  ('проговорила машурина', 4),
#  ('подошел окну', 4),
#  ('нежданов пожал', 4),
#  ('имел вид', 4),
#  ('паклин паклин', 4),
#  ('машурину остродумова', 4),
#  ('руку нежданова', 4),
#  ('свои сани', 4),
#  ('голосом нежданов', 4),
#  ('нежданов покраснел', 4),
#  ('позвольте спросить', 4),
#  ('это главное', 4),
#  ('это чувствовал', 4),
#  ('следующего дня', 4),
#  ('вс общество', 4),
#  ('своего мужа', 4),
#  ('зеленую комнату', 4),
#  ('нежданов глядел', 4),
#  ('марианна села', 4),
#  ('десять часов', 4),
#  ('отец киприан', 4),
#  ('очень мало', 4),
#  ('это ваше', 4),
#  ('муж жена', 4),
#  ('движением руки', 4),
#  ('подхватила марианна', 4),
#  ('своего места', 4),
#  ('маркелов отвечал', 4),
#  ('равно вс', 4),
#  ('вс переделать', 4),
#  ('стоял неподвижно', 4),
#  ('ехать дальше', 4),
#  ('вместе неждановым', 4),
#  ('этому поводу', 4),
#  ('нежданов взял', 4),
#  ('марианна стояла', 4),
#  ('перебила марианна', 4),
#  ('голову марианна', 4),
#  ('а а', 4),
#  ('другу руки', 4),
#  ('свои руки', 4),
#  ('да да', 4),
#  ('любим друг', 4),
#  ('шепнула марианна', 4),
#  ('начал соломин', 4),
#  ('сергей михайлыч', 4),
#  ('маркелов соломин', 4),
#  ('сын дьячка', 4),
#  ('соломин улыбнулся', 4),
#  ('нежданов стал', 4),
#  ('старый слуга', 4),
#  ('большей частью', 4),
#  ('паклин сказал', 4),
#  ('нигде нигде', 4),
#  ('зло зло', 4),
#  ('многая многая', 4),
#  ('должен сказать', 4),
#  ('дай руку', 4),
#  ('это вздор', 4),
#  ('это равно', 4),
#  ('михайловна посматривала', 4),
#  ('нежданов марианна', 4),
#  ('нежданов хотел', 4),
#  ('посмотрела нежданова', 4),
#  ('тебе сказать', 4),
#  ('рук вон', 4),
#  ('валентине михайловне', 4),
#  ('вмешался калломейцев', 4),
#  ('продолжал соломин', 4),
#  ('милая барышня', 4),
#  ('спросил соломин', 4),
#  ('дети мои', 4),
#  ('спинке стула', 4),
#  ('василия федотыча', 4),
#  ('этих двух', 4),
#  ('алексея дмитрича', 4),
#  ('дурковатый приказчик', 4),
#  ('русского мужика', 4),
#  ('паклин сила', 4),
#  ('рокко ди', 4),
#  ('ди сантофиуме', 4),
#  ('пунин бабурин', 3),
#  ('каждым днем', 3),
#  ('моей жизни', 3),
#  ('самой середине', 3),
#  ('шевелился своем', 3),
#  ('спросила бабушка', 3),
#  ('точно такс', 3),
#  ('ровным голосом', 3),
#  ('лицо бабурина', 3),
#  ('это твое', 3),
#  ('совершенно вс', 3),
#  ('ко свое', 3),
#  ('мое изумление', 3),
#  ('сюда приехали', 3),
#  ('бабурин пунин', 3),
#  ('ж ж', 3),
#  ('мадмуазель фрикэ', 3),
#  ('мною пунин', 3),
#  ('отправился сад', 3),
#  ('приходил восторг', 3),
#  ('одно лишь', 3),
#  ('тайное дело', 3),
#  ('эта самая', 3),
#  ('самый развал', 3),
#  ('нескольких шагах', 3),
#  ('понурив голову', 3),
#  ('головою сверху', 3),
#  ('это я', 3),
#  ('николай антонов', 3),
#  ('боже боже', 3),
#  ('котором часу', 3),
#  ('утро рано', 3),
#  ('сидел комнате', 3),
#  ('тотчас вскочил', 3),
#  ('пожалуйста пожалуйста', 3),
#  ('нечего бояться', 3),
#  ('музу музу', 3),
#  ('начал я', 3),
#  ('обратил внимания', 3),
#  ('мое присутствие', 3),
#  ('владимир николаич', 3),
#  ('муза музочка', 3),
#  ('почему почему', 3),
#  ('пожала плечами', 3),
#  ('дней спустя', 3),
#  ('муза это', 3),
#  ('нам нам', 3),
#  ('будешь делать', 3),
#  ('выражение лица', 3),
#  ('семеныч бабурин', 3),
#  ('пожелал узнать', 3),
#  ('приходите завтра', 3),
#  ('непременно нужно', 3),
#  ('поспешно промолвил', 3),
#  ('целая неделя', 3),
#  ('прямо глаза', 3),
#  ('новый тип', 3),
#  ('левой стороны', 3),
#  ('произвол судьбы', 3),
#  ('немногих словах', 3),
#  ('это спросил', 3),
#  ('вышел дому', 3),
#  ('свои мысли', 3),
#  ('своем стуле', 3),
#  ('руки груди', 3),
#  ('одно время', 3),
#  ('бабурин честный', 3),
#  ('честный тупец', 3),
#  ('пожал плечом', 3),
#  ('нового типа', 3),
#  ('намерен сделать', 3),
#  ('появился пороге', 3),
#  ('вс дело', 3),
#  ('ко спиною', 3),
#  ('каждом шагу', 3),
#  ('брат петя', 3),
#  ('единым словом', 3),
#  ('буду просить', 3),
#  ('чтото невнятное', 3),
#  ('сообщить нечто', 3),
#  ('боже это', 3),
#  ('одному человеку', 3),
#  ('самой смерти', 3),
#  ('бросился вон', 3),
#  ('молодым человеком', 3),
#  ('дна души', 3),
#  ('самый момент', 3),
#  ('го года', 3),
#  ('вс шло', 3),
#  ('чтото сказать', 3),
#  ('прежние времена', 3),
#  ('брат егор', 3),
#  ('нам дом', 3),
#  ('серебряные часы', 3),
#  ('както особенно', 3),
#  ('меня это', 3),
#  ('мальчик лет', 3),
#  ('дело хорошее', 3),
#  ('это последнее', 3),
#  ('извольте получить', 3),
#  ('самую глубь', 3),
#  ('нашей комнаты', 3),
#  ('своему обыкновению', 3),
#  ('нашу комнату', 3),
#  ('время очень', 3),
#  ('большими шагами', 3),
#  ('который очень', 3),
#  ('это мол', 3),
#  ('одна мысль', 3),
#  ('отец которого', 3),
#  ('втором этаже', 3),
#  ('это знал', 3),
#  ('ш пот', 3),
#  ('ах это', 3),
#  ('легче пуха', 3),
#  ('нашего дома', 3),
#  ('весь дом', 3),
#  ('несколько назад', 3),
#  ('недальнем расстоянии', 3),
#  ('лицо которое', 3),
#  ('лицо приняло', 3),
#  ('приняло выражение', 3),
#  ('отвечал давыд', 3),
#  ('вздохнула ах', 3),
#  ('заметил давыд', 3),
#  ('спросил давыд', 3),
#  ('это скоро', 3),
#  ('встал вышел', 3),
#  ('собственными глазами', 3),
#  ('будущую жену', 3),
#  ('возле окна', 3),
#  ('никак мог', 3),
#  ('давыд егорыч', 3),
#  ('давыд это', 3),
#  ('ч рту', 3),
#  ('солдат пикой', 3),
#  ('той стороны', 3),
#  ('мгновений спустя', 3),
#  ('вышел вон', 3),
#  ('несколько сряду', 3),
#  ('нему лицом', 3),
#  ('направилась двери', 3),
#  ('вместе крали', 3),
#  ('го мя', 3),
#  ('слова промолвил', 3),
#  ('вышла комнаты', 3),
#  ('лицом глаза', 3),
#  ('однако скоро', 3),
#  ('большею частью', 3),
#  ('сказать трудно', 3),
#  ('который тотчас', 3),
#  ('скрестив руки', 3),
#  ('передо мной', 3),
#  ('мог хорошенько', 3),
#  ('пор пока', 3),
#  ('выражению лица', 3),
#  ('время моего', 3),
#  ('несколько минут', 3),
#  ('играть карты', 3),
#  ('несколько лет', 3),
#  ('приподнял голову', 3),
#  ('оглянулся назад', 3),
#  ('наш хозяин', 3),
#  ('лежал спине', 3),
#  ('единого слова', 3),
#  ('одного человека', 3),
#  ('черты лица', 3),
#  ('русские люди', 3),
#  ('мое намерение', 3),
#  ('сохрани бог', 3),
#  ('женский пол', 3),
#  ('каким манером', 3),
#  ('говорит яков', 3),
#  ('каким это', 3),
#  ('четвертый месяц', 3),
#  ('сперва очень', 3),
#  ('исполнить волю', 3),
#  ('пойду говорит', 3),
#  ('остается одно', 3),
#  ('закрыл глаза', 3),
#  ('дома офицерской', 3),
#  ('женский голос', 3),
#  ('спросила машурина', 3),
#  ('вошла комнату', 3),
#  ('паклин засмеялся', 3),
#  ('паклин снова', 3),
#  ('однако это', 3),
#  ('рублей серебром', 3),
#  ('нужно переговорить', 3),
#  ('дверь отворилась', 3),
#  ('паклин первый', 3),
#  ('хороший человек', 3),
#  ('промолвил паклин', 3),
#  ('сделайте одолжение', 3),
#  ('гн нежданов', 3),
#  ('опустился стул', 3),
#  ('островского свои', 3),
#  ('сани садись', 3),
#  ('это чувство', 3),
#  ('сипягин говорил', 3),
#  ('с ой', 3),
#  ('верстах губернского', 3),
#  ('губернского города', 3),
#  ('промолвил сипягин', 3),
#  ('перебил сипягин', 3),
#  ('кого это', 3),
#  ('перебил нежданов', 3),
#  ('должен знать', 3),
#  ('собой пожертвовать', 3),
#  ('говорю тебе', 3),
#  ('пришла голову', 3),
#  ('пустил эстетике', 3),
#  ('нежданов заметил', 3),
#  ('спустя нежданов', 3),
#  ('михайловна очень', 3),
#  ('прибытия мужа', 3),
#  ('поцеловал руку', 3),
#  ('семена петровича', 3),
#  ('заметила сипягина', 3),
#  ('гжа сипягина', 3),
#  ('это марианна', 3),
#  ('племянница сипягина', 3),
#  ('марианна сказал', 3),
#  ('спросила сипягина', 3),
#  ('часов нежданов', 3),
#  ('сипягин принялся', 3),
#  ('пойдет факелом', 3),
#  ('нежданов который', 3),
#  ('обед кончился', 3),
#  ('воскликнул сипягин', 3),
#  ('коля анной', 3),
#  ('первый урок', 3),
#  ('нежданов сидел', 3),
#  ('нежданову пришлось', 3),
#  ('писал нему', 3),
#  ('нему очень', 3),
#  ('нежданов говорил', 3),
#  ('это приятно', 3),
#  ('м году', 3),
#  ('женское платье', 3),
#  ('сергея михайловича', 3),
#  ('лица нежданов', 3),
#  ('дивился тому', 3),
#  ('цвет лица', 3),
#  ('губы крупные', 3),
#  ('гн маркелов', 3),
#  ('маркелов нежданов', 3),
#  ('маркелов начал', 3),
#  ('отвечал маркелов', 3),
#  ('борз нково', 3),
#  ('немцев особенно', 3),
#  ('особенно русских', 3),
#  ('русских немцев', 3),
#  ('герцена особенности', 3),
#  ('одну девушку', 3),
#  ('еремей еремей', 3),
#  ('говорил мало', 3),
#  ('нечто странное', 3),
#  ('промолвил маркелов', 3),
#  ('маркелов тотчас', 3),
#  ('проговорил маркелов', 3),
#  ('это чувствует', 3),
#  ('почему именно', 3),
#  ('друг буду', 3),
#  ('покорить нози', 3),
#  ('минуту спустя', 3),
#  ('марианна тотчас', 3),
#  ('повторила марианна', 3),
#  ('гна маркелова', 3),
#  ('эта мысль', 3),
#  ('чужой хлеб', 3),
#  ('таким видом', 3),
#  ('кивнула головою', 3),
#  ('марианна выпрямилась', 3),
#  ('сипягин величественно', 3),
#  ('сторону нежданова', 3),
#  ('бог ведает', 3),
#  ('это лицо', 3),
#  ('дело которое', 3),
#  ('сипягина который', 3),
#  ('угрюмо маркелов', 3),
#  ('соломин вошел', 3),
#  ('обратился нежданову', 3),
#  ('купец голушкин', 3),
#  ('капитон голушкин', 3),
#  ('маркелова который', 3),
#  ('соломин отвечал', 3),
#  ('соломин нежданов', 3),
#  ('проговорил соломин', 3),
#  ('русской жизни', 3),
#  ('свои штучки', 3),
#  ('хотите узнать', 3),
#  ('паклин нежданову', 3),
#  ('очень хороший', 3),
#  ('паклин начал', 3),
#  ('прикусил язык', 3),
#  ('прибавил громко', 3),
#  ('скажите нам', 3),
#  ('капитон андреич', 3),
#  ('закурил сигару', 3),
#  ('ваше дело', 3),
#  ('продолжал маркелов', 3),
#  ('маркелов пригнул', 3),
#  ('брат алексей', 3),
#  ('конце концов', 3),
#  ('быстрый взгляд', 3),
#  ('пятна света', 3),
#  ('соломина марианна', 3),
#  ('своей комнаты', 3),
#  ('буду звать', 3),
#  ('белогороховый лакей', 3),
#  ('насчет нежданова', 3),
#  ('открой глаза', 3),
#  ('это говорю', 3),
#  ('нужно соломин', 3),
#  ('очень благодарен', 3),
#  ('василий федосеич', 3),
#  ('соломин встал', 3),
#  ('позвольте позвольте', 3),
#  ('както очень', 3),
#  ('правую руку', 3),
#  ('сипягин громко', 3),
#  ('одну руку', 3),
#  ('прибавил вполголоса', 3),
#  ('народ наш', 3),
#  ('этих слов', 3),
#  ('оставить дом', 3),
#  ('честная девушка', 3),
#  ('соломин поднялся', 3),
#  ('поднялся стула', 3),
#  ('господин сипягин', 3),
#  ('впечатление произведенное', 3),
#  ('страшная сцена', 3),
#  ('это говорит', 3),
#  ('та девушка', 3),
#  ('василию федотычу', 3),
#  ('это верно', 3),
#  ('трудно это', 3),
#  ('это никуда', 3),
#  ('никуда годится', 3),
#  ('нечто подобное', 3),
#  ('это портрет', 3),
#  ('переменить разговор', 3),
#  ('марианна пожала', 3),
#  ('вышел марианна', 3),
#  ('поп зосима', 3),
#  ('т м', 3),
#  ('м уезде', 3),
#  ('соломин марианна', 3),
#  ('госпожа машурина', 3),
#  ('желает перейти', 3),
#  ('перейти православие', 3),
#  ('господина сипягина', 3),
#  ('понурил голову', 3),
#  ('это сказал', 3),
#  ('знаете знаете', 3),
#  ('господина паклина', 3),
#  ('отвечал сипягин', 3),
#  ('это безумие', 3),
#  ('те те', 3),
#  ('любезный барон', 3),
#  ('тихо благородно', 3),
#  ('сила паклин', 3),
#  ('некто господин', 3),
#  ('прощай марианна', 3),
#  ('остродумов убит', 3),
#  ('дворянское гнездо', 3),
#  ('иванович р', 3),
#  ('новой повести', 3),
#  ('р сер', 3),
#  ('является нему', 3),
#  ('входит вс', 3),
#  ('показать нем', 3),
#  ('весь день', 3),
#  ('хлеб ест', 3),
#  ('соломину описание', 3),
#  ('гдето застрял', 3),
#  ('разговор коляске', 3),
#  ('повести рассказы', 2),
#  ('мои мысли', 2),
#  ('моем воображении', 2),
#  ('большое письмо', 2),
#  ('своем уголку', 2),
#  ('минут пять', 2),
#  ('пять спустя', 2),
#  ('тридцати пяти', 2),
#  ('рябым лицом', 2),
#  ('густыми бровями', 2),
#  ('небольшие серые', 2),
#  ('серые глаза', 2),
#  ('этих глаз', 2),
#  ('самой двери', 2),
#  ('такс отвечал', 2),
#  ('руки спину', 2),
#  ('другого качества', 2),
#  ('чтото понимаю', 2),
#  ('телесного наказания', 2),
#  ('бабушка удивилась', 2),
#  ('бабурина покраснело', 2),
#  ('которых люблю', 2),
#  ('никак нетс', 2),
#  ('человек которым', 2),
#  ('нашего брата', 2),
#  ('перебила бабушка', 2),
#  ('подумав немного', 2),
#  ('одно тех', 2),
#  ('переставая улыбаться', 2),
#  ('свои чашечки', 2),
#  ('слабый голос', 2),
#  ('давно сюда', 2),
#  ('господин бабурин', 2),
#  ('слышите слышите', 2),
#  ('поместился рядом', 2),
#  ('невольно воскликнул', 2),
#  ('поднял глаза', 2),
#  ('закрывал глаза', 2),
#  ('настоящее яйцо', 2),
#  ('милости моих', 2),
#  ('который оказался', 2),
#  ('жизни моей', 2),
#  ('сколько угодно', 2),
#  ('это самое', 2),
#  ('меня чтото', 2),
#  ('напившись чаю', 2),
#  ('отправился людскую', 2),
#  ('постучавшись дверь', 2),
#  ('угодно промолвил', 2),
#  ('насупив брови', 2),
#  ('снимая шапки', 2),
#  ('никандра вавилыча', 2),
#  ('минуту точно', 2),
#  ('дома отвечал', 2),
#  ('позвольте заметить', 2),
#  ('входить чужую', 2),
#  ('чужую комнату', 2),
#  ('вс едино', 2),
#  ('комната эта', 2),
#  ('пожалуйста перебил', 2),
#  ('пунин вероятно', 2),
#  ('вероятно догадался', 2),
#  ('догадался выражению', 2),
#  ('барчук барчук', 2),
#  ('нечто такое', 2),
#  ('почел нужное', 2),
#  ('почувствовать степени', 2),
#  ('степени презирает', 2),
#  ('ваш приятель', 2),
#  ('наклонился самому', 2),
#  ('самому моему', 2),
#  ('моему уху', 2),
#  ('повторил пунин', 2),
#  ('этим двум', 2),
#  ('всею душою', 2),
#  ('серебристых тополей', 2),
#  ('чудесный человек', 2),
#  ('человек однако', 2),
#  ('духовному званию', 2),
#  ('какойто бесноватый', 2),
#  ('старая няня', 2),
#  ('которое испытывал', 2),
#  ('улучив удобную', 2),
#  ('всем телом', 2),
#  ('губы которых', 2),
#  ('впечатление чегото', 2),
#  ('никто знает', 2),
#  ('правду говоря', 2),
#  ('читать стихи', 2),
#  ('наша жизнь', 2),
#  ('вс покончилось', 2),
#  ('бабушка всем', 2),
#  ('нанковый кафтан', 2),
#  ('это спросила', 2),
#  ('курной избе', 2),
#  ('крайней бедности', 2),
#  ('виднелась крестьянская', 2),
#  ('лицо обращенное', 2),
#  ('это бабурин', 2),
#  ('начал это', 2),
#  ('я решился', 2),
#  ('имею честь', 2),
#  ('продолжал бабурин', 2),
#  ('боже сохрани', 2),
#  ('моем присутствии', 2),
#  ('махнула платком', 2),
#  ('описать мое', 2),
#  ('отправился комнату', 2),
#  ('зато беспрестанно', 2),
#  ('нечего думать', 2),
#  ('своего лица', 2),
#  ('смотрите берегитесь', 2),
#  ('откуда взялся', 2),
#  ('ваш долг', 2),
#  ('узелок который', 2),
#  ('ушел несколько', 2),
#  ('глаза красны', 2),
#  ('г прошло', 2),
#  ('прошло семь', 2),
#  ('семь лет', 2),
#  ('последние годы', 2),
#  ('течение нескольких', 2),
#  ('стал замечать', 2),
#  ('прежде случалось', 2),
#  ('прямо лицо', 2),
#  ('лицо должен', 2),
#  ('твоей музой', 2),
#  ('тархов вс', 2),
#  ('кажется это', 2),
#  ('это идет', 2),
#  ('дверь распахнулась', 2),
#  ('пороге показалась', 2),
#  ('соломенной шляпой', 2),
#  ('подалась назад', 2),
#  ('музу павловну', 2),
#  ('тархов засмеялся', 2),
#  ('знал пока', 2),
#  ('моего приятеля', 2),
#  ('музе павловне', 2),
#  ('немного странным', 2),
#  ('наша мадам', 2),
#  ('наклонила голову', 2),
#  ('воскликнул тархов', 2),
#  ('тархов посидите', 2),
#  ('ах владимир', 2),
#  ('юрий милославский', 2),
#  ('встала стула', 2),
#  ('подошла двери', 2),
#  ('вон комнаты', 2),
#  ('это значило', 2),
#  ('рассказал эта', 2),
#  ('первого взгляда', 2),
#  ('произошло нами', 2),
#  ('тебе скажу', 2),
#  ('самая эта', 2),
#  ('пустился толковать', 2),
#  ('скоро ушел', 2),
#  ('гостиного двора', 2),
#  ('фунт изюму', 2),
#  ('схватила руку', 2),
#  ('представьте мое', 2),
#  ('раскрыл рот', 2),
#  ('троицкий барчук', 2),
#  ('моей бабушки', 2),
#  ('мог убедиться', 2),
#  ('это время', 2),
#  ('имел удовольствия', 2),
#  ('б у', 2),
#  ('младых летах', 2),
#  ('любить жаловать', 2),
#  ('маков цвет', 2),
#  ('пунин вышел', 2),
#  ('котором квартировал', 2),
#  ('успел сообщить', 2),
#  ('года тому', 2),
#  ('пунин засмеялся', 2),
#  ('пунин помолчал', 2),
#  ('этим именем', 2),
#  ('хотя пунин', 2),
#  ('очень вс', 2),
#  ('очень оно', 2),
#  ('переднем фасе', 2),
#  ('пунина хотя', 2),
#  ('покачивал головою', 2),
#  ('упорно молчала', 2),
#  ('всячески старался', 2),
#  ('бабурин самый', 2),
#  ('такого рода', 2),
#  ('хуже самого', 2),
#  ('письменным столом', 2),
#  ('заметил сквозь', 2),
#  ('большое удовольствие', 2),
#  ('докончил начатой', 2),
#  ('начатой фразы', 2),
#  ('нужно видеть', 2),
#  ('опущенными глазами', 2),
#  ('люди поднялись', 2),
#  ('павловна начал', 2),
#  ('показалось словно', 2),
#  ('послушайте прибавила', 2),
#  ('руки наложу', 2),
#  ('промолвил можете', 2),
#  ('сколько знаю', 2),
#  ('должна сказать', 2),
#  ('начала снова', 2),
#  ('двадцать пять', 2),
#  ('пять лет', 2),
#  ('лицо дышало', 2),
#  ('мелькнуло голове', 2),
#  ('кусочек сахара', 2),
#  ('пришло голову', 2),
#  ('говорил обо', 2),
#  ('бросили произвол', 2),
#  ('царя давыда', 2),
#  ('певучим голосом', 2),
#  ('произнес пунин', 2),
#  ('вся трепет', 2),
#  ('дело почему', 2),
#  ('старой памяти', 2),
#  ('старом муже', 2),
#  ('настаивал своем', 2),
#  ('комнате никого', 2),
#  ('соседней комнаты', 2),
#  ('комнаты растворилась', 2),
#  ('молча пожал', 2),
#  ('хотя тотчас', 2),
#  ('тотчас почувствовал', 2),
#  ('это известие', 2),
#  ('вперив глаза', 2),
#  ('желал сказать', 2),
#  ('посмотрел лицо', 2),
#  ('другого человека', 2),
#  ('таким манером', 2),
#  ('знаю говорил', 2),
#  ('говорил это', 2),
#  ('скрестил руки', 2),
#  ('лицо выразило', 2),
#  ('четверти часа', 2),
#  ('вс молчал', 2),
#  ('изредка взглядывал', 2),
#  ('хотя стороны', 2),
#  ('подобных людей', 2),
#  ('своем веку', 2),
#  ('одно двух', 2),
#  ('либо понимает', 2),
#  ('торопливым голосом', 2),
#  ('настоящий друг', 2),
#  ('таком волнении', 2),
#  ('казался доволен', 2),
#  ('той минуты', 2),
#  ('должен сознаться', 2),
#  ('время своего', 2),
#  ('голова болела', 2),
#  ('хотел уйти', 2),
#  ('чашку чаю', 2),
#  ('ваших слов', 2),
#  ('черные глаза', 2),
#  ('сегодня говорили', 2),
#  ('право кажется', 2),
#  ('готова вс', 2),
#  ('вс сказать', 2),
#  ('голос музы', 2),
#  ('могу скрыть', 2),
#  ('скрыть муза', 2),
#  ('это прелесть', 2),
#  ('подняв голову', 2),
#  ('знать это', 2),
#  ('это тебе', 2),
#  ('это сказали', 2),
#  ('почем знаете', 2),
#  ...]

# %% [markdown]
# def ngrams_text (word,num):
#     word = word.lower()
#     word = re.sub("[!\"#$%&\'—()*+,-»«./:;<=>?@[\\]^_`{|}~]?",'',word)
#     #tokens = re.findall ('он\s\w+',word)
#     #tokens = [token for token in word.split(" ") if token != ""]
#     mystem.lemmatize(word)
#     wordsFiltered = []
#     for w in word:
#         if w not in stopwords:
#             wordsFiltered.append(w)
#
#     output = list(ngrams(tokens,num))
#     mostcommon = Counter(output).most_common()
#     return mostcommon
# #лемматизировать можно прямо из nltk，lemmatize, а стоп слова также есть в nltk.есть такая тетрадка.
# #чтобы свести все свои документы в один нужно просто конкатенировать все переменны. открывааем и читаем фал, сохраняем в переменную, складываем все переменные.
# #append только для списка

# %% [markdown]
# from nltk.util import ngrams
