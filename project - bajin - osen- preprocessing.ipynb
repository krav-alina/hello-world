# %%
with open ('Ба Цзинь. Осень - royallib.com.txt') as file1:
    bajin1 = file1.read()

# %%
from sklearn.feature_extraction.text import CountVectorizer
import nltk
from collections import Counter
import re
import os

# %%
from nltk.corpus import stopwords
from nltk.tokenize import word_tokenize
import nltk
nltk.download('punkt')
# Out:
# [nltk_data] Downloading package punkt to
# [nltk_data]     C:\Users\sidor\AppData\Roaming\nltk_data...
# [nltk_data]   Package punkt is already up-to-date!
# True

# %%
import nltk
nltk.download('stopwords')
# Out:
# [nltk_data] Downloading package stopwords to
# [nltk_data]     C:\Users\sidor\AppData\Roaming\nltk_data...
# [nltk_data]   Package stopwords is already up-to-date!
# True

# %%
from pymystem3 import Mystem

# %%
mystem = Mystem()

# %%
def normalized_text (word):
    word = word.lower()
    word = re.sub("[!\"#$%&\'—()*+,-»«./:;<=>?@[\\]^_`{|}~]?",'',word)
    word = " ".join([word for word in word.split() if word not in(stopwords.words('russian'))])
    word = word.split()
    output = len(word)
    return output

# %%
bajin1 = bajin1.lower()
bajin1 = re.sub("[!\"#$%&\'—()*+,-»«./:;<=>?@[\\]^_`{|}~]?",'',bajin1)
bajin1 = " ".join([word for word in bajin1.split() if word not in(stopwords.words('russian'))])

# %%
print(bajin1)
# Out:
# ба цзинь осень последнее время просто измучился обрушиваются одни неприятности тетя чжан крайне недовольная дядя кэдин период траура взял дом сиэр наложницу старший дядя кэмин мог воспрепятствовать этому второй половины прошлого года предлогом болезни бывала уход шуин дому дядя кэмин предал гласности пытался узнать почему это произошло однако стал очень раздражительным ссоры семье участились смерти сына сердце словно чтото оборвалось снова беспокоит желудок последние дни боль обострилась превратилась настоящую пытку нахожусь полнейшем смятении душа чему лежит поэтому стал реже писать вам… третья тетя постоянно справляется сестре шуин получила письма узнав живете осталась очень довольна деньги которые перевел вчера дала шуин говорят дядя кэмин раскаивается однако держится непреклонно идет уступки позволяет упоминать нем имя шуин кажется пройдет немного времени сердце смягчится… ночам охватывает отчаяние тысячи чувств теснятся груди моей вспоминаю вспоминаю покойных родителей умершую жену безвременно погибшего сына сестер мэй хой других сердце тоскует живые далеко мертвых вернешь… месте рука цзюесиня задрожала кончик кисти заскользил бумаге сразу оторвавшись повис воздухе цзюесинь решил отложить письмо глазах рябило усталости старший брат негромко прозвучал ухом знакомый голос пошевельнулся словно слышал слезы навернулись глаза цзюеминь подошел цзюесиню положил руку плечо увидев написанное сочувственно произнес чему думаешь мертвых воскресишь подумай своем собственном здоровье цзюесинь поднял голову повернулся вращающемся стуле цзюеминь увидел брат плачет цзюесинь схватил руку младшего брата крепко сжал сквозь слезы проговорил потвоему должен делать цзюеминь понял брат ищет поддержки стал ласково уговаривать старший брат почему сих пор сильно переживаешь напрасно мучаешь исстрадался страшны страдания могу вынести пусть принуждают подчиняться воле словно борясь собой горечью произнес цзюесинь этим хочешь сказать понял цзюеминь хотят женился вторично ответил цзюесинь цзюеминь помолчал процедил сквозь зубы вечно никак хотят оставить покое утирая слезы жалобно произнес цзюесинь это твое личное дело смеют вмешиваться трудом подавляя гнев твердо сказал цзюеминь понимал всей серьезности положения думал старшему брату легко разрешить вопрос обойдя цзюесиня подошел плетеному креслу стоявшему окна спокойно уселся против брата энергичнее мать уговаривает говорят несколько месяцев истекает срок моего траура едва слышно словно произнес цзюесинь плача изза трех видов непочтения родителям самое страшное непродление рода… саркастически бросил цзюеминь цзюесинь ответил сунул карман носовой платок уныло опустил голову взор казалось прикован письму видел глазами проносились туманные образы прошлого каждый знаком хотелось удержать мысленно побеседовать ними цзюеминь понимал происходит душе брата произносил звука думал другом воображении постепенно вырисовывалось лицо молодой девушки видел улыбается казалось комната погружается безмолвие электрическая лампочка постепенно тускнела лунный свет посеребрил оконные стекла неясные тени падавшие занавесок легли углах комнаты окном светло лишь монотонное тиканье маятника напоминало неумолимом течении времени неожиданно цзюесинь вздохнул вздох настолько слабым цзюеминь услышал раздался гудок протяжный резкий вой заставил цзюесиня вздрогнуть широко открыв глаза огляделся изменилось хэсао позвал едва слышно ответа поднялся подошел столу зажег керосиновую лампу вернувшись опустился стул взгляд снова упал письмо лежавшее столе взял кисточку собираясь продолжать письмо свет электрической лампочки становился тусклым строчки сливались глазами невольно вздохнув уронил кисточку подняв голову тоской уставился лампочку свет окончательно потускнел мерцала лишь красная нить нить постепенно угасла одиноко светилась столе керосиновая лампа освещая всей комнаты словно воспользовавшись этим комнату прокрался лунный свет полу задней комнаты освещенной лампой лежали тени деревьев оконной занавески передняя комната залита лунны ...

# %%
#filtered_words = [Word for Word in tom6 if Word not in stopwords.words('russian')]
#text = 'здравствуй дорогой читатель сегодня очень ветренно поэтому я и он не пошли гулять хотя очень хотелось'
#text = ' '.join([word for word in text.split() if word not in (stopwords.words('russian'))])
#tom = " ".join([word for word in tom.split() if word not in(stopwords.words('russian'))])

# %%
bajin1 = " ".join([word for word in bajin1.split() if word not in(newstoplist)])
print(bajin1)
# Out:
# ба цзинь осень последнее время просто измучился обрушиваются одни неприятности тетя крайне недовольная дядя кэдин период траура взял дом сиэр наложницу старший дядя кэмин мог воспрепятствовать этому второй половины прошлого года предлогом болезни бывала уход шуин дому дядя кэмин предал гласности пытался узнать почему произошло однако стал очень раздражительным ссоры семье участились смерти сына сердце словно чтото оборвалось снова беспокоит желудок последние дни боль обострилась превратилась настоящую пытку нахожусь полнейшем смятении душа чему лежит поэтому стал реже писать вам… третья тетя постоянно справляется сестре шуин получила письма узнав живете осталась очень довольна деньги которые перевел вчера дала шуин говорят дядя кэмин раскаивается однако держится непреклонно идет уступки позволяет упоминать нем имя шуин кажется пройдет немного времени сердце смягчится… ночам охватывает отчаяние тысячи чувств теснятся груди моей вспоминаю вспоминаю покойных родителей умершую жену безвременно погибшего сына сестер хой других сердце тоскует живые далеко мертвых вернешь… месте рука задрожала кончик кисти заскользил бумаге сразу оторвавшись повис воздухе решил отложить письмо глазах рябило усталости старший брат негромко прозвучал ухом знакомый голос пошевельнулся словно слышал слезы навернулись глаза подошел цзюесиню положил руку плечо увидев написанное сочувственно произнес чему думаешь мертвых воскресишь подумай своем собственном здоровье поднял голову повернулся вращающемся стуле увидел брат плачет схватил руку младшего брата крепко сжал сквозь слезы проговорил потвоему должен делать понял брат ищет поддержки стал ласково уговаривать старший брат почему сих пор сильно переживаешь напрасно мучаешь исстрадался страшны страдания могу вынести пусть принуждают подчиняться воле словно борясь собой горечью произнес этим хочешь сказать понял хотят женился вторично ответил помолчал процедил сквозь зубы вечно никак хотят оставить покое утирая слезы жалобно произнес твое личное дело смеют вмешиваться трудом подавляя гнев твердо сказал понимал всей серьезности положения думал старшему брату легко разрешить вопрос обойдя подошел плетеному креслу стоявшему окна спокойно уселся против брата энергичнее мать уговаривает говорят несколько месяцев истекает срок моего траура едва слышно словно произнес плача изза трех видов непочтения родителям самое страшное непродление рода… саркастически бросил ответил сунул карман носовой платок уныло опустил голову взор казалось прикован письму видел глазами проносились туманные образы прошлого каждый знаком хотелось удержать мысленно побеседовать ними понимал происходит душе брата произносил звука думал другом воображении постепенно вырисовывалось лицо молодой девушки видел улыбается казалось комната погружается безмолвие электрическая лампочка постепенно тускнела лунный свет посеребрил оконные стекла неясные тени падавшие занавесок легли углах комнаты окном светло лишь монотонное тиканье маятника напоминало неумолимом течении времени неожиданно вздохнул вздох настолько слабым услышал раздался гудок протяжный резкий вой заставил вздрогнуть широко открыв глаза огляделся изменилось хэсао позвал едва слышно ответа поднялся подошел столу зажег керосиновую лампу вернувшись опустился стул взгляд снова упал письмо лежавшее столе взял кисточку собираясь продолжать письмо свет электрической лампочки становился тусклым строчки сливались глазами невольно вздохнув уронил кисточку подняв голову тоской уставился лампочку свет окончательно потускнел мерцала лишь красная нить нить постепенно угасла одиноко светилась столе керосиновая лампа освещая всей комнаты словно воспользовавшись этим комнату прокрался лунный свет полу задней комнаты освещенной лампой лежали тени деревьев оконной занавески передняя комната залита лунным светом выдержав резко встал горечью сказал брату тебе действительно жениться вторично жить живешь тебе очень тоскливо совершенно одинок согласен ними невозможно могу поступить подобным образом покачал гол ...

# %%
bigram_vectorizer = CountVectorizer(ngram_range=(2,2),
                                    token_pattern=r'[А-Яа-я]+', min_df=2)

# %%
analyze = bigram_vectorizer.build_analyzer()

# %%
z = analyze(bajin1)

# %%
Counter(z).most_common()
# Out:
# [('чэнь итай', 143),
#  ('госпожа шэнь', 136),
#  ('госпожа ван', 124),
#  ('старая госпожа', 103),
#  ('госпожа чэнь', 71),
#  ('чэн цзяньбин', 52),
#  ('покачал головой', 35),
#  ('опустив голову', 34),
#  ('хуан цуньжэнь', 33),
#  ('последнее время', 30),
#  ('госпожа сюй', 28),
#  ('госпожи ван', 25),
#  ('сяо хойфан', 24),
#  ('фан цзишунь', 23),
#  ('некоторое время', 22),
#  ('поднял голову', 21),
#  ('дядя кэмин', 20),
#  ('ван чэнь', 20),
#  ('госпожи шэнь', 19),
#  ('обо всем', 18),
#  ('тетя ван', 18),
#  ('госпоже ван', 18),
#  ('сказала госпожа', 17),
#  ('обращая внимания', 17),
#  ('тетя шэнь', 17),
#  ('госпожа госпожа', 17),
#  ('старой госпожи', 17),
#  ('письменного стола', 17),
#  ('дядя кэдин', 16),
#  ('тех пор', 16),
#  ('таком случае', 16),
#  ('молодой барин', 16),
#  ('последние слова', 16),
#  ('покачала головой', 16),
#  ('чтото сказать', 16),
#  ('госпожу шэнь', 16),
#  ('госпожу ван', 16),
#  ('старой госпоже', 16),
#  ('тетушка тан', 16),
#  ('старший брат', 15),
#  ('опустил голову', 15),
#  ('каждый день', 15),
#  ('сквозь слезы', 14),
#  ('подняв голову', 14),
#  ('конце концов', 14),
#  ('тихим голосом', 14),
#  ('друг друга', 14),
#  ('ответила госпожа', 14),
#  ('сяо хойфана', 14),
#  ('подняла голову', 13),
#  ('своей комнате', 13),
#  ('госпожи чэнь', 13),
#  ('сих пор', 12),
#  ('целый день', 12),
#  ('самом деле', 12),
#  ('этих словах', 12),
#  ('прошлом году', 12),
#  ('несколько дней', 12),
#  ('всяком случае', 12),
#  ('цзюеин цзюецюнь', 11),
#  ('семье гао', 11),
#  ('лицо выражало', 11),
#  ('этими словами', 11),
#  ('тебе нужно', 11),
#  ('появилось выражение', 11),
#  ('чэнь госпожа', 11),
#  ('несколько лет', 11),
#  ('дядя кэань', 11),
#  ('кэань кэдин', 11),
#  ('взглянул брата', 11),
#  ('опустила голову', 11),
#  ('гроб телом', 10),
#  ('друг другу', 10),
#  ('выражение лица', 10),
#  ('крайней мере', 10),
#  ('целыми днями', 10),
#  ('голосе звучала', 10),
#  ('немного погодя', 10),
#  ('лицо мэя', 10),
#  ('другим тоном', 10),
#  ('обратилась цзюесиню', 10),
#  ('произнесла госпожа', 10),
#  ('поговорить тобой', 10),
#  ('покачав головой', 9),
#  ('старшего брата', 9),
#  ('речь зашла', 9),
#  ('очень тяжело', 9),
#  ('старшая сестра', 9),
#  ('семьи гао', 9),
#  ('изо сил', 9),
#  ('цзюецюнь цзюеши', 9),
#  ('хотел сказать', 9),
#  ('голос звучал', 9),
#  ('лице появилось', 9),
#  ('старую госпожу', 9),
#  ('лицо руками', 9),
#  ('госпожой ван', 9),
#  ('изменилась лице', 9),
#  ('раскрыть рта', 9),
#  ('младшего брата', 8),
#  ('письменному столу', 8),
#  ('улыбнулась госпожа', 8),
#  ('душе стало', 8),
#  ('дело концом', 8),
#  ('кивнул головой', 8),
#  ('говоря слова', 8),
#  ('обеим сторонам', 8),
#  ('сегодня вечером', 8),
#  ('твоя мать', 8),
#  ('лице появилась', 8),
#  ('могу сделать', 8),
#  ('дяди кэмина', 8),
#  ('стало легче', 8),
#  ('старой госпожой', 8),
#  ('письменным столом', 8),
#  ('сказать чтото', 8),
#  ('ко всему', 8),
#  ('чтонибудь случится', 8),
#  ('извиняющимся тоном', 8),
#  ('юбилейный номер', 8),
#  ('каждым днем', 8),
#  ('доме гао', 8),
#  ('взгляд цзюеминя', 8),
#  ('письменный стол', 8),
#  ('ван госпожа', 8),
#  ('молодых людей', 8),
#  ('продать дом', 8),
#  ('ко всем', 7),
#  ('понимаю почему', 7),
#  ('обратил внимания', 7),
#  ('очень нравится', 7),
#  ('слова цзюеминя', 7),
#  ('комнату госпожи', 7),
#  ('вышла комнаты', 7),
#  ('стояла рядом', 7),
#  ('сдерживая смех', 7),
#  ('тому назад', 7),
#  ('тихо ответил', 7),
#  ('будем говорить', 7),
#  ('фонарем руке', 7),
#  ('взглянула цзюеминя', 7),
#  ('правде говоря', 7),
#  ('угрызения совести', 7),
#  ('тихо ответила', 7),
#  ('этих слов', 7),
#  ('спросила госпожа', 7),
#  ('изза стола', 7),
#  ('глаза покраснели', 7),
#  ('свои слова', 7),
#  ('молодые сердца', 7),
#  ('вызыватель духов', 7),
#  ('открыл глаза', 7),
#  ('приходилось видеть', 7),
#  ('госпоже чэнь', 7),
#  ('своего места', 7),
#  ('вошел комнату', 7),
#  ('изменился лице', 7),
#  ('холодно усмехнулась', 7),
#  ('собственно говоря', 7),
#  ('слезами глазах', 7),
#  ('итай госпожа', 7),
#  ('взгляд сторону', 7),
#  ('будучи силах', 7),
#  ('своей комнаты', 7),
#  ('сути дела', 7),
#  ('ло цзинтина', 7),
#  ('руку плечо', 6),
#  ('хочешь сказать', 6),
#  ('происходит душе', 6),
#  ('лунный свет', 6),
#  ('опустился стул', 6),
#  ('госпожа сказала', 6),
#  ('проговорила госпожа', 6),
#  ('внимания слова', 6),
#  ('срок траура', 6),
#  ('выражения лица', 6),
#  ('поникшей головой', 6),
#  ('вышел комнаты', 6),
#  ('спросил кэмин', 6),
#  ('спокойно ответил', 6),
#  ('покачивая головой', 6),
#  ('цзюеши цзюежэнь', 6),
#  ('протянул руку', 6),
#  ('свое время', 6),
#  ('таким тоном', 6),
#  ('младший брат', 6),
#  ('голос цзюеминя', 6),
#  ('успел ответить', 6),
#  ('вошли комнату', 6),
#  ('госпожа велела', 6),
#  ('обратилась госпожа', 6),
#  ('звонким голосом', 6),
#  ('очень быстро', 6),
#  ('вспоминать прошлом', 6),
#  ('настала очередь', 6),
#  ('голову приходило', 6),
#  ('почему тебе', 6),
#  ('дожидаясь ответа', 6),
#  ('барышня шуин', 6),
#  ('молча смотрел', 6),
#  ('услышав слова', 6),
#  ('хотела сказать', 6),
#  ('последних сил', 6),
#  ('протянула руку', 6),
#  ('чайный столик', 6),
#  ('вызывателем духов', 6),
#  ('сделал вид', 6),
#  ('стоявший рядом', 6),
#  ('хотел чтото', 6),
#  ('всем этим', 6),
#  ('можешь говорить', 6),
#  ('тетей ван', 6),
#  ('госпоже шэнь', 6),
#  ('голос госпожи', 6),
#  ('безразличным видом', 6),
#  ('сяо хойфаном', 6),
#  ('кэань бисю', 6),
#  ('бисю кэань', 6),
#  ('дверей зала', 6),
#  ('главным образом', 6),
#  ('отсутствующим взглядом', 6),
#  ('прерывающимся голосом', 6),
#  ('дом чжэнов', 6),
#  ('головой госпожа', 6),
#  ('никто знает', 6),
#  ('могу видеть', 6),
#  ('свое дело', 6),
#  ('прямо лицо', 6),
#  ('большое спасибо', 6),
#  ('произнести слова', 6),
#  ('ло цзинтином', 6),
#  ('ван юньбо', 6),
#  ('глава семьи', 6),
#  ('знакомый голос', 5),
#  ('сквозь зубы', 5),
#  ('личное дело', 5),
#  ('старшему брату', 5),
#  ('несколько месяцев', 5),
#  ('лунным светом', 5),
#  ('горечью сказал', 5),
#  ('жалостью глядя', 5),
#  ('посреди комнаты', 5),
#  ('двоюродного брата', 5),
#  ('мои дела', 5),
#  ('тихо проговорил', 5),
#  ('дядя ботао', 5),
#  ('семья чжэн', 5),
#  ('лице цзюеминя', 5),
#  ('несколько глотков', 5),
#  ('обратился брату', 5),
#  ('повернул голову', 5),
#  ('двоюродный брат', 5),
#  ('пор пока', 5),
#  ('видя молчит', 5),
#  ('само собой', 5),
#  ('собой разумеется', 5),
#  ('вымолвить слова', 5),
#  ('вчера вечером', 5),
#  ('перевел взгляд', 5),
#  ('стиснув зубы', 5),
#  ('кивнула головой', 5),
#  ('берегу озера', 5),
#  ('вмешался разговор', 5),
#  ('стараясь скрыть', 5),
#  ('свои мысли', 5),
#  ('сбежала лица', 5),
#  ('улыбку лице', 5),
#  ('появилась улыбка', 5),
#  ('солнечные лучи', 5),
#  ('обратилась госпоже', 5),
#  ('ласково сказала', 5),
#  ('мама сегодня', 5),
#  ('тебе придется', 5),
#  ('твое дело', 5),
#  ('словно слыша', 5),
#  ('старшей сестры', 5),
#  ('искусственные горки', 5),
#  ('глаза наполнились', 5),
#  ('наполнились слезами', 5),
#  ('схватила руку', 5),
#  ('нашей семьи', 5),
#  ('поспешно вышла', 5),
#  ('голосе слышалось', 5),
#  ('весь свой', 5),
#  ('уговаривала госпожа', 5),
#  ('довольным тоном', 5),
#  ('голосом сказал', 5),
#  ('вернувшись домой', 5),
#  ('казалось видит', 5),
#  ('словно сне', 5),
#  ('хочу спросить', 5),
#  ('мог найти', 5),
#  ('искусственную горку', 5),
#  ('дрожащим голосом', 5),
#  ('тихо сказал', 5),
#  ('каменными плитами', 5),
#  ('молодого барина', 5),
#  ('понизив голос', 5),
#  ('взоры обратились', 5),
#  ('наше время', 5),
#  ('вслед цзюесинем', 5),
#  ('внутреннем дворике', 5),
#  ('оставалось лишь', 5),
#  ('дом гао', 5),
#  ('чтонибудь сделать', 5),
#  ('ко рту', 5),
#  ('несколько минут', 5),
#  ('хэ жоцзюнь', 5),
#  ('очень занят', 5),
#  ('хуан цуньжэня', 5),
#  ('отвечал хойжу', 5),
#  ('несколько слов', 5),
#  ('низко опустив', 5),
#  ('говорил медленно', 5),
#  ('взглянув брата', 5),
#  ('всей души', 5),
#  ('лицо стало', 5),
#  ('взглянув цзюеминя', 5),
#  ('осталось следа', 5),
#  ('слабая улыбка', 5),
#  ('обратилась нему', 5),
#  ('никуда годится', 5),
#  ('придет конец', 5),
#  ('немного успокоившись', 5),
#  ('члены семьи', 5),
#  ('старшая госпожа', 5),
#  ('посмотрел жену', 5),
#  ('своем месте', 5),
#  ('кормилица ян', 5),
#  ('пришла госпожа', 5),
#  ('своего сына', 5),
#  ('очень плохо', 5),
#  ('худое лицо', 5),
#  ('сжал руку', 5),
#  ('ответил кэань', 5),
#  ('кэдин сяо', 5),
#  ('господин кэань', 5),
#  ('кэаня кэань', 5),
#  ('дверные занавески', 5),
#  ('подойдя столу', 5),
#  ('первым делом', 5),
#  ('правого флигеля', 5),
#  ('перевела взгляд', 5),
#  ('главой семьи', 5),
#  ('словно очнувшись', 5),
#  ('звонкий голос', 5),
#  ('закусил губу', 5),
#  ('помоему дядя', 5),
#  ('вернулся домой', 5),
#  ('комнате госпожи', 5),
#  ('никакого внимания', 5),
#  ('мог сказать', 5),
#  ('жены мэя', 5),
#  ('закрыл глаза', 5),
#  ('зная решиться', 5),
#  ('молодой человек', 5),
#  ('жизненных сил', 5),
#  ('вышла вслед', 5),
#  ('стоял своем', 5),
#  ('последних словах', 5),
#  ('хочу поговорить', 5),
#  ('стоявшая рядом', 5),
#  ('закрыв лицо', 5),
#  ('молодому барину', 5),
#  ('вернуться домой', 5),
#  ('последние дни', 4),
#  ('носовой платок', 4),
#  ('взгляд снова', 4),
#  ('керосиновая лампа', 4),
#  ('подобным образом', 4),
#  ('уронив голову', 4),
#  ('внимательно посмотрел', 4),
#  ('судьба судьба', 4),
#  ('горько усмехнулся', 4),
#  ('девичий голос', 4),
#  ('дверная занавеска', 4),
#  ('сандалового дерева', 4),
#  ('женитьбе мэя', 4),
#  ('почему дядя', 4),
#  ('лице госпожи', 4),
#  ('легкая улыбка', 4),
#  ('нужно идти', 4),
#  ('взяла чашку', 4),
#  ('чашку чаю', 4),
#  ('очень упрям', 4),
#  ('европейская медицина', 4),
#  ('старшим братом', 4),
#  ('сегодня очень', 4),
#  ('смеешься мной', 4),
#  ('честное слово', 4),
#  ('сказал цзюеин', 4),
#  ('наша семья', 4),
#  ('людей которые', 4),
#  ('голосе звучали', 4),
#  ('такая жизнь', 4),
#  ('сердце стало', 4),
#  ('стало тяжелее', 4),
#  ('глядя прямо', 4),
#  ('утирала слезы', 4),
#  ('обращай внимания', 4),
#  ('сказал слова', 4),
#  ('кэдин продал', 4),
#  ('сказал кэмин', 4),
#  ('кулаком столу', 4),
#  ('всеми силами', 4),
#  ('нам всем', 4),
#  ('проронил звука', 4),
#  ('свое мнение', 4),
#  ('комнате остались', 4),
#  ('госпожа остальные', 4),
#  ('фэн лэшань', 4),
#  ('отвечала госпожа', 4),
#  ('лица цзюеминя', 4),
#  ('будем играть', 4),
#  ('госпожа поняла', 4),
#  ('вытирая слезы', 4),
#  ('откровенно призналась', 4),
#  ('слова сказал', 4),
#  ('чужие дела', 4),
#  ('помолчав добавил', 4),
#  ('друг другом', 4),
#  ('тебе самому', 4),
#  ('слова мэя', 4),
#  ('одной стороны', 4),
#  ('время очень', 4),
#  ('улыбка сбежала', 4),
#  ('подожди пока', 4),
#  ('вместе нами', 4),
#  ('повернулась цзюесиню', 4),
#  ('лицо попрежнему', 4),
#  ('голову тихо', 4),
#  ('против воли', 4),
#  ('свои чувства', 4),
#  ('хочется пить', 4),
#  ('палочки еды', 4),
#  ('обращать внимания', 4),
#  ('понимающе кивнула', 4),
#  ('взяла руку', 4),
#  ('откуда знать', 4),
#  ('ктонибудь услышит', 4),
#  ('очень редко', 4),
#  ('подошла столу', 4),
#  ('никто ответил', 4),
#  ('довольной улыбкой', 4),
#  ('предложила госпожа', 4),
#  ('свое место', 4),
#  ('целый год', 4),
#  ('свет фонаря', 4),
#  ('тронула губы', 4),
#  ('почему сегодня', 4),
#  ('барин молодой', 4),
#  ('собственными глазами', 4),
#  ('произнося слова', 4),
#  ('сердце сжалось', 4),
#  ('весь день', 4),
#  ('нашей семье', 4),
#  ('этих людей', 4),
#  ('барин барышня', 4),
#  ('слова застряли', 4),
#  ('самим собой', 4),
#  ('голову увидел', 4),
#  ('довольным видом', 4),
#  ('громко сказала', 4),
#  ('направилась выходу', 4),
#  ('услышав шаги', 4),
#  ('похлопал плечу', 4),
#  ('хотел заговорить', 4),
#  ('злой рок', 4),
#  ('тетей шэнь', 4),
#  ('приказала служанке', 4),
#  ('твоей матери', 4),
#  ('отлегло сердца', 4),
#  ('могла сказать', 4),
#  ('сердце каждого', 4),
#  ('принесла чай', 4),
#  ('вместе госпожой', 4),
#  ('лице мэя', 4),
#  ('снова вернулся', 4),
#  ('госпожа приказала', 4),
#  ('откуда знаешь', 4),
#  ('пойди скажи', 4),
#  ('несправедливо обидели', 4),
#  ('принялась мягко', 4),
#  ('одной рукой', 4),
#  ('помоему тебе', 4),
#  ('тихо спросила', 4),
#  ('внутреннюю комнату', 4),
#  ('шепнул ухо', 4),
#  ('тоном произнес', 4),
#  ('старый строй', 4),
#  ('молодые люди', 4),
#  ('спросила чэн', 4),
#  ('чтото вроде', 4),
#  ('паланкин остановился', 4),
#  ('боковую дверь', 4),
#  ('стало ясно', 4),
#  ('сестра сестра', 4),
#  ('откинулся спинку', 4),
#  ('свое горе', 4),
#  ('проводить время', 4),
#  ('хороший человек', 4),
#  ('вмешалась госпожа', 4),
#  ('возразила госпожа', 4),
#  ('глаза полны', 4),
#  ('полны слез', 4),
#  ('принялась успокаивать', 4),
#  ('госпожу чэнь', 4),
#  ('свет лампы', 4),
#  ('ожидая пока', 4),
#  ('повернув голову', 4),
#  ('казалось вотвот', 4),
#  ('жене мэя', 4),
#  ('слова словно', 4),
#  ('немного боюсь', 4),
#  ('тяжелым камнем', 4),
#  ('держа руке', 4),
#  ('книгу тетрадь', 4),
#  ('сначала хотела', 4),
#  ('всему этому', 4),
#  ('цзюеминя казалось', 4),
#  ('сколько времени', 4),
#  ('смотрела цзюеминя', 4),
#  ('быстро встав', 4),
#  ('мягко обратилась', 4),
#  ('праздник лета', 4),
#  ('собачьей смертью', 4),
#  ('вне гнева', 4),
#  ('вошла комнату', 4),
#  ('голову взглянул', 4),
#  ('сомкнуть глаз', 4),
#  ('господин кэмин', 4),
#  ('пойду скажу', 4),
#  ('пойду тобой', 4),
#  ('обратился нему', 4),
#  ('женском флигеле', 4),
#  ('обратился цзюесиню', 4),
#  ('голосом спросил', 4),
#  ('ожидая скажет', 4),
#  ('произнес кэмин', 4),
#  ('испытывала чувство', 4),
#  ('тетушка ван', 4),
#  ('расскажу тебе', 4),
#  ('продолжала госпожа', 4),
#  ('госпожа подошла', 4),
#  ('видя дядя', 4),
#  ('усмехнулась госпожа', 4),
#  ('прав виноват', 4),
#  ('затаив дыхание', 4),
#  ('дяди кэдина', 4),
#  ('каждое слово', 4),
#  ('шэнь которая', 4),
#  ('масла огонь', 4),
#  ('моей комнате', 4),
#  ('отец умер', 4),
#  ('госпожа кэмин', 4),
#  ('отпустил руку', 4),
#  ('смотрел лицо', 4),
#  ('руку жены', 4),
#  ('лет назад', 4),
#  ('госпожой шэнь', 4),
#  ('шэнь сказала', 4),
#  ('стоит сердиться', 4),
#  ('шэнь госпожа', 4),
#  ('вне радости', 4),
#  ('игральный стол', 4),
#  ('спросил бисю', 4),
#  ('пойдем домой', 4),
#  ('всем телом', 4),
#  ('пошел навстречу', 4),
#  ('этому времени', 4),
#  ('пойдем посмотрим', 4),
#  ('кэмин другие', 4),
#  ('эта мысль', 4),
#  ('честно говоря', 4),
#  ('своему гневу', 4),
#  ('таким образом', 4),
#  ('свое сердце', 4),
#  ('вид мэя', 4),
#  ('непонимающе смотрел', 4),
#  ('знаю почему', 4),
#  ('чжэн гогуан', 4),
#  ('скрыть свое', 4),
#  ('наш полководец', 4),
#  ('ладно ладно', 4),
#  ('комнате молодых', 4),
#  ('чьято рука', 4),
#  ('решительно произнес', 4),
#  ('свадебный паланкин', 4),
#  ('смысл слов', 4),
#  ('шаг шагом', 4),
#  ('глядя мэя', 4),
#  ('широко раскрытыми', 4),
#  ('раскрытыми глазами', 4),
#  ('творится душе', 4),
#  ('домой вместе', 4),
#  ('взглядом смотрел', 4),
#  ('голосом сказала', 4),
#  ('твоего отца', 4),
#  ('сказала очень', 4),
#  ('видя госпожа', 4),
#  ('прямого ответа', 4),
#  ('сюй видя', 4),
#  ('сказал несколько', 4),
#  ('пятого числа', 4),
#  ('очень удобно', 4),
#  ('цзюесиню казалось', 4),
#  ('ванюн чэньчи', 4),
#  ('находившихся комнате', 4),
#  ('подняла глаза', 4),
#  ('ту сторону', 4),
#  ('ответил хойжу', 4),
#  ('знак согласия', 4),
#  ('задумчиво произнес', 4),
#  ('уехать отсюда', 4),
#  ('твой брат', 4),
#  ('мимо ушей', 4),
#  ('чьято тень', 4),
#  ('тобой поговорить', 4),
#  ('словно обращаясь', 4),
#  ('вежливо поддакивал', 4),
#  ('таким видом', 4),
#  ('старый господин', 4),
#  ('гроб хой', 4),
#  ('конце года', 4),
#  ('презрительный взгляд', 4),
#  ('говорила госпожа', 4),
#  ('кэаня дома', 4),
#  ('никак мог', 4),
#  ('дядю кэаня', 4),
#  ('нечистой крови', 4),
#  ('нашем доме', 4),
#  ('госпожа знала', 4),
#  ('голосе слышалась', 4),
#  ('голову грудь', 4),
#  ('брат очень', 4),
#  ('хорошего врача', 4),
#  ('спасибо барышня', 4),
#  ('вместе тобой', 4),
#  ('позапрошлом году', 4),
#  ('говорил говорил', 4),
#  ('краю кровати', 4),
#  ('вижу тебе', 4),
#  ('нужно побыстрее', 4),
#  ('сводя глаз', 4),
#  ('скажи делать', 4),
#  ('руки груди', 4),
#  ('жена мэя', 4),
#  ('тетя чэнь', 4),
#  ('следы крови', 4),
#  ('жертвенном столике', 4),
#  ('ло цзинтин', 4),
#  ('молодой женщины', 4),
#  ('бросилась колодец', 4),
#  ('придет время', 4),
#  ('здоровье дяди', 4),
#  ('торговые ряды', 4),
#  ('вдова мэя', 4),
#  ('старший дядя', 3),
#  ('третья тетя', 3),
#  ('деньги которые', 3),
#  ('немного времени', 3),
#  ('слезы навернулись', 3),
#  ('навернулись глаза', 3),
#  ('схватил руку', 3),
#  ('ласково уговаривать', 3),
#  ('электрическая лампочка', 3),
#  ('неожиданно вздохнул', 3),
#  ('подошел столу', 3),
#  ('снова упал', 3),
#  ('упал письмо', 3),
#  ('тебе очень', 3),
#  ('глядя брата', 3),
#  ('кусая губы', 3),
#  ('взволнованно произнес', 3),
#  ('благодарен тебе', 3),
#  ('горячо возразил', 3),
#  ('какойнибудь выход', 3),
#  ('изза двери', 3),
#  ('комнату вошла', 3),
#  ('хочет видеть', 3),
#  ('вышли комнаты', 3),
#  ('остановила госпожа', 3),
#  ('цися поставила', 3),
#  ('сестра хой', 3),
#  ('посмотрел цзюеминя', 3),
#  ('цися налейка', 3),
#  ('обращаясь ко', 3),
#  ('совести говоря', 3),
#  ('отца госпожа', 3),
#  ('давайте поговорим', 3),
#  ('вашего дяди', 3),
#  ('досадой сказала', 3),
#  ('нахмурил брови', 3),
#  ('опасаясь слова', 3),
#  ('слова могут', 3),
#  ('скверный характер', 3),
#  ('семья фэн', 3),
#  ('никто обратил', 3),
#  ('никак могу', 3),
#  ('могу понять', 3),
#  ('продолжатель рода', 3),
#  ('испортил жизнь', 3),
#  ('имею права', 3),
#  ('тебе следует', 3),
#  ('вслед цзюеминем', 3),
#  ('приказала госпожа', 3),
#  ('скоро женится', 3),
#  ('вся семья', 3),
#  ('сестра шуин', 3),
#  ('десять часов', 3),
#  ('громко окликнула', 3),
#  ('лице играла', 3),
#  ('склонив голову', 3),
#  ('старшая тетя', 3),
#  ('ответил цзюеин', 3),
#  ('обратилась цзюеминю', 3),
#  ('сказал кому', 3),
#  ('несколько шагов', 3),
#  ('жить спокойно', 3),
#  ('вернее сказать', 3),
#  ('сказал затем', 3),
#  ('чтото сказала', 3),
#  ('ван тетя', 3),
#  ('сквозь густую', 3),
#  ('двоюродную сестру', 3),
#  ('участливо спросила', 3),
#  ('весь вечер', 3),
#  ('какое имеет', 3),
#  ('зная ответить', 3),
#  ('голубое небо', 3),
#  ('эта девушка', 3),
#  ('пора тебе', 3),
#  ('прямо глаза', 3),
#  ('чтонибудь придумаем', 3),
#  ('цзюеминя сегодня', 3),
#  ('удивленно взглянул', 3),
#  ('сестру руку', 3),
#  ('искусственная горка', 3),
#  ('служанка госпожи', 3),
#  ('сказала ладно', 3),
#  ('господин кэдин', 3),
#  ('помолчал затем', 3),
#  ('кому обращаясь', 3),
#  ('трудом сдерживая', 3),
#  ('тени улыбки', 3),
#  ('который стоял', 3),
#  ('немного отдохнуть', 3),
#  ('юаньчэн суфу', 3),
#  ('тяжело дышал', 3),
#  ('промолвил кэмин', 3),
#  ('долгого молчания', 3),
#  ('участия разговоре', 3),
#  ('душе очень', 3),
#  ('давно видела', 3),
#  ('время разговора', 3),
#  ('разу видела', 3),
#  ('фэн лэшаня', 3),
#  ('такие вещи', 3),
#  ('слова дочери', 3),
#  ('поспешно встала', 3),
#  ('внутренний дворик', 3),
#  ('коньке крыши', 3),
#  ('такие церемонии', 3),
#  ('уголках глаз', 3),
#  ('вместе вами', 3),
#  ('пить вино', 3),
#  ('оживилась госпожа', 3),
#  ('согласилась госпожа', 3),
#  ('выбежала комнаты', 3),
#  ('какоето странное', 3),
#  ('арочный мост', 3),
#  ('нечего сказать', 3),
#  ('цзюеин цзюежэнь', 3),
#  ('давай сюда', 3),
#  ('старшей сестре', 3),
#  ('голосом спросила', 3),
#  ('могу дать', 3),
#  ('старшему поколению', 3),
#  ('хочу посмотреть', 3),
#  ('закусив губу', 3),
#  ('положив руку', 3),
#  ('ушах звучали', 3),
#  ('звучали слова', 3),
#  ('затем сказал', 3),
#  ('привлек внимание', 3),
#  ('поверхность воды', 3),
#  ('бледном лице', 3),
#  ('тебе нравится', 3),
#  ('сочувственно сказал', 3),
#  ('казалось понимает', 3),
#  ('мог ответить', 3),
#  ('отец говорит', 3),
#  ('тобой очень', 3),
#  ('вовсе собирался', 3),
#  ('направила лодку', 3),
#  ('заросли лотоса', 3),
#  ('прислушивался разговору', 3),
#  ('лодка приблизилась', 3),
#  ('едва сдерживая', 3),
#  ('проучи следует', 3),
#  ('слегка покраснела', 3),
#  ('отношение ко', 3),
#  ('просто знаю', 3),
#  ('сама знаю', 3),
#  ('утра вечера', 3),
#  ('твой характер', 3),
#  ('думать будущем', 3),
#  ('лицо просветлело', 3),
#  ('услышав последние', 3),
#  ('маленькие ножки', 3),
#  ('лучи солнца', 3),
#  ('улыбающиеся лица', 3),
#  ('давайте споем', 3),
#  ('сегодня просто', 3),
#  ('прислонившись перилам', 3),
#  ('почему должен', 3),
#  ('отец хочет', 3),
#  ('головой тихо', 3),
#  ('своему отцу', 3),
#  ('оно таким', 3),
#  ('звучала боль', 3),
#  ('левой рукой', 3),
#  ('своей правоте', 3),
#  ('чтото ухо', 3),
#  ('легонько стукнула', 3),
#  ('стукнула голове', 3),
#  ('слегка нахмурившись', 3),
#  ('искусственной горки', 3),
#  ('присутствующих обратились', 3),
#  ('госпожа трудом', 3),
#  ('удивилась госпожа', 3),
#  ('пусть тетя', 3),
#  ('тетя тетя', 3),
#  ('тетя сегодня', 3),
#  ('госпожа обращаясь', 3),
#  ('вместе цися', 3),
#  ('могу пить', 3),
#  ('пить вина', 3),
#  ('самого начала', 3),
#  ('госпожа снова', 3),
#  ('делая вид', 3),
#  ('очень хотелось', 3),
#  ('разговор госпожа', 3),
#  ('внимательно следили', 3),
#  ('тебе пришлось', 3),
#  ('силами пытался', 3),
#  ('хой сказала', 3),
#  ('молодое сердце', 3),
#  ('госпожу госпожу', 3),
#  ('середине озера', 3),
#  ('участливо спросил', 3),
#  ('чтото буркнул', 3),
#  ('набравшись храбрости', 3),
#  ('изумленно взглянул', 3),
#  ('мире мираж', 3),
#  ('сказал лишь', 3),
#  ('заколдованного круга', 3),
#  ('единственный сын', 3),
#  ('неужели действительно', 3),
#  ('чтото невнятное', 3),
#  ('очнувшись сна', 3),
#  ('которой стоял', 3),
#  ('черная тень', 3),
#  ('эта тварь', 3),
#  ('сказала таким', 3),
#  ('коем случае', 3),
#  ('глубине души', 3),
#  ('улыбкой сказала', 3),
#  ('такие люди', 3),
#  ('барышни шуин', 3),
#  ('время мог', 3),
#  ('вновь спросила', 3),
#  ('утвердительный ответ', 3),
#  ('слова которые', 3),
#  ('сказать слова', 3),
#  ('застряли горле', 3),
#  ('услышал голос', 3),
#  ('слышал слов', 3),
#  ('говорил сегодня', 3),
#  ('брат тебе', 3),
#  ('почему говоришь', 3),
#  ('полюбоваться луной', 3),
#  ('каменным ступеням', 3),
#  ('звучали ушах', 3),
#  ('никто решался', 3),
#  ('силах продолжать', 3),
#  ('трудно понять', 3),
#  ('голос срывался', 3),
#  ('полон энергии', 3),
#  ('оставят покое', 3),
#  ('одно дело', 3),
#  ('обращал внимания', 3),
#  ('можешь думать', 3),
#  ('заблестели слезы', 3),
#  ('тебе хочется', 3),
#  ('торопливо ответил', 3),
#  ('мое положение', 3),
#  ('ктото позвал', 3),
#  ('всем вместе', 3),
#  ('помогу тебе', 3),
#  ('отвечала чуньлань', 3),
#  ('бумажные деньги', 3),
#  ('возвращаться домой', 3),
#  ('боюсь знаю', 3),
#  ('поднимая головы', 3),
#  ('потерпи немного', 3),
#  ('головой лицо', 3),
#  ('закусила губу', 3),
#  ('пора идти', 3),
#  ('тихо спросил', 3),
#  ('цися цися', 3),
#  ('барышня барин', 3),
#  ('собрались вместе', 3),
#  ('почувствовал сердце', 3),
#  ('прошлый год', 3),
#  ('приготовили стол', 3),
#  ('прямо собой', 3),
#  ('слишком поздно', 3),
#  ('год назад', 3),
#  ('следующий день', 3),
#  ('удивлением спросила', 3),
#  ('вошла цися', 3),
#  ('поднос стол', 3),
#  ('произнесла слова', 3),
#  ('мягко уговаривать', 3),
#  ('стоит думать', 3),
#  ('почему всем', 3),
#  ('понимаю хочешь', 3),
#  ('свои собственные', 3),
#  ('тебе понять', 3),
#  ('отрывая глаз', 3),
#  ('шепотом предупредила', 3),
#  ('левого флигеля', 3),
#  ('сегодня обеда', 3),
#  ('пойдем вместе', 3),
#  ('пьесе накануне', 3),
#  ('цзишунь чэн', 3),
#  ('сказал хуан', 3),
#  ('какимто предлогом', 3),
#  ('около окна', 3),
#  ('сказала сегодня', 3),
#  ('лишь несколько', 3),
#  ('несколько писем', 3),
#  ('очень мало', 3),
#  ('люди которые', 3),
#  ('цуньжэнь хойжу', 3),
#  ('говорил таким', 3),
#  ('непременно нужно', 3),
#  ('чтонибудь новое', 3),
#  ('учебных заведениях', 3),
#  ('сказал хуаньжу', 3),
#  ('года тому', 3),
#  ('прекрасный день', 3),
#  ('хотела чтото', 3),
#  ('служанку та', 3),
#  ('стуле около', 3),
#  ('около письменного', 3),
#  ('голову увидела', 3),
#  ('сдерживая слезы', 3),
#  ('лист бумаги', 3),
#  ('противоречивые чувства', 3),
#  ('бабушка мама', 3),
#  ('горечью произнесла', 3),
#  ('сестра нужно', 3),
#  ('несколько слезинок', 3),
#  ('снова спросила', 3),
#  ('будущее смутно', 3),
#  ('смутно прежде', 3),
#  ('прежде спасать', 3),
#  ('спасать самого', 3),
#  ('слез глаза', 3),
#  ('видя брат', 3),
#  ('слез лице', 3),
#  ('выражение скорби', 3),
#  ('глаза заблестели', 3),
#  ('слезы потекли', 3),
#  ('спросил откуда', 3),
#  ('хой умерла', 3),
#  ('говорил очень', 3),
#  ('хотел улыбнуться', 3),
#  ('лицо вспыхнуло', 3),
#  ('слова проникли', 3),
#  ('пришлись душе', 3),
#  ('ряда вон', 3),
#  ('которые приходилось', 3),
#  ('старшего поколения', 3),
#  ('слова брата', 3),
#  ('молодых сердец', 3),
#  ('внутреннему дворику', 3),
#  ('сегодня хой', 3),
#  ('несли паланкин', 3),
#  ('густую тень', 3),
#  ('светом фонаря', 3),
#  ('госпожа остановила', 3),
#  ('цуйфэн принесика', 3),
#  ('дяди ботао', 3),
#  ('взять наложницу', 3),
#  ('чтото понимаю', 3),
#  ('перестала плакать', 3),
#  ('такое время', 3),
#  ...]

# %%
print(stopwords.words('russian'))
# Out:
# ['и', 'в', 'во', 'не', 'что', 'он', 'на', 'я', 'с', 'со', 'как', 'а', 'то', 'все', 'она', 'так', 'его', 'но', 'да', 'ты', 'к', 'у', 'же', 'вы', 'за', 'бы', 'по', 'только', 'ее', 'мне', 'было', 'вот', 'от', 'меня', 'еще', 'нет', 'о', 'из', 'ему', 'теперь', 'когда', 'даже', 'ну', 'вдруг', 'ли', 'если', 'уже', 'или', 'ни', 'быть', 'был', 'него', 'до', 'вас', 'нибудь', 'опять', 'уж', 'вам', 'ведь', 'там', 'потом', 'себя', 'ничего', 'ей', 'может', 'они', 'тут', 'где', 'есть', 'надо', 'ней', 'для', 'мы', 'тебя', 'их', 'чем', 'была', 'сам', 'чтоб', 'без', 'будто', 'чего', 'раз', 'тоже', 'себе', 'под', 'будет', 'ж', 'тогда', 'кто', 'этот', 'того', 'потому', 'этого', 'какой', 'совсем', 'ним', 'здесь', 'этом', 'один', 'почти', 'мой', 'тем', 'чтобы', 'нее', 'сейчас', 'были', 'куда', 'зачем', 'всех', 'никогда', 'можно', 'при', 'наконец', 'два', 'об', 'другой', 'хоть', 'после', 'над', 'больше', 'тот', 'через', 'эти', 'нас', 'про', 'всего', 'них', 'какая', 'много', 'разве', 'три', 'эту', 'моя', 'впрочем', 'хорошо', 'свою', 'этой', 'перед', 'иногда', 'лучше', 'чуть', 'том', 'нельзя', 'такой', 'им', 'более', 'всегда', 'конечно', 'всю', 'между']

# %%
newstoplist = ['цзюесинь','шухуа', 'это', 'цинь', 'цзюеминь', 'чжоу', 'чжан', 'цуйхуань', 'юнь', 'шучжэнь', 'цзюесиня', 'мэй']

# %% [markdown]
# def ngrams_text (word,num):
#     word = word.lower()
#     word = re.sub("[!\"#$%&\'—()*+,-»«./:;<=>?@[\\]^_`{|}~]?",'',word)
#     #tokens = re.findall ('он\s\w+',word)
#     #tokens = [token for token in word.split(" ") if token != ""]
#     mystem.lemmatize(word)
#     wordsFiltered = []
#     for w in word:
#         if w not in stopwords:
#             wordsFiltered.append(w)
#
#     output = list(ngrams(tokens,num))
#     mostcommon = Counter(output).most_common()
#     return mostcommon
# #лемматизировать можно прямо из nltk，lemmatize, а стоп слова также есть в nltk.есть такая тетрадка.
# #чтобы свести все свои документы в один нужно просто конкатенировать все переменны. открывааем и читаем фал, сохраняем в переменную, складываем все переменные.
# #append только для списка

# %% [markdown]
# from nltk.util import ngrams

# %% [markdown]
# ngrams_text(tom6,3)
