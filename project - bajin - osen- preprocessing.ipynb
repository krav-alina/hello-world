# %%
with open ('Ба Цзинь. Осень - royallib.com.txt') as file1:
    bajin1 = file1.read()

# %%
from sklearn.feature_extraction.text import CountVectorizer
import nltk
from collections import Counter
import re
import os

# %%
from nltk.corpus import stopwords
from nltk.tokenize import word_tokenize
import nltk
nltk.download('punkt')
# Out:
# [nltk_data] Downloading package punkt to
# [nltk_data]     C:\Users\sidor\AppData\Roaming\nltk_data...
# [nltk_data]   Package punkt is already up-to-date!
# True

# %%
import nltk
nltk.download('stopwords')
# Out:
# [nltk_data] Downloading package stopwords to
# [nltk_data]     C:\Users\sidor\AppData\Roaming\nltk_data...
# [nltk_data]   Package stopwords is already up-to-date!
# True

# %%
from pymystem3 import Mystem

# %%
mystem = Mystem()

# %%
def normalized_text (word):
    word = word.lower()
    word = re.sub("[!\"#$%&\'—()*+,-»«./:;<=>?@[\\]^_`{|}~]?",'',word)
    word = " ".join([word for word in word.split() if word not in(stopwords.words('russian'))])
    word = word.split()
    output = len(word)
    return output

# %%
normalized_text(bajin1)
# Out:
# 97682

# %%
#filtered_words = [Word for Word in tom6 if Word not in stopwords.words('russian')]
#text = 'здравствуй дорогой читатель сегодня очень ветренно поэтому я и он не пошли гулять хотя очень хотелось'
#text = ' '.join([word for word in text.split() if word not in (stopwords.words('russian'))])
#tom = " ".join([word for word in tom.split() if word not in(stopwords.words('russian'))])

# %%
bigram_vectorizer = CountVectorizer(ngram_range=(4,6),
                                    token_pattern=r'[А-Яа-я]+', min_df=2)

# %%
analyze = bigram_vectorizer.build_analyzer()

# %%
z = analyze(bajin1)

# %%
Counter(z).most_common()
# Out:
# [('цзюе синь и цзюе', 20),
#  ('ван и чэнь итай', 19),
#  ('синь и цзюе минь', 18),
#  ('цзюе синь и цзюе минь', 18),
#  ('что же ты не', 16),
#  ('цуй хуань и ци', 16),
#  ('хуань и ци ся', 16),
#  ('цуй хуань и ци ся', 16),
#  ('шу хуа цзюе синь', 14),
#  ('что то сказать но', 14),
#  ('не обращая внимания на', 13),
#  ('и вместе с тем', 13),
#  ('у нас в доме', 13),
#  ('и чжан би сю', 12),
#  ('цзюе минь цзюе синь', 11),
#  ('я больше не буду', 11),
#  ('ни за что не', 11),
#  ('в то же время', 11),
#  ('чжан би сю и', 11),
#  ('старая госпожа чжоу и', 11),
#  ('госпожа ван и чэнь', 11),
#  ('госпожа ван и чэнь итай', 11),
#  ('шу хуа цзюе минь', 10),
#  ('шу хуа и шу', 10),
#  ('хуа и шу чжэнь', 10),
#  ('чжоу бо тао и', 10),
#  ('шу хуа и шу чжэнь', 10),
#  ('шу хуа шу чжэнь', 9),
#  ('на цзюе синя и', 9),
#  ('ци ся и цуй', 9),
#  ('ся и цуй хуань', 9),
#  ('шу хуа шу хуа', 9),
#  ('шу хуа и цзюе', 9),
#  ('так же как и', 9),
#  ('обратилась к цзюе синю', 9),
#  ('чжан хой жу и', 9),
#  ('юнь и шу хуа', 9),
#  ('кэ ань и кэ', 9),
#  ('ань и кэ дин', 9),
#  ('ци ся и цуй хуань', 9),
#  ('кэ ань и кэ дин', 9),
#  ('чжоу бо тао не', 8),
#  ('и дело с концом', 8),
#  ('на душе у него', 8),
#  ('шу хуа и цуй', 8),
#  ('хуа и цуй хуань', 8),
#  ('цзюе минь и цинь', 8),
#  ('с тех пор как', 8),
#  ('шу хуа и цуй хуань', 8),
#  ('видя что цзюе минь', 7),
#  ('как раз в этот', 7),
#  ('раз в этот момент', 7),
#  ('ни в чем не', 7),
#  ('не говоря ни слова', 7),
#  ('цзюе ин цзюе цюнь', 7),
#  ('госпожа чжоу и госпожа', 7),
#  ('взглянула на цзюе миня', 7),
#  ('цзюе синь не мог', 7),
#  ('цинь юнь и шу', 7),
#  ('цинь и цзюе минь', 7),
#  ('госпожа чэнь и госпожа', 7),
#  ('чэнь и госпожа сюй', 7),
#  ('со слезами на глазах', 7),
#  ('чжан би сю кэ', 7),
#  ('будучи не в силах', 7),
#  ('как раз в этот момент', 7),
#  ('госпожа чэнь и госпожа сюй', 7),
#  ('дядя кэ мин не', 6),
#  ('цзюе синь цзюе минь', 6),
#  ('покачал головой цзюе синь', 6),
#  ('сказал цзюе минь и', 6),
#  ('ты не знаешь что', 6),
#  ('на цзюе миня и', 6),
#  ('видя что шу хуа', 6),
#  ('цзюе минь шу хуа', 6),
#  ('цзюе ин и цзюе', 6),
#  ('душе у него было', 6),
#  ('цзюе ши и цзюе', 6),
#  ('ши и цзюе жэнь', 6),
#  ('цзюе минь и шу', 6),
#  ('минь и шу хуа', 6),
#  ('с фонарем в руке', 6),
#  ('у нее не было', 6),
#  ('он так и не', 6),
#  ('в комнате цзюе синя', 6),
#  ('но цзюе синь не', 6),
#  ('цинь и шу хуа', 6),
#  ('цзюе синь по моему', 6),
#  ('ни во что не', 6),
#  ('с сяо хой фаном', 6),
#  ('чжан би сю а', 6),
#  ('цзюе синь и госпожа', 6),
#  ('к старой госпоже чжоу', 6),
#  ('чэнь итай и госпожа', 6),
#  ('итай и госпожа ван', 6),
#  ('за ло цзин тином', 6),
#  ('на душе у него было', 6),
#  ('цзюе ши и цзюе жэнь', 6),
#  ('цзюе минь и шу хуа', 6),
#  ('чэнь итай и госпожа ван', 6),
#  ('цинь юнь и шу хуа', 6),
#  ('с жалостью глядя на', 5),
#  ('на шу хуа и', 5),
#  ('на лице цзюе миня', 5),
#  ('на душе у нее', 5),
#  ('гроб с ее телом', 5),
#  ('цуй хуань шу хуа', 5),
#  ('до тех пор пока', 5),
#  ('на сердце у него', 5),
#  ('цзюе синь кэ мин', 5),
#  ('ответила шу хуа и', 5),
#  ('ему казалось что он', 5),
#  ('цзюе синь и мэй', 5),
#  ('ни на что не', 5),
#  ('в голосе цзюе синя', 5),
#  ('хуа и цзюе минь', 5),
#  ('цзюе синь цуй хуань', 5),
#  ('цзюе синь все еще', 5),
#  ('не успел цзюе синь', 5),
#  ('глядя на цзюе синя', 5),
#  ('и не дожидаясь ответа', 5),
#  ('вслед за цзюе синем', 5),
#  ('к тому же он', 5),
#  ('фан цзи шунь и', 5),
#  ('и чэн цзянь бин', 5),
#  ('у него на душе', 5),
#  ('о том что она', 5),
#  ('ей казалось что она', 5),
#  ('то сказать но не', 5),
#  ('дядя кэ ань и', 5),
#  ('что то еще но', 5),
#  ('не осталось и следа', 5),
#  ('цзюе цюнь и цзюе', 5),
#  ('цюнь и цзюе ши', 5),
#  ('кэ ань и чжан', 5),
#  ('ань и чжан би', 5),
#  ('би сю кэ ань', 5),
#  ('для чжан би сю', 5),
#  ('чжан би сю он', 5),
#  ('ничего не оставалось как', 5),
#  ('с чжан би сю', 5),
#  ('и не в силах', 5),
#  ('к цзюе синю он', 5),
#  ('чжоу и госпожа чэнь', 5),
#  ('не зная на что', 5),
#  ('зная на что решиться', 5),
#  ('чэнь чи и ван', 5),
#  ('но вместе с тем', 5),
#  ('лишь о том чтобы', 5),
#  ('шу хуа и цзюе минь', 5),
#  ('что то сказать но не', 5),
#  ('цзюе цюнь и цзюе ши', 5),
#  ('кэ ань и чжан би', 5),
#  ('ань и чжан би сю', 5),
#  ('чжан би сю кэ ань', 5),
#  ('старая госпожа чжоу и госпожа', 5),
#  ('госпожа чжоу и госпожа чэнь', 5),
#  ('не зная на что решиться', 5),
#  ('кэ ань и чжан би сю', 5),
#  ('старая госпожа чжоу и госпожа чэнь', 5),
#  ('в глазах у него', 4),
#  ('что происходит в душе', 4),
#  ('шу хуа а ты', 4),
#  ('не обратил внимания на', 4),
#  ('душе у нее стало', 4),
#  ('к цзюе синю и', 4),
#  ('обратился к шу хуа', 4),
#  ('не задумываясь над тем', 4),
#  ('но не успел цзюе', 4),
#  ('но ничего не сказал', 4),
#  ('взглянул на цзюе синя', 4),
#  ('ни к кому не', 4),
#  ('в комнату госпожи чжоу', 4),
#  ('цзюе минь он не', 4),
#  ('шу хуа и не', 4),
#  ('шу хуа что ты', 4),
#  ('бы то ни было', 4),
#  ('последние слова шу хуа', 4),
#  ('повернулась к цзюе синю', 4),
#  ('к цзюе синю а', 4),
#  ('и в самом деле', 4),
#  ('но он все же', 4),
#  ('он хотел сказать что', 4),
#  ('шу хуа ци ся', 4),
#  ('внимания на то что', 4),
#  ('шу хуа и ты', 4),
#  ('он был уверен что', 4),
#  ('видя что цзюе синь', 4),
#  ('был не в силах', 4),
#  ('цзюе синь цзюе синь', 4),
#  ('но в этот момент', 4),
#  ('повернувшись к шу хуа', 4),
#  ('к шу хуа а', 4),
#  ('старой госпожи чжоу и', 4),
#  ('чжоу и шу хуа', 4),
#  ('цзюе синя цзюе синь', 4),
#  ('но не успел он', 4),
#  ('и не обращая внимания', 4),
#  ('к чжан хой жу', 4),
#  ('чжан хой жу он', 4),
#  ('и хуан цунь жэнь', 4),
#  ('хуан цунь жэнь и', 4),
#  ('чэн цзянь бин и', 4),
#  ('отвечал чжан хой жу', 4),
#  ('спросила чэн цзянь бин', 4),
#  ('в комнату цзюе синя', 4),
#  ('взглянула на него и', 4),
#  ('да к тому же', 4),
#  ('в голову не приходило', 4),
#  ('голову не приходило что', 4),
#  ('но на этот раз', 4),
#  ('но старая госпожа чжоу', 4),
#  ('госпожа чжоу госпожа чэнь', 4),
#  ('глаза ее были полны', 4),
#  ('ее были полны слез', 4),
#  ('и в то же', 4),
#  ('на лице его появилось', 4),
#  ('и дядя кэ дин', 4),
#  ('сказать что то еще', 4),
#  ('смотрела на цзюе миня', 4),
#  ('шу хуа у вас', 4),
#  ('как бы про себя', 4),
#  ('вне себя от гнева', 4),
#  ('в голове у него', 4),
#  ('обратился к цзюе синю', 4),
#  ('цзюе синь видя что', 4),
#  ('кто прав кто виноват', 4),
#  ('и сяо хой фана', 4),
#  ('вне себя от радости', 4),
#  ('можно было подумать что', 4),
#  ('спросил чжан би сю', 4),
#  ('чжан би сю за', 4),
#  ('кэ аня кэ ань', 4),
#  ('на чжан би сю', 4),
#  ('у него было тяжело', 4),
#  ('кэ мин и другие', 4),
#  ('взглянув на цзюе миня', 4),
#  ('несмотря на то что', 4),
#  ('госпожа чжоу и цзюе', 4),
#  ('чжоу и цзюе синь', 4),
#  ('чжоу бо тао а', 4),
#  ('и не хочу чтобы', 4),
#  ('на лице шу хуа', 4),
#  ('а то бы я', 4),
#  ('внимание на то что', 4),
#  ('ты не должен так', 4),
#  ('ответил чжан хой жу', 4),
#  ('чжоу бо тао но', 4),
#  ('ни с того ни', 4),
#  ('с того ни с', 4),
#  ('того ни с сего', 4),
#  ('хочу поговорить с тобой', 4),
#  ('вырвалось у шу хуа', 4),
#  ('глядя на шу хуа', 4),
#  ('на душе у нее стало', 4),
#  ('и не обращая внимания на', 4),
#  ('в голову не приходило что', 4),
#  ('глаза ее были полны слез', 4),
#  ('и в то же время', 4),
#  ('сказать что то еще но', 4),
#  ('госпожа чжоу и цзюе синь', 4),
#  ('ни с того ни с', 4),
#  ('с того ни с сего', 4),
#  ('ни с того ни с сего', 4),
#  ('что дядя кэ дин', 3),
#  ('ни к чему не', 3),
#  ('цзюе минь подошел к', 3),
#  ('цзюе синь поднял голову', 3),
#  ('цзюе синь что ты', 3),
#  ('с ними цзюе минь', 3),
#  ('что цзюе минь не', 3),
#  ('к нему и с', 3),
#  ('ты еще не спишь', 3),
#  ('за спиной цзюе синя', 3),
#  ('ничего не случится если', 3),
#  ('цзюе синь ци ся', 3),
#  ('ни о чем не', 3),
#  ('ци ся налей ка', 3),
#  ('в словах шу хуа', 3),
#  ('не сдавалась шу хуа', 3),
#  ('не знаю что будет', 3),
#  ('цзюе синь и шу', 3),
#  ('синь и шу хуа', 3),
#  ('когда речь зашла о', 3),
#  ('я никак не могу', 3),
#  ('госпожа чжоу цзюе синь', 3),
#  ('цзюе синь он не', 3),
#  ('вслед за цзюе минем', 3),
#  ('цзюе синя и шу', 3),
#  ('и шу хуа а', 3),
#  ('а я и не', 3),
#  ('обратилась к цзюе миню', 3),
#  ('ты не понимаешь что', 3),
#  ('на этот раз он', 3),
#  ('само собой разумеется что', 3),
#  ('ну и не надо', 3),
#  ('меня за то что', 3),
#  ('почему же она не', 3),
#  ('шу хуа не зная', 3),
#  ('хуа не зная что', 3),
#  ('не зная что ответить', 3),
#  ('сердце у него стало', 3),
#  ('мы что нибудь придумаем', 3),
#  ('в таком случае ты', 3),
#  ('ее цзюе минь и', 3),
#  ('ин и цзюе цюнь', 3),
#  ('цзюе ин шу хуа', 3),
#  ('и увидев что все', 3),
#  ('разве ты не знаешь', 3),
#  ('к кому не обращаясь', 3),
#  ('у нас в семье', 3),
#  ('не проронил ни звука', 3),
#  ('в комнате остались только', 3),
#  ('смотрел на цзюе синя', 3),
#  ('цзюе синь я не', 3),
#  ('и не говоря ни', 3),
#  ('взглянула на шу хуа', 3),
#  ('я ни разу не', 3),
#  ('ни разу не видела', 3),
#  ('разу не видела чтобы', 3),
#  ('на шу хуа потом', 3),
#  ('тем что ее слова', 3),
#  ('из комнаты шу хуа', 3),
#  ('ин и цзюе жэнь', 3),
#  ('ты в конце концов', 3),
#  ('к шу хуа и', 3),
#  ('что цзюе минь и', 3),
#  ('шу чжэнь шу хуа', 3),
#  ('через некоторое время он', 3),
#  ('что же вы не', 3),
#  ('но шу хуа не', 3),
#  ('проучи его как следует', 3),
#  ('цуй хуань и шу', 3),
#  ('с утра до вечера', 3),
#  ('улыбка сбежала с лица', 3),
#  ('же ты раньше не', 3),
#  ('шу хуа и затем', 3),
#  ('шу хуа за руку', 3),
#  ('глаза его наполнились слезами', 3),
#  ('то же время он', 3),
#  ('что то на ухо', 3),
#  ('шу ин и цзюе', 3),
#  ('госпожа чжоу с трудом', 3),
#  ('обратилась к цинь цинь', 3),
#  ('я больше не могу', 3),
#  ('взглянула на цзюе синя', 3),
#  ('на цзюе синя ничего', 3),
#  ('госпожу чжоу и госпожу', 3),
#  ('цзюе синь вспомнил что', 3),
#  ('я хочу тебя спросить', 3),
#  ('что все в мире', 3),
#  ('все в мире мираж', 3),
#  ('не произнося ни слова', 3),
#  ('мне кажется что он', 3),
#  ('почему бы тебе не', 3),
#  ('что он не может', 3),
#  ('он не мог больше', 3),
#  ('ни в коем случае', 3),
#  ('он не знал что', 3),
#  ('цуй хуань цзюе синь', 3),
#  ('в это время в', 3),
#  ('цзюе синь ты что', 3),
#  ('он был не в', 3),
#  ('не в силах продолжать', 3),
#  ('я не верю что', 3),
#  ('если так будет продолжаться', 3),
#  ('цзюе минь и обратился', 3),
#  ('минь и обратился к', 3),
#  ('не боюсь я не', 3),
#  ('в руках у нее', 3),
#  ('бо тао и мэй', 3),
#  ('у него не было', 3),
#  ('цзюе синь знал что', 3),
#  ('у него не хватало', 3),
#  ('откуда ты знаешь что', 3),
#  ('и обратилась к цзюе', 3),
#  ('понимаю что ты хочешь', 3),
#  ('цзюе синь не ответил', 3),
#  ('на вопрос шу хуа', 3),
#  ('начал цзюе синь но', 3),
#  ('обращая внимания на то', 3),
#  ('не отрывая глаз от', 3),
#  ('цинь и цзюе миня', 3),
#  ('цзюе минь видя что', 3),
#  ('сказал хуан цунь жэнь', 3),
#  ('под каким то предлогом', 3),
#  ('хой жу и цзюе', 3),
#  ('жу и цзюе минь', 3),
#  ('на чжан хой жу', 3),
#  ('фан цзи шунь он', 3),
#  ('и чжан хой жу', 3),
#  ('я тоже так думаю', 3),
#  ('было у него на', 3),
#  ('хуан цунь жэня и', 3),
#  ('чжан хой жу с', 3),
#  ('сказал чжан хуань жу', 3),
#  ('чжан хуань жу и', 3),
#  ('в один прекрасный день', 3),
#  ('шу хуа и юнь', 3),
#  ('цзюе миня и цинь', 3),
#  ('будущее смутно прежде всего', 3),
#  ('смутно прежде всего надо', 3),
#  ('прежде всего надо спасать', 3),
#  ('всего надо спасать самого', 3),
#  ('надо спасать самого себя', 3),
#  ('цзюе синь по прежнему', 3),
#  ('и в голову не', 3),
#  ('на лице цзюе синя', 3),
#  ('и она не могла', 3),
#  ('старая госпожа чжоу остановила', 3),
#  ('цуй фэн принеси ка', 3),
#  ('рядом с ней и', 3),
#  ('старая госпожа чжоу она', 3),
#  ('старая госпожа чжоу госпожа', 3),
#  ('да что же это', 3),
#  ('что же это такое', 3),
#  ('я что то не', 3),
#  ('что то не понимаю', 3),
#  ('все в этой комнате', 3),
#  ('было что то сказать', 3),
#  ('я не хочу чтобы', 3),
#  ('ни за что ни', 3),
#  ('за что ни про', 3),
#  ('что ни про что', 3),
#  ('в то время как', 3),
#  ('цзюе цюня и цзюе', 3),
#  ('кэ ань и дядя', 3),
#  ('ань и дядя кэ', 3),
#  ('хотел сказать что то', 3),
#  ('цзюе минь взглянул на', 3),
#  ('он и сам не', 3),
#  ('и сам не знал', 3),
#  ('юань чэна и су', 3),
#  ('чэна и су фу', 3),
#  ('в комнату шу хуа', 3),
#  ('мы с ци ся', 3),
#  ('и на лице ее', 3),
#  ('на лице ее не', 3),
#  ('у дяди кэ мина', 3),
#  ('вырвалось у цзюе синя', 3),
#  ('у цзюе синя он', 3),
#  ('и ты еще говоришь', 3),
#  ('все больше и больше', 3),
#  ('с цзюе цюнем и', 3),
#  ('цзюе цюнем и цзюе', 3),
#  ('цюнем и цзюе ши', 3),
#  ('цзюе синь ты не', 3),
#  ('шу хуа но не', 3),
#  ('я не сделала ничего', 3),
#  ('я не хочу спать', 3),
#  ('согласился цзюе синь кэ', 3),
#  ('ин цзюе цюнь и', 3),
#  ('она вошла в комнату', 3),
#  ('к нему в комнату', 3),
#  ('цзюе ина и цзюе', 3),
#  ('закинув ногу на ногу', 3),
#  ('когда он вошел в', 3),
#  ('я ни при чем', 3),
#  ('в это время вошла', 3),
#  ('кэ мин видя что', 3),
#  ('кэ мина кэ мин', 3),
#  ('не зная что он', 3),
#  ('меня ни во что', 3),
#  ('во что не ставят', 3),
#  ('я даже не знаю', 3),
#  ('к ней и она', 3),
#  ('чжан би сю тоже', 3),
#  ('а чжан би сю', 3),
#  ('сяо хой фан и', 3),
#  ('би сю и сяо', 3),
#  ('сю и сяо хой', 3),
#  ('и сяо хой фан', 3),
#  ('сяо хой фана и', 3),
#  ('схватил чжан би сю', 3),
#  ('чжан би сю из', 3),
#  ('чжан би сю не', 3),
#  ('сказал чжан би сю', 3),
#  ('би сю за руку', 3),
#  ('лицо чжан би сю', 3),
#  ('ему было не до', 3),
#  ('взглянул на брата и', 3),
#  ('о том что они', 3),
#  ('в это время из', 3),
#  ('госпожа ван и госпожа', 3),
#  ('цзюе синя цзюе минь', 3),
#  ('взгляд на цзюе синя', 3),
#  ('цзюе синя и цзюе', 3),
#  ('изменилась в лице и', 3),
#  ('ответил цзюе минь ты', 3),
#  ('ты еще говоришь что', 3),
#  ('цзюе синь думая о', 3),
#  ('я и сам не', 3),
#  ('подойдя к столу он', 3),
#  ('госпожа чжоу и шу', 3),
#  ('не мог удержаться от', 3),
#  ('мысли о том что', 3),
#  ('ему ничего не оставалось', 3),
#  ('не могло быть и', 3),
#  ('могло быть и речи', 3),
#  ('только чжоу бо тао', 3),
#  ('поэтому я и не', 3),
#  ('все с тем же', 3),
#  ('шу хуа не дала', 3),
#  ('книг в старинных переплетах', 3),
#  ('в этот момент были', 3),
#  ('но цзюе синь уже', 3),
#  ('и шу хуа он', 3),
#  ('цзюе синь вернулся домой', 3),
#  ('в кабинет чжоу бо', 3),
#  ('кабинет чжоу бо тао', 3),
#  ('чжоу бо тао с', 3),
#  ('чжоу чжоу бо тао', 3),
#  ('вид у него был', 3),
#  ('цзюе синь тоже не', 3),
#  ('о том о сем', 3),
#  ('стоял у письменного стола', 3),
#  ('не обращая никакого внимания', 3),
#  ('обращая никакого внимания на', 3),
#  ('в лицо цзюе синю', 3),
#  ('что чжоу бо тао', 3),
#  ('при этих словах цзюе', 3),
#  ('цзюе синь почувствовал как', 3),
#  ('госпожа сюй видя что', 3),
#  ('чжоу бо тао в', 3),
#  ('из себя старая госпожа', 3),
#  ('себя старая госпожа чжоу', 3),
#  ('цзюе синь ты опять', 3),
#  ('вышел из за стола', 3),
#  ('к себе в комнату', 3),
#  ('цзюе синю казалось что', 3),
#  ('на глазах у нее', 3),
#  ('не в силах говорить', 3),
#  ('чи и ван юн', 3),
#  ('улыбнулась чэн цзянь бин', 3),
#  ('потому что ты сам', 3),
#  ('а может быть и', 3),
#  ('чжан хой жу я', 3),
#  ('спокойно ответил чжан хой', 3),
#  ('и в свою очередь', 3),
#  ('в свою очередь спросил', 3),
#  ('взглянул на брата но', 3),
#  ('на брата но ничего', 3),
#  ('брата но ничего не', 3),
#  ('вместе с тем он', 3),
#  ('шу чжэнь все еще', 3),
#  ('шу чжэнь уже не', 3),
#  ('сказала шу хуа и', 3),
#  ('вернулся в дом чжоу', 3),
#  ('старой госпоже чжоу и', 3),
#  ('к чжоу бо тао', 3),
#  ('жена чжоу бо тао', 3),
#  ('цзюе синь нахмурился и', 3),
#  ('а что я могу', 3),
#  ('когда цзюе синь вернулся', 3),
#  ('шу хуа и ци', 3),
#  ('хуа и ци ся', 3),
#  ('думала лишь о том', 3),
#  ('поговорить с тобой я', 3),
#  ('у меня единственная дочь', 3),
#  ('если бы не ты', 3),
#  ('не сделала ничего дурного', 3),
#  ('я знаю что я', 3),
#  ('не в силах произнести', 3),
#  ('в силах произнести ни', 3),
#  ('силах произнести ни слова', 3),
#  ('к чэнь итай и', 3),
#  ('что чэнь итай и', 3),
#  ('от света нечистой крови', 3),
#  ('вместе с тем радостно', 3),
#  ('по мере того как', 3),
#  ('с каждым днем все', 3),
#  ('было не по себе', 3),
#  ('и повернувшись к шу', 3),
#  ('с шу хуа и', 3),
#  ('я хочу поговорить с', 3),
#  ('если бы не было', 3),
#  ('в голосе ее слышалось', 3),
#  ('словно обращаясь к самой', 3),
#  ('обращаясь к самой себе', 3),
#  ('видя что она молчит', 3),
#  ('хотел что то сказать', 3),
#  ('но не знал что', 3),
#  ('и цзюе минь не', 3),
#  ('была не в силах', 3),
#  ('а цзюе синь и', 3),
#  ('звать ло цзин тина', 3),
#  ('ло цзин тина и', 3),
#  ('цзюе минь не выдержал', 3),
#  ('ни один из них', 3),
#  ('один из них не', 3),
#  ('на цзюе синя она', 3),
#  ('все равно лишь бы', 3),
#  ('не сводя глаз с', 3),
#  ('цзюе синь госпожа шэнь', 3),
#  ('заботливо сказал цзюе синь', 3),
#  ('цзюе синь и шу хуа', 3),
#  ('шу хуа не зная что', 3),
#  ('на сердце у него стало', 3),
#  ('цзюе ин и цзюе цюнь', 3),
#  ('разве ты не знаешь что', 3),
#  ('ни к кому не обращаясь', 3),
#  ('и не говоря ни слова', 3),
#  ('ни разу не видела чтобы', 3),
#  ('цзюе ин и цзюе жэнь', 3),
#  ('в то же время он', 3),
#  ('он был не в силах', 3),
#  ('цзюе минь и обратился к', 3),
#  ('чжоу бо тао и мэй', 3),
#  ('не обращая внимания на то', 3),
#  ('обращая внимания на то что', 3),
#  ('чжан хой жу и цзюе', 3),
#  ('хой жу и цзюе минь', 3),
#  ('было у него на душе', 3),
#  ('будущее смутно прежде всего надо', 3),
#  ('смутно прежде всего надо спасать', 3),
#  ('прежде всего надо спасать самого', 3),
#  ('всего надо спасать самого себя', 3),
#  ('и в голову не приходило', 3),
#  ('старая госпожа чжоу госпожа чэнь', 3),
#  ('да что же это такое', 3),
#  ('было что то сказать но', 3),
#  ('ни за что ни про', 3),
#  ('за что ни про что', 3),
#  ('дядя кэ ань и дядя', 3),
#  ('кэ ань и дядя кэ', 3),
#  ('ань и дядя кэ дин', 3),
#  ('он хотел сказать что то', 3),
#  ('хотел сказать что то еще', 3),
#  ('он и сам не знал', 3),
#  ('юань чэна и су фу', 3),
#  ('вырвалось у цзюе синя он', 3),
#  ('с цзюе цюнем и цзюе', 3),
#  ('цзюе цюнем и цзюе ши', 3),
#  ('согласился цзюе синь кэ мин', 3),
#  ('цзюе ин цзюе цюнь и', 3),
#  ('меня ни во что не', 3),
#  ('ни во что не ставят', 3),
#  ('чжан би сю и сяо', 3),
#  ('би сю и сяо хой', 3),
#  ('схватил чжан би сю за', 3),
#  ('чжан би сю за руку', 3),
#  ('госпожа чжоу и шу хуа', 3),
#  ('ему ничего не оставалось как', 3),
#  ('не могло быть и речи', 3),
#  ('в кабинет чжоу бо тао', 3),
#  ('не обращая никакого внимания на', 3),
#  ('из себя старая госпожа чжоу', 3),
#  ('чэнь чи и ван юн', 3),
#  ('спокойно ответил чжан хой жу', 3),
#  ('на брата но ничего не', 3),
#  ('но вместе с тем он', 3),
#  ('шу хуа и ци ся', 3),
#  ('не в силах произнести ни', 3),
#  ('в силах произнести ни слова', 3),
#  ('и вместе с тем радостно', 3),
#  ('и повернувшись к шу хуа', 3),
#  ('я хочу поговорить с тобой', 3),
#  ('словно обращаясь к самой себе', 3),
#  ('хотел что то сказать но', 3),
#  ('ни один из них не', 3),
#  ('не обращая внимания на то что', 3),
#  ('чжан хой жу и цзюе минь', 3),
#  ('будущее смутно прежде всего надо спасать', 3),
#  ('смутно прежде всего надо спасать самого', 3),
#  ('прежде всего надо спасать самого себя', 3),
#  ('и в голову не приходило что', 3),
#  ('ни за что ни про что', 3),
#  ('дядя кэ ань и дядя кэ', 3),
#  ('кэ ань и дядя кэ дин', 3),
#  ('он хотел сказать что то еще', 3),
#  ('хотел сказать что то еще но', 3),
#  ('с цзюе цюнем и цзюе ши', 3),
#  ('чжан би сю и сяо хой', 3),
#  ('не в силах произнести ни слова', 3),
#  ('не бывала у нас', 2),
#  ('но мне кажется что', 2),
#  ('глазах у него рябило', 2),
#  ('но он даже не', 2),
#  ('слезы навернулись ему на', 2),
#  ('навернулись ему на глаза', 2),
#  ('минь подошел к цзюе', 2),
#  ('подошел к цзюе синю', 2),
#  ('руку ему на плечо', 2),
#  ('на вращающемся стуле и', 2),
#  ('цзюе минь увидел что', 2),
#  ('цзюе минь не понял', 2),
#  ('ты до сих пор', 2),
#  ('произнес цзюе синь что', 2),
#  ('не понял цзюе минь', 2),
#  ('они хотят чтобы я', 2),
#  ('ответил цзюе синь цзюе', 2),
#  ('сказал цзюе минь он', 2),
#  ('цзюе синь ничего не', 2),
#  ('но он ничего не', 2),
#  ('не произносил ни звука', 2),
#  ('взгляд его снова упал', 2),
#  ('его снова упал на', 2),
#  ('снова упал на письмо', 2),
#  ('и с горечью сказал', 2),
#  ('подошел к письменному столу', 2),
#  ('за руку цзюе синь', 2),
#  ('горячо возразил цзюе минь', 2),
#  ('по твоему я могу', 2),
#  ('что нибудь цзюе минь', 2),
#  ('машинально ответил цзюе синь', 2),
#  ('ответил цзюе синь и', 2),
#  ('подошел к столу и', 2),
#  ('с любопытством спросила шу', 2),
#  ('любопытством спросила шу хуа', 2),
#  ('уклончиво ответил цзюе синь', 2),
#  ('цзюе синь шу хуа', 2),
#  ('цзюе минь а я', 2),
#  ('я знаю ты не', 2),
#  ('если дядя кэ мин', 2),
#  ('холодно спросил цзюе минь', 2),
#  ('остановила его госпожа чжоу', 2),
#  ('мама права улыбнулся цзюе', 2),
#  ('права улыбнулся цзюе синь', 2),
#  ('дядя чжоу бо тао', 2),
#  ('женитьбе мэя шу хуа', 2),
#  ('мэя шу хуа не', 2),
#  ('с горечью посмотрел на', 2),
#  ('очень подходят друг к', 2),
#  ('подходят друг к другу', 2),
#  ('а ты не знаешь', 2),
#  ('и обращаясь к шу', 2),
#  ('обращаясь к шу хуа', 2),
#  ('шу хуа она сказала', 2),
#  ('от рождения такой характер', 2),
#  ('я не понимаю почему', 2),
#  ('опасаясь что слова шу', 2),
#  ('что слова шу хуа', 2),
#  ('слова шу хуа могут', 2),
#  ('выражение ее лица не', 2),
#  ('я ничего не могу', 2),
#  ('цзюе минь обращаясь к', 2),
#  ('но никто не обратил', 2),
#  ('никто не обратил внимания', 2),
#  ('внимания на его слова', 2),
#  ('лучшего и желать нечего', 2),
#  ('лучше и не говори', 2),
#  ('но на душе у', 2),
#  ('еще кое о чем', 2),
#  ('кое о чем посоветоваться', 2),
#  ('о чем посоветоваться с', 2),
#  ('с твоим старшим братом', 2),
#  ('спросил цзюе синь он', 2),
#  ('говорила что кэ мин', 2),
#  ('на то что я', 2),
#  ('к тому же я', 2),
#  ('я не имею права', 2),
#  ('хорошо согласился цзюе минь', 2),
#  ('к себе цзюе синь', 2),
#  ('синя и шу хуа', 2),
#  ('шу хуа что то', 2),
#  ('что то ты сегодня', 2),
#  ('ты смеешься надо мной', 2),
#  ('взглянул на цзюе миня', 2),
#  ('цзюе миня цзюе минь', 2),
#  ('шу хуа ну ка', 2),
#  ('что шу хуа не', 2),
#  ('не двигается с места', 2),
#  ('двигается с места он', 2),
#  ('шу хуа покраснела от', 2),
#  ('и она направилась к', 2),
#  ('его уже не было', 2),
#  ('тех пор пока не', 2),
#  ('и на этот раз', 2),
#  ('тетя ван и тетя', 2),
#  ('ван и тетя шэнь', 2),
#  ('цзюе минь в душе', 2),
#  ('к ней шу хуа', 2),
#  ('но она не в', 2),
#  ('не в силах была', 2),
#  ('участливо спросила шу хуа', 2),
#  ('за то что я', 2),
#  ('шу чжэнь не убивайся', 2),
#  ('пришла ему на ум', 2),
#  ('у него стало еще', 2),
#  ('него стало еще тяжелее', 2),
#  ('цзюе минь ну и', 2),
#  ('минь ну и что', 2),
#  ('но она уже не', 2),
#  ('сказала шу хуа а', 2),
#  ('и все из за', 2),
#  ('не отставала шу хуа', 2),
#  ('к брату шу хуа', 2),
#  ('что происходит в его', 2),
#  ('происходит в его душе', 2),
#  ('не успел цзюе минь', 2),
#  ('удивился цзюе минь а', 2),
#  ('ее за рукав и', 2),
#  ('за рукав и шепотом', 2),
#  ('не надо так говорить', 2),
#  ('усмехнулась шу хуа цзюе', 2),
#  ('цзюе минь все еще', 2),
#  ('взглянула на шу чжэнь', 2),
#  ('сказала я больше не', 2),
#  ('цзюе минь удивленно взглянул', 2),
#  ('минь удивленно взглянул на', 2),
#  ('взглянул на нее и', 2),
#  ('не желаю тебя слушать', 2),
#  ('ничего не сказал не', 2),
#  ('цзюе цюнь но цзюе', 2),
#  ('в комнате слышалось только', 2),
#  ('не сказал ни слова', 2),
#  ('кэ ань не успел', 2),
#  ('сказал ни к кому', 2),
#  ('как ни в чем', 2),
#  ('в чем не бывало', 2),
#  ('рукопись цзинь дун синя', 2),
#  ('ты не имел права', 2),
#  ('стуча кулаком по столу', 2),
#  ('к кэ аню и', 2),
#  ('кэ мин кэ дин', 2),
#  ('не меняя выражения лица', 2),
#  ('юань чэн и су', 2),
#  ('чэн и су фу', 2),
#  ('за ним в комнате', 2),
#  ('кэ мин тяжело дышал', 2),
#  ('я не умру от', 2),
#  ('семьи только на тебя', 2),
#  ('я хочу только чтобы', 2),
#  ('я во всем полагаюсь', 2),
#  ('во всем полагаюсь на', 2),
#  ('на тебя цзюе синь', 2),
#  ('тебя цзюе синь я', 2),
#  ('себя цзюе минь не', 2),
#  ('у него было очень', 2),
#  ('хуа шу чжэнь и', 2),
#  ('цинь шу хуа и', 2),
#  ('шу чжэнь ци ся', 2),
#  ('о предстоящей женитьбе мэя', 2),
#  ('шу хуа не выдержала', 2),
#  ('на шу хуа она', 2),
#  ('шу хуа это не', 2),
#  ('госпожа чжоу нахмурилась и', 2),
#  ('улыбнулась юнь шу хуа', 2),
#  ('но мне все же', 2),
#  ('но я знаю что', 2),
#  ('не видела чтобы он', 2),
#  ('видела чтобы он улыбался', 2),
#  ('доведись мне я бы', 2),
#  ('мне я бы ни', 2),
#  ('я бы ни за', 2),
#  ('бы ни за что', 2),
#  ('за что не согласилась', 2),
#  ('глубокой эрудицией и высокими', 2),
#  ('эрудицией и высокими моральными', 2),
#  ('и высокими моральными качествами', 2),
#  ('шу хуа потом на', 2),
#  ('хуа потом на цинь', 2),
#  ('госпожа чжоу лежала на', 2),
#  ('юнь поспешно встала и', 2),
#  ('шу хуа и глядя', 2),
#  ('хуа и глядя на', 2),
#  ('глядя на цзюе миня', 2),
#  ('сбежала с лица цзюе', 2),
#  ('с лица цзюе миня', 2),
#  ('цзюе миня и он', 2),
#  ('рассмеялась шу хуа вызвав', 2),
#  ('но он тут же', 2),
#  ('внимания на шу хуа', 2),
#  ('зачем такие церемонии цинь', 2),
#  ('играть в пилань и', 2),
#  ('шу хуа я не', 2),
#  ('хорошо пусть будет по', 2),
#  ('цзюе цюнь цзюе ши', 2),
#  ('шу хуа не выдержав', 2),
#  ('и направилась к ним', 2),
#  ('она увидела что цзюе', 2),
#  ('к ним шу хуа', 2),
#  ('в конце концов или', 2),
#  ('конце концов или нет', 2),
#  ('в это время к', 2),
#  ('цзюе ин с цзюе', 2),
#  ('ин с цзюе цюнем', 2),
#  ('я не совсем понимаю', 2),
#  ('чжоу бо тао так', 2),
#  ('за то что они', 2),
#  ('а у нас в', 2),
#  ('удивилась шу хуа она', 2),
#  ('шу хуа она внимательно', 2),
#  ('внимательно посмотрела в лицо', 2),
#  ('по лицу цзюе миня', 2),
#  ('в ушах ее все', 2),
#  ('ушах ее все еще', 2),
#  ('ее все еще звучали', 2),
#  ('с корзиной в руке', 2),
#  ('цзюе минь и мэй', 2),
#  ('шу хуа сидела на', 2),
#  ('на его бледном лице', 2),
#  ('казалось что он понимает', 2),
#  ('все будет в порядке', 2),
#  ('сказал цзюе синь и', 2),
#  ('что ж ты не', 2),
#  ('а я как раз', 2),
#  ('я как раз собиралась', 2),
#  ('не думай что я', 2),
#  ('теперь я узнаю свою', 2),
#  ('я узнаю свою сестру', 2),
#  ('он вовсе не собирался', 2),
#  ('ци ся не стоит', 2),
#  ('цзюе минь что то', 2),
#  ('цзюе минь не прислушивался', 2),
#  ('минь не прислушивался к', 2),
#  ('а я тебя заждалась', 2),
#  ('какое это имеет отношение', 2),
#  ('просто не знаю как', 2),
#  ('обратилась цинь к юнь', 2),
#  ('она участливо взглянула на', 2),
#  ('на шу чжэнь ее', 2),
#  ('у шу хуа действительно', 2),
#  ('себя не так как', 2),
#  ('а мне кажется что', 2),
#  ('мне кажется что я', 2),
#  ('заявила шу хуа и', 2),
#  ('шу хуа и приказала', 2),
#  ('последнее время она очень', 2),
#  ('откровенно призналась шу хуа', 2),
#  ('возразила шу хуа шу', 2),
#  ('с лица шу хуа', 2),
#  ('что же ты раньше', 2),
#  ('сказала цинь шу хуа', 2),
#  ('цинь шу хуа вдруг', 2),
#  ('обрадовано воскликнула шу хуа', 2),
#  ('цзюе миня шу хуа', 2),
#  ('хуа шу хуа не', 2),
#  ('услышав последние слова шу', 2),
#  ('в таком случае я', 2),
#  ('ответил цзюе минь а', 2),
#  ('выпалила шу хуа и', 2),
#  ('шу хуа в один', 2),
#  ('хуа в один голос', 2),
#  ('за руку шу чжэнь', 2),
#  ('цзюе синь с мэем', 2),
#  ('цинь и шу чжэнь', 2),
#  ('цзюе синя и мэя', 2),
#  ('цзюе минь стоя на', 2),
#  ('удивился цзюе минь и', 2),
#  ('не хочешь ли ты', 2),
#  ('цзюе минь и видя', 2),
#  ('минь и видя что', 2),
#  ('и видя что шу', 2),
#  ('ее по голове и', 2),
#  ('шу хуа она уже', 2),
#  ('но вдруг повернулась к', 2),
#  ('цзюе синю а ты', 2),
#  ('ты не будешь петь', 2),
#  ('цзюе синь услышав что', 2),
#  ('цзюе минь цинь и', 2),
#  ('цзюе синь взглянул на', 2),
#  ('лицо шу хуа и', 2),
#  ('ты еще так молод', 2),
#  ('почему же ты должен', 2),
#  ('что он не мог', 2),
#  ('по тому же пути', 2),
#  ('смотрел на него не', 2),
#  ('лицо его по прежнему', 2),
#  ('на что не надеялся', 2),
#  ('же время он чувствовал', 2),
#  ('в самом деле не', 2),
#  ('цзюе синь почувствовал что', 2),
#  ('над тем что его', 2),
#  ('собрав все свое мужество', 2),
#  ('все свое мужество он', 2),
#  ('так ни о чем', 2),
#  ('головой цзюе синь только', 2),
#  ('цзюе синь только что', 2),
#  ('голосе цзюе синя звучала', 2),
#  ('не успел он ответить', 2),
#  ('схватила его за руку', 2),
#  ('его за руку и', 2),
#  ('отвечала шу хуа цзюе', 2),
#  ('минь цзюе синь с', 2),
#  ('шу хуа посмотрела вверх', 2),
#  ('цзюе минь не только', 2),
#  ('посмотрела на цзюе миня', 2),
#  ('госпожи чжоу еще не', 2),
#  ('разговаривали шу хуа и', 2),
#  ('направилась к шу хуа', 2),
#  ('цзюе минь шепнул ей', 2),
#  ('в голосе шу хуа', 2),
#  ('что кто нибудь услышит', 2),
#  ('покачала головой шу чжэнь', 2),
#  ('не будем больше говорить', 2),
#  ('он увидел цуй хуань', 2),
#  ('увидел цуй хуань с', 2),
#  ('цуй хуань с фонарем', 2),
#  ('хуань с фонарем в', 2),
#  ('взоры всех присутствующих обратились', 2),
#  ('шу хуа госпожа чжоу', 2),
#  ('чжоу и госпожа чжан', 2),
#  ('только после того как', 2),
#  ('двумя тремя словами с', 2),
#  ('мне тоже кажется что', 2),
#  ('чжан и обращаясь к', 2),
#  ('шу хуа ты же', 2),
#  ('на то что здесь', 2),
#  ('вы с ци ся', 2),
#  ...]

# %%
def ngrams_text (word,num):
    word = word.lower()
    word = re.sub("[!\"#$%&\'—()*+,-»«./:;<=>?@[\\]^_`{|}~]?",'',word)
    #tokens = re.findall ('он\s\w+',word)
    #tokens = [token for token in word.split(" ") if token != ""]
    mystem.lemmatize(word)
    wordsFiltered = []
    for w in word:
        if w not in stopwords:
            wordsFiltered.append(w)
    
    output = list(ngrams(tokens,num))
    mostcommon = Counter(output).most_common()
    return mostcommon
#лемматизировать можно прямо из nltk，lemmatize, а стоп слова также есть в nltk.есть такая тетрадка. 
#чтобы свести все свои документы в один нужно просто конкатенировать все переменны. открывааем и читаем фал, сохраняем в переменную, складываем все переменные.
#append только для списка

# %%
def ngrams_text (word,num):
    word = word.lower()
    word = re.sub("[!\"#$%&\'—()*+,-»«./:;<=>?@[\\]^_`{|}~]?",'',word)
    #tokens = re.findall ('он\s\w+',word)
    #tokens = [token for token in word.split(" ") if token != ""]
    mystem.lemmatize(word)
    wordsFiltered = []
    for w in word:
        if w not in stopwords:
            wordsFiltered.append(w)
    
    output = list(ngrams(tokens,num))
    mostcommon = Counter(output).most_common()
    return mostcommon
#лемматизировать можно прямо из nltk，lemmatize, а стоп слова также есть в nltk.есть такая тетрадка. 
#чтобы свести все свои документы в один нужно просто конкатенировать все переменны. открывааем и читаем фал, сохраняем в переменную, складываем все переменные.
#append только для списка

# %%
def ngrams_text (word,num):
    word = word.lower()
    word = re.sub("[!\"#$%&\'—()*+,-»«./:;<=>?@[\\]^_`{|}~]?",'',word)
    #tokens = re.findall ('он\s\w+',word)
    #tokens = [token for token in word.split(" ") if token != ""]
    mystem.lemmatize(word)
    wordsFiltered = []
    for w in word:
        if w not in stopwords:
            wordsFiltered.append(w)
    
    output = list(ngrams(tokens,num))
    mostcommon = Counter(output).most_common()
    return mostcommon
#лемматизировать можно прямо из nltk，lemmatize, а стоп слова также есть в nltk.есть такая тетрадка. 
#чтобы свести все свои документы в один нужно просто конкатенировать все переменны. открывааем и читаем фал, сохраняем в переменную, складываем все переменные.
#append только для списка

# %%
ngrams_text("любовь",3)
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-22-120f9802b2fd> in <module>
# ----> 1 ngrams_text("любовь",3)
#
# <ipython-input-5-5e497a6001b9> in ngrams_text(word, num)
#       4     #tokens = re.findall ('он\s\w+',word)
#       5     #tokens = [token for token in word.split(" ") if token != ""]
# ----> 6     mystem.lemmatize(word)
#       7     wordsFiltered = []
#       8     for w in word:
#
# c:\users\sidor\appdata\local\programs\python\python37\lib\site-packages\pymystem3\mystem.py in lemmatize(self, text)
#     263         need_encode = (sys.version_info[0] < 3 and isinstance(text, str))
#     264
# --> 265         infos = self.analyze(text)
#     266         lemmas = list(filter(None, map(self._get_lemma, infos)))
#     267
#
# c:\users\sidor\appdata\local\programs\python\python37\lib\site-packages\pymystem3\mystem.py in analyze(self, text)
#     248         result = []
#     249         for line in text.splitlines():
# --> 250             result.extend(self._analyze_impl(line))
#     251         return result
#     252
#
# c:\users\sidor\appdata\local\programs\python\python37\lib\site-packages\pymystem3\mystem.py in _analyze_impl(self, text)
#     308                 self._start_mystem()
#     309
# --> 310             self._procin.write(text)
#     311             self._procin.write(_NL)
#     312
#
# ValueError: I/O operation on closed file

# %%
from nltk.util import ngrams

# %%
ngrams_text(tom6,3)
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-15-f6c145f82854> in <module>
# ----> 1 ngrams_text(tom6,3)
#
# <ipython-input-5-5e497a6001b9> in ngrams_text(word, num)
#       4     #tokens = re.findall ('он\s\w+',word)
#       5     #tokens = [token for token in word.split(" ") if token != ""]
# ----> 6     mystem.lemmatize(word)
#       7     wordsFiltered = []
#       8     for w in word:
#
# c:\users\sidor\appdata\local\programs\python\python37\lib\site-packages\pymystem3\mystem.py in lemmatize(self, text)
#     263         need_encode = (sys.version_info[0] < 3 and isinstance(text, str))
#     264
# --> 265         infos = self.analyze(text)
#     266         lemmas = list(filter(None, map(self._get_lemma, infos)))
#     267
#
# c:\users\sidor\appdata\local\programs\python\python37\lib\site-packages\pymystem3\mystem.py in analyze(self, text)
#     248         result = []
#     249         for line in text.splitlines():
# --> 250             result.extend(self._analyze_impl(line))
#     251         return result
#     252
#
# c:\users\sidor\appdata\local\programs\python\python37\lib\site-packages\pymystem3\mystem.py in _analyze_impl(self, text)
#     308                 self._start_mystem()
#     309
# --> 310             self._procin.write(text)
#     311             self._procin.write(_NL)
#     312
#
# ValueError: I/O operation on closed file
