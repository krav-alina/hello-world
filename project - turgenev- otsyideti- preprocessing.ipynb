# %%
with open ('ottsy_i_dieti_-_ivan_sierghieievich_turghieniev.txt') as file1:
    tom = file1.read()

# %%
from sklearn.feature_extraction.text import CountVectorizer
import nltk
from collections import Counter
import re
import os

# %%
from nltk.corpus import stopwords
from nltk.tokenize import word_tokenize
import nltk
nltk.download('punkt')
# Out:
# [nltk_data] Downloading package punkt to
# [nltk_data]     C:\Users\sidor\AppData\Roaming\nltk_data...
# [nltk_data]   Package punkt is already up-to-date!
# True

# %%
import nltk
nltk.download('stopwords')
# Out:
# [nltk_data] Downloading package stopwords to
# [nltk_data]     C:\Users\sidor\AppData\Roaming\nltk_data...
# [nltk_data]   Package stopwords is already up-to-date!
# True

# %%
from pymystem3 import Mystem

# %%
mystem = Mystem()

# %%
def normalized_text (word):
    word = word.lower()
    word = re.sub("[!\"#$%&\'—()*+,-»«./:;<=>?@[\\]^_`{|}~]?",'',word)
    word = " ".join([word for word in word.split() if word not in(stopwords.words('russian'))])
    word = word.split()
    output = len(word)
    return output

# %%
normalized_text(tom)
# Out:
# 35831

# %%
#filtered_words = [Word for Word in tom6 if Word not in stopwords.words('russian')]
#text = 'здравствуй дорогой читатель сегодня очень ветренно поэтому я и он не пошли гулять хотя очень хотелось'
#text = ' '.join([word for word in text.split() if word not in (stopwords.words('russian'))])
#tom = " ".join([word for word in tom.split() if word not in(stopwords.words('russian'))])

# %%
bigram_vectorizer = CountVectorizer(ngram_range=(2,4),
                                    token_pattern=r'[А-Яа-я]+', min_df=1)

# %%
analyze = bigram_vectorizer.build_analyzer()

# %%
z = analyze(tom)

# %%
Counter(z).most_common()
# Out:
# [('павел петрович', 155),
#  ('николай петрович', 143),
#  ('василий иванович', 89),
#  ('анна сергеевна', 85),
#  ('евгений васильич', 31),
#  ('что то', 28),
#  ('все таки', 26),
#  ('арина власьевна', 26),
#  ('промолвил базаров', 24),
#  ('николая петровича', 22),
#  ('павла петровича', 18),
#  ('промолвил он', 18),
#  ('перебил базаров', 18),
#  ('спросил базаров', 18),
#  ('спросил аркадий', 16),
#  ('заметил аркадий', 15),
#  ('аркадий николаич', 15),
#  ('тех пор', 14),
#  ('как это', 14),
#  ('как то', 13),
#  ('по прежнему', 13),
#  ('самом деле', 13),
#  ('анны сергеевны', 13),
#  ('крайней мере', 12),
#  ('правда ли', 12),
#  ('из за', 12),
#  ('что это', 12),
#  ('прибавил он', 11),
#  ('отвечал базаров', 11),
#  ('друг друга', 11),
#  ('проговорил базаров', 11),
#  ('какое то', 11),
#  ('что нибудь', 11),
#  ('что ж', 11),
#  ('повторил базаров', 11),
#  ('следующий день', 11),
#  ('начал он', 10),
#  ('да да', 10),
#  ('это мгновение', 10),
#  ('спросил павел', 10),
#  ('может быть', 10),
#  ('да с', 10),
#  ('слава богу', 10),
#  ('заметил базаров', 10),
#  ('матвей ильич', 10),
#  ('спросил павел петрович', 10),
#  ('из под', 9),
#  ('ну да', 9),
#  ('промолвил аркадий', 9),
#  ('ответил аркадий', 9),
#  ('стало быть', 9),
#  ('вы можете', 9),
#  ('какой то', 9),
#  ('ответил базаров', 9),
#  ('каким то', 9),
#  ('василия ивановича', 9),
#  ('молодые люди', 8),
#  ('сквозь зубы', 8),
#  ('во первых', 8),
#  ('это дело', 8),
#  ('очень хорошо', 8),
#  ('воскликнул базаров', 8),
#  ('а что', 8),
#  ('точки зрения', 8),
#  ('аркадий а', 8),
#  ('возразил базаров', 8),
#  ('базаров это', 8),
#  ('должно быть', 8),
#  ('милостивый государь', 8),
#  ('анной сергеевной', 8),
#  ('в самом', 8),
#  ('лишь изредка', 7),
#  ('аркадий да', 7),
#  ('так с', 7),
#  ('это равно', 7),
#  ('а это', 7),
#  ('отвечал аркадий', 7),
#  ('таком случае', 7),
#  ('воскликнул аркадий', 7),
#  ('какой нибудь', 7),
#  ('павлу петровичу', 7),
#  ('подхватил базаров', 7),
#  ('петрович я', 7),
#  ('я думаю', 7),
#  ('молодых людей', 7),
#  ('с да', 7),
#  ('хочу сказать', 7),
#  ('какая то', 7),
#  ('я знаю', 7),
#  ('василий иваныч', 7),
#  ('павел петрович я', 7),
#  ('в самом деле', 7),
#  ('несколько минут', 6),
#  ('впрочем это', 6),
#  ('во вторых', 6),
#  ('какого то', 6),
#  ('подумал аркадий', 6),
#  ('обеими руками', 6),
#  ('большею частью', 6),
#  ('что такое', 6),
#  ('петрович это', 6),
#  ('человека который', 6),
#  ('вот как', 6),
#  ('павлом петровичем', 6),
#  ('я тебе', 6),
#  ('сих пор', 6),
#  ('продолжал аркадий', 6),
#  ('базаров а', 6),
#  ('я люблю', 6),
#  ('я понимаю', 6),
#  ('нет нет', 6),
#  ('продолжал он', 6),
#  ('ой ой', 6),
#  ('ха ха', 6),
#  ('отец алексей', 6),
#  ('катерина сергеевна', 6),
#  ('чем нибудь', 5),
#  ('своего сына', 5),
#  ('то то', 5),
#  ('точно так', 5),
#  ('чем то', 5),
#  ('по французски', 5),
#  ('сделай одолжение', 5),
#  ('когда нибудь', 5),
#  ('кое где', 5),
#  ('а ты', 5),
#  ('он я', 5),
#  ('подумал он', 5),
#  ('аркадий и', 5),
#  ('всяком случае', 5),
#  ('в таком', 5),
#  ('федосья николаевна', 5),
#  ('заметил павел', 5),
#  ('базаров аркадий', 5),
#  ('петрович нет', 5),
#  ('ну это', 5),
#  ('проговорил аркадий', 5),
#  ('петрович он', 5),
#  ('своей стороны', 5),
#  ('начал аркадий', 5),
#  ('отвечал павел', 5),
#  ('я говорю', 5),
#  ('а все', 5),
#  ('оба приятеля', 5),
#  ('начал павел', 5),
#  ('твой отец', 5),
#  ('по своему', 5),
#  ('это почему', 5),
#  ('если б', 5),
#  ('по вашему', 5),
#  ('он обращаясь', 5),
#  ('вы быть', 5),
#  ('не знаю', 5),
#  ('евгений васильевич', 5),
#  ('мне очень', 5),
#  ('какою то', 5),
#  ('она очень', 5),
#  ('ко мне', 5),
#  ('начала она', 5),
#  ('анну сергеевну', 5),
#  ('промолвила она', 5),
#  ('кто нибудь', 5),
#  ('все это', 5),
#  ('а я', 5),
#  ('базаров я', 5),
#  ('погодя немного', 5),
#  ('в таком случае', 5),
#  ('заметил павел петрович', 5),
#  ('отвечал павел петрович', 5),
#  ('а все таки', 5),
#  ('начал павел петрович', 5),
#  ('своему брату', 4),
#  ('петрович вышел', 4),
#  ('в м', 4),
#  ('несколько мгновений', 4),
#  ('позвольте узнать', 4),
#  ('николаю петровичу', 4),
#  ('заговорил николай', 4),
#  ('я могу', 4),
#  ('заметил николай', 4),
#  ('это совершенно', 4),
#  ('петрович посмотрел', 4),
#  ('петрович слегка', 4),
#  ('петрович медленно', 4),
#  ('взад вперед', 4),
#  ('какое нибудь', 4),
#  ('да что', 4),
#  ('продолжал базаров', 4),
#  ('бог знает', 4),
#  ('базаров который', 4),
#  ('господин базаров', 4),
#  ('ко всему', 4),
#  ('перебил павел', 4),
#  ('промолвил павел', 4),
#  ('какую то', 4),
#  ('петрович и', 4),
#  ('чуть чуть', 4),
#  ('проговорил он', 4),
#  ('что делать', 4),
#  ('спросила она', 4),
#  ('знаете ли', 4),
#  ('ты говоришь', 4),
#  ('я уверен', 4),
#  ('проговорил павел', 4),
#  ('а павел', 4),
#  ('повторила она', 4),
#  ('вышел вон', 4),
#  ('тому назад', 4),
#  ('спросила его', 4),
#  ('руки голову', 4),
#  ('твоего отца', 4),
#  ('а вы', 4),
#  ('прибавил базаров', 4),
#  ('ну прекрасно', 4),
#  ('по моему', 4),
#  ('аркадий николаевич', 4),
#  ('позвольте спросить', 4),
#  ('базаров поднял', 4),
#  ('базаров в', 4),
#  ('он ожидал', 4),
#  ('черт знает', 4),
#  ('стало досадно', 4),
#  ('но это', 4),
#  ('молодым людям', 4),
#  ('сказал ему', 4),
#  ('полчаса спустя', 4),
#  ('думал он', 4),
#  ('боже мой', 4),
#  ('аркадий он', 4),
#  ('своего приятеля', 4),
#  ('что что', 4),
#  ('несколько дней', 4),
#  ('и казалось', 4),
#  ('около часа', 4),
#  ('промолвила одинцова', 4),
#  ('вот тебе', 4),
#  ('кончил тем', 4),
#  ('базаров и', 4),
#  ('небольшого молчания', 4),
#  ('вас это', 4),
#  ('промолвила анна', 4),
#  ('подумал базаров', 4),
#  ('самом себе', 4),
#  ('еще бы', 4),
#  ('вот например', 4),
#  ('базаров нет', 4),
#  ('сергеевна это', 4),
#  ('стиснул руку', 4),
#  ('вы знаете', 4),
#  ('вы вы', 4),
#  ('да вы', 4),
#  ('обе руки', 4),
#  ('анне сергеевне', 4),
#  ('это значит', 4),
#  ('двадцать пять', 4),
#  ('проходя мимо', 4),
#  ('василию ивановичу', 4),
#  ('короткое время', 4),
#  ('спросил он', 4),
#  ('я это', 4),
#  ('своего брата', 4),
#  ('вы думаете', 4),
#  ('адского камня', 4),
#  ('заговорил николай петрович', 4),
#  ('заметил николай петрович', 4),
#  ('павел петрович медленно', 4),
#  ('николай петрович это', 4),
#  ('павел петрович нет', 4),
#  ('перебил павел петрович', 4),
#  ('промолвил павел петрович', 4),
#  ('павел петрович и', 4),
#  ('проговорил павел петрович', 4),
#  ('с да с', 4),
#  ('промолвила анна сергеевна', 4),
#  ('постоялого двора', 3),
#  ('русский человек', 3),
#  ('самый день', 3),
#  ('м году', 3),
#  ('он едва', 3),
#  ('ничего ничего', 3),
#  ('сказал он', 3),
#  ('быстро обернулся', 3),
#  ('свое лицо', 3),
#  ('говорил николай', 3),
#  ('твой приятель', 3),
#  ('он хотел', 3),
#  ('почему то', 3),
#  ('с промолвил', 3),
#  ('будет да', 3),
#  ('это пустяки', 3),
#  ('нет это', 3),
#  ('совершенно равно', 3),
#  ('начал николай', 3),
#  ('заметил вполголоса', 3),
#  ('проговорил николай', 3),
#  ('подхватил аркадий', 3),
#  ('отвечал николай', 3),
#  ('твоего приезда', 3),
#  ('душа моя', 3),
#  ('а впрочем', 3),
#  ('аркадий который', 3),
#  ('часа спустя', 3),
#  ('с проговорил', 3),
#  ('лаковые полусапожки', 3),
#  ('по русски', 3),
#  ('умный человек', 3),
#  ('аркадию базаров', 3),
#  ('а отец', 3),
#  ('таки это', 3),
#  ('петровича он', 3),
#  ('держал руках', 3),
#  ('выражение лица', 3),
#  ('молодая женщина', 3),
#  ('да тебе', 3),
#  ('тебе это', 3),
#  ('проговорил наконец', 3),
#  ('очень приятно', 3),
#  ('нечто вроде', 3),
#  ('опустился стул', 3),
#  ('аркадий бросился', 3),
#  ('кои то', 3),
#  ('то веки', 3),
#  ('оно следует', 3),
#  ('куда нибудь', 3),
#  ('тэ тэ', 3),
#  ('повторил аркадий', 3),
#  ('могу судить', 3),
#  ('быть это', 3),
#  ('это слово', 3),
#  ('человек который', 3),
#  ('это хорошо', 3),
#  ('опустила глаза', 3),
#  ('естественными науками', 3),
#  ('последнее время', 3),
#  ('высокого мнения', 3),
#  ('он начинал', 3),
#  ('это очень', 3),
#  ('лицо приняло', 3),
#  ('какие то', 3),
#  ('это все', 3),
#  ('хорошо с', 3),
#  ('ваше мнение', 3),
#  ('вашим услугам', 3),
#  ('ты вижу', 3),
#  ('вижу точно', 3),
#  ('это вздор', 3),
#  ('петрович отправился', 3),
#  ('ведь это', 3),
#  ('ну полно', 3),
#  ('евгений это', 3),
#  ('он начал', 3),
#  ('всякого рода', 3),
#  ('молодыми людьми', 3),
#  ('принимало выражение', 3),
#  ('вы я', 3),
#  ('самого себя', 3),
#  ('таким образом', 3),
#  ('это время', 3),
#  ('он стал', 3),
#  ('какими то', 3),
#  ('меня нет', 3),
#  ('нет брат', 3),
#  ('раздался голос', 3),
#  ('слушаю с', 3),
#  ('вдоль стен', 3),
#  ('и самом', 3),
#  ('промолвила фенечка', 3),
#  ('завернул сюда', 3),
#  ('где нибудь', 3),
#  ('кабинет и', 3),
#  ('кто то', 3),
#  ('то есть', 3),
#  ('ради бога', 3),
#  ('мне а', 3),
#  ('некоторое время', 3),
#  ('это то', 3),
#  ('как тебе', 3),
#  ('аркадий я', 3),
#  ('эге ге', 3),
#  ('несколько шагов', 3),
#  ('начал базаров', 3),
#  ('я начинаю', 3),
#  ('это что', 3),
#  ('базаров продолжал', 3),
#  ('больше книг', 3),
#  ('книг вы', 3),
#  ('можете скачать', 3),
#  ('скачать сайте', 3),
#  ('обоих молодых', 3),
#  ('аркадий отвечал', 3),
#  ('а почему', 3),
#  ('передо мной', 3),
#  ('матвея ильича', 3),
#  ('поднял глаза', 3),
#  ('я очень', 3),
#  ('я хочу', 3),
#  ('я говорил', 3),
#  ('русский народ', 3),
#  ('так кажется', 3),
#  ('это называется', 3),
#  ('ему стало', 3),
#  ('базаров отвечал', 3),
#  ('петрович дрогнул', 3),
#  ('посмотрел своего', 3),
#  ('нынешняя молодежь', 3),
#  ('я напротив', 3),
#  ('каждым днем', 3),
#  ('мелькнуло голове', 3),
#  ('будет а', 3),
#  ('на день', 3),
#  ('он однако', 3),
#  ('ваше с', 3),
#  ('с с', 3),
#  ('с ство', 3),
#  ('друг мой', 3),
#  ('нечего делать', 3),
#  ('это вы', 3),
#  ('моего отца', 3),
#  ('я надеюсь', 3),
#  ('состоянии понять', 3),
#  ('знаете что', 3),
#  ('что же', 3),
#  ('подхватил ситников', 3),
#  ('авдотья никитишна', 3),
#  ('все равно', 3),
#  ('не правда', 3),
#  ('прибавила она', 3),
#  ('ваш приятель', 3),
#  ('это ничего', 3),
#  ('он очень', 3),
#  ('часа прошло', 3),
#  ('а заметили', 3),
#  ('и подумав', 3),
#  ('день аркадию', 3),
#  ('она знала', 3),
#  ('руку она', 3),
#  ('покойный одинцов', 3),
#  ('в город', 3),
#  ('базарова он', 3),
#  ('немного прибавил', 3),
#  ('тебе говорю', 3),
#  ('это по', 3),
#  ('глазами она', 3),
#  ('очень мило', 3),
#  ('это удивляет', 3),
#  ('это сказали', 3),
#  ('базаров усмехнулся', 3),
#  ('базарова и', 3),
#  ('а теперь', 3),
#  ('чай пить', 3),
#  ('порфирий платоныч', 3),
#  ('тем что', 3),
#  ('а базаров', 3),
#  ('базаров остался', 3),
#  ('она что', 3),
#  ('это говоришь', 3),
#  ('чего то', 3),
#  ('ко всем', 3),
#  ('где то', 3),
#  ('думала она', 3),
#  ('он чувствовал', 3),
#  ('катей аркадий', 3),
#  ('аркадий это', 3),
#  ('то особенное', 3),
#  ('с и', 3),
#  ('и мать', 3),
#  ('взглянул нее', 3),
#  ('во всяком', 3),
#  ('да вот', 3),
#  ('васильич вы', 3),
#  ('базаров встал', 3),
#  ('пробормотал он', 3),
#  ('как нибудь', 3),
#  ('базаров да', 3),
#  ('это знаете', 3),
#  ('вы говорите', 3),
#  ('одно слово', 3),
#  ('одинцова протянула', 3),
#  ('протянула руку', 3),
#  ('извините меня', 3),
#  ('отчего это', 3),
#  ('уездный лекарь', 3),
#  ('зачем это', 3),
#  ('да аркадий', 3),
#  ('наклонил голову', 3),
#  ('посмотрела него', 3),
#  ('я должен', 3),
#  ('хотела сказать', 3),
#  ('вы извините', 3),
#  ('аркадий ну', 3),
#  ('лошадей и', 3),
#  ('промолвил василий', 3),
#  ('проговорил василий', 3),
#  ('вас господа', 3),
#  ('сию минуту', 3),
#  ('помилуй евгений', 3),
#  ('базаров василий', 3),
#  ('иванович вышел', 3),
#  ('воскликнул он', 3),
#  ('я полагаю', 3),
#  ('когда либо', 3),
#  ('я хотел', 3),
#  ('общее место', 3),
#  ('тебе сказать', 3),
#  ('руку но', 3),
#  ('иванович он', 3),
#  ('целый день', 3),
#  ('четыре часа', 3),
#  ('сказала она', 3),
#  ('петрович но', 3),
#  ('ответил павел', 3),
#  ('вы посмотрите', 3),
#  ('он вы', 3),
#  ('открыл глаза', 3),
#  ('бледное лицо', 3),
#  ('но базаров', 3),
#  ('ты это', 3),
#  ('промолвила да', 3),
#  ('что значит', 3),
#  ('прелестные ножки', 3),
#  ('сюда приехал', 3),
#  ('ну ну', 3),
#  ('в м году', 3),
#  ('говорил николай петрович', 3),
#  ('спросил аркадий да', 3),
#  ('точно так с', 3),
#  ('начал николай петрович', 3),
#  ('проговорил николай петрович', 3),
#  ('отвечал николай петрович', 3),
#  ('павел петрович слегка', 3),
#  ('кои то веки', 3),
#  ('очень хорошо с', 3),
#  ('николай петрович он', 3),
#  ('а павел петрович', 3),
#  ('и самом деле', 3),
#  ('больше книг вы', 3),
#  ('книг вы можете', 3),
#  ('вы можете скачать', 3),
#  ('можете скачать сайте', 3),
#  ('да с да', 3),
#  ('не правда ли', 3),
#  ('ой ой ой', 3),
#  ('во всяком случае', 3),
#  ('да вот например', 3),
#  ('евгений васильич вы', 3),
#  ('анна сергеевна это', 3),
#  ('прибавил он обращаясь', 3),
#  ('проговорил василий иванович', 3),
#  ('базаров василий иванович', 3),
#  ('василий иванович вышел', 3),
#  ('ха ха ха', 3),
#  ('василий иванович он', 3),
#  ('ответил павел петрович', 3),
#  ('спросил павел петрович нет', 3),
#  ('больше книг вы можете', 3),
#  ('книг вы можете скачать', 3),
#  ('вы можете скачать сайте', 3),
#  ('да с да с', 3),
#  ('иван сергеевич', 2),
#  ('сергеевич тургенев', 2),
#  ('русской жизни', 2),
#  ('отцы дети', 2),
#  ('еще спрашивал', 2),
#  ('лет сорока', 2),
#  ('вдоль дороги', 2),
#  ('нет с', 2),
#  ('не видать', 2),
#  ('николаем петровичем', 2),
#  ('постоялого дворика', 2),
#  ('петрович родился', 2),
#  ('брату павлу', 2),
#  ('речь впереди', 2),
#  ('агафоклея кузьминишна', 2),
#  ('сына николай', 2),
#  ('махнул рукой', 2),
#  ('ту пору', 2),
#  ('одной квартире', 2),
#  ('своей супруге', 2),
#  ('генерал кирсанов', 2),
#  ('между николай', 2),
#  ('петрович успел', 2),
#  ('родился сын', 2),
#  ('десять лет', 2),
#  ('лет прошло', 2),
#  ('хотя немного', 2),
#  ('аркадия на', 2),
#  ('чувства приличия', 2),
#  ('закурил трубку', 2),
#  ('посматривала него', 2),
#  ('те мысли', 2),
#  ('покойница жена', 2),
#  ('стал глядеть', 2),
#  ('мгновений спустя', 2),
#  ('голосом аркадий', 2),
#  ('покажи ка', 2),
#  ('поскорее николай', 2),
#  ('нас николай', 2),
#  ('и подойдя', 2),
#  ('высокого роста', 2),
#  ('крепко стиснул', 2),
#  ('руку которую', 2),
#  ('душевно рад', 2),
#  ('узнать ваше', 2),
#  ('ваше имя', 2),
#  ('голосом и', 2),
#  ('продолжал николай', 2),
#  ('губы базарова', 2),
#  ('так же', 2),
#  ('же аркадий', 2),
#  ('петрович оборачиваясь', 2),
#  ('подошел ручке', 2),
#  ('вполголоса аркадий', 2),
#  ('аркадий ты', 2),
#  ('барин то', 2),
#  ('воскликнул николай', 2),
#  ('отец сыном', 2),
#  ('оба экипажа', 2),
#  ('так как', 2),
#  ('наконец а', 2),
#  ('здоров он', 2),
#  ('поцеловал щеку', 2),
#  ('могу тебе', 2),
#  ('естественные науки', 2),
#  ('руку это', 2),
#  ('куда это', 2),
#  ('это человек', 2),
#  ('нынешнем году', 2),
#  ('наемными работниками', 2),
#  ('аркадий отвечая', 2),
#  ('промолвил николай', 2),
#  ('славно пахнет', 2),
#  ('косвенный взгляд', 2),
#  ('перемен марьине', 2),
#  ('я решился', 2),
#  ('прибавил николай', 2),
#  ('я считаю', 2),
#  ('своим долгом', 2),
#  ('предварить тебя', 2),
#  ('первых это', 2),
#  ('тебе известно', 2),
#  ('насчет отношений', 2),
#  ('эта девушка', 2),
#  ('ты вероятно', 2),
#  ('аркадий николай', 2),
#  ('помилуй папаша', 2),
#  ('гостить будет', 2),
#  ('он выше', 2),
#  ('ну ты', 2),
#  ('вот это', 2),
#  ('деньги нужны', 2),
#  ('аркадий глядел', 2),
#  ('размышления он', 2),
#  ('посмотрел отца', 2),
#  ('это тебе', 2),
#  ('друг другом', 2),
#  ('голос базарова', 2),
#  ('петрович умолк', 2),
#  ('которую аркадий', 2),
#  ('спустя оба', 2),
#  ('кирсанова он', 2),
#  ('за двери', 2),
#  ('человек лет', 2),
#  ('аркадию и', 2),
#  ('од женку', 2),
#  ('взял обеими', 2),
#  ('ты аркадий', 2),
#  ('петрович кирсанов', 2),
#  ('лет сорок', 2),
#  ('седые волосы', 2),
#  ('которое большею', 2),
#  ('петрович вынул', 2),
#  ('добро пожаловать', 2),
#  ('я думал', 2),
#  ('я нахожу', 2),
#  ('заметил он', 2),
#  ('за ужином', 2),
#  ('базаров говорил', 2),
#  ('т д', 2),
#  ('спускал глаз', 2),
#  ('свое время', 2),
#  ('время я', 2),
#  ('я когда', 2),
#  ('нибудь расскажу', 2),
#  ('николаич это', 2),
#  ('хороший человек', 2),
#  ('явление а', 2),
#  ('славный малый', 2),
#  ('человек заметил', 2),
#  ('удивительное дело', 2),
#  ('дело продолжал', 2),
#  ('базаров ушел', 2),
#  ('и базаров', 2),
#  ('далеко полночь', 2),
#  ('последний нумер', 2),
#  ('новую усадьбу', 2),
#  ('внутри делается', 2),
#  ('тобой те', 2),
#  ('те лягушки', 2),
#  ('это а', 2),
#  ('я боюсь', 2),
#  ('отец сын', 2),
#  ('федосья николавна', 2),
#  ('чай сливками', 2),
#  ('и помолчав', 2),
#  ('помолчав немного', 2),
#  ('что промолвил', 2),
#  ('он аркадий', 2),
#  ('аркадий опустил', 2),
#  ('опустил глаза', 2),
#  ('чай разливать', 2),
#  ('аркадий начал', 2),
#  ('но аркадий', 2),
#  ('посмотрел вслед', 2),
#  ('бросился шею', 2),
#  ('петрович в', 2),
#  ('в кои', 2),
#  ('вчерашнего дня', 2),
#  ('да это', 2),
#  ('петрович начал', 2),
#  ('базаров николай', 2),
#  ('базаров кажется', 2),
#  ('собственно такое', 2),
#  ('такое спросил', 2),
#  ('скажу он', 2),
#  ('он нигилист', 2),
#  ('спросил николай', 2),
#  ('петрович павел', 2),
#  ('остался неподвижен', 2),
#  ('сколько могу', 2),
#  ('который который', 2),
#  ('подхватил павел', 2),
#  ('ж это', 2),
#  ('очень дурно', 2),
#  ('это вижу', 2),
#  ('аркадий напротив', 2),
#  ('дай бог', 2),
#  ('брат николай', 2),
#  ('сама фенечка', 2),
#  ('женщина лет', 2),
#  ('и поставив', 2),
#  ('лица она', 2),
#  ('кончики пальцев', 2),
#  ('время чувствовала', 2),
#  ('здравствуй фенечка', 2),
#  ('и глянув', 2),
#  ('течение нескольких', 2),
#  ('поднял голову', 2),
#  ('он быстро', 2),
#  ('господа извините', 2),
#  ('дом это', 2),
#  ('петрович почувствовал', 2),
#  ('пить чай', 2),
#  ('нет вы', 2),
#  ('спросил очередь', 2),
#  ('да вообще', 2),
#  ('базаров слово', 2),
#  ('однако никто', 2),
#  ('лекарский сын', 2),
#  ('так так', 2),
#  ('вы вероятно', 2),
#  ('так это', 2),
#  ('голову назад', 2),
#  ('да стану', 2),
#  ('и чему', 2),
#  ('сказать ему', 2),
#  ('что касается', 2),
#  ('а пошли', 2),
#  ('базаров вот', 2),
#  ('как промолвил', 2),
#  ('вы стало', 2),
#  ('наука вообще', 2),
#  ('с ну', 2),
#  ('ну насчет', 2),
#  ('отрицательного направления', 2),
#  ('базаров павел', 2),
#  ('с своей', 2),
#  ('науками я', 2),
#  ('я вашим', 2),
#  ('петрович нам', 2),
#  ('подумал николай', 2),
#  ('а нам', 2),
#  ('петрович поднялся', 2),
#  ('отправился вслед', 2),
#  ('базаров аркадия', 2),
#  ('я нашел', 2),
#  ('полно евгений', 2),
#  ('ты увидишь', 2),
#  ('это следует', 2),
#  ('и аркадий', 2),
#  ('то забавно', 2),
#  ('пять шесть', 2),
#  ('княгиня р', 2),
#  ('всем лице', 2),
#  ('загадочный взгляд', 2),
#  ('своей цели', 2),
#  ('никто мог', 2),
#  ('лицо принимало', 2),
#  ('чувствовал сердце', 2),
#  ('сердце ту', 2),
#  ('чего хочу', 2),
#  ('он однажды', 2),
#  ('очень лестно', 2),
#  ('глаза глядели', 2),
#  ('это случилось', 2),
#  ('она тихонько', 2),
#  ('двумя тремя', 2),
#  ('он разумеется', 2),
#  ('смерти княгини', 2),
#  ('он встал', 2),
#  ('раньше обыкновенного', 2),
#  ('через несколько', 2),
#  ('несколько времени', 2),
#  ('за границы', 2),
#  ('обоих братьев', 2),
#  ('петрович потерял', 2),
#  ('всякого другого', 2),
#  ('сказал однажды', 2),
#  ('этим именем', 2),
#  ('ты думаю', 2),
#  ('по английски', 2),
#  ('те другие', 2),
#  ('видишь ли', 2),
#  ('ли евгений', 2),
#  ('говорю том', 2),
#  ('известное дело', 2),
#  ('базаров может', 2),
#  ('всякий человек', 2),
#  ('я например', 2),
#  ('а касается', 2),
#  ('это романтизм', 2),
#  ('аркадий сказал', 2),
#  ('сказал правду', 2),
#  ('окну и', 2),
#  ('бормотал сквозь', 2),
#  ('постоянно казалось', 2),
#  ('свое рвение', 2),
#  ('рассуждал собою', 2),
#  ('я человек', 2),
#  ('говаривал он', 2),
#  ('он недаром', 2),
#  ('и поравнявшись', 2),
#  ('голос фенечки', 2),
#  ('отворил дверь', 2),
#  ('своим ребенком', 2),
#  ('вон комнаты', 2),
#  ('глядя нее', 2),
#  ('а здесь', 2),
#  ('шепнула фенечка', 2),
#  ('перебирая пальцами', 2),
#  ('покажите ка', 2),
#  ('вся покраснела', 2),
#  ('она боялась', 2),
#  ('оглянулся кругом', 2),
#  ('одном углу', 2),
#  ('минут пять', 2),
#  ('всем телом', 2),
#  ('свои волосы', 2),
#  ('это дядя', 2),
#  ('лицо слегка', 2),
#  ('шесть месяцев', 2),
#  ('проговорила фенечка', 2),
#  ('на кого', 2),
#  ('да продолжал', 2),
#  ('самим собой', 2),
#  ('павел ты', 2),
#  ('чаю и', 2),
#  ('был не', 2),
#  ('н нет', 2),
#  ('познакомился фенечкой', 2),
#  ('умер оставив', 2),
#  ('так звали', 2),
#  ('приходской церкви', 2),
#  ('и обыкновению', 2),
#  ('хотела выйти', 2),
#  ('руки и', 2),
#  ('раскрытые губы', 2),
#  ('он увидал', 2),
#  ('фенечке она', 2),
#  ('своей матери', 2),
#  ('так таки', 2),
#  ('дай ка', 2),
#  ('и николай', 2),
#  ('письменном столе', 2),
#  ('бросился диван', 2),
#  ('вместе аркадием', 2),
#  ('есть в', 2),
#  ('базаров остановился', 2),
#  ('объяснил коротких', 2),
#  ('коротких словах', 2),
#  ('а нравится', 2),
#  ('базаров народ', 2),
#  ('аркадию николаевичу', 2),
#  ('базаров не', 2),
#  ('базаров взял', 2),
#  ('скажите мне', 2),
#  ('вот ваш', 2),
#  ('промолвила вполголоса', 2),
#  ('дуняша это', 2),
#  ('это точно', 2),
#  ('это нужно', 2),
#  ('ней что', 2),
#  ('ну нет', 2),
#  ('тебе стыдно', 2),
#  ('такие мысли', 2),
#  ('сделали несколько', 2),
#  ('сегодня евгений', 2),
#  ('русский мужик', 2),
#  ('эка важность', 2),
#  ('и природа', 2),
#  ('природа пустяки', 2),
#  ('задумчиво глядя', 2),
#  ('играет виолончели', 2),
#  ('сорок четыре', 2),
#  ('базаров работал', 2),
#  ('все доме', 2),
#  ('человек которого', 2),
#  ('дворовые мальчишки', 2),
#  ('погода стояла', 2),
#  ('базаров вставал', 2),
#  ('очень рано', 2),
#  ('возвратном пути', 2),
#  ('обыкновенно оставался', 2),
#  ('своего товарища', 2),
#  ('сад и', 2),
#  ('людей они', 2),
#  ('они шли', 2),
#  ('могли видеть', 2),
#  ('видеть ты', 2),
#  ('говорил аркадий', 2),
#  ('отец добрый', 2),
#  ('добрый малый', 2),
#  ('базаров человек', 2),
#  ('песенка спета', 2),
#  ('третьего дня', 2),
#  ('говорил день', 2),
#  ('отставные люди', 2),
#  ('базаров прав', 2),
#  ('остался назади', 2),
#  ('ушел вперед', 2),
#  ('воскликнул павел', 2),
#  ('всеми своими', 2),
#  ('недалеко ушел', 2),
#  ('петрович да', 2),
#  ('отстать века', 2),
#  ('что брат', 2),
#  ('начинаю думать', 2),
#  ('петрович повертел', 2),
#  ('по немецки', 2),
#  ('я по', 2),
#  ('исподлобья взглянул', 2),
#  ('него он', 2),
#  ('да брат', 2),
#  ('вздохом николай', 2),
#  ('базаров вообще', 2),
#  ('считаю долгом', 2),
#  ('смею сказать', 2),
#  ('вспомните милостивый', 2),
#  ('глаза павла', 2),
#  ('эфтимхочу доказать', 2),
#  ('александровского времени', 2),
#  ('мы мол', 2),
#  ('собственного достоинства', 2),
#  ('самому себе', 2),
#  ('наконец это', 2),
#  ('сложа руки', 2),
#  ('наше время', 2),
#  ('время могут', 2),
#  ('говорил это', 2),
#  ('день приезда', 2),
#  ('ли николай', 2),
#  ('кивнул головой', 2),
#  ('нужны что', 2),
#  ('как так', 2),
#  ('так да', 2),
#  ('да же', 2),
#  ('же вы', 2),
#  ('говорил вам', 2),
#  ('призна м', 2),
#  ('аркадий мы', 2),
#  ('все все', 2),
#  ('аркадий должны', 2),
#  ('своего молодого', 2),
#  ('вы господа', 2),
#  ('нет русский', 2),
#  ('готов согласиться', 2),
#  ('игрока который', 2),
#  ('да притом', 2),
#  ('как же', 2),
#  ('петрович приподнялся', 2),
#  ('улыбнулся и', 2),
#  ('и положив', 2),
#  ('положив руку', 2),
#  ('базарову вы', 2),
#  ('напрасно это', 2),
#  ('кажется это', 2),
#  ('соглашаюсь но', 2),
#  ('стоит труда', 2),
#  ('это ведет', 2),
#  ('ругаться и', 2),
#  ('и это', 2),
#  ...]

# %%
def ngrams_text (word,num):
    word = word.lower()
    word = re.sub("[!\"#$%&\'—()*+,-»«./:;<=>?@[\\]^_`{|}~]?",'',word)
    #tokens = re.findall ('он\s\w+',word)
    #tokens = [token for token in word.split(" ") if token != ""]
    mystem.lemmatize(word)
    wordsFiltered = []
    for w in word:
        if w not in stopwords:
            wordsFiltered.append(w)
    
    output = list(ngrams(tokens,num))
    mostcommon = Counter(output).most_common()
    return mostcommon
#лемматизировать можно прямо из nltk，lemmatize, а стоп слова также есть в nltk.есть такая тетрадка. 
#чтобы свести все свои документы в один нужно просто конкатенировать все переменны. открывааем и читаем фал, сохраняем в переменную, складываем все переменные.
#append только для списка

# %%
def ngrams_text (word,num):
    word = word.lower()
    word = re.sub("[!\"#$%&\'—()*+,-»«./:;<=>?@[\\]^_`{|}~]?",'',word)
    #tokens = re.findall ('он\s\w+',word)
    #tokens = [token for token in word.split(" ") if token != ""]
    mystem.lemmatize(word)
    wordsFiltered = []
    for w in word:
        if w not in stopwords:
            wordsFiltered.append(w)
    
    output = list(ngrams(tokens,num))
    mostcommon = Counter(output).most_common()
    return mostcommon
#лемматизировать можно прямо из nltk，lemmatize, а стоп слова также есть в nltk.есть такая тетрадка. 
#чтобы свести все свои документы в один нужно просто конкатенировать все переменны. открывааем и читаем фал, сохраняем в переменную, складываем все переменные.
#append только для списка

# %%
def ngrams_text (word,num):
    word = word.lower()
    word = re.sub("[!\"#$%&\'—()*+,-»«./:;<=>?@[\\]^_`{|}~]?",'',word)
    #tokens = re.findall ('он\s\w+',word)
    #tokens = [token for token in word.split(" ") if token != ""]
    mystem.lemmatize(word)
    wordsFiltered = []
    for w in word:
        if w not in stopwords:
            wordsFiltered.append(w)
    
    output = list(ngrams(tokens,num))
    mostcommon = Counter(output).most_common()
    return mostcommon
#лемматизировать можно прямо из nltk，lemmatize, а стоп слова также есть в nltk.есть такая тетрадка. 
#чтобы свести все свои документы в один нужно просто конкатенировать все переменны. открывааем и читаем фал, сохраняем в переменную, складываем все переменные.
#append только для списка

# %%
ngrams_text("любовь",3)
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-22-120f9802b2fd> in <module>
# ----> 1 ngrams_text("любовь",3)
#
# <ipython-input-5-5e497a6001b9> in ngrams_text(word, num)
#       4     #tokens = re.findall ('он\s\w+',word)
#       5     #tokens = [token for token in word.split(" ") if token != ""]
# ----> 6     mystem.lemmatize(word)
#       7     wordsFiltered = []
#       8     for w in word:
#
# c:\users\sidor\appdata\local\programs\python\python37\lib\site-packages\pymystem3\mystem.py in lemmatize(self, text)
#     263         need_encode = (sys.version_info[0] < 3 and isinstance(text, str))
#     264
# --> 265         infos = self.analyze(text)
#     266         lemmas = list(filter(None, map(self._get_lemma, infos)))
#     267
#
# c:\users\sidor\appdata\local\programs\python\python37\lib\site-packages\pymystem3\mystem.py in analyze(self, text)
#     248         result = []
#     249         for line in text.splitlines():
# --> 250             result.extend(self._analyze_impl(line))
#     251         return result
#     252
#
# c:\users\sidor\appdata\local\programs\python\python37\lib\site-packages\pymystem3\mystem.py in _analyze_impl(self, text)
#     308                 self._start_mystem()
#     309
# --> 310             self._procin.write(text)
#     311             self._procin.write(_NL)
#     312
#
# ValueError: I/O operation on closed file

# %%
from nltk.util import ngrams

# %%
ngrams_text(tom6,3)
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-15-f6c145f82854> in <module>
# ----> 1 ngrams_text(tom6,3)
#
# <ipython-input-5-5e497a6001b9> in ngrams_text(word, num)
#       4     #tokens = re.findall ('он\s\w+',word)
#       5     #tokens = [token for token in word.split(" ") if token != ""]
# ----> 6     mystem.lemmatize(word)
#       7     wordsFiltered = []
#       8     for w in word:
#
# c:\users\sidor\appdata\local\programs\python\python37\lib\site-packages\pymystem3\mystem.py in lemmatize(self, text)
#     263         need_encode = (sys.version_info[0] < 3 and isinstance(text, str))
#     264
# --> 265         infos = self.analyze(text)
#     266         lemmas = list(filter(None, map(self._get_lemma, infos)))
#     267
#
# c:\users\sidor\appdata\local\programs\python\python37\lib\site-packages\pymystem3\mystem.py in analyze(self, text)
#     248         result = []
#     249         for line in text.splitlines():
# --> 250             result.extend(self._analyze_impl(line))
#     251         return result
#     252
#
# c:\users\sidor\appdata\local\programs\python\python37\lib\site-packages\pymystem3\mystem.py in _analyze_impl(self, text)
#     308                 self._start_mystem()
#     309
# --> 310             self._procin.write(text)
#     311             self._procin.write(_NL)
#     312
#
# ValueError: I/O operation on closed file
