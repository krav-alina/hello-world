# %%
with open ('ottsy_i_dieti_-_ivan_sierghieievich_turghieniev.txt') as file1:
    tom = file1.read()

# %%
from sklearn.feature_extraction.text import CountVectorizer
import nltk
from collections import Counter
import re
import os

# %%
from nltk.corpus import stopwords
from nltk.tokenize import word_tokenize
import nltk
nltk.download('punkt')
# Out:
# [nltk_data] Downloading package punkt to
# [nltk_data]     C:\Users\sidor\AppData\Roaming\nltk_data...
# [nltk_data]   Package punkt is already up-to-date!
# True

# %%
import nltk
nltk.download('stopwords')
# Out:
# [nltk_data] Downloading package stopwords to
# [nltk_data]     C:\Users\sidor\AppData\Roaming\nltk_data...
# [nltk_data]   Package stopwords is already up-to-date!
# True

# %%
from pymystem3 import Mystem

# %%
mystem = Mystem()

# %%
tom = tom.lower()
tom = re.sub("[!\"#$%&\'—()*+,-»«./:;<=>?@[\\]^_`{|}~]?",'',tom)
tom = " ".join([word for word in tom.split() if word not in(stopwords.words('russian'))])

# %% [markdown]
# def normalized_text (word):
#     word = word.lower()
#     word = re.sub("[!\"#$%&\'—()*+,-»«./:;<=>?@[\\]^_`{|}~]?",'',word)
#     word = " ".join([word for word in word.split() if word not in(stopwords.words('russian'))])
#     word = word.split()
#     output = len(word)
#     return output

# %% [markdown]
# normalized_text(tom)

# %% [markdown]
# #filtered_words = [Word for Word in tom6 if Word not in stopwords.words('russian')]
# #text = 'здравствуй дорогой читатель сегодня очень ветренно поэтому я и он не пошли гулять хотя очень хотелось'
# #text = ' '.join([word for word in text.split() if word not in (stopwords.words('russian'))])
# #tom = " ".join([word for word in tom.split() if word not in(stopwords.words('russian'))])

# %%
newstoplist = ['это','базаров','петрович','аркадий','павел','николай','очень','тебе','василий','сергеевна','иванович','анна','евгений','одинцова','базарова','фенечка','катя','нам','аркадия','своей','своего','аркадию','петровича']
tom = " ".join([word for word in tom.split() if word not in(newstoplist)])
print(tom)
# Out:
# иван сергеевич тургенев выдающийся русский писатель бесспорный классик мировой литературы безупречный стилист знаток русской жизни персонажей романа бесы фмдостоевского которым тургенев находился неприязненных отношениях главных героев трилогии тома стоппарда берег утопии автор знаменитых произведений любви дворянское гнездо первая любовь вешние воды менее известных романов россии открытом автором лишнем человеке рудин накануне отцы дети история любви неординарного сумевшего найти применение своим выдающимся качествам профессиональном поприще личной жизни наши дни трогает заставляет сопереживать главному герою удивительной цельности силе личности также недовоплощенности русской жизни столь щедро одаренных природой людей иван сергеевич тургенев отцы дети посвящается памяти виссариона григорьевича белинского – петр видать – спрашивал мая года выходя шапки низкое крылечко постоялого двора шоссе барин лет сорока небольшим запыленном пальто клетчатых панталонах слуги молодого щекастого малого беловатым пухом подбородке маленькими тусклыми глазенками слуга котором бирюзовая сережка ухе напомаженные разноцветные волосы учтивые телодвижения словом изобличало человека новейшего усовершенствованного поколения посмотрел снисходительно вдоль дороги ответствовал никак нетс видать – видать – повторил барин – видать – вторично ответствовал слуга барин вздохнул присел скамеечку познакомим читателя пока сидит подогнувши ножки задумчиво поглядывая кругом зовут николаем петровичем кирсановым пятнадцати верстах постоялого дворика хорошее имение двести душ выражается тех пор размежевался крестьянами завел ферму – две тысячи десятин земли отец боевой генерал года полуграмотный грубый злой русский человек жизнь тянул лямку командовал сперва бригадой дивизией постоянно жил провинции силу чина играл довольно значительную роль родился юге россии подобно старшему своему брату павлу котором речь впереди воспитывался четырнадцатилетнего возраста дома окруженный дешевыми гувернерами развязными подобострастными адъютантами прочими полковыми штабными личностями родительница фамилии колязиных девицах генеральшах агафоклея кузьминишна кирсанова принадлежала числу матушеккомандирш носила пышные чепцы шумные шелковые платья церкви подходила первая ко кресту говорила громко допускала детей утром ручке ночь благословляла – словом жила свое удовольствие качестве генеральского сына – хотя отличался храбростью заслужил прозвище трусишки – должен подобно брату павлу поступить военную службу переломил ногу самый день прибыло известие определении пролежав месяца постели жизнь остался хроменьким отец махнул рукой пустил штатской повез петербург минул восемнадцатый год поместил университет кстати брат ту пору вышел офицером гвардейский полк молодые люди стали жить вдвоем одной квартире отдаленным надзором двоюродного дяди материнской стороны ильи колязина важного чиновника отец вернулся дивизии супруге лишь изредка присылал сыновьям большие четвертушки серой бумаги испещренные размашистым писарским почерком конце этих четвертушек красовались старательно окруженные выкрутасами слова пиотр кирсаноф генералмайор году вышел университета кандидатом году генерал кирсанов уволенный отставку неудачный смотр приехал петербург женою житье нанял дом таврического сада записался английский клуб внезапно умер удара агафоклея кузьминишна скоро последовала могла привыкнуть глухой столичной жизни тоска отставного существованья загрызла успел жизни родителей немалому огорчению влюбиться дочку чиновника преполовенского бывшего хозяина квартиры миловидную говорится развитую девицу журналах читала серьезные статьи отделе наук женился минул срок траура покинув министерство уделов протекции отец записал блаженствовал своею машей сперва даче около лесного института городе маленькой хорошенькой квартире чистою лестницей холодноватою гостиной – деревне поселился окончательно скором времени родился сын супруги жили тихо расставались читали вместе играли четыре руки фортепьяно пели дуэты сажала цвет ...

# %%
bigram_vectorizer = CountVectorizer(ngram_range=(2,2),
                                    token_pattern=r'[А-Яа-я]+', min_df=1)

# %%
analyze = bigram_vectorizer.build_analyzer()

# %%
z = analyze(tom)

# %%
Counter(z).most_common()
# Out:
# [('арина власьевна', 26),
#  ('тех пор', 14),
#  ('самом деле', 13),
#  ('анны сергеевны', 13),
#  ('крайней мере', 12),
#  ('друг друга', 11),
#  ('следующий день', 11),
#  ('матвей ильич', 10),
#  ('василия ивановича', 9),
#  ('молодые люди', 8),
#  ('сквозь зубы', 8),
#  ('точки зрения', 8),
#  ('слава богу', 8),
#  ('милостивый государь', 8),
#  ('анной сергеевной', 8),
#  ('лишь изредка', 7),
#  ('таком случае', 7),
#  ('павлу петровичу', 7),
#  ('молодых людей', 7),
#  ('хочу сказать', 7),
#  ('несколько минут', 6),
#  ('обеими руками', 6),
#  ('большею частью', 6),
#  ('человека который', 6),
#  ('павлом петровичем', 6),
#  ('сих пор', 6),
#  ('отец алексей', 6),
#  ('сделай одолжение', 5),
#  ('всяком случае', 5),
#  ('федосья николаевна', 5),
#  ('оба приятеля', 5),
#  ('твой отец', 5),
#  ('анну сергеевну', 5),
#  ('погодя немного', 5),
#  ('своему брату', 4),
#  ('несколько мгновений', 4),
#  ('позвольте узнать', 4),
#  ('николаю петровичу', 4),
#  ('взад вперед', 4),
#  ('бог знает', 4),
#  ('ко всему', 4),
#  ('вышел вон', 4),
#  ('тому назад', 4),
#  ('руки голову', 4),
#  ('твоего отца', 4),
#  ('прибавил обращаясь', 4),
#  ('позвольте спросить', 4),
#  ('черт знает', 4),
#  ('стало досадно', 4),
#  ('молодым людям', 4),
#  ('полчаса спустя', 4),
#  ('несколько дней', 4),
#  ('около часа', 4),
#  ('небольшого молчания', 4),
#  ('стиснул руку', 4),
#  ('обе руки', 4),
#  ('анне сергеевне', 4),
#  ('двадцать пять', 4),
#  ('проходя мимо', 4),
#  ('василию ивановичу', 4),
#  ('короткое время', 4),
#  ('адского камня', 4),
#  ('постоялого двора', 3),
#  ('русский человек', 3),
#  ('сына хотя', 3),
#  ('самый день', 3),
#  ('м году', 3),
#  ('быстро обернулся', 3),
#  ('свое лицо', 3),
#  ('твой приятель', 3),
#  ('точно такс', 3),
#  ('совершенно равно', 3),
#  ('заметил вполголоса', 3),
#  ('твоего приезда', 3),
#  ('часа спустя', 3),
#  ('лаковые полусапожки', 3),
#  ('умный человек', 3),
#  ('держал руках', 3),
#  ('выражение лица', 3),
#  ('молодая женщина', 3),
#  ('нечто вроде', 3),
#  ('опустился стул', 3),
#  ('които веки', 3),
#  ('оно следует', 3),
#  ('могу судить', 3),
#  ('человек который', 3),
#  ('опустила глаза', 3),
#  ('естественными науками', 3),
#  ('последнее время', 3),
#  ('высокого мнения', 3),
#  ('лицо приняло', 3),
#  ('ваше мнение', 3),
#  ('вашим услугам', 3),
#  ('вижу точно', 3),
#  ('всякого рода', 3),
#  ('молодыми людьми', 3),
#  ('принимало выражение', 3),
#  ('таким образом', 3),
#  ('раздался голос', 3),
#  ('вдоль стен', 3),
#  ('завернул сюда', 3),
#  ('ради бога', 3),
#  ('некоторое время', 3),
#  ('несколько шагов', 3),
#  ('книг можете', 3),
#  ('можете скачать', 3),
#  ('скачать сайте', 3),
#  ('обоих молодых', 3),
#  ('говорил день', 3),
#  ('передо мной', 3),
#  ('матвея ильича', 3),
#  ('поднял глаза', 3),
#  ('дас дас', 3),
#  ('русский народ', 3),
#  ('нынешняя молодежь', 3),
#  ('каждым днем', 3),
#  ('мелькнуло голове', 3),
#  ('ваше с', 3),
#  ('с с', 3),
#  ('с ство', 3),
#  ('нечего делать', 3),
#  ('моего отца', 3),
#  ('состоянии понять', 3),
#  ('подхватил ситников', 3),
#  ('авдотья никитишна', 3),
#  ('ваш приятель', 3),
#  ('часа прошло', 3),
#  ('покойный одинцов', 3),
#  ('немного прибавил', 3),
#  ('чай пить', 3),
#  ('порфирий платоныч', 3),
#  ('ко всем', 3),
#  ('хотел сказать', 3),
#  ('одно слово', 3),
#  ('протянула руку', 3),
#  ('уездный лекарь', 3),
#  ('наклонил голову', 3),
#  ('хотела сказать', 3),
#  ('сию минуту', 3),
#  ('общее место', 3),
#  ('целый день', 3),
#  ('четыре часа', 3),
#  ('открыл глаза', 3),
#  ('бледное лицо', 3),
#  ('прелестные ножки', 3),
#  ('сюда приехал', 3),
#  ('иван сергеевич', 2),
#  ('сергеевич тургенев', 2),
#  ('русской жизни', 2),
#  ('отцы дети', 2),
#  ('лет сорока', 2),
#  ('вдоль дороги', 2),
#  ('николаем петровичем', 2),
#  ('постоялого дворика', 2),
#  ('брату павлу', 2),
#  ('речь впереди', 2),
#  ('агафоклея кузьминишна', 2),
#  ('махнул рукой', 2),
#  ('ту пору', 2),
#  ('одной квартире', 2),
#  ('генерал кирсанов', 2),
#  ('родился сын', 2),
#  ('десять лет', 2),
#  ('лет прошло', 2),
#  ('хотя немного', 2),
#  ('чувства приличия', 2),
#  ('закурил трубку', 2),
#  ('наш сын', 2),
#  ('те мысли', 2),
#  ('стал глядеть', 2),
#  ('мгновений спустя', 2),
#  ('высокого роста', 2),
#  ('крепко стиснул', 2),
#  ('руку которую', 2),
#  ('душевно рад', 2),
#  ('узнать ваше', 2),
#  ('ваше имя', 2),
#  ('подошел ручке', 2),
#  ('отец сыном', 2),
#  ('оба экипажа', 2),
#  ('поцеловал щеку', 2),
#  ('могу выразить', 2),
#  ('естественные науки', 2),
#  ('нынешнем году', 2),
#  ('продолжал обращаясь', 2),
#  ('наемными работниками', 2),
#  ('славно пахнет', 2),
#  ('косвенный взгляд', 2),
#  ('жив жив', 2),
#  ('перемен марьине', 2),
#  ('своим долгом', 2),
#  ('насчет отношений', 2),
#  ('эта девушка', 2),
#  ('помилуй папаша', 2),
#  ('деньги нужны', 2),
#  ('посмотрел отца', 2),
#  ('друг другом', 2),
#  ('спустя оба', 2),
#  ('павла кирсанова', 2),
#  ('изза двери', 2),
#  ('человек лет', 2),
#  ('од женку', 2),
#  ('взял обеими', 2),
#  ('лет сорок', 2),
#  ('седые волосы', 2),
#  ('которое большею', 2),
#  ('добро пожаловать', 2),
#  ('пойду воскликнул', 2),
#  ('спускал глаз', 2),
#  ('возле постели', 2),
#  ('свое время', 2),
#  ('когданибудь расскажу', 2),
#  ('расскажу историю', 2),
#  ('хороший человек', 2),
#  ('славный малый', 2),
#  ('человек заметил', 2),
#  ('удивительное дело', 2),
#  ('дело продолжал', 2),
#  ('далеко полночь', 2),
#  ('последний нумер', 2),
#  ('новую усадьбу', 2),
#  ('внутри делается', 2),
#  ('тобой те', 2),
#  ('те лягушки', 2),
#  ('отец сын', 2),
#  ('федосья николавна', 2),
#  ('чай сливками', 2),
#  ('помолчав немного', 2),
#  ('опустил глаза', 2),
#  ('чай разливать', 2),
#  ('посмотрел вслед', 2),
#  ('сказал брат', 2),
#  ('бросился шею', 2),
#  ('вчерашнего дня', 2),
#  ('спросил дома', 2),
#  ('собственно такое', 2),
#  ('такое спросил', 2),
#  ('остался неподвижен', 2),
#  ('который который', 2),
#  ('дай бог', 2),
#  ('бог здоровья', 2),
#  ('брат пора', 2),
#  ('женщина лет', 2),
#  ('кончики пальцев', 2),
#  ('время чувствовала', 2),
#  ('течение нескольких', 2),
#  ('поднял голову', 2),
#  ('господа извините', 2),
#  ('пить чай', 2),
#  ('спросил очередь', 2),
#  ('однако никто', 2),
#  ('лекарский сын', 2),
#  ('голову назад', 2),
#  ('дело говорят', 2),
#  ('наука вообще', 2),
#  ('отрицательного направления', 2),
#  ('отправился вслед', 2),
#  ('княгиня р', 2),
#  ('всем лице', 2),
#  ('загадочный взгляд', 2),
#  ('никто мог', 2),
#  ('лицо принимало', 2),
#  ('чувствовал сердце', 2),
#  ('сердце ту', 2),
#  ('глаза глядели', 2),
#  ('смерти княгини', 2),
#  ('раньше обыкновенного', 2),
#  ('несколько времени', 2),
#  ('изза границы', 2),
#  ('обоих братьев', 2),
#  ('всякого другого', 2),
#  ('сказал однажды', 2),
#  ('этим именем', 2),
#  ('прежде решился', 2),
#  ('те другие', 2),
#  ('всякий человек', 2),
#  ('сказал правду', 2),
#  ('бормотал сквозь', 2),
#  ('постоянно казалось', 2),
#  ('свое рвение', 2),
#  ('рассуждал собою', 2),
#  ('голос фенечки', 2),
#  ('отворил дверь', 2),
#  ('своим ребенком', 2),
#  ('вон комнаты', 2),
#  ('перебирая пальцами', 2),
#  ('вся покраснела', 2),
#  ('оглянулся кругом', 2),
#  ('одном углу', 2),
#  ('минут пять', 2),
#  ('всем телом', 2),
#  ('свои волосы', 2),
#  ('лицо слегка', 2),
#  ('шесть месяцев', 2),
#  ('самим собой', 2),
#  ('познакомился фенечкой', 2),
#  ('умер оставив', 2),
#  ('приходской церкви', 2),
#  ('хотела выйти', 2),
#  ('раскрытые губы', 2),
#  ('мать арина', 2),
#  ('письменном столе', 2),
#  ('бросился диван', 2),
#  ('вместе аркадием', 2),
#  ('объяснил коротких', 2),
#  ('коротких словах', 2),
#  ('промолвила вполголоса', 2),
#  ('такие мысли', 2),
#  ('сделали несколько', 2),
#  ('русский мужик', 2),
#  ('эка важность', 2),
#  ('природа пустяки', 2),
#  ('задумчиво глядя', 2),
#  ('играет виолончели', 2),
#  ('сорок четыре', 2),
#  ('виолончели продолжал', 2),
#  ('человек которого', 2),
#  ('дворовые мальчишки', 2),
#  ('погода стояла', 2),
#  ('возвратном пути', 2),
#  ('обыкновенно оставался', 2),
#  ('могли видеть', 2),
#  ('знаешь говорил', 2),
#  ('отец добрый', 2),
#  ('добрый малый', 2),
#  ('песенка спета', 2),
#  ('третьего дня', 2),
#  ('отставные люди', 2),
#  ('остался назади', 2),
#  ('ушел вперед', 2),
#  ('всеми своими', 2),
#  ('недалеко ушел', 2),
#  ('отстать века', 2),
#  ('начинаю думать', 2),
#  ('почему почему', 2),
#  ('исподлобья взглянул', 2),
#  ('считаю долгом', 2),
#  ('смею сказать', 2),
#  ('вспомните милостивый', 2),
#  ('глаза павла', 2),
#  ('эфтимхочу доказать', 2),
#  ('александровского времени', 2),
#  ('собственного достоинства', 2),
#  ('сложа руки', 2),
#  ('наше время', 2),
#  ('время могут', 2),
#  ('день приезда', 2),
#  ('кивнул головой', 2),
#  ('призна м', 2),
#  ('готов согласиться', 2),
#  ('игрока который', 2),
#  ('русский русский', 2),
#  ('положив руку', 2),
#  ('стоит труда', 2),
#  ('называется нигилизмом', 2),
#  ('произнес сквозь', 2),
#  ('бабушка надвое', 2),
#  ('надвое сказала', 2),
#  ('наши наследники', 2),
#  ('напротив уверен', 2),
#  ('продолжал сидеть', 2),
#  ('произошла перемена', 2),
#  ('глаза небу', 2),
#  ('нем происходило', 2),
#  ('повороте дорожки', 2),
#  ('думаю чай', 2),
#  ('скрыть свое', 2),
#  ('наши приятели', 2),
#  ('этому поводу', 2),
#  ('первых порах', 2),
#  ('всем каждому', 2),
#  ('чудак твой', 2),
#  ('молодой человек', 2),
#  ('например сегодня', 2),
#  ('ство такое', 2),
#  ('пятница ваше', 2),
#  ('пятница пятница', 2),
#  ('старинных понятий', 2),
#  ('доложил приезде', 2),
#  ('какими судьбами', 2),
#  ('ситников визгливо', 2),
#  ('визгливо засмеялся', 2),
#  ('господин кирсанов', 2),
#  ('дворянский домик', 2),
#  ('пять лет', 2),
#  ('кирсанов проговорил', 2),
#  ('милости просим', 2),
#  ('пожала руку', 2),
#  ('дети говорят', 2),
#  ('ситников который', 2),
#  ('который успел', 2),
#  ('мое мнение', 2),
#  ('позвольте полюбопытствовать', 2),
#  ('чтото такое', 2),
#  ('хладнокровно заметил', 2),
#  ('знаю думаю', 2),
#  ('знаете знаю', 2),
#  ('самым приятным', 2),
#  ('нашу беседу', 2),
#  ('последней капли', 2),
#  ('будемте говорить', 2),
#  ('говорить любви', 2),
#  ('эта барыня', 2),
#  ('ситников вскочил', 2),
#  ('лице своем', 2),
#  ('обнаженные руки', 2),
#  ('губы улыбались', 2),
#  ('ситников подвел', 2),
#  ('почему думаете', 2),
#  ('отошел сторону', 2),
#  ('наблюдать нею', 2),
#  ('одно время', 2),
#  ('обернулась нему', 2),
#  ('провел около', 2),
#  ('который имеет', 2),
#  ('имеет смелость', 2),
#  ('тобой познакомиться', 2),
#  ('часто случается', 2),
#  ('обратил внимания', 2),
#  ('часу ночи', 2),
#  ('говорил следующий', 2),
#  ('вышла замуж', 2),
#  ('против обыкновения', 2),
#  ('глаза светились', 2),
#  ('подумав немного', 2),
#  ('богатое тело', 2),
#  ('дня спустя', 2),
#  ('понизив голос', 2),
#  ('аллея стриженых', 2),
#  ('стриженых елок', 2),
#  ('черном фраке', 2),
#  ('карты играть', 2),
#  ('борзая собака', 2),
#  ('принялась разбирать', 2),
#  ('художественного смысла', 2),
#  ('например извините', 2),
#  ('люди друг', 2),
#  ('друга похожи', 2),
#  ('одни те', 2),
#  ('деревья лесу', 2),
#  ('подняла глаза', 2),
#  ('одним словом', 2),
#  ('одна та', 2),
#  ('кресло которое', 2),
#  ('чай кушать', 2),
#  ('пойти гулять', 2),
#  ('уездного лекаря', 2),
#  ('стиснув губы', 2),
#  ('латинские названия', 2),
#  ('оставшись наедине', 2),
#  ('эта смугленькая', 2),
#  ('странное существо', 2),
#  ('имея никаких', 2),
#  ('жилось легко', 2),
#  ('сама зная', 2),
#  ('отправился комнату', 2),
#  ('каждый человек', 2),
#  ('свои мнения', 2),
#  ('наших приятелей', 2),
#  ('свои замечания', 2),
#  ('чемто вроде', 2),
#  ('вокруг шеи', 2),
#  ('чтото особенное', 2),
#  ('вашу милость', 2),
#  ('белое платье', 2),
#  ('сами сказали', 2),
#  ('десять часов', 2),
#  ('можете остаться', 2),
#  ('беседовать вами', 2),
#  ('хотелось узнать', 2),
#  ('такие слова', 2),
#  ('глухо промолвил', 2),
#  ('б могла', 2),
#  ('мое дело', 2),
#  ('слову пришлось', 2),
#  ('быстрыми шагами', 2),
#  ('долго сидел', 2),
#  ('обыкновению своему', 2),
#  ('свое место', 2),
#  ('нечего говорить', 2),
#  ('мог отвечать', 2),
#  ('полноте васильич', 2),
#  ('думать будущем', 2),
#  ('почему высказать', 2),
#  ('желали знать', 2),
#  ('васильич проговорила', 2),
#  ('остаться завтра', 2),
#  ('выше всяких', 2),
#  ('всяких предрассудков', 2),
#  ('упорно угрюмо', 2),
#  ('нет нет', 2),
#  ('должен извиниться', 2),
#  ('самого вечера', 2),
#  ('некоторых пор', 2),
#  ('хохловских выселков', 2),
#  ('свои вещи', 2),
#  ('както странно', 2),
#  ('своему бывшему', 2),
#  ('тарантас покатил', 2),
#  ('пять верст', 2),
#  ('продолжал вполголоса', 2),
#  ('промолвил кажется', 2),
#  ('рядом нею', 2),
#  ('можешь судить', 2),
#  ('который стоял', 2),
#  ('имею чести', 2),
#  ('обрадовался старый', 2),
#  ('старый барбос', 2),
#  ('лазаря петь', 2),
#  ('мое время', 2),
#  ('своем веку', 2),
#  ('принадлежал числу', 2),
#  ('проговорил доктор', 2),
#  ('сколько времени', 2),
#  ('раскрыв глаза', 2),
#  ('прекрасно отвечал', 2),
#  ('голову знаю', 2),
#  ('мира сего', 2),
#  ('какого мнения', 2),
#  ('должен сказать', 2),
#  ('голос старика', 2),
#  ('старика перервался', 2),
#  ('трудно сказать', 2),
#  ('кстати нужно', 2),
#  ('закон закон', 2),
#  ('должно тото', 2),
#  ('закидывая руки', 2),
#  ('злость почему', 2),
#  ('цып цып', 2),
#  ('противоположное общее', 2),
#  ('настоящий человек', 2),
#  ('последнего мужика', 2),
#  ('силу ощущения', 2),
#  ('печальным голосом', 2),
#  ('судить нем', 2),
#  ('раздался мгновение', 2),
#  ('отцу алексею', 2),
#  ('эпизод чумы', 2),
#  ('арины власьевны', 2),
#  ('глаза матери', 2),
#  ('спросила погодя', 2),
#  ('произнес отец', 2),
#  ('промолвил отец', 2),
#  ('плечами пожал', 2),
#  ('день прошел', 2),
#  ('вынул платок', 2),
#  ('сына арина', 2),
#  ('город оттуда', 2),
#  ('довольно долго', 2),
#  ('обоим говорю', 2),
#  ('заявить свое', 2),
#  ('одном доме', 2),
#  ('своих лягушек', 2),
#  ('николая находилось', 2),
#  ('увидел собою', 2),
#  ('лихорадка работы', 2),
#  ('николае петровиче', 2),
#  ('пор стал', 2),
#  ('пульс пощупать', 2),
#  ('сто лет', 2),
#  ('повернулась нему', 2),
#  ('свои глаза', 2),
#  ('вышла вон', 2),
#  ('моего брата', 2),
#  ('слышать ваши', 2),
#  ('какое ваше', 2),
#  ('хотите сказать', 2),
#  ('приятно слышать', 2),
#  ('ваши слова', 2),
#  ('несколько слов', 2),
#  ('десяти шагах', 2),
#  ('подобных случаях', 2),
#  ('вид озабоченный', 2),
#  ('спутанных лошадей', 2),
#  ('шепнул петр', 2),
#  ('довольно промолвил', 2),
#  ('драться серьезно', 2),
#  ('прежде должен', 2),
#  ('ступай водой', 2),
#  ('взволнованным голосом', 2),
#  ('одним лишь', 2),
#  ('совесть чиста', 2),
#  ('всем сердцем', 2),
#  ('кого свете', 2),
#  ('своим губам', 2),
#  ('свежий румяный', 2),
#  ('отступил шаг', 2),
#  ('милый брат', 2),
#  ('придав своему', 2),
#  ('старые следы', 2),
#  ('кажется пошла', 2),
#  ('прибавил отчего', 2),
#  ('продолжал недаром', 2),
#  ('катерина заговорил', 2),
#  ('голос анны', 2),
#  ('благополучно здоровы', 2),
#  ('почел нужным', 2),
#  ('дела анной', 2),
#  ('друг другу', 2),
#  ('любовь чувство', 2),
#  ('чувство напускное', 2),
#  ('базаровым хотя', 2),
#  ('продолжалась недолго', 2),
#  ('некоторым образом', 2),
#  ('слово люблю', 2),
#  ('катерину сергеевну', 2),
#  ('смеяться полагаю', 2),
#  ('слишком долго', 2),
#  ('дело хорошее', 2),
#  ('василием ивановичем', 2),
#  ('трех рыбах', 2),
#  ('уездного врача', 2),
#  ('тотчас вернулся', 2),
#  ('повернулся стене', 2),
#  ('продолжал лежать', 2),
#  ('руку судорожно', 2),
#  ('признаки заражения', 2),
#  ('пошли нарочного', 2),
#  ('кланяться велел', 2),
#  ('возле дивана', 2),
#  ('поцеловал руку', 2),
#  ('наступил кризис', 2),
#  ('кризис прошел', 2),
#  ('кабинет доктор', 2),
#  ('нечего думать', 2),
#  ('профессоров своим', 2),
#  ('тургенев выдающийся', 1),
#  ('выдающийся русский', 1),
#  ('русский писатель', 1),
#  ('писатель бесспорный', 1),
#  ('бесспорный классик', 1),
#  ('классик мировой', 1),
#  ('мировой литературы', 1),
#  ('литературы безупречный', 1),
#  ('безупречный стилист', 1),
#  ('стилист знаток', 1),
#  ('знаток русской', 1),
#  ('жизни персонажей', 1),
#  ('персонажей романа', 1),
#  ('романа бесы', 1),
#  ('бесы фмдостоевского', 1),
#  ('фмдостоевского которым', 1),
#  ('которым тургенев', 1),
#  ('тургенев находился', 1),
#  ('находился неприязненных', 1),
#  ('неприязненных отношениях', 1),
#  ('отношениях главных', 1),
#  ('главных героев', 1),
#  ('героев трилогии', 1),
#  ('трилогии тома', 1),
#  ('тома стоппарда', 1),
#  ('стоппарда берег', 1),
#  ('берег утопии', 1),
#  ('утопии автор', 1),
#  ('автор знаменитых', 1),
#  ('знаменитых произведений', 1),
#  ('произведений любви', 1),
#  ('любви дворянское', 1),
#  ('дворянское гнездо', 1),
#  ('гнездо первая', 1),
#  ('первая любовь', 1),
#  ('любовь вешние', 1),
#  ('вешние воды', 1),
#  ('воды менее', 1),
#  ('менее известных', 1),
#  ('известных романов', 1),
#  ('романов россии', 1),
#  ('россии открытом', 1),
#  ('открытом автором', 1),
#  ('автором лишнем', 1),
#  ('лишнем человеке', 1),
#  ('человеке рудин', 1),
#  ('рудин накануне', 1),
#  ('накануне отцы', 1),
#  ('дети история', 1),
#  ('история любви', 1),
#  ('любви неординарного', 1),
#  ('неординарного сумевшего', 1),
#  ('сумевшего найти', 1),
#  ('найти применение', 1),
#  ('применение своим', 1),
#  ('своим выдающимся', 1),
#  ('выдающимся качествам', 1),
#  ('качествам профессиональном', 1),
#  ('профессиональном поприще', 1),
#  ('поприще личной', 1),
#  ('личной жизни', 1),
#  ('жизни наши', 1),
#  ('наши дни', 1),
#  ('дни трогает', 1),
#  ('трогает заставляет', 1),
#  ('заставляет сопереживать', 1),
#  ('сопереживать главному', 1),
#  ('главному герою', 1),
#  ('герою удивительной', 1),
#  ('удивительной цельности', 1),
#  ('цельности силе', 1),
#  ('силе личности', 1),
#  ('личности также', 1),
#  ('также недовоплощенности', 1),
#  ('недовоплощенности русской', 1),
#  ('жизни столь', 1),
#  ('столь щедро', 1),
#  ('щедро одаренных', 1),
#  ('одаренных природой', 1),
#  ('природой людей', 1),
#  ('людей иван', 1),
#  ('тургенев отцы', 1),
#  ('дети посвящается', 1),
#  ('посвящается памяти', 1),
#  ('памяти виссариона', 1),
#  ('виссариона григорьевича', 1),
#  ('григорьевича белинского', 1),
#  ('белинского петр', 1),
#  ('петр видать', 1),
#  ('видать спрашивал', 1),
#  ('спрашивал мая', 1),
#  ('мая года', 1),
#  ('года выходя', 1),
#  ('выходя шапки', 1),
#  ('шапки низкое', 1),
#  ('низкое крылечко', 1),
#  ('крылечко постоялого', 1),
#  ('двора шоссе', 1),
#  ('шоссе барин', 1),
#  ('барин лет', 1),
#  ('сорока небольшим', 1),
#  ('небольшим запыленном', 1),
#  ('запыленном пальто', 1),
#  ('пальто клетчатых', 1),
#  ('клетчатых панталонах', 1),
#  ('панталонах слуги', 1),
#  ('слуги молодого', 1),
#  ('молодого щекастого', 1),
#  ('щекастого малого', 1),
#  ('малого беловатым', 1),
#  ('беловатым пухом', 1),
#  ('пухом подбородке', 1),
#  ('подбородке маленькими', 1),
#  ('маленькими тусклыми', 1),
#  ('тусклыми глазенками', 1),
#  ('глазенками слуга', 1),
#  ('слуга котором', 1),
#  ('котором бирюзовая', 1),
#  ('бирюзовая сережка', 1),
#  ('сережка ухе', 1),
#  ('ухе напомаженные', 1),
#  ('напомаженные разноцветные', 1),
#  ('разноцветные волосы', 1),
#  ('волосы учтивые', 1),
#  ('учтивые телодвижения', 1),
#  ('телодвижения словом', 1),
#  ('словом изобличало', 1),
#  ('изобличало человека', 1),
#  ('человека новейшего', 1),
#  ('новейшего усовершенствованного', 1),
#  ('усовершенствованного поколения', 1),
#  ('поколения посмотрел', 1),
#  ('посмотрел снисходительно', 1),
#  ('снисходительно вдоль', 1),
#  ('дороги ответствовал', 1),
#  ('ответствовал никак', 1),
#  ('никак нетс', 1),
#  ('нетс видать', 1),
#  ('видать видать', 1),
#  ('видать повторил', 1),
#  ('повторил барин', 1),
#  ('барин видать', 1),
#  ('видать вторично', 1),
#  ('вторично ответствовал', 1),
#  ('ответствовал слуга', 1),
#  ('слуга барин', 1),
#  ('барин вздохнул', 1),
#  ('вздохнул присел', 1),
#  ('присел скамеечку', 1),
#  ('скамеечку познакомим', 1),
#  ('познакомим читателя', 1),
#  ('читателя пока', 1),
#  ('пока сидит', 1),
#  ('сидит подогнувши', 1),
#  ('подогнувши ножки', 1),
#  ('ножки задумчиво', 1),
#  ('задумчиво поглядывая', 1),
#  ('поглядывая кругом', 1),
#  ('кругом зовут', 1),
#  ('зовут николаем', 1),
#  ('петровичем кирсановым', 1),
#  ('кирсановым пятнадцати', 1),
#  ('пятнадцати верстах', 1),
#  ('верстах постоялого', 1),
#  ('дворика хорошее', 1),
#  ('хорошее имение', 1),
#  ('имение двести', 1),
#  ('двести душ', 1),
#  ('душ выражается', 1),
#  ('выражается тех', 1),
#  ('пор размежевался', 1),
#  ('размежевался крестьянами', 1),
#  ('крестьянами завел', 1),
#  ('завел ферму', 1),
#  ('ферму две', 1),
#  ('две тысячи', 1),
#  ('тысячи десятин', 1),
#  ('десятин земли', 1),
#  ('земли отец', 1),
#  ('отец боевой', 1),
#  ('боевой генерал', 1),
#  ('генерал года', 1),
#  ('года полуграмотный', 1),
#  ('полуграмотный грубый', 1),
#  ('грубый злой', 1),
#  ('злой русский', 1),
#  ('человек жизнь', 1),
#  ('жизнь тянул', 1),
#  ('тянул лямку', 1),
#  ('лямку командовал', 1),
#  ('командовал сперва', 1),
#  ('сперва бригадой', 1),
#  ('бригадой дивизией', 1),
#  ('дивизией постоянно', 1),
#  ('постоянно жил', 1),
#  ('жил провинции', 1),
#  ('провинции силу', 1),
#  ('силу чина', 1),
#  ('чина играл', 1),
#  ('играл довольно', 1),
#  ('довольно значительную', 1),
#  ('значительную роль', 1),
#  ('роль родился', 1),
#  ('родился юге', 1),
#  ('юге россии', 1),
#  ('россии подобно', 1),
#  ('подобно старшему', 1),
#  ('старшему своему', 1),
#  ('павлу котором', 1),
#  ('котором речь', 1),
#  ('впереди воспитывался', 1),
#  ('воспитывался четырнадцатилетнего', 1),
#  ('четырнадцатилетнего возраста', 1),
#  ('возраста дома', 1),
#  ('дома окруженный', 1),
#  ('окруженный дешевыми', 1),
#  ('дешевыми гувернерами', 1),
#  ('гувернерами развязными', 1),
#  ('развязными подобострастными', 1),
#  ('подобострастными адъютантами', 1),
#  ('адъютантами прочими', 1),
#  ('прочими полковыми', 1),
#  ('полковыми штабными', 1),
#  ('штабными личностями', 1),
#  ('личностями родительница', 1),
#  ('родительница фамилии', 1),
#  ('фамилии колязиных', 1),
#  ('колязиных девицах', 1),
#  ('девицах генеральшах', 1),
#  ('генеральшах агафоклея', 1),
#  ('кузьминишна кирсанова', 1),
#  ('кирсанова принадлежала', 1),
#  ('принадлежала числу', 1),
#  ('числу матушеккомандирш', 1),
#  ('матушеккомандирш носила', 1),
#  ('носила пышные', 1),
#  ('пышные чепцы', 1),
#  ('чепцы шумные', 1),
#  ('шумные шелковые', 1),
#  ('шелковые платья', 1),
#  ('платья церкви', 1),
#  ('церкви подходила', 1),
#  ('подходила первая', 1),
#  ('первая ко', 1),
#  ('ко кресту', 1),
#  ('кресту говорила', 1),
#  ('говорила громко', 1),
#  ('громко допускала', 1),
#  ('допускала детей', 1),
#  ('детей утром', 1),
#  ('утром ручке', 1),
#  ('ручке ночь', 1),
#  ('ночь благословляла', 1),
#  ('благословляла словом', 1),
#  ('словом жила', 1),
#  ('жила свое', 1),
#  ('свое удовольствие', 1),
#  ('удовольствие качестве', 1),
#  ('качестве генеральского', 1),
#  ('генеральского сына', 1),
#  ('хотя отличался', 1),
#  ('отличался храбростью', 1),
#  ('храбростью заслужил', 1),
#  ('заслужил прозвище', 1),
#  ('прозвище трусишки', 1),
#  ('трусишки должен', 1),
#  ('должен подобно', 1),
#  ('подобно брату', 1),
#  ('павлу поступить', 1),
#  ('поступить военную', 1),
#  ('военную службу', 1),
#  ('службу переломил', 1),
#  ('переломил ногу', 1),
#  ('ногу самый', 1),
#  ('день прибыло', 1),
#  ('прибыло известие', 1),
#  ('известие определении', 1),
#  ('определении пролежав', 1),
#  ('пролежав месяца', 1),
#  ('месяца постели', 1),
#  ('постели жизнь', 1),
#  ('жизнь остался', 1),
#  ('остался хроменьким', 1),
#  ('хроменьким отец', 1),
#  ('отец махнул', 1),
#  ('рукой пустил', 1),
#  ('пустил штатской', 1),
#  ('штатской повез', 1),
#  ('повез петербург', 1),
#  ('петербург минул', 1),
#  ('минул восемнадцатый', 1),
#  ('восемнадцатый год', 1),
#  ('год поместил', 1),
#  ('поместил университет', 1),
#  ('университет кстати', 1),
#  ('кстати брат', 1),
#  ('брат ту', 1),
#  ('пору вышел', 1),
#  ('вышел офицером', 1),
#  ('офицером гвардейский', 1),
#  ('гвардейский полк', 1),
#  ('полк молодые', 1),
#  ('люди стали', 1),
#  ('стали жить', 1),
#  ('жить вдвоем', 1),
#  ('вдвоем одной', 1),
#  ('квартире отдаленным', 1),
#  ('отдаленным надзором', 1),
#  ('надзором двоюродного', 1),
#  ('двоюродного дяди', 1),
#  ('дяди материнской', 1),
#  ('материнской стороны', 1),
#  ('стороны ильи', 1),
#  ('ильи колязина', 1),
#  ('колязина важного', 1),
#  ('важного чиновника', 1),
#  ('чиновника отец', 1),
#  ('отец вернулся', 1),
#  ('вернулся дивизии', 1),
#  ('дивизии супруге', 1),
#  ('супруге лишь', 1),
#  ('изредка присылал', 1),
#  ('присылал сыновьям', 1),
#  ('сыновьям большие', 1),
#  ('большие четвертушки', 1),
#  ('четвертушки серой', 1),
#  ('серой бумаги', 1),
#  ('бумаги испещренные', 1),
#  ('испещренные размашистым', 1),
#  ('размашистым писарским', 1),
#  ('писарским почерком', 1),
#  ('почерком конце', 1),
#  ('конце этих', 1),
#  ('этих четвертушек', 1),
#  ('четвертушек красовались', 1),
#  ('красовались старательно', 1),
#  ('старательно окруженные', 1),
#  ('окруженные выкрутасами', 1),
#  ('выкрутасами слова', 1),
#  ('слова пиотр', 1),
#  ('пиотр кирсаноф', 1),
#  ('кирсаноф генералмайор', 1),
#  ('генералмайор году', 1),
#  ('году вышел', 1),
#  ('вышел университета', 1),
#  ('университета кандидатом', 1),
#  ('кандидатом году', 1),
#  ('году генерал', 1),
#  ('кирсанов уволенный', 1),
#  ('уволенный отставку', 1),
#  ('отставку неудачный', 1),
#  ('неудачный смотр', 1),
#  ('смотр приехал', 1),
#  ('приехал петербург', 1),
#  ('петербург женою', 1),
#  ('женою житье', 1),
#  ('житье нанял', 1),
#  ('нанял дом', 1),
#  ('дом таврического', 1),
#  ('таврического сада', 1),
#  ('сада записался', 1),
#  ('записался английский', 1),
#  ('английский клуб', 1),
#  ('клуб внезапно', 1),
#  ('внезапно умер', 1),
#  ('умер удара', 1),
#  ('удара агафоклея', 1),
#  ('кузьминишна скоро', 1),
#  ('скоро последовала', 1),
#  ('последовала могла', 1),
#  ('могла привыкнуть', 1),
#  ('привыкнуть глухой', 1),
#  ('глухой столичной', 1),
#  ('столичной жизни', 1),
#  ...]

# %%
def ngrams_text (word,num):
    word = word.lower()
    word = re.sub("[!\"#$%&\'—()*+,-»«./:;<=>?@[\\]^_`{|}~]?",'',word)
    #tokens = re.findall ('он\s\w+',word)
    #tokens = [token for token in word.split(" ") if token != ""]
    mystem.lemmatize(word)
    wordsFiltered = []
    for w in word:
        if w not in stopwords:
            wordsFiltered.append(w)
    
    output = list(ngrams(tokens,num))
    mostcommon = Counter(output).most_common()
    return mostcommon
#лемматизировать можно прямо из nltk，lemmatize, а стоп слова также есть в nltk.есть такая тетрадка. 
#чтобы свести все свои документы в один нужно просто конкатенировать все переменны. открывааем и читаем фал, сохраняем в переменную, складываем все переменные.
#append только для списка

# %%
def ngrams_text (word,num):
    word = word.lower()
    word = re.sub("[!\"#$%&\'—()*+,-»«./:;<=>?@[\\]^_`{|}~]?",'',word)
    #tokens = re.findall ('он\s\w+',word)
    #tokens = [token for token in word.split(" ") if token != ""]
    mystem.lemmatize(word)
    wordsFiltered = []
    for w in word:
        if w not in stopwords:
            wordsFiltered.append(w)
    
    output = list(ngrams(tokens,num))
    mostcommon = Counter(output).most_common()
    return mostcommon
#лемматизировать можно прямо из nltk，lemmatize, а стоп слова также есть в nltk.есть такая тетрадка. 
#чтобы свести все свои документы в один нужно просто конкатенировать все переменны. открывааем и читаем фал, сохраняем в переменную, складываем все переменные.
#append только для списка

# %%
def ngrams_text (word,num):
    word = word.lower()
    word = re.sub("[!\"#$%&\'—()*+,-»«./:;<=>?@[\\]^_`{|}~]?",'',word)
    #tokens = re.findall ('он\s\w+',word)
    #tokens = [token for token in word.split(" ") if token != ""]
    mystem.lemmatize(word)
    wordsFiltered = []
    for w in word:
        if w not in stopwords:
            wordsFiltered.append(w)
    
    output = list(ngrams(tokens,num))
    mostcommon = Counter(output).most_common()
    return mostcommon
#лемматизировать можно прямо из nltk，lemmatize, а стоп слова также есть в nltk.есть такая тетрадка. 
#чтобы свести все свои документы в один нужно просто конкатенировать все переменны. открывааем и читаем фал, сохраняем в переменную, складываем все переменные.
#append только для списка

# %%
ngrams_text("любовь",3)
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-22-120f9802b2fd> in <module>
# ----> 1 ngrams_text("любовь",3)
#
# <ipython-input-5-5e497a6001b9> in ngrams_text(word, num)
#       4     #tokens = re.findall ('он\s\w+',word)
#       5     #tokens = [token for token in word.split(" ") if token != ""]
# ----> 6     mystem.lemmatize(word)
#       7     wordsFiltered = []
#       8     for w in word:
#
# c:\users\sidor\appdata\local\programs\python\python37\lib\site-packages\pymystem3\mystem.py in lemmatize(self, text)
#     263         need_encode = (sys.version_info[0] < 3 and isinstance(text, str))
#     264
# --> 265         infos = self.analyze(text)
#     266         lemmas = list(filter(None, map(self._get_lemma, infos)))
#     267
#
# c:\users\sidor\appdata\local\programs\python\python37\lib\site-packages\pymystem3\mystem.py in analyze(self, text)
#     248         result = []
#     249         for line in text.splitlines():
# --> 250             result.extend(self._analyze_impl(line))
#     251         return result
#     252
#
# c:\users\sidor\appdata\local\programs\python\python37\lib\site-packages\pymystem3\mystem.py in _analyze_impl(self, text)
#     308                 self._start_mystem()
#     309
# --> 310             self._procin.write(text)
#     311             self._procin.write(_NL)
#     312
#
# ValueError: I/O operation on closed file

# %%
from nltk.util import ngrams

# %%
ngrams_text(tom6,3)
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-15-f6c145f82854> in <module>
# ----> 1 ngrams_text(tom6,3)
#
# <ipython-input-5-5e497a6001b9> in ngrams_text(word, num)
#       4     #tokens = re.findall ('он\s\w+',word)
#       5     #tokens = [token for token in word.split(" ") if token != ""]
# ----> 6     mystem.lemmatize(word)
#       7     wordsFiltered = []
#       8     for w in word:
#
# c:\users\sidor\appdata\local\programs\python\python37\lib\site-packages\pymystem3\mystem.py in lemmatize(self, text)
#     263         need_encode = (sys.version_info[0] < 3 and isinstance(text, str))
#     264
# --> 265         infos = self.analyze(text)
#     266         lemmas = list(filter(None, map(self._get_lemma, infos)))
#     267
#
# c:\users\sidor\appdata\local\programs\python\python37\lib\site-packages\pymystem3\mystem.py in analyze(self, text)
#     248         result = []
#     249         for line in text.splitlines():
# --> 250             result.extend(self._analyze_impl(line))
#     251         return result
#     252
#
# c:\users\sidor\appdata\local\programs\python\python37\lib\site-packages\pymystem3\mystem.py in _analyze_impl(self, text)
#     308                 self._start_mystem()
#     309
# --> 310             self._procin.write(text)
#     311             self._procin.write(_NL)
#     312
#
# ValueError: I/O operation on closed file
