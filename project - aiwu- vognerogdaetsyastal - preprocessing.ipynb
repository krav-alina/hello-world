# %%
with open ('Ай У. В огне рождается сталь - royallib.com.txt') as file1:
    aiwu = file1.read()

# %%
from sklearn.feature_extraction.text import CountVectorizer
import nltk
from collections import Counter
import re
import os

# %%
from nltk.corpus import stopwords
from nltk.tokenize import word_tokenize
import nltk
nltk.download('punkt')
# Out:
# [nltk_data] Downloading package punkt to
# [nltk_data]     C:\Users\sidor\AppData\Roaming\nltk_data...
# [nltk_data]   Package punkt is already up-to-date!
# True

# %%
import nltk
nltk.download('stopwords')
# Out:
# [nltk_data] Downloading package stopwords to
# [nltk_data]     C:\Users\sidor\AppData\Roaming\nltk_data...
# [nltk_data]   Package stopwords is already up-to-date!
# True

# %%
from pymystem3 import Mystem

# %%
mystem = Mystem()

# %%
def normalized_text (word):
    word = word.lower()
    word = re.sub("[!\"#$%&\'—()*+,-»«./:;<=>?@[\\]^_`{|}~]?",'',word)
    word = " ".join([word for word in word.split() if word not in(stopwords.words('russian'))])
    word = word.split()
    output = len(word)
    return output

# %%
normalized_text(aiwu)
# Out:
# 51015

# %%
#filtered_words = [Word for Word in tom6 if Word not in stopwords.words('russian')]
#text = 'здравствуй дорогой читатель сегодня очень ветренно поэтому я и он не пошли гулять хотя очень хотелось'
#text = ' '.join([word for word in text.split() if word not in (stopwords.words('russian'))])
#tom = " ".join([word for word in tom.split() if word not in(stopwords.words('russian'))])

# %%
bigram_vectorizer = CountVectorizer(ngram_range=(4,6),
                                    token_pattern=r'[А-Яа-я]+', min_df=2)

# %%
analyze = bigram_vectorizer.build_analyzer()

# %%
z = analyze(aiwu)

# %%
Counter(z).most_common()
# Out:
# [('юань тин фа и', 41),
#  ('что цинь дэ гуй', 36),
#  ('ответил цинь дэ гуй', 34),
#  ('цинь дэ гуй не', 29),
#  ('с цинь дэ гуем', 29),
#  ('цинь дэ гуй и', 27),
#  ('с чжан фу цюанем', 23),
#  ('сунь юй фэнь и', 22),
#  ('лян цзин чунь и', 21),
#  ('хэ цзы сюе и', 20),
#  ('но цинь дэ гуй', 20),
#  ('что юань тин фа', 19),
#  ('цинь дэ гуя и', 19),
#  ('цинь дэ гуя он', 19),
#  ('и цинь дэ гуй', 19),
#  ('чжан фу цюань и', 19),
#  ('с сунь юй фэнь', 19),
#  ('ответил чжан фу цюань', 19),
#  ('что сунь юй фэнь', 18),
#  ('ответил юань тин фа', 17),
#  ('сел на велосипед и', 15),
#  ('юань тин фа а', 15),
#  ('на цинь дэ гуя', 14),
#  ('сказал лян цзин чунь', 14),
#  ('но юань тин фа', 14),
#  ('сказал хэ цзы сюе', 13),
#  ('у цинь дэ гуя', 13),
#  ('юань тин фа не', 12),
#  ('и юань тин фа', 12),
#  ('сунь юй фэнь он', 12),
#  ('спросил лян цзин чунь', 12),
#  ('а цинь дэ гуй', 11),
#  ('к цинь дэ гую', 11),
#  ('цинь дэ гуй он', 11),
#  ('цинь дэ гуй в', 11),
#  ('юань тин фа он', 11),
#  ('чжан фу цюань не', 11),
#  ('юань тин фа но', 11),
#  ('ответил лян цзин чунь', 10),
#  ('цинь дэ гуй ты', 10),
#  ('лян цзин чунь не', 10),
#  ('до сих пор не', 10),
#  ('чжан фу цюань он', 10),
#  ('с юань тин фа', 10),
#  ('ответил хэ цзы сюе', 10),
#  ('и чжан фу цюань', 10),
#  ('сунь юй фэнь но', 10),
#  ('чжан фу цюань в', 10),
#  ('хэ цзы сюе но', 9),
#  ('его цинь дэ гуй', 9),
#  ('что чжан фу цюань', 9),
#  ('спросил цинь дэ гуй', 9),
#  ('сказал цинь дэ гуй', 9),
#  ('ли цзи мин и', 9),
#  ('и хэ цзы сюе', 9),
#  ('с хэ цзы сюе', 9),
#  ('но чжан фу цюань', 9),
#  ('и сунь юй фэнь', 9),
#  ('сунь юй фэнь я', 9),
#  ('но сунь юй фэнь', 9),
#  ('на велосипед и поехал', 9),
#  ('спросил юань тин фа', 9),
#  ('дин чунь сю и', 9),
#  ('к лян цзин чуню', 8),
#  ('рассмеялся цинь дэ гуй', 8),
#  ('хэ цзы сюе не', 8),
#  ('на душе у него', 8),
#  ('сунь юй фэнь она', 8),
#  ('цинь дэ гуй да', 8),
#  ('цинь дэ гуй а', 8),
#  ('цинь дэ гуй я', 8),
#  ('чжан фу цюаня и', 8),
#  ('сел на велосипед и поехал', 8),
#  ('цинь дэ гуй с', 7),
#  ('во что бы то', 7),
#  ('что бы то ни', 7),
#  ('бы то ни стало', 7),
#  ('цинь дэ гуй сел', 7),
#  ('чжан фу цюань ты', 7),
#  ('мужа дин чунь сю', 7),
#  ('как чжан фу цюань', 7),
#  ('к юань тин фа', 7),
#  ('сунь юй фэнь не', 7),
#  ('чжао ли мин и', 7),
#  ('сунь юй фэнь в', 7),
#  ('сказал чжан фу цюань', 7),
#  ('дин чунь сю а', 7),
#  ('во что бы то ни', 7),
#  ('что бы то ни стало', 7),
#  ('ответил цинь дэ гуй и', 7),
#  ('во что бы то ни стало', 7),
#  ('хэ цзы сюе я', 6),
#  ('цинь дэ гуй стал', 6),
#  ('юань тин фа на', 6),
#  ('цинь дэ гуй но', 6),
#  ('когда цинь дэ гуй', 6),
#  ('дэ гуй сел на', 6),
#  ('гуй сел на велосипед', 6),
#  ('что хэ цзы сюе', 6),
#  ('не обратил внимания на', 6),
#  ('к хэ цзы сюе', 6),
#  ('юань тин фа снова', 6),
#  ('а чжан фу цюань', 6),
#  ('он был уверен что', 6),
#  ('с тех пор как', 6),
#  ('мысли о том что', 6),
#  ('товарищ хэ цзы сюе', 6),
#  ('сунь юй фэнь ты', 6),
#  ('и лян цзин чунь', 6),
#  ('лицо цинь дэ гуя', 6),
#  ('цинь дэ гуя за', 6),
#  ('как цинь дэ гуй', 6),
#  ('цинь дэ гуй как', 6),
#  ('у чжан фу цюаня', 6),
#  ('чжан фу цюань а', 6),
#  ('цинь дэ гуя то', 6),
#  ('на лян цзин чуня', 6),
#  ('цинь дэ гуй сел на', 6),
#  ('дэ гуй сел на велосипед', 6),
#  ('гуй сел на велосипед и', 6),
#  ('ответил чжан фу цюань и', 6),
#  ('цинь дэ гуй сел на велосипед', 6),
#  ('дэ гуй сел на велосипед и', 6),
#  ('ты что же это', 5),
#  ('цинь дэ гуя в', 5),
#  ('ни в коем случае', 5),
#  ('юань тин фа что', 5),
#  ('голову цинь дэ гуй', 5),
#  ('том что цинь дэ', 5),
#  ('цинь дэ гуй взял', 5),
#  ('рассмеялся чжан фу цюань', 5),
#  ('цинь дэ гуй так', 5),
#  ('цинь дэ гуя не', 5),
#  ('покачал головой цинь дэ', 5),
#  ('головой цинь дэ гуй', 5),
#  ('цинь дэ гуй если', 5),
#  ('смену цинь дэ гуй', 5),
#  ('ни на минуту не', 5),
#  ('хэ цзы сюе уже', 5),
#  ('хэ цзы сюе ты', 5),
#  ('юань тин фа да', 5),
#  ('дин чунь сю она', 5),
#  ('до тех пор пока', 5),
#  ('цинь дэ гуя а', 5),
#  ('юань тин фа когда', 5),
#  ('как бы там ни', 5),
#  ('бы там ни было', 5),
#  ('там ни было а', 5),
#  ('лян цзин чунь ты', 5),
#  ('чжан фу цюань я', 5),
#  ('этот цинь дэ гуй', 5),
#  ('у юань тин фа', 5),
#  ('сунь юй фэнь с', 5),
#  ('чжан фу цюаню и', 5),
#  ('ты ведь знаешь что', 5),
#  ('на велосипед и помчался', 5),
#  ('воскликнула дин чунь сю', 5),
#  ('юань тин фа установил', 5),
#  ('спросила дин чунь сю', 5),
#  ('что лян цзин чунь', 5),
#  ('сунь юй фэнь по', 5),
#  ('у нас на заводе', 5),
#  ('не проронив ни слова', 5),
#  ('и на этот раз', 5),
#  ('ничего не оставалось как', 5),
#  ('на занятия в вечернюю', 5),
#  ('занятия в вечернюю школу', 5),
#  ('как юань тин фа', 5),
#  ('в погоне за рекордом', 5),
#  ('к тому же он', 5),
#  ('улыбнулся юань тин фа', 5),
#  ('к чжан фу цюаню', 5),
#  ('лян цзин чунь я', 5),
#  ('и дин чунь сю', 5),
#  ('инженер лу цзинь чэн', 5),
#  ('не все в порядке', 5),
#  ('чжао ли мин с', 5),
#  ('ли цзи мин подошел', 5),
#  ('цзи мин подошел к', 5),
#  ('аварии на девятом мартене', 5),
#  ('том что цинь дэ гуй', 5),
#  ('покачал головой цинь дэ гуй', 5),
#  ('как бы там ни было', 5),
#  ('бы там ни было а', 5),
#  ('но цинь дэ гуй не', 5),
#  ('на занятия в вечернюю школу', 5),
#  ('ли цзи мин подошел к', 5),
#  ('как бы там ни было а', 5),
#  ('подумал лян цзин чунь', 4),
#  ('в это время к', 4),
#  ('цинь дэ гуй все', 4),
#  ('не обращая внимания на', 4),
#  ('хэ цзы сюе он', 4),
#  ('предложил хэ цзы сюе', 4),
#  ('чем же все таки', 4),
#  ('в это время в', 4),
#  ('цинь дэ гуй очень', 4),
#  ('юань тин фа молча', 4),
#  ('с первого же взгляда', 4),
#  ('цинь дэ гуй на', 4),
#  ('что цинь дэ гуя', 4),
#  ('мэн сю ди и', 4),
#  ('о том что цинь', 4),
#  ('цинь дэ гуй сегодня', 4),
#  ('завода по ремонту электрооборудования', 4),
#  ('ответил ли цзи мин', 4),
#  ('ли цзи мин я', 4),
#  ('цинь дэ гуй снова', 4),
#  ('лицо ли цзи мина', 4),
#  ('ничего не ответил и', 4),
#  ('ли цзи мина и', 4),
#  ('хэ цзы сюе как', 4),
#  ('юань тин фа уже', 4),
#  ('строго сказал хэ цзы', 4),
#  ('чтобы цинь дэ гуй', 4),
#  ('что на этот раз', 4),
#  ('душе у него было', 4),
#  ('цинь дэ гуя с', 4),
#  ('лицо юань тин фа', 4),
#  ('дин чунь сю с', 4),
#  ('цинь дэ гуй по', 4),
#  ('юань тин фа ничего', 4),
#  ('тин фа ничего не', 4),
#  ('цинь дэ гуя она', 4),
#  ('товарищ юань тин фа', 4),
#  ('с таким видом словно', 4),
#  ('юань тин фа продолжал', 4),
#  ('чжан фу цюань сегодня', 4),
#  ('юань тин фа я', 4),
#  ('это никуда не годится', 4),
#  ('хэ цзы сюе у', 4),
#  ('хэ цзы сюе в', 4),
#  ('чжан фу цюаню не', 4),
#  ('цинь дэ гуя был', 4),
#  ('подачу газа и воздуха', 4),
#  ('цинь дэ гуя на', 4),
#  ('и днем и ночью', 4),
#  ('товарищ цинь дэ гуй', 4),
#  ('кто это тебе сказал', 4),
#  ('ответила сунь юй фэнь', 4),
#  ('цинь дэ гуй сразу', 4),
#  ('к сунь юй фэнь', 4),
#  ('воскликнул цинь дэ гуй', 4),
#  ('с дин чунь сю', 4),
#  ('велосипед и поехал в', 4),
#  ('поехал в женское общежитие', 4),
#  ('цинь дэ гуя о', 4),
#  ('цинь дэ гуй решил', 4),
#  ('смену юань тин фа', 4),
#  ('слова юань тин фа', 4),
#  ('поведение чжан фу цюаня', 4),
#  ('спросила сунь юй фэнь', 4),
#  ('не удержалась от вопроса', 4),
#  ('что ли цзи мин', 4),
#  ('возразил чжан фу цюань', 4),
#  ('юй фэнь и ее', 4),
#  ('я никак не могу', 4),
#  ('юань тин фа ты', 4),
#  ('дин чунь сю он', 4),
#  ('на сунь юй фэнь', 4),
#  ('сказал юань тин фа', 4),
#  ('изо всех сил старался', 4),
#  ('спросил чжан фу цюань', 4),
#  ('улыбнулся лян цзин чунь', 4),
#  ('я знаю что ты', 4),
#  ('сказала дин чунь сю', 4),
#  ('предложение цинь дэ гуя', 4),
#  ('сунь юй фэнь очень', 4),
#  ('ставить печь на ремонт', 4),
#  ('о том что цинь дэ', 4),
#  ('строго сказал хэ цзы сюе', 4),
#  ('на душе у него было', 4),
#  ('что цинь дэ гуй в', 4),
#  ('юань тин фа ничего не', 4),
#  ('ответил юань тин фа и', 4),
#  ('что цинь дэ гуй не', 4),
#  ('на велосипед и поехал в', 4),
#  ('сунь юй фэнь и ее', 4),
#  ('сказал лян цзин чунь и', 4),
#  ('о том что цинь дэ гуй', 4),
#  ('сел на велосипед и поехал в', 4),
#  ('лян цзин чуня и', 3),
#  ('то тут то там', 3),
#  ('же цинь дэ гуй', 3),
#  ('очень хорошо что ты', 3),
#  ('лян цзин чуню в', 3),
#  ('лян цзин чунь да', 3),
#  ('директор нахмурил брови и', 3),
#  ('его за руку и', 3),
#  ('лян цзин чунь взял', 3),
#  ('посмотрел на цинь дэ', 3),
#  ('лян цзин чунь подошел', 3),
#  ('цзин чунь подошел к', 3),
#  ('подошел к цинь дэ', 3),
#  ('но хэ цзы сюе', 3),
#  ('предложил лян цзин чунь', 3),
#  ('лян цзин чунь в', 3),
#  ('ничего не ответил только', 3),
#  ('цинь дэ гуй тогда', 3),
#  ('в коем случае не', 3),
#  ('цинь дэ гуй подошел', 3),
#  ('дэ гуй подошел к', 3),
#  ('цинь дэ гуй мог', 3),
#  ('цинь дэ гуй вышел', 3),
#  ('дело в том что', 3),
#  ('на велосипед и отправился', 3),
#  ('велосипед и отправился в', 3),
#  ('цинь дэ гуй установил', 3),
#  ('но он не стал', 3),
#  ('цинь дэ гуй это', 3),
#  ('чжан фу цюань у', 3),
#  ('и дело с концом', 3),
#  ('не успел цинь дэ', 3),
#  ('успел цинь дэ гуй', 3),
#  ('за цинь дэ гуем', 3),
#  ('цинь дэ гуем на', 3),
#  ('цинь дэ гуй о', 3),
#  ('вовсе не для того', 3),
#  ('согласился цинь дэ гуй', 3),
#  ('в лучах заходящего солнца', 3),
#  ('дэ гуй если бы', 3),
#  ('увеличить подачу газа и', 3),
#  ('рекорд цинь дэ гуя', 3),
#  ('даже в таких условиях', 3),
#  ('спросил хэ цзы сюе', 3),
#  ('как же ты можешь', 3),
#  ('помогал на седьмом мартене', 3),
#  ('ты что ж это', 3),
#  ('дин чунь сю подошла', 3),
#  ('чунь сю подошла к', 3),
#  ('ее юань тин фа', 3),
#  ('посмотрела ему в лицо', 3),
#  ('тин фа и он', 3),
#  ('цинь дэ гуй сжег', 3),
#  ('дэ гуй сжег свод', 3),
#  ('как же он мог', 3),
#  ('юань тин фа был', 3),
#  ('на следующий день юань', 3),
#  ('следующий день юань тин', 3),
#  ('день юань тин фа', 3),
#  ('фа ничего не ответил', 3),
#  ('рекорде цинь дэ гуя', 3),
#  ('юань тин фа понял', 3),
#  ('тин фа понял что', 3),
#  ('цинь дэ гуй уже', 3),
#  ('юань тин фа с', 3),
#  ('цинь дэ гуем но', 3),
#  ('здесь ни при чем', 3),
#  ('дэ гуя и он', 3),
#  ('в двенадцать часов ночи', 3),
#  ('смену чжан фу цюань', 3),
#  ('чжан фу цюань раньше', 3),
#  ('не в свое дело', 3),
#  ('все будет в порядке', 3),
#  ('усмехнулся юань тин фа', 3),
#  ('тин фа а разве', 3),
#  ('рассмеялся юань тин фа', 3),
#  ('я думаю что если', 3),
#  ('и только после этого', 3),
#  ('лян цзин чунь еще', 3),
#  ('ты должен знать что', 3),
#  ('лян цзин чунь посмотрел', 3),
#  ('подсказал хэ цзы сюе', 3),
#  ('объяснил хэ цзы сюе', 3),
#  ('народных добровольцев в корее', 3),
#  ('произнес хэ цзы сюе', 3),
#  ('у меня есть к', 3),
#  ('меня есть к тебе', 3),
#  ('в душе он был', 3),
#  ('а ли цзи мин', 3),
#  ('из кабинета секретаря парткома', 3),
#  ('согласился чжан фу цюань', 3),
#  ('и ли цзи мин', 3),
#  ('чжан фу цюань шел', 3),
#  ('ли цзи мин стал', 3),
#  ('усмехнулся чжан фу цюань', 3),
#  ('не будет знать о', 3),
#  ('воскликнула сунь юй фэнь', 3),
#  ('чжан фу цюань подошел', 3),
#  ('чжан фу цюань по', 3),
#  ('цинь дэ гуй чжан', 3),
#  ('дэ гуй чжан фу', 3),
#  ('дин чунь сю только', 3),
#  ('директор я думаю что', 3),
#  ('я думаю что они', 3),
#  ('тин фа и не', 3),
#  ('юань тин фа только', 3),
#  ('юань тин фа о', 3),
#  ('радостно воскликнула дин чунь', 3),
#  ('дин чунь сю это', 3),
#  ('никак не мог уснуть', 3),
#  ('несмотря на то что', 3),
#  ('от этих мыслей на', 3),
#  ('следил за состоянием свода', 3),
#  ('он то и дело', 3),
#  ('тин фа установил новый', 3),
#  ('фа установил новый рекорд', 3),
#  ('дин чунь сю почему', 3),
#  ('юань тин фа дин', 3),
#  ('тин фа дин чунь', 3),
#  ('фа дин чунь сю', 3),
#  ('о том что она', 3),
#  ('признался цинь дэ гуй', 3),
#  ('думал над этим но', 3),
#  ('цинь дэ гуй понял', 3),
#  ('дэ гуй понял что', 3),
#  ('сделал глубокую затяжку и', 3),
#  ('не удержался от улыбки', 3),
#  ('дэ гуй да и', 3),
#  ('цинь дэ гуй встал', 3),
#  ('в ответ цинь дэ', 3),
#  ('ответ цинь дэ гуй', 3),
#  ('юань тин фа очень', 3),
#  ('лян цзин чунь взглянул', 3),
#  ('цзин чунь взглянул на', 3),
#  ('сунь юй фэнь да', 3),
#  ('цинь дэ гуй мы', 3),
#  ('разговор на другую тему', 3),
#  ('удивилась сунь юй фэнь', 3),
#  ('сунь юй фэнь поэтому', 3),
#  ('сунь юй фэнь ну', 3),
#  ('сунь юй фэнь а', 3),
#  ('возразил цинь дэ гуй', 3),
#  ('предложил цинь дэ гуй', 3),
#  ('цинь дэ гуй нет', 3),
#  ('только для того чтобы', 3),
#  ('дэ гуй сразу же', 3),
#  ('улыбнулся цинь дэ гуй', 3),
#  ('цинь дэ гуй ничего', 3),
#  ('дэ гуй ничего не', 3),
#  ('гуй ничего не ответил', 3),
#  ('цинь дэ гуй молча', 3),
#  ('ни было а я', 3),
#  ('как рукой сняло и', 3),
#  ('цинь дэ гуй ну', 3),
#  ('юй фэнь цинь дэ', 3),
#  ('фэнь цинь дэ гуй', 3),
#  ('ему ничего не оставалось', 3),
#  ('сунь юй фэнь уже', 3),
#  ('головой хэ цзы сюе', 3),
#  ('сунь юй фэнь от', 3),
#  ('слова хэ цзы сюе', 3),
#  ('хэ цзы сюе а', 3),
#  ('после того как он', 3),
#  ('чжан фу цюанем не', 3),
#  ('и поехал в общежитие', 3),
#  ('его позвали к телефону', 3),
#  ('цинь дэ гуй ладно', 3),
#  ('общежития цинь дэ гуй', 3),
#  ('дежурная цинь дэ гуй', 3),
#  ('вскочил на велосипед и', 3),
#  ('цинь дэ гуй вспомнил', 3),
#  ('цинь дэ гуй тут', 3),
#  ('дэ гуй тут же', 3),
#  ('время цинь дэ гуй', 3),
#  ('мэн сю ди не', 3),
#  ('чжан фу цюань с', 3),
#  ('отношения с чжан фу', 3),
#  ('внимательно посмотрел в лицо', 3),
#  ('цинь дэ гуй всегда', 3),
#  ('жену юань тин фа', 3),
#  ('что в последнее время', 3),
#  ('цинь дэ гуй к', 3),
#  ('чжан фу цюаню о', 3),
#  ('смена чжан фу цюаня', 3),
#  ('только после того как', 3),
#  ('только юань тин фа', 3),
#  ('чжан фу цюаня но', 3),
#  ('не чжан фу цюань', 3),
#  ('чжан фу цюань мы', 3),
#  ('его чжан фу цюань', 3),
#  ('цинь дэ гуя но', 3),
#  ('техник чэнь лян хан', 3),
#  ('на чжан фу цюаня', 3),
#  ('разобраться в этом деле', 3),
#  ('да и сунь юй', 3),
#  ('чжан фу цюаня было', 3),
#  ('по душе чжан фу', 3),
#  ('душе чжан фу цюаню', 3),
#  ('цинь дэ гую он', 3),
#  ('усмехнулся хэ цзы сюе', 3),
#  ('юань тин фа ведь', 3),
#  ('хэ цзы сюе поспешно', 3),
#  ('произнес юань тин фа', 3),
#  ('дин чунь сю взяла', 3),
#  ('как ты думаешь почему', 3),
#  ('о сунь юй фэнь', 3),
#  ('чжан фу цюаню он', 3),
#  ('директор чжао ли мин', 3),
#  ('инженер чжан цзи линь', 3),
#  ('хэ цзы сюе если', 3),
#  ('чжао ли мин несколько', 3),
#  ('разговора с цинь дэ', 3),
#  ('ее сунь юй фэнь', 3),
#  ('стояла на своем дин', 3),
#  ('на своем дин чунь', 3),
#  ('своем дин чунь сю', 3),
#  ('а раз так то', 3),
#  ('юань тин фа она', 3),
#  ('чжан фу цюань она', 3),
#  ('только сунь юй фэнь', 3),
#  ('в том что он', 3),
#  ('дин чунь сю не', 3),
#  ('бы сунь юй фэнь', 3),
#  ('лицо сунь юй фэнь', 3),
#  ('ни за что не', 3),
#  ('когда юань тин фа', 3),
#  ('чжан фу цюанем и', 3),
#  ('к дин чунь сю', 3),
#  ('о том что он', 3),
#  ('подумал чжан фу цюань', 3),
#  ('но дин чунь сю', 3),
#  ('дин чунь сю ты', 3),
#  ('улыбнулся хэ цзы сюе', 3),
#  ('улыбнулся чжан фу цюань', 3),
#  ('холодно ответил чжан фу', 3),
#  ('лян цзин чунь а', 3),
#  ('по твоему выходит что', 3),
#  ('согласился лян цзин чунь', 3),
#  ('обернулся к лян цзин', 3),
#  ('директора лян цзин чунь', 3),
#  ('лян цзин чунь но', 3),
#  ('лян цзин чунь с', 3),
#  ('цинь дэ гуя ты', 3),
#  ('дин чунь сю очень', 3),
#  ('дин чунь сю но', 3),
#  ('с секретарем парткома но', 3),
#  ('его лян цзин чунь', 3),
#  ('рассердилась дин чунь сю', 3),
#  ('хэ цзы сюе дин', 3),
#  ('цзы сюе дин чунь', 3),
#  ('сюе дин чунь сю', 3),
#  ('спросил чжао ли мин', 3),
#  ('спокойно ответил лян цзин', 3),
#  ('юань тин фа его', 3),
#  ('сказал чжао ли мин', 3),
#  ('цинь дэ гуя секретарь', 3),
#  ('дэ гуя секретарь парткома', 3),
#  ('лян цзин чунь он', 3),
#  ('о том что его', 3),
#  ('чжуан гуй лань и', 3),
#  ('портрет цинь дэ гуя', 3),
#  ('головой чжан фу цюань', 3),
#  ('его сунь юй фэнь', 3),
#  ('условия для работы следующей', 3),
#  ('для работы следующей смены', 3),
#  ('думал он по дороге', 3),
#  ('товарищ лян цзин чунь', 3),
#  ('лян цзин чунь все', 3),
#  ('посмотрел на цинь дэ гуя', 3),
#  ('лян цзин чунь подошел к', 3),
#  ('подошел к цинь дэ гую', 3),
#  ('ни в коем случае не', 3),
#  ('цинь дэ гуй подошел к', 3),
#  ('сел на велосипед и отправился', 3),
#  ('на велосипед и отправился в', 3),
#  ('не успел цинь дэ гуй', 3),
#  ('цинь дэ гуй если бы', 3),
#  ('дин чунь сю подошла к', 3),
#  ('юань тин фа и он', 3),
#  ('что цинь дэ гуй сжег', 3),
#  ('цинь дэ гуй сжег свод', 3),
#  ('на следующий день юань тин', 3),
#  ('следующий день юань тин фа', 3),
#  ('тин фа ничего не ответил', 3),
#  ('юань тин фа понял что', 3),
#  ('с цинь дэ гуем но', 3),
#  ('цинь дэ гуя и он', 3),
#  ('юань тин фа а разве', 3),
#  ('у меня есть к тебе', 3),
#  ('цинь дэ гуй чжан фу', 3),
#  ('сел на велосипед и помчался', 3),
#  ('юань тин фа и не', 3),
#  ('радостно воскликнула дин чунь сю', 3),
#  ('юань тин фа установил новый', 3),
#  ('тин фа установил новый рекорд', 3),
#  ('юань тин фа дин чунь', 3),
#  ('тин фа дин чунь сю', 3),
#  ('ответил цинь дэ гуй а', 3),
#  ('цинь дэ гуй понял что', 3),
#  ('цинь дэ гуй да и', 3),
#  ('в ответ цинь дэ гуй', 3),
#  ('лян цзин чунь взглянул на', 3),
#  ('цинь дэ гуй сразу же', 3),
#  ('цинь дэ гуй ничего не', 3),
#  ('дэ гуй ничего не ответил', 3),
#  ('там ни было а я', 3),
#  ('юй фэнь цинь дэ гуй', 3),
#  ('ему ничего не оставалось как', 3),
#  ('с чжан фу цюанем не', 3),
#  ('велосипед и поехал в общежитие', 3),
#  ('цинь дэ гуй тут же', 3),
#  ('отношения с чжан фу цюанем', 3),
#  ('как юань тин фа установил', 3),
#  ('да и сунь юй фэнь', 3),
#  ('у чжан фу цюаня было', 3),
#  ('по душе чжан фу цюаню', 3),
#  ('ответил чжан фу цюань а', 3),
#  ('разговора с цинь дэ гуем', 3),
#  ('стояла на своем дин чунь', 3),
#  ('на своем дин чунь сю', 3),
#  ('лицо сунь юй фэнь и', 3),
#  ('с чжан фу цюанем и', 3),
#  ('холодно ответил чжан фу цюань', 3),
#  ('обернулся к лян цзин чуню', 3),
#  ('хэ цзы сюе дин чунь', 3),
#  ('цзы сюе дин чунь сю', 3),
#  ('спокойно ответил лян цзин чунь', 3),
#  ('ответил лян цзин чунь и', 3),
#  ('цинь дэ гуя секретарь парткома', 3),
#  ('условия для работы следующей смены', 3),
#  ('сел на велосипед и отправился в', 3),
#  ('что цинь дэ гуй сжег свод', 3),
#  ('на следующий день юань тин фа', 3),
#  ('юань тин фа ничего не ответил', 3),
#  ('юань тин фа установил новый рекорд', 3),
#  ('юань тин фа дин чунь сю', 3),
#  ('цинь дэ гуй ничего не ответил', 3),
#  ('бы там ни было а я', 3),
#  ('гуй сел на велосипед и поехал', 3),
#  ('на велосипед и поехал в общежитие', 3),
#  ('стояла на своем дин чунь сю', 3),
#  ('хэ цзы сюе дин чунь сю', 3),
#  ('директора завода чжао ли', 2),
#  ('завода чжао ли мина', 2),
#  ('она знала что когда', 2),
#  ('по обеим сторонам дороги', 2),
#  ('не обращал внимания на', 2),
#  ('лян цзин чунь когда', 2),
#  ('а лян цзин чунь', 2),
#  ('лян цзин чунь из', 2),
#  ('было что юань тин', 2),
#  ('семь часов и пять', 2),
#  ('часов и пять минут', 2),
#  ('он положил трубку и', 2),
#  ('и не удержался от', 2),
#  ('попросите к телефону бригадира', 2),
#  ('сказал лян цзин чуню', 2),
#  ('места лян цзин чунь', 2),
#  ('посмотрел в окно на', 2),
#  ('дело не только в', 2),
#  ('чжао ли мин но', 2),
#  ('снова повернулся к лян', 2),
#  ('повернулся к лян цзин', 2),
#  ('здесь а я пойду', 2),
#  ('лян цзин чунь встал', 2),
#  ('ни с того ни', 2),
#  ('с того ни с', 2),
#  ('того ни с сего', 2),
#  ('от пышущего жаром мартена', 2),
#  ('во все стороны разлетались', 2),
#  ('все стороны разлетались огненные', 2),
#  ('стороны разлетались огненные искры', 2),
#  ('лян цзин чунь снова', 2),
#  ('ай й я вот', 2),
#  ('это цинь дэ гуй', 2),
#  ('семь часов пять минут', 2),
#  ('хэ цзы сюе да', 2),
#  ('технолог чэнь лян хан', 2),
#  ('с недоумением посмотрел на', 2),
#  ('лице цинь дэ гуя', 2),
#  ('посмотреть как идет работа', 2),
#  ('в чем же все', 2),
#  ('чэнь лян хан в', 2),
#  ('чэнь лян хан товарищ', 2),
#  ('лян хан товарищ секретарь', 2),
#  ('причины сказал лян цзин', 2),
#  ('чэнь лян хан ничего', 2),
#  ('лян хан ничего не', 2),
#  ('вышел из цеха и', 2),
#  ('цинь дэ гую стало', 2),
#  ('лю кэ юй цинь', 2),
#  ('кэ юй цинь дэ', 2),
#  ('цинь дэ гуй находился', 2),
#  ('дэ гуй находился в', 2),
#  ('подумал цинь дэ гуй', 2),
#  ('гуй подошел к нему', 2),
#  ('цинь дэ гуй тоже', 2),
#  ('лю кэ юй я', 2),
#  ('и хочу чтобы вы', 2),
#  ('так цинь дэ гуй', 2),
#  ('его за то что', 2),
#  ('за то что он', 2),
#  ('в партизанском отряде и', 2),
#  ('цинь дэ гуя назначили', 2),
#  ('дэ гуя назначили бригадиром', 2),
#  ('руку цинь дэ гуй', 2),
#  ('цинь дэ гуй поспешил', 2),
#  ('дэ гуй поспешил к', 2),
#  ('печи юань тин фа', 2),
#  ('тебе и дела нет', 2),
#  ('опустил на глаза защитные', 2),
#  ('на глаза защитные очки', 2),
#  ('глаза защитные очки и', 2),
#  ('дэ гуй с первого', 2),
#  ('а на девятом мартене', 2),
#  ('так что цинь дэ', 2),
#  ('сегодня цинь дэ гуй', 2),
#  ('сейчас юань тин фа', 2),
#  ('как это получилось что', 2),
#  ('ответил мэн сю ди', 2),
#  ('дэ гуй не знал', 2),
#  ('тоном ответил цинь дэ', 2),
#  ('юань тин фа ни', 2),
#  ('ни слова не сказал', 2),
#  ('и в каком месте', 2),
#  ('в каком месте он', 2),
#  ('когда он вошел в', 2),
#  ('он вошел в кабинет', 2),
#  ('на седьмом мартене и', 2),
#  ('с улыбкой цинь дэ', 2),
#  ('улыбкой цинь дэ гуй', 2),
#  ('рекорд по скоростной плавке', 2),
#  ('цинь дэ гуй еще', 2),
#  ('хотел было добавить что', 2),
#  ('поднял голову цинь дэ', 2),
#  ('он набрался смелости и', 2),
#  ('цинь дэ гуя сколько', 2),
#  ('но я думаю что', 2),
#  ('дэ гуя он твердо', 2),
#  ('после летучки цинь дэ', 2),
#  ('летучки цинь дэ гуй', 2),
#  ('небе не было ни', 2),
#  ('оттуда то и дело', 2),
#  ('день цинь дэ гуй', 2),
#  ('бросил быстрый взгляд на', 2),
#  ('не давали ему покоя', 2),
#  ('у входа в общежитие', 2),
#  ('цинь дэ гуй любил', 2),
#  ('хлопнул его по плечу', 2),
#  ('друзьями цинь дэ гуй', 2),
#  ('и снова уткнулся в', 2),
#  ('снова уткнулся в тарелку', 2),
#  ('пошутил чжан фу цюань', 2),
#  ('прервал его цинь дэ', 2),
#  ('ли цзи мин не', 2),
#  ('установил новый рекорд она', 2),
#  ('ли цзи мин нет', 2),
#  ('чжан фу цюань но', 2),
#  ('на заводе по ремонту', 2),
#  ('заводе по ремонту электрооборудования', 2),
#  ('по ремонту электрооборудования не', 2),
#  ('ли цзи мин ты', 2),
#  ('имени сунь юй фэнь', 2),
#  ('сунь юй фэнь его', 2),
#  ('ли цзи мин уже', 2),
#  ('мне надо поговорить с', 2),
#  ('надо поговорить с тобой', 2),
#  ('спросил ли цзи мин', 2),
#  ('не поднимая головы от', 2),
#  ('и встал с места', 2),
#  ('усмехнулся ли цзи мин', 2),
#  ('он не придал бы', 2),
#  ('тон цинь дэ гуя', 2),
#  ('было цинь дэ гуй', 2),
#  ('и уже мягче продолжал', 2),
#  ('дэ гуй но ты', 2),
#  ('тебя это не волнует', 2),
#  ('ли цзи мин ничего', 2),
#  ('цзи мин ничего не', 2),
#  ('мин ничего не ответил', 2),
#  ('в первое время после', 2),
#  ('первое время после освобождения', 2),
#  ('на ли цзи мина', 2),
#  ('так же как и', 2),
#  ('дэ гуй не стал', 2),
#  ('что цинь дэ гую', 2),
#  ('плавки юань тин фа', 2),
#  ('поэтому юань тин фа', 2),
#  ('не отходил от мартена', 2),
#  ('уменьшить подачу газа в', 2),
#  ('подачу газа в печь', 2),
#  ('газа в печь чтобы', 2),
#  ('не мог отойти от', 2),
#  ('цеха хэ цзы сюе', 2),
#  ('подошел к девятому мартену', 2),
#  ('тин фа не стал', 2),
#  ('не стал разговаривать с', 2),
#  ('раньше он работал первым', 2),
#  ('он работал первым подручным', 2),
#  ('сразу же после освобождения', 2),
#  ('мартену хэ цзы сюе', 2),
#  ('защитные очки и стал', 2),
#  ('однако юань тин фа', 2),
#  ('тин фа не обратил', 2),
#  ('фа не обратил внимания', 2),
#  ('внимания на его вопрос', 2),
#  ('к парторгу старина юань', 2),
#  ('хэ цзы сюе еще', 2),
#  ('хэ цзы сюе понимал', 2),
#  ('считал что юань тин', 2),
#  ('спокойно спросил хэ цзы', 2),
#  ('хэ цзы сюе изумленно', 2),
#  ('сверкнул глазами юань тин', 2),
#  ('глазами юань тин фа', 2),
#  ('что за вздор ты', 2),
#  ('только тридцать два года', 2),
#  ('к нему как к', 2),
#  ('его не иначе как', 2),
#  ('я думаю что в', 2),
#  ('рекорда цинь дэ гуя', 2),
#  ('на то чтобы они', 2),
#  ('из за этого дела', 2),
#  ('сказал цинь дэ гую', 2),
#  ('цинь дэ гую чтобы', 2),
#  ('юань тин фа понимал', 2),
#  ('тин фа понимал что', 2),
#  ('не смог удержаться от', 2),
#  ('ведь цинь дэ гуй', 2),
#  ('что во всем виноват', 2),
#  ('во всем виноват цинь', 2),
#  ('всем виноват цинь дэ', 2),
#  ('виноват цинь дэ гуй', 2),
#  ('свод юань тин фа', 2),
#  ('юань тин фа рассказал', 2),
#  ('чжан фу цюаня старина', 2),
#  ('фу цюань он был', 2),
#  ('цюань он был уверен', 2),
#  ('по милости цинь дэ', 2),
#  ('милости цинь дэ гуя', 2),
#  ('девушкой сунь юй фэнь', 2),
#  ('он все время думал', 2),
#  ('и при сдаче смены', 2),
#  ('и направляясь в кухню', 2),
#  ('остановил ее юань тин', 2),
#  ('внимательно посмотрела ему в', 2),
#  ('и снова спросила сегодня', 2),
#  ('дин чунь сю успокоилась', 2),
#  ('чунь сю она села', 2),
#  ('гуй сжег свод печи', 2),
#  ('сжег свод печи и', 2),
#  ('свод печи и поэтому', 2),
#  ('цинь дэ гуй она', 2),
#  ('ай й я это', 2),
#  ('нахмурил брови юань тин', 2),
#  ('брови юань тин фа', 2),
#  ('юань тин фа поспешно', 2),
#  ('юань тин фа при', 2),
#  ('тин фа и тот', 2),
#  ('юань тин фа впервые', 2),
#  ('юань тин фа начал', 2),
#  ('юань тин фа тайком', 2),
#  ('юань тин фа поднял', 2),
#  ('на юань тин фа', 2),
#  ('юань тин фа как', 2),
#  ('когда на следующий день', 2),
#  ('юань тин фа явился', 2),
#  ('подала ему завтрак и', 2),
#  ('было юань тин фа', 2),
#  ('брови дин чунь сю', 2),
#  ('дин чунь сю сердито', 2),
#  ('заводских ворот он увидел', 2),
#  ('дэ гуя она была', 2),
#  ('цинь дэ гуй сейчас', 2),
#  ('о рекорде цинь дэ', 2),
#  ('сообщение о том что', 2),
#  ('в смену цинь дэ', 2),
#  ('смену цинь дэ гуя', 2),
#  ('этого юань тин фа', 2),
#  ('парторга хэ цзы сюе', 2),
#  ('добавил цинь дэ гуй', 2),
#  ('он сжег свод печи', 2),
#  ('когда лян цзин чунь', 2),
#  ('юань тин фа тихо', 2),
#  ('парткома лян цзин чунь', 2),
#  ('очки и подошел к', 2),
#  ('лян цзин чунь продолжал', 2),
#  ('поинтересовался лян цзин чунь', 2),
#  ('лян цзин чунь помолчал', 2),
#  ('и ничего не ответил', 2),
#  ('юань тин фа чувствовал', 2),
#  ('тин фа чувствовал себя', 2),
#  ('то обстоятельство что директор', 2),
#  ('на смену чжан фу', 2),
#  ('чжан фу цюаня на', 2),
#  ('чжан фу цюань сразу', 2),
#  ('от цинь дэ гуя', 2),
#  ('в голосе юань тин', 2),
#  ('голосе юань тин фа', 2),
#  ('что она относится к', 2),
#  ('я и не знаю', 2),
#  ('вмешивается не в свое', 2),
#  ('о нем в газетах', 2),
#  ('вот я и думаю', 2),
#  ('я и думаю что', 2),
#  ('и думаю что ты', 2),
#  ('меня это не касается', 2),
#  ('так много скоростных плавок', 2),
#  ('я никогда не слышала', 2),
#  ('никогда не слышала чтобы', 2),
#  ('жена мастера скоростных плавок', 2),
#  ('пошутил юань тин фа', 2),
#  ('тин фа а если', 2),
#  ('проговорила дин чунь сю', 2),
#  ('дин чунь сю у', 2),
#  ('чунь сю у меня', 2),
#  ('тин фа я думаю', 2),
#  ('фа я думаю что', 2),
#  ('сон никак не шел', 2),
#  ('лян цзин чунь попросил', 2),
#  ('цзин чунь попросил хэ', 2),
#  ('чунь попросил хэ цзы', 2),
#  ('попросил хэ цзы сюе', 2),
#  ('хэ цзы сюе с', 2),
#  ('взглянул на секретаря парткома', 2),
#  ('цзы сюе ты должен', 2),
#  ('цзин чунь посмотрел на', 2),
#  ('скажи мне товарищ хэ', 2),
#  ('мне товарищ хэ цзы', 2),
#  ('приходило в голову что', 2),
#  ('как хэ цзы сюе', 2),
#  ('стряхнул в пепельницу пепел', 2),
#  ('у тебя есть еще', 2),
#  ('и поэтому не очень', 2),
#  ('не очень хорошо знаю', 2),
#  ('рабочих лян цзин чунь', 2),
#  ('лян цзин чунь глубоко', 2),
#  ('цзин чунь глубоко затянулся', 2),
#  ('цзы сюе у меня', 2),
#  ('но он тут же', 2),
#  ('чжоу кай линь не', 2),
#  ('а по правде говоря', 2),
#  ('из за того что', 2),
#  ('поднялся со своего места', 2),
#  ('вышел из кабинета секретаря', 2),
#  ('чжан фу цюань да', 2),
#  ('похоже было что он', 2),
#  ('хэ цзы сюе они', 2),
#  ('ли цзи мин но', 2),
#  ('я как раз собирался', 2),
#  ('это очень хорошо но', 2),
#  ('на нашем девятом мартене', 2),
#  ('к тому же его', 2),
#  ('в эти дни ты', 2),
#  ('чжан фу цюань это', 2),
#  ('когда же это вы', 2),
#  ('разве ты не слышал', 2),
#  ('ты действительно не знаешь', 2),
#  ('говорю тебе что я', 2),
#  ('вместе с цинь дэ', 2),
#  ('я поговорю с ним', 2),
#  ('с ней чжан фу', 2),
#  ('ней чжан фу цюань', 2),
#  ('ее чжан фу цюань', 2),
#  ('подбежала к нему и', 2),
#  ('в тот раз он', 2),
#  ('сунь юй фэнь на', 2),
#  ('сунь юй фэнь чжан', 2),
#  ('юй фэнь чжан фу', 2),
#  ('фэнь чжан фу цюань', 2),
#  ('фу цюань не мог', 2),
#  ('об этом и он', 2),
#  ('не обратила внимания на', 2),
#  ('обратила внимания на его', 2),
#  ('чжан фу цюань твердо', 2),
#  ('плавки на пять минут', 2),
#  ('знаешь сунь юй фэнь', 2),
#  ('юй фэнь я не', 2),
#  ('юань тин фа то', 2),
#  ('сунь юй фэнь привыкла', 2),
#  ('юй фэнь привыкла верить', 2),
#  ('и о том что', 2),
#  ('улучшил старый рекорд на', 2),
#  ('старый рекорд на пять', 2),
#  ('рекорд на пять минут', 2),
#  ('чжан фу цюань только', 2),
#  ('печь он был очень', 2),
#  ('будет знать о чем', 2),
#  ('сунь юй фэнь конечно', 2),
#  ('себя за то что', 2),
#  ('после окончания рабочего дня', 2),
#  ('фу цюань подошел к', 2),
#  ('таким видом словно он', 2),
#  ('помог дин чунь сю', 2),
#  ('дин чунь сю сделать', 2),
#  ('о своей встрече с', 2),
#  ('дин чунь сю этот', 2),
#  ('этот негодяй цинь дэ', 2),
#  ('негодяй цинь дэ гуй', 2),
#  ('гуй чжан фу цюань', 2),
#  ('велосипед и поехал к', 2),
#  ('и поехал к себе', 2),
#  ('поехал к себе в', 2),
#  ('к себе в общежитие', 2),
#  ('ответила дин чунь сю', 2),
#  ('велосипед и помчался на', 2),
#  ('и помчался на завод', 2),
#  ('дверь чжао ли мин', 2),
#  ('так то они не', 2),
#  ('юань тин фа вышел', 2),
#  ('тин фа вышел из', 2),
#  ('тин фа и что', 2),
#  ('хотя юань тин фа', 2),
#  ('в свои блокноты затем', 2),
#  ('юань тин фа после', 2),
#  ('директор и посмотрел на', 2),
#  ('ему юань тин фа', 2),
#  ('напишут еще и в', 2),
#  ('еще и в иностранных', 2),
#  ('сел на кан и', 2),
#  ...]

# %%
def ngrams_text (word,num):
    word = word.lower()
    word = re.sub("[!\"#$%&\'—()*+,-»«./:;<=>?@[\\]^_`{|}~]?",'',word)
    #tokens = re.findall ('он\s\w+',word)
    #tokens = [token for token in word.split(" ") if token != ""]
    mystem.lemmatize(word)
    wordsFiltered = []
    for w in word:
        if w not in stopwords:
            wordsFiltered.append(w)
    
    output = list(ngrams(tokens,num))
    mostcommon = Counter(output).most_common()
    return mostcommon
#лемматизировать можно прямо из nltk，lemmatize, а стоп слова также есть в nltk.есть такая тетрадка. 
#чтобы свести все свои документы в один нужно просто конкатенировать все переменны. открывааем и читаем фал, сохраняем в переменную, складываем все переменные.
#append только для списка

# %%
def ngrams_text (word,num):
    word = word.lower()
    word = re.sub("[!\"#$%&\'—()*+,-»«./:;<=>?@[\\]^_`{|}~]?",'',word)
    #tokens = re.findall ('он\s\w+',word)
    #tokens = [token for token in word.split(" ") if token != ""]
    mystem.lemmatize(word)
    wordsFiltered = []
    for w in word:
        if w not in stopwords:
            wordsFiltered.append(w)
    
    output = list(ngrams(tokens,num))
    mostcommon = Counter(output).most_common()
    return mostcommon
#лемматизировать можно прямо из nltk，lemmatize, а стоп слова также есть в nltk.есть такая тетрадка. 
#чтобы свести все свои документы в один нужно просто конкатенировать все переменны. открывааем и читаем фал, сохраняем в переменную, складываем все переменные.
#append только для списка

# %%
def ngrams_text (word,num):
    word = word.lower()
    word = re.sub("[!\"#$%&\'—()*+,-»«./:;<=>?@[\\]^_`{|}~]?",'',word)
    #tokens = re.findall ('он\s\w+',word)
    #tokens = [token for token in word.split(" ") if token != ""]
    mystem.lemmatize(word)
    wordsFiltered = []
    for w in word:
        if w not in stopwords:
            wordsFiltered.append(w)
    
    output = list(ngrams(tokens,num))
    mostcommon = Counter(output).most_common()
    return mostcommon
#лемматизировать можно прямо из nltk，lemmatize, а стоп слова также есть в nltk.есть такая тетрадка. 
#чтобы свести все свои документы в один нужно просто конкатенировать все переменны. открывааем и читаем фал, сохраняем в переменную, складываем все переменные.
#append только для списка

# %%
ngrams_text("любовь",3)
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-22-120f9802b2fd> in <module>
# ----> 1 ngrams_text("любовь",3)
#
# <ipython-input-5-5e497a6001b9> in ngrams_text(word, num)
#       4     #tokens = re.findall ('он\s\w+',word)
#       5     #tokens = [token for token in word.split(" ") if token != ""]
# ----> 6     mystem.lemmatize(word)
#       7     wordsFiltered = []
#       8     for w in word:
#
# c:\users\sidor\appdata\local\programs\python\python37\lib\site-packages\pymystem3\mystem.py in lemmatize(self, text)
#     263         need_encode = (sys.version_info[0] < 3 and isinstance(text, str))
#     264
# --> 265         infos = self.analyze(text)
#     266         lemmas = list(filter(None, map(self._get_lemma, infos)))
#     267
#
# c:\users\sidor\appdata\local\programs\python\python37\lib\site-packages\pymystem3\mystem.py in analyze(self, text)
#     248         result = []
#     249         for line in text.splitlines():
# --> 250             result.extend(self._analyze_impl(line))
#     251         return result
#     252
#
# c:\users\sidor\appdata\local\programs\python\python37\lib\site-packages\pymystem3\mystem.py in _analyze_impl(self, text)
#     308                 self._start_mystem()
#     309
# --> 310             self._procin.write(text)
#     311             self._procin.write(_NL)
#     312
#
# ValueError: I/O operation on closed file

# %%
from nltk.util import ngrams

# %%
ngrams_text(tom6,3)
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-15-f6c145f82854> in <module>
# ----> 1 ngrams_text(tom6,3)
#
# <ipython-input-5-5e497a6001b9> in ngrams_text(word, num)
#       4     #tokens = re.findall ('он\s\w+',word)
#       5     #tokens = [token for token in word.split(" ") if token != ""]
# ----> 6     mystem.lemmatize(word)
#       7     wordsFiltered = []
#       8     for w in word:
#
# c:\users\sidor\appdata\local\programs\python\python37\lib\site-packages\pymystem3\mystem.py in lemmatize(self, text)
#     263         need_encode = (sys.version_info[0] < 3 and isinstance(text, str))
#     264
# --> 265         infos = self.analyze(text)
#     266         lemmas = list(filter(None, map(self._get_lemma, infos)))
#     267
#
# c:\users\sidor\appdata\local\programs\python\python37\lib\site-packages\pymystem3\mystem.py in analyze(self, text)
#     248         result = []
#     249         for line in text.splitlines():
# --> 250             result.extend(self._analyze_impl(line))
#     251         return result
#     252
#
# c:\users\sidor\appdata\local\programs\python\python37\lib\site-packages\pymystem3\mystem.py in _analyze_impl(self, text)
#     308                 self._start_mystem()
#     309
# --> 310             self._procin.write(text)
#     311             self._procin.write(_NL)
#     312
#
# ValueError: I/O operation on closed file
