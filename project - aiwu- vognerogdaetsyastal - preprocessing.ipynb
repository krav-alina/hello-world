# %%
with open ('Ай У. В огне рождается сталь - royallib.com.txt') as file1:
    aiwu = file1.read()

# %%
from sklearn.feature_extraction.text import CountVectorizer
import nltk
from collections import Counter
import re
import os

# %%
from nltk.corpus import stopwords
from nltk.tokenize import word_tokenize
import nltk
nltk.download('punkt')
# Out:
# [nltk_data] Downloading package punkt to
# [nltk_data]     C:\Users\sidor\AppData\Roaming\nltk_data...
# [nltk_data]   Package punkt is already up-to-date!
# True

# %%
import nltk
nltk.download('stopwords')
# Out:
# [nltk_data] Downloading package stopwords to
# [nltk_data]     C:\Users\sidor\AppData\Roaming\nltk_data...
# [nltk_data]   Package stopwords is already up-to-date!
# True

# %%
from pymystem3 import Mystem

# %%
mystem = Mystem()

# %% [markdown]
# def normalized_text (word):
#     word = word.lower()
#     word = re.sub("[!\"#$%&\'—()*+,-»«./:;<=>?@[\\]^_`{|}~]?",'',word)
#     word = " ".join([word for word in word.split() if word not in(stopwords.words('russian'))])
#     word = word.split()
#     output = len(word)
#     return output

# %% [markdown]
# #filtered_words = [Word for Word in tom6 if Word not in stopwords.words('russian')]
# #text = 'здравствуй дорогой читатель сегодня очень ветренно поэтому я и он не пошли гулять хотя очень хотелось'
# #text = ' '.join([word for word in text.split() if word not in (stopwords.words('russian'))])
# #tom = " ".join([word for word in tom.split() if word not in(stopwords.words('russian'))])

# %%
aiwu = aiwu.lower()
aiwu = re.sub("[!\"#$%&\'—()*+,-»«./:;<=>?@[\\]^_`{|}~]?",'',aiwu)
aiwu = " ".join([word for word in aiwu.split() if word not in(stopwords.words('russian'))])

# %%
bigram_vectorizer = CountVectorizer(ngram_range=(2,2),
                                    token_pattern=r'[А-Яа-я]+', min_df=2)

# %%
analyze = bigram_vectorizer.build_analyzer()

# %%
z = analyze(aiwu)

# %%
Counter(z).most_common()
# Out:
# [('цинь дэгуй', 548),
#  ('юань тинфа', 421),
#  ('сунь юйфэнь', 309),
#  ('чжан фуцюань', 264),
#  ('лян цзинчунь', 234),
#  ('хэ цзысюе', 225),
#  ('цинь дэгуя', 178),
#  ('дин чуньсю', 169),
#  ('чжао лимин', 90),
#  ('секретарь парткома', 89),
#  ('чжан фуцюаня', 69),
#  ('цинь дэгую', 58),
#  ('цинь дэгуем', 41),
#  ('ответил цинь', 34),
#  ('товарищ секретарь', 33),
#  ('секретаря парткома', 32),
#  ('чжан фуцюаню', 32),
#  ('это время', 27),
#  ('мэн сюди', 27),
#  ('скоростных плавок', 27),
#  ('чжан фуцюанем', 27),
#  ('цю биюнь', 24),
#  ('мастер юань', 23),
#  ('девятом мартене', 23),
#  ('это очень', 23),
#  ('лян цзинчуню', 22),
#  ('чэнь лянхан', 22),
#  ('лян цзинчуня', 21),
#  ('свод печи', 21),
#  ('это дело', 21),
#  ('секретарю парткома', 21),
#  ('чжуан гуйлань', 21),
#  ('чжоу юэвэнь', 21),
#  ('новый рекорд', 20),
#  ('нахмурил брови', 19),
#  ('ответил чжан', 19),
#  ('таком случае', 18),
#  ('выпускное отверстие', 18),
#  ('скоростную плавку', 18),
#  ('ответил юань', 18),
#  ('лю сяньцзюй', 18),
#  ('сказал лян', 17),
#  ('покачал головой', 17),
#  ('время плавки', 17),
#  ('сел велосипед', 17),
#  ('девятого мартена', 17),
#  ('старина цинь', 17),
#  ('последнее время', 17),
#  ('сжег свод', 16),
#  ('обо всем', 16),
#  ('каждый день', 16),
#  ('сих пор', 15),
#  ('сказал хэ', 13),
#  ('первый подручный', 13),
#  ('свод мартена', 13),
#  ('сказал цинь', 13),
#  ('старина чжан', 13),
#  ('никак мог', 13),
#  ('директор завода', 12),
#  ('твердо решил', 12),
#  ('тех пор', 12),
#  ('правде говоря', 12),
#  ('изо сил', 12),
#  ('целый день', 12),
#  ('несколько дней', 12),
#  ('спросил лян', 12),
#  ('четвертого мартена', 12),
#  ('скоростные плавки', 11),
#  ('седьмом мартене', 11),
#  ('мартеновский цех', 11),
#  ('это просто', 11),
#  ('товарищ директор', 11),
#  ('подачу газа', 11),
#  ('спросил юань', 11),
#  ('секретарем парткома', 10),
#  ('ответил лян', 10),
#  ('пять минут', 10),
#  ('спросил цинь', 10),
#  ('старина юань', 10),
#  ('почему это', 10),
#  ('ответил хэ', 10),
#  ('кивнул головой', 10),
#  ('чжао лимина', 9),
#  ('семь часов', 9),
#  ('выпускного отверстия', 9),
#  ('секретарь партбюро', 9),
#  ('очень трудно', 9),
#  ('дэгуй стал', 9),
#  ('партизанском отряде', 9),
#  ('время времени', 9),
#  ('установил новый', 9),
#  ('таких условиях', 9),
#  ('тяжело вздохнул', 9),
#  ('следующий день', 9),
#  ('ночную смену', 9),
#  ('сегодня вечером', 9),
#  ('велосипед поехал', 9),
#  ('продолжать разговор', 9),
#  ('свода печи', 9),
#  ('наварку подины', 9),
#  ('глава двадцать', 9),
#  ('девятый мартен', 8),
#  ('рассмеялся цинь', 8),
#  ('строго сказал', 8),
#  ('дэгуй это', 8),
#  ('поговорить тобой', 8),
#  ('понизил голос', 8),
#  ('смену цинь', 8),
#  ('выходной день', 8),
#  ('обратил внимания', 8),
#  ('тинфа очень', 8),
#  ('друг друга', 8),
#  ('установил рекорд', 8),
#  ('тетушка сунь', 8),
#  ('свободное время', 8),
#  ('женское общежитие', 8),
#  ('серьезным тоном', 8),
#  ('следующей смены', 8),
#  ('никак могу', 8),
#  ('сказал чжан', 8),
#  ('печь ремонт', 8),
#  ('лу цзиньчэн', 8),
#  ('положил трубку', 7),
#  ('мартеновском цехе', 7),
#  ('товарищ цинь', 7),
#  ('тысяч юаней', 7),
#  ('лю кэюй', 7),
#  ('дэгуй очень', 7),
#  ('подошел нему', 7),
#  ('это тебе', 7),
#  ('защитные очки', 7),
#  ('тоном ответил', 7),
#  ('вашем мартене', 7),
#  ('поднял голову', 7),
#  ('дэгуй сел', 7),
#  ('заступать смену', 7),
#  ('тинфа снова', 7),
#  ('мужа дин', 7),
#  ('первого подручного', 7),
#  ('должен знать', 7),
#  ('это сделать', 7),
#  ('часов вечера', 7),
#  ('старина хэ', 7),
#  ('варить сталь', 7),
#  ('спокойно ответил', 7),
#  ('тебе сказал', 7),
#  ('очень хотелось', 7),
#  ('сердито сказал', 7),
#  ('опустив голову', 7),
#  ('принимать смену', 7),
#  ('чжан цзилинь', 7),
#  ('инженер оборудованию', 7),
#  ('линь цзюань', 7),
#  ('заводских ворот', 6),
#  ('подумал лян', 6),
#  ('первого взгляда', 6),
#  ('молодого сталевара', 6),
#  ('опустил голову', 6),
#  ('голову цинь', 6),
#  ('сказал директор', 6),
#  ('ремонту электрооборудования', 6),
#  ('очень странно', 6),
#  ('конце концов', 6),
#  ('помолчал немного', 6),
#  ('время ремонта', 6),
#  ('юйфэнь очень', 6),
#  ('тени деревьев', 6),
#  ('внимательно посмотрела', 6),
#  ('снова спросила', 6),
#  ('холодно ответил', 6),
#  ('десяти часов', 6),
#  ('часов ночи', 6),
#  ('смену чжан', 6),
#  ('сменный журнал', 6),
#  ('это могло', 6),
#  ('товарищ хэ', 6),
#  ('вышел кабинета', 6),
#  ('поехал общежитие', 6),
#  ('велосипед помчался', 6),
#  ('очень обрадовалась', 6),
#  ('газа воздуха', 6),
#  ('выдал скоростную', 6),
#  ('тинфа дин', 6),
#  ('выпуска стали', 6),
#  ('лицо цинь', 6),
#  ('самом деле', 6),
#  ('вечернюю школу', 6),
#  ('это правда', 6),
#  ('железной лестнице', 6),
#  ('ставить ремонт', 6),
#  ('действительно очень', 6),
#  ('свое мнение', 6),
#  ('инженер лу', 6),
#  ('это предложение', 6),
#  ('очень хороший', 6),
#  ('директора завода', 5),
#  ('бросил взгляд', 5),
#  ('улыбнулся ответ', 5),
#  ('мао цзэдуна', 5),
#  ('кабинет директора', 5),
#  ('выпуска металла', 5),
#  ('телефонную трубку', 5),
#  ('тихо сказал', 5),
#  ('громко сказал', 5),
#  ('никакого внимания', 5),
#  ('внимательно посмотрел', 5),
#  ('член партии', 5),
#  ('снова спросил', 5),
#  ('чэнь лянхана', 5),
#  ('коем случае', 5),
#  ('подумал цинь', 5),
#  ('дэгуй знал', 5),
#  ('хотел добавить', 5),
#  ('одну плавку', 5),
#  ('это чжан', 5),
#  ('дэгуй взял', 5),
#  ('рассмеялся чжан', 5),
#  ('жена мастера', 5),
#  ('удивленно спросил', 5),
#  ('дэгуй снова', 5),
#  ('это волнует', 5),
#  ('понизив голос', 5),
#  ('головой цинь', 5),
#  ('увеличить подачу', 5),
#  ('рекорд цинь', 5),
#  ('старый мастер', 5),
#  ('выдать скоростную', 5),
#  ('скоростных плавках', 5),
#  ('плохое настроение', 5),
#  ('спросила сегодня', 5),
#  ('двенадцать часов', 5),
#  ('сократить время', 5),
#  ('очень недоволен', 5),
#  ('пор пока', 5),
#  ('нахмурив брови', 5),
#  ('рабочего дня', 5),
#  ('почесал затылок', 5),
#  ('совета домохозяек', 5),
#  ('свое дело', 5),
#  ('тебе нравится', 5),
#  ('никуда годится', 5),
#  ('фуцюань это', 5),
#  ('дэгуй чжан', 5),
#  ('воскликнула дин', 5),
#  ('несколько минут', 5),
#  ('тинфа установил', 5),
#  ('очень сильно', 5),
#  ('спросила дин', 5),
#  ('вечернюю смену', 5),
#  ('днем ночью', 5),
#  ('снова обратился', 5),
#  ('молодых людей', 5),
#  ('народные добровольцы', 5),
#  ('юйфэнь это', 5),
#  ('дэгуй сразу', 5),
#  ('проронив слова', 5),
#  ('немного помолчал', 5),
#  ('махнул рукой', 5),
#  ('следующее утро', 5),
#  ('сказать тебе', 5),
#  ('свой велосипед', 5),
#  ('сказал старина', 5),
#  ('мартена это', 5),
#  ('занятия вечернюю', 5),
#  ('сказал это', 5),
#  ('душе очень', 5),
#  ('дэгуй решил', 5),
#  ('смену юань', 5),
#  ('легкий ветерок', 5),
#  ('спросила сунь', 5),
#  ('ван юнмин', 5),
#  ('погоне рекордом', 5),
#  ('направился выходу', 5),
#  ('тинфа цинь', 5),
#  ('печи это', 5),
#  ('улыбнулся юань', 5),
#  ('каждое слово', 5),
#  ('дневную смену', 5),
#  ('первой смены', 5),
#  ('читать газеты', 5),
#  ('парткома это', 5),
#  ('черт побрал', 5),
#  ('условия работы', 5),
#  ('цзимин подошел', 5),
#  ('появились ямы', 5),
#  ('аварии девятом', 5),
#  ('завода чжао', 4),
#  ('лучи солнца', 4),
#  ('заводские трубы', 4),
#  ('мартеновского цеха', 4),
#  ('какое время', 4),
#  ('мартен это', 4),
#  ('часов пять', 4),
#  ('сделал это', 4),
#  ('опытный мастер', 4),
#  ('выпуска продукции', 4),
#  ('потерял сознание', 4),
#  ('последние дни', 4),
#  ('снова повернулся', 4),
#  ('сердито бросил', 4),
#  ('цзинчунь взял', 4),
#  ('дэгуя снова', 4),
#  ('задал вопрос', 4),
#  ('обращая внимания', 4),
#  ('подошел цинь', 4),
#  ('новый секретарь', 4),
#  ('предложил хэ', 4),
#  ('секретаря партбюро', 4),
#  ('дэгуй встал', 4),
#  ('трудом сдерживая', 4),
#  ('принять участие', 4),
#  ('нового китая', 4),
#  ('металлургический завод', 4),
#  ('рабочие смены', 4),
#  ('дэгуй мог', 4),
#  ('тинфа молча', 4),
#  ('таких мыслей', 4),
#  ('спросил старина', 4),
#  ('загружал шихту', 4),
#  ('это произошло', 4),
#  ('каком месте', 4),
#  ('установить рекорд', 4),
#  ('такое большое', 4),
#  ('большим интересом', 4),
#  ('тихо ответил', 4),
#  ('слова директора', 4),
#  ('смены девятого', 4),
#  ('дэгуй сегодня', 4),
#  ('улыбкой сказал', 4),
#  ('завода ремонту', 4),
#  ('второй этаж', 4),
#  ('недовольно проворчал', 4),
#  ('ответил цзимин', 4),
#  ('какое дело', 4),
#  ('лицо цзимина', 4),
#  ('третьей смены', 4),
#  ('это имеет', 4),
#  ('заходящего солнца', 4),
#  ('таким тоном', 4),
#  ('девятому мартену', 4),
#  ('тинфа стал', 4),
#  ('первым подручным', 4),
#  ('тихо спросил', 4),
#  ('скажи пожалуйста', 4),
#  ('сердито ответил', 4),
#  ('спокойно спросил', 4),
#  ('спросил хэ', 4),
#  ('сверкнул глазами', 4),
#  ('виноват цинь', 4),
#  ('сдаче смены', 4),
#  ('состоянием свода', 4),
#  ('обеденный перерыв', 4),
#  ('лицо юань', 4),
#  ('сел кан', 4),
#  ('подумала это', 4),
#  ('скоростная плавка', 4),
#  ('девять часов', 4),
#  ('дэгуй сжег', 4),
#  ('покачала головой', 4),
#  ('большим уважением', 4),
#  ('этому делу', 4),
#  ('хотел сказать', 4),
#  ('выходные дни', 4),
#  ('новом рекорде', 4),
#  ('товарищ юань', 4),
#  ('мастер скоростных', 4),
#  ('таким видом', 4),
#  ('видом словно', 4),
#  ('данном случае', 4),
#  ('тинфа продолжал', 4),
#  ('установить новый', 4),
#  ('фуцюань раньше', 4),
#  ('совет домохозяек', 4),
#  ('глубине души', 4),
#  ('фуцюань сегодня', 4),
#  ('это никуда', 4),
#  ('народных добровольцев', 4),
#  ('чжоу кайлинь', 4),
#  ('нам следует', 4),
#  ('своего места', 4),
#  ('кабинета секретаря', 4),
#  ('цзысюе это', 4),
#  ('согласился чжан', 4),
#  ('нашем мартене', 4),
#  ('говорю тебе', 4),
#  ('своего рекорда', 4),
#  ('цзимин стал', 4),
#  ('своей работе', 4),
#  ('производство стали', 4),
#  ('радостно воскликнула', 4),
#  ('мог уснуть', 4),
#  ('мыслей душе', 4),
#  ('набравшись храбрости', 4),
#  ('скоростными плавками', 4),
#  ('своей бригады', 4),
#  ('спросила тебе', 4),
#  ('чуньсю взяла', 4),
#  ('это сказал', 4),
#  ('вечерней школе', 4),
#  ('парткома очень', 4),
#  ('это плохо', 4),
#  ('глубокую затяжку', 4),
#  ('свой опыт', 4),
#  ('очень мало', 4),
#  ('юйфэнь вместе', 4),
#  ('таких случаях', 4),
#  ('ответила сунь', 4),
#  ('сама подумай', 4),
#  ('никак пойму', 4),
#  ('думаю всетаки', 4),
#  ('очень нравится', 4),
#  ('тебе скажу', 4),
#  ('дэгуй сказал', 4),
#  ('заводе очень', 4),
#  ('дело рук', 4),
#  ('другую комнату', 4),
#  ('воскликнул цинь', 4),
#  ('всячески старался', 4),
#  ('юйфэнь время', 4),
#  ('громкий смех', 4),
#  ('голосом сказал', 4),
#  ('сигарету закурил', 4),
#  ('вашего мартена', 4),
#  ('взял трубку', 4),
#  ('вскочил велосипед', 4),
#  ('женского общежития', 4),
#  ('поехал женское', 4),
#  ('время цинь', 4),
#  ('выпуск металла', 4),
#  ('боюсь это', 4),
#  ('листья деревьев', 4),
#  ('слова юань', 4),
#  ('поведение чжан', 4),
#  ('таким путем', 4),
#  ('идти занятия', 4),
#  ('удержалась вопроса', 4),
#  ('очень любил', 4),
#  ('молодой сталевар', 4),
#  ('дэгуй просто', 4),
#  ('пот лица', 4),
#  ('стукнул кулаком', 4),
#  ('кулаком столу', 4),
#  ('это говорит', 4),
#  ('возразил чжан', 4),
#  ('техник чэнь', 4),
#  ('какие это', 4),
#  ('вернуться домой', 4),
#  ('рабочие должны', 4),
#  ('тоном сказал', 4),
#  ('весело сказал', 4),
#  ('директор чжао', 4),
#  ('принимая смену', 4),
#  ('очень тяжело', 4),
#  ('лимин несколько', 4),
#  ('разговора цинь', 4),
#  ('условия соревнования', 4),
#  ('чуньсю очень', 4),
#  ('сказал юань', 4),
#  ('ту ночь', 4),
#  ('помолчал затем', 4),
#  ('сил старался', 4),
#  ('загрузке шихты', 4),
#  ('подумал чжан', 4),
#  ('взял руки', 4),
#  ('беспокойством спросил', 4),
#  ('брат чжан', 4),
#  ('спросил чжан', 4),
#  ('улыбнулся лян', 4),
#  ('это здорово', 4),
#  ('пан мин', 4),
#  ('лян цзинчунем', 4),
#  ('сегодня воскресенье', 4),
#  ('железных дорог', 4),
#  ('день ото', 4),
#  ('ото дня', 4),
#  ('голос цинь', 4),
#  ('спустился вниз', 4),
#  ('друг другу', 4),
#  ('сказала дин', 4),
#  ('хороший человек', 4),
#  ('нему домой', 4),
#  ('очень доволен', 4),
#  ('беспокойством спросила', 4),
#  ('немного помолчав', 4),
#  ('тихо сказала', 4),
#  ('четвертом мартене', 4),
#  ('предложение цинь', 4),
#  ('рационализаторское предложение', 4),
#  ('директор это', 4),
#  ('спускаться вниз', 4),
#  ('советского специалиста', 4),
#  ('отверстие заряда', 4),
#  ('головой чжан', 4),
#  ('стал очень', 4),
#  ('товарищ лян', 4),
#  ('ставить печь', 4),
#  ('выпуск стали', 4),
#  ('это собрание', 4),
#  ('очень тонким', 4),
#  ('пятом мартене', 4),
#  ('ответила сестра', 4),
#  ('дуань юй', 4),
#  ('дом отдыха', 4),
#  ('это одна', 3),
#  ('обратили внимание', 3),
#  ('обращал внимания', 3),
#  ('улыбкой спросил', 3),
#  ('сразу начал', 3),
#  ('снова стал', 3),
#  ('спросил директор', 3),
#  ('это цинь', 3),
#  ('подумал юань', 3),
#  ('выдает скоростные', 3),
#  ('начал объяснять', 3),
#  ('говорит директор', 3),
#  ('особенно тщательно', 3),
#  ('сколько времени', 3),
#  ('поднялся места', 3),
#  ('директор нахмурил', 3),
#  ('сердито спросил', 3),
#  ('цзинчунь снова', 3),
#  ('аййя это', 3),
#  ('молодой рабочий', 3),
#  ('отложил сторону', 3),
#  ('обернулся увидел', 3),
#  ('посмотрел цинь', 3),
#  ('добавил это', 3),
#  ('противном случае', 3),
#  ('улыбкой ответил', 3),
#  ('словно камень', 3),
#  ('цзинчунь подошел', 3),
#  ('парткома завода', 3),
#  ('количество углерода', 3),
#  ('лице цинь', 3),
#  ('цзысюе посмотрел', 3),
#  ('посмотреть идет', 3),
#  ('предложил лян', 3),
#  ('развел руками', 3),
#  ('взглянул часы', 3),
#  ('дэгуй почувствовал', 3),
#  ('вышел цеха', 3),
#  ('своем мартене', 3),
#  ('товарищ командир', 3),
#  ('дэгуй подошел', 3),
#  ('около мартена', 3),
#  ('плавки цинь', 3),
#  ('дэгуй вышел', 3),
#  ('добавить печь', 3),
#  ('могу идти', 3),
#  ('вся жизнь', 3),
#  ('руку цинь', 3),
#  ('около печи', 3),
#  ('невольно покраснел', 3),
#  ('опустил глаза', 3),
#  ('осмотрел свод', 3),
#  ('поспешно подошел', 3),
#  ('свод потечь', 3),
#  ('хочу выяснить', 3),
#  ('выяснить причину', 3),
#  ('слова сказал', 3),
#  ('выражением лица', 3),
#  ('недовольным тоном', 3),
#  ('лицо директора', 3),
#  ('скоростной плавке', 3),
#  ('строгим голосом', 3),
#  ('дэгуя твердо', 3),
#  ('велосипед отправился', 3),
#  ('давали покоя', 3),
#  ('дэгуй установил', 3),
#  ('свободное место', 3),
#  ('дэгуй любил', 3),
#  ('второй смены', 3),
#  ('уткнулся тарелку', 3),
#  ('сколько лет', 3),
#  ('фуцюань решил', 3),
#  ('дело концом', 3),
#  ('поднимая головы', 3),
#  ('обожди немного', 3),
#  ('успел цинь', 3),
#  ('заходящее солнце', 3),
#  ('своим видом', 3),
#  ('тобой поговорить', 3),
#  ('это успели', 3),
#  ('начальником цеха', 3),
#  ('ущерб государству', 3),
#  ('тебе это', 3),
#  ('согласился цинь', 3),
#  ('неужели это', 3),
#  ('лучах заходящего', 3),
#  ('клубы дыма', 3),
#  ('печи поэтому', 3),
#  ('пора идти', 3),
#  ('достал кармана', 3),
#  ('хороший характер', 3),
#  ('словно наяву', 3),
#  ('шихтового двора', 3),
#  ('затем снова', 3),
#  ('поэтому юань', 3),
#  ('стоило увидеть', 3),
#  ('цеха хэ', 3),
#  ('стал внимательно', 3),
#  ('поворачивая головы', 3),
#  ('тинфа это', 3),
#  ('мог понять', 3),
#  ('спросил это', 3),
#  ('ответил мастер', 3),
#  ('тридцать года', 3),
#  ('это вздумал', 3),
#  ('написал объяснение', 3),
#  ('тинфа понимал', 3),
#  ('помогал седьмом', 3),
#  ('рекорд это', 3),
#  ('стал продолжать', 3),
#  ('всем виноват', 3),
#  ('тинфа хотел', 3),
#  ('мог успокоиться', 3),
#  ('время думал', 3),
#  ('свода цинь', 3),
#  ('сегодня душе', 3),
#  ('постучал дверь', 3),
#  ('чуньсю подошла', 3),
#  ('голосом спросила', 3),
#  ('посмотрела лицо', 3),
#  ('скоростной плавки', 3),
#  ('чуньсю села', 3),
#  ('слова жены', 3),
#  ('директор очень', 3),
#  ('день юань', 3),
#  ('мог знать', 3),
#  ('другие рабочие', 3),
#  ('около десяти', 3),
#  ('часов утра', 3),
#  ('близко сердцу', 3),
#  ('тинфа ответил', 3),
#  ('отправился завод', 3),
#  ('рекорде цинь', 3),
#  ('тинфа понял', 3),
#  ('заводского парткома', 3),
#  ('парткома лян', 3),
#  ('почему всетаки', 3),
#  ('высокой температуры', 3),
#  ('продолжал допытываться', 3),
#  ('должен это', 3),
#  ('дэгую очень', 3),
#  ('вырваться вперед', 3),
#  ('очень рад', 3),
#  ('хочу поговорить', 3),
#  ('тинфа чувствовал', 3),
#  ('дэгуй цинь', 3),
#  ('усмехнулся юань', 3),
#  ('это касается', 3),
#  ('мастера скоростных', 3),
#  ('тебе сказать', 3),
#  ('сказать чжан', 3),
#  ('говорит это', 3),
#  ('рассмеялся юань', 3),
#  ('хочу спросить', 3),
#  ('первые подручные', 3),
#  ('цзинчунь глубоко', 3),
#  ('глубоко затянулся', 3),
#  ('сказал товарищ', 3),
#  ('дело это', 3),
#  ('подумал это', 3),
#  ('поспешно ответил', 3),
#  ('цзысюе должен', 3),
#  ('цзинчунь посмотрел', 3),
#  ('подсказал хэ', 3),
#  ('объяснил хэ', 3),
#  ('рабочих лян', 3),
#  ('добровольцев корее', 3),
#  ('произнес хэ', 3),
#  ('торопливо ответил', 3),
#  ('очень любит', 3),
#  ('шесть часов', 3),
#  ('поступил завод', 3),
#  ('фуцюань шел', 3),
#  ('совести говоря', 3),
#  ('увидев чжан', 3),
#  ('тему разговора', 3),
#  ('тинфа сунь', 3),
#  ('тинфа тебе', 3),
#  ('люди которые', 3),
#  ('усмехнулся чжан', 3),
#  ('важное дело', 3),
#  ('воскликнула сунь', 3),
#  ('двоюродной сестры', 3),
#  ('ответила девушка', 3),
#  ('фуцюань подошел', 3),
#  ('стал смотреть', 3),
#  ('оставил велосипед', 3),
#  ('сохранность свода', 3),
#  ('вставай скорее', 3),
#  ('помчался завод', 3),
#  ('какието бумаги', 3),
#  ('иностранными гостями', 3),
#  ('начал успокаивать', 3),
#  ('директор думаю', 3),
#  ('директор взглянул', 3),
#  ('кабинета директора', 3),
#  ('ответил директор', 3),
#  ('чуньсю это', 3),
#  ('именно это', 3),
#  ('этих мыслей', 3),
#  ('выражение лица', 3),
#  ('юйфэнь узнала', 3),
#  ('шерстяное платье', 3),
#  ('пустыми руками', 3),
#  ('немного успокоился', 3),
#  ('следил состоянием', 3),
#  ('напряженная работа', 3),
#  ('это нарочно', 3),
#  ('государственному имуществу', 3),
#  ('снова выдал', 3),
#  ('чуньсю почему', 3),
#  ('почему решила', 3),
#  ('вышла комнаты', 3),
#  ('вышла улицу', 3),
#  ('дэгуй пришел', 3),
#  ('радостно возбужденный', 3),
#  ('решил воспользоваться', 3),
#  ('обычно вместе', 3),
#  ('мера длины', 3),
#  ('длины равная', 3),
#  ('зале ожидания', 3),
#  ('работал заводе', 3),
#  ('нему подошел', 3),
#  ('очень обрадовался', 3),
#  ('веселой улыбкой', 3),
#  ('печь известь', 3),
#  ('очень занят', 3),
#  ('признался цинь', 3),
#  ('думал этим', 3),
#  ('смены цинь', 3),
#  ('дэгуй понял', 3),
#  ('это значит', 3),
#  ('твоей смены', 3),
#  ('сделал глубокую', 3),
#  ('другие мартены', 3),
#  ('удержался улыбки', 3),
#  ('почему раньше', 3),
#  ('глаза цинь', 3),
#  ('заботливо спросил', 3),
#  ('ответ цинь', 3),
#  ('снова обернулся', 3),
#  ('этих словах', 3),
#  ('цзинчунь взглянул', 3),
#  ('сунь дафа', 3),
#  ('вышел дома', 3),
#  ('целыми днями', 3),
#  ('четыре года', 3),
#  ('партизанский отряд', 3),
#  ('чжан дачунь', 3),
#  ('должна идти', 3),
#  ('продолжал стоять', 3),
#  ('стал говорить', 3),
#  ('ночной смене', 3),
#  ('тому назад', 3),
#  ('ходить кино', 3),
#  ('кино это', 3),
#  ('внимания слова', 3),
#  ('тебе почему', 3),
#  ('разговор другую', 3),
#  ('другую тему', 3),
#  ('удивилась сунь', 3),
#  ('юйфэнь поэтому', 3),
#  ('возразил цинь', 3),
#  ('предложил цинь', 3),
#  ('голосом спросил', 3),
#  ('снова закрыл', 3),
#  ('очень устал', 3),
#  ('мать сказала', 3),
#  ('эта девушка', 3),
#  ('лошадь запрягла', 3),
#  ('мог забыть', 3),
#  ('поставила кан', 3),
#  ('улыбнулся цинь', 3),
#  ('дэгуй ответил', 3),
#  ('стоял своем', 3),
#  ('дэгуй молча', 3),
#  ('нашего мартена', 3),
#  ('рукой сняло', 3),
#  ('узнать всетаки', 3),
#  ('юйфэнь цинь', 3),
#  ('стал работать', 3),
#  ('часа дня', 3),
#  ('тебе коечто', 3),
#  ('сказал очень', 3),
#  ('головой хэ', 3),
#  ('сердце цинь', 3),
#  ('безразличным тоном', 3),
#  ('слова хэ', 3),
#  ('цзысюе спросил', 3),
#  ('бригадами вашего', 3),
#  ('сокрушенно покачал', 3),
#  ('довольно долго', 3),
#  ('своего мартена', 3),
#  ('обязательно поговорю', 3),
#  ('ко всему', 3),
#  ('позвали телефону', 3),
#  ('дэгуй ладно', 3),
#  ('крикнул цинь', 3),
#  ('повесил трубку', 3),
#  ('ума сошел', 3),
#  ('пот лба', 3),
#  ('вошел вестибюль', 3),
#  ('общежития цинь', 3),
#  ('дежурная цинь', 3),
#  ('дэгуй вспомнил', 3),
#  ('дэгуй поехал', 3),
#  ('пятнадцати минут', 3),
#  ('сторону цинь', 3),
#  ('отношения чжан', 3),
#  ('восьми часов', 3),
#  ('сказал несколько', 3),
#  ('посмотрел лицо', 3),
#  ('жену юань', 3),
#  ('масла огонь', 3),
#  ('вышел улицу', 3),
#  ('вчера вечером', 3),
#  ('принял смену', 3),
#  ('пода печи', 3),
#  ('смена чжан', 3),
#  ('подготовку пода', 3),
#  ('будем соревноваться', 3),
#  ('соревнование рабочими', 3),
#  ('тинфа время', 3),
#  ('просто хочет', 3),
#  ('относится нему', 3),
#  ('принимать вызов', 3),
#  ('приказал рабочим', 3),
#  ('вытирая полотенцем', 3),
#  ('полотенцем пот', 3),
#  ('четырех часов', 3),
#  ('моей смены', 3),
#  ('фуцюань ушел', 3),
#  ('дэгуя очень', 3),
#  ('тебе хочется', 3),
#  ('фуцюань тебе', 3),
#  ('прошу скажи', 3),
#  ('езде велосипеде', 3),
#  ('тоном спросил', 3),
#  ('день утром', 3),
#  ('громко крикнул', 3),
#  ('говори прямо', 3),
#  ('ходом плавки', 3),
#  ('дальше продолжаться', 3),
#  ('разобраться деле', 3),
#  ('часов пятьдесят', 3),
#  ('первым делом', 3),
#  ('спросил мастер', 3),
#  ('удалось быстро', 3),
#  ('высокая температура', 3),
#  ('душе чжан', 3),
#  ('плавка длилась', 3),
#  ('разрушения свода', 3),
#  ('сменном журнале', 3),
#  ('вместе мной', 3),
#  ('усмехнулся хэ', 3),
#  ('имел виду', 3),
#  ('следы разрушения', 3),
#  ('тинфа человек', 3),
#  ('семи часов', 3),
#  ('видел цинь', 3),
#  ('осматривал свод', 3),
#  ('инженеры техники', 3),
#  ('почему цинь', 3),
#  ('своей страны', 3),
#  ('цзысюе поспешно', 3),
#  ('произнес юань', 3),
#  ('плохом настроении', 3),
#  ('обвалился свод', 3),
#  ('думаешь почему', 3),
#  ('думал цинь', 3),
#  ('могу понять', 3),
#  ('это должно', 3),
#  ('инженер чжан', 3),
#  ('руководство завода', 3),
#  ('твердо ответил', 3),
#  ('своих личных', 3),
#  ('зайти нему', 3),
#  ('возбужденно сказал', 3),
#  ('дэгуй должен', 3),
#  ('должны выяснить', 3),
#  ('юйфэнь вышла', 3),
#  ('мужское общежитие', 3),
#  ('скрепя сердце', 3),
#  ('очень обрадовались', 3),
#  ('стояла своем', 3),
#  ('своем дин', 3),
#  ('юйфэнь вовсе', 3),
#  ('это случилось', 3),
#  ('неловкое молчание', 3),
#  ('юйфэнь сразу', 3),
#  ('сразу заводит', 3),
#  ('лян шаньбо', 3),
#  ('нынешние девушки', 3),
#  ('трещали цикады', 3),
#  ('баскетбольной площадке', 3),
#  ('чжан фуцюане', 3),
#  ('дэгуй считал', 3),
#  ('лицо сунь', 3),
#  ('цзысюе верит', 3),
#  ('это клевета', 3),
#  ('сказать это', 3),
#  ('должен понять', 3),
#  ('очень высокая', 3),
#  ('мог стать', 3),
#  ('директор уехал', 3),
#  ('цзысюе рассказал', 3),
#  ('свое согласие', 3),
#  ('подошел поближе', 3),
#  ('очень удобно', 3),
#  ('производственным отделом', 3),
#  ('мастера юаня', 3),
#  ('такого человека', 3),
#  ('пока это', 3),
#  ('общежитие чжан', 3),
#  ('улыбнулся хэ', 3),
#  ('улыбнулся чжан', 3),
#  ('фуцюань кажется', 3),
#  ('говорил тебе', 3),
#  ('должен поговорить', 3),
#  ('ветерок приятно', 3),
#  ('приятно освежал', 3),
#  ('стало известно', 3),
#  ('наш новый', 3),
#  ('очень люблю', 3),
#  ('потвоему выходит', 3),
#  ('заводские дела', 3),
#  ('обобщить опыт', 3),
#  ('развернуть соревнование', 3),
#  ('согласился лян', 3),
#  ('лимин встал', 3),
#  ('обернулся лян', 3),
#  ('критике самокритике', 3),
#  ('молча курил', 3),
#  ('тихо спросила', 3),
#  ('это принести', 3),
#  ('свой кабинет', 3),
#  ('своем кабинете', 3),
#  ('директора лян', 3),
#  ('многие рабочие', 3),
#  ('голову ответил', 3),
#  ('других рабочих', 3),
#  ('цзинчунь спросил', 3),
#  ('своего бригадира', 3),
#  ('очень плохое', 3),
#  ('цзинчунь хэ', 3),
#  ('любое время', 3),
#  ('новых железных', 3),
#  ('своей смены', 3),
#  ('цзинчунь немного', 3),
#  ('парткома немного', 3),
#  ('ваши отношения', 3),
#  ('всей стране', 3),
#  ('подины доломитом', 3),
#  ('директор распорядился', 3),
#  ('очень внимательно', 3),
#  ('прежде должны', 3),
#  ('отличник производства', 3),
#  ('хотел поговорить', 3),
#  ('цзысюе юань', 3),
#  ('тинфа лицо', 3),
#  ('примирительно сказал', 3),
#  ('стал вытирать', 3),
#  ('сегодня выдал', 3),
#  ('тоном сказала', 3),
#  ('почему сих', 3),
#  ('металлургических заводов', 3),
#  ('опытных сталеваров', 3),
#  ('рассердилась дин', 3),
#  ('холодно спросил', 3),
#  ('достал сигарету', 3),
#  ('цзысюе дин', 3),
#  ('изо рта', 3),
#  ('будем проводить', 3),
#  ('моей работе', 3),
#  ('отсталый элемент', 3),
#  ('тебе следует', 3),
#  ('отличником производства', 3),
#  ('подины четвертого', 3),
#  ('спросил чжао', 3),
#  ('увеличить выпуск', 3),
#  ('сказал чжао', 3),
#  ('это почему', 3),
#  ('дэгуя секретарь', 3),
#  ('советский специалист', 3),
#  ('третьего мартена', 3),
#  ('цзинчунь стал', 3),
#  ('кружилась голова', 3),
#  ('лица пот', 3),
#  ('ждать пока', 3),
#  ('стало легко', 3),
#  ('портрет цинь', 3),
#  ('одна девушек', 3),
#  ('кивнула головой', 3),
#  ('начал оправдываться', 3),
#  ('работы следующей', 3),
#  ('думал дороге', 3),
#  ('хотя душе', 3),
#  ...]
